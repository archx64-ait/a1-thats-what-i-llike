# %% [markdown]
# ## Set torch.device to CUDA

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available. Using GPU.")
else:
    device = torch.device("cpu")
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. Using GPU.

# %% [markdown]
# ## Download NLTK

# %%
import nltk
import os
CUSTOM_DIR = './nltk_data/'

nltk.data.path.append(CUSTOM_DIR)

resources = [
    ('reuters.zip', os.path.join(CUSTOM_DIR, 'corpora', 'reuters')),
    ('punkt.zip', os.path.join(CUSTOM_DIR, 'tokenizers', 'punkt')),
    ('punkt_tab.zip', os.path.join(CUSTOM_DIR, 'tokenizers', 'punkt_tab')),
    ('stopwords.zip', os.path.join(CUSTOM_DIR, 'corpora', 'stopwords')),
]

for resource, path in resources:
    try:
        nltk.data.find(resource)
    except LookupError:
        if not os.path.exists(path):
            nltk.download(resource.split('.')[0], download_dir=CUSTOM_DIR)
# Out:
# [nltk_data] Downloading package reuters to ./nltk_data/...
# [nltk_data]   Package reuters is already up-to-date!

# %%
from nltk.corpus import reuters

category = "trade"
category_fileids = reuters.fileids(category)
category_docs = [reuters.raw(fileids) for fileids in category_fileids]

print(f"# of documents in category '{category}': {len(category_docs)}")
print(f"1st document:\n{category_docs[0][:500]}")
# Out:
# # of documents in category 'trade': 485
# 1st document:
# ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT
#   Mounting trade friction between the
#   U.S. And Japan has raised fears among many of Asia's exporting
#   nations that the row could inflict far-reaching economic
#   damage, businessmen and officials said.
#       They told Reuter correspondents in Asian capitals a U.S.
#   Move against Japan might boost protectionist sentiment in the
#   U.S. And lead to curbs on American imports of their products.
#       But some exporters said that while the conflict wo

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words and word not in string.punctuation]
    return tokens

# %%
preprocessed_docs = [preprocess_text(doc) for doc in category_docs]
preprocessed_docs
# Out:
# [['asian',
#   'exporters',
#   'fear',
#   'damage',
#   'u.s.-japan',
#   'rift',
#   'mounting',
#   'trade',
#   'friction',
#   'u.s.',
#   'japan',
#   'raised',
#   'fears',
#   'among',
#   'many',
#   'asia',
#   "'s",
#   'exporting',
#   'nations',
#   'row',
#   'could',
#   'inflict',
#   'far-reaching',
#   'economic',
#   'damage',
#   'businessmen',
#   'officials',
#   'said',
#   'told',
#   'reuter',
#   'correspondents',
#   'asian',
#   'capitals',
#   'u.s.',
#   'move',
#   'japan',
#   'might',
#   'boost',
#   'protectionist',
#   'sentiment',
#   'u.s.',
#   'lead',
#   'curbs',
#   'american',
#   'imports',
#   'products',
#   'exporters',
#   'said',
#   'conflict',
#   'would',
#   'hurt',
#   'long-run',
#   'short-term',
#   'tokyo',
#   "'s",
#   'loss',
#   'might',
#   'gain',
#   'u.s.',
#   'said',
#   'impose',
#   '300',
#   'mln',
#   'dlrs',
#   'tariffs',
#   'imports',
#   'japanese',
#   'electronics',
#   'goods',
#   'april',
#   '17',
#   'retaliation',
#   'japan',
#   "'s",
#   'alleged',
#   'failure',
#   'stick',
#   'pact',
#   'sell',
#   'semiconductors',
#   'world',
#   'markets',
#   'cost',
#   'unofficial',
#   'japanese',
#   'estimates',
#   'put',
#   'impact',
#   'tariffs',
#   '10',
#   'billion',
#   'dlrs',
#   'spokesmen',
#   'major',
#   'electronics',
#   'firms',
#   'said',
#   'would',
#   'virtually',
#   'halt',
#   'exports',
#   'products',
#   'hit',
#   'new',
#   'taxes',
#   '``',
#   'would',
#   "n't",
#   'able',
#   'business',
#   "''",
#   'said',
#   'spokesman',
#   'leading',
#   'japanese',
#   'electronics',
#   'firm',
#   'matsushita',
#   'electric',
#   'industrial',
#   'co',
#   'ltd',
#   'lt',
#   'mc.t',
#   '``',
#   'tariffs',
#   'remain',
#   'place',
#   'length',
#   'time',
#   'beyond',
#   'months',
#   'mean',
#   'complete',
#   'erosion',
#   'exports',
#   'goods',
#   'subject',
#   'tariffs',
#   'u.s.',
#   "''",
#   'said',
#   'tom',
#   'murtha',
#   'stock',
#   'analyst',
#   'tokyo',
#   'office',
#   'broker',
#   'lt',
#   'james',
#   'capel',
#   'co',
#   'taiwan',
#   'businessmen',
#   'officials',
#   'also',
#   'worried',
#   '``',
#   'aware',
#   'seriousness',
#   'u.s.',
#   'threat',
#   'japan',
#   'serves',
#   'warning',
#   'us',
#   "''",
#   'said',
#   'senior',
#   'taiwanese',
#   'trade',
#   'official',
#   'asked',
#   'named',
#   'taiwan',
#   'trade',
#   'trade',
#   'surplus',
#   '15.6',
#   'billion',
#   'dlrs',
#   'last',
#   'year',
#   '95',
#   'pct',
#   'u.s.',
#   'surplus',
#   'helped',
#   'swell',
#   'taiwan',
#   "'s",
#   'foreign',
#   'exchange',
#   'reserves',
#   '53',
#   'billion',
#   'dlrs',
#   'among',
#   'world',
#   "'s",
#   'largest',
#   '``',
#   'must',
#   'quickly',
#   'open',
#   'markets',
#   'remove',
#   'trade',
#   'barriers',
#   'cut',
#   'import',
#   'tariffs',
#   'allow',
#   'imports',
#   'u.s.',
#   'products',
#   'want',
#   'defuse',
#   'problems',
#   'possible',
#   'u.s.',
#   'retaliation',
#   "''",
#   'said',
#   'paul',
#   'sheen',
#   'chairman',
#   'textile',
#   'exporters',
#   'lt',
#   'taiwan',
#   'safe',
#   'group',
#   'senior',
#   'official',
#   'south',
#   'korea',
#   "'s",
#   'trade',
#   'promotion',
#   'association',
#   'said',
#   'trade',
#   'dispute',
#   'u.s.',
#   'japan',
#   'might',
#   'also',
#   'lead',
#   'pressure',
#   'south',
#   'korea',
#   'whose',
#   'chief',
#   'exports',
#   'similar',
#   'japan',
#   'last',
#   'year',
#   'south',
#   'korea',
#   'trade',
#   'surplus',
#   '7.1',
#   'billion',
#   'dlrs',
#   'u.s.',
#   '4.9',
#   'billion',
#   'dlrs',
#   '1985.',
#   'malaysia',
#   'trade',
#   'officers',
#   'businessmen',
#   'said',
#   'tough',
#   'curbs',
#   'japan',
#   'might',
#   'allow',
#   'hard-hit',
#   'producers',
#   'semiconductors',
#   'third',
#   'countries',
#   'expand',
#   'sales',
#   'u.s.',
#   'hong',
#   'kong',
#   'newspapers',
#   'alleged',
#   'japan',
#   'selling',
#   'below-cost',
#   'semiconductors',
#   'electronics',
#   'manufacturers',
#   'share',
#   'view',
#   'businessmen',
#   'said',
#   'short-term',
#   'commercial',
#   'advantage',
#   'would',
#   'outweighed',
#   'u.s.',
#   'pressure',
#   'block',
#   'imports',
#   '``',
#   'short-term',
#   'view',
#   "''",
#   'said',
#   'lawrence',
#   'mills',
#   'director-general',
#   'federation',
#   'hong',
#   'kong',
#   'industry',
#   '``',
#   'whole',
#   'purpose',
#   'prevent',
#   'imports',
#   'one',
#   'day',
#   'extended',
#   'sources',
#   'much',
#   'serious',
#   'hong',
#   'kong',
#   'disadvantage',
#   'action',
#   'restraining',
#   'trade',
#   "''",
#   'said',
#   'u.s.',
#   'last',
#   'year',
#   'hong',
#   'kong',
#   "'s",
#   'biggest',
#   'export',
#   'market',
#   'accounting',
#   '30',
#   'pct',
#   'domestically',
#   'produced',
#   'exports',
#   'australian',
#   'government',
#   'awaiting',
#   'outcome',
#   'trade',
#   'talks',
#   'u.s.',
#   'japan',
#   'interest',
#   'concern',
#   'industry',
#   'minister',
#   'john',
#   'button',
#   'said',
#   'canberra',
#   'last',
#   'friday',
#   '``',
#   'kind',
#   'deterioration',
#   'trade',
#   'relations',
#   'two',
#   'countries',
#   'major',
#   'trading',
#   'partners',
#   'serious',
#   'matter',
#   "''",
#   'button',
#   'said',
#   'said',
#   'australia',
#   "'s",
#   'concerns',
#   'centred',
#   'coal',
#   'beef',
#   'australia',
#   "'s",
#   'two',
#   'largest',
#   'exports',
#   'japan',
#   'also',
#   'significant',
#   'u.s.',
#   'exports',
#   'country',
#   'meanwhile',
#   'u.s.-japanese',
#   'diplomatic',
#   'manoeuvres',
#   'solve',
#   'trade',
#   'stand-off',
#   'continue',
#   'japan',
#   "'s",
#   'ruling',
#   'liberal',
#   'democratic',
#   'party',
#   'yesterday',
#   'outlined',
#   'package',
#   'economic',
#   'measures',
#   'boost',
#   'japanese',
#   'economy',
#   'measures',
#   'proposed',
#   'include',
#   'large',
#   'supplementary',
#   'budget',
#   'record',
#   'public',
#   'works',
#   'spending',
#   'first',
#   'half',
#   'financial',
#   'year',
#   'also',
#   'call',
#   'stepped-up',
#   'spending',
#   'emergency',
#   'measure',
#   'stimulate',
#   'economy',
#   'despite',
#   'prime',
#   'minister',
#   'yasuhiro',
#   'nakasone',
#   "'s",
#   'avowed',
#   'fiscal',
#   'reform',
#   'program',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'makoto',
#   'kuroda',
#   'japan',
#   "'s",
#   'deputy',
#   'minister',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'due',
#   'meet',
#   'washington',
#   'week',
#   'effort',
#   'end',
#   'dispute'],
#  ['thai',
#   'trade',
#   'deficit',
#   'widens',
#   'first',
#   'quarter',
#   'thailand',
#   "'s",
#   'trade',
#   'deficit',
#   'widened',
#   '4.5',
#   'billion',
#   'baht',
#   'first',
#   'quarter',
#   '1987',
#   '2.1',
#   'billion',
#   'year',
#   'ago',
#   'business',
#   'economics',
#   'department',
#   'said',
#   'said',
#   'janunary/march',
#   'imports',
#   'rose',
#   '65.1',
#   'billion',
#   'baht',
#   '58.7',
#   'billion',
#   'thailand',
#   "'s",
#   'improved',
#   'business',
#   'climate',
#   'year',
#   'resulted',
#   '27',
#   'pct',
#   'increase',
#   'imports',
#   'raw',
#   'materials',
#   'semi-finished',
#   'products',
#   'country',
#   "'s",
#   'oil',
#   'import',
#   'bill',
#   'however',
#   'fell',
#   '23',
#   'pct',
#   'first',
#   'quarter',
#   'due',
#   'lower',
#   'oil',
#   'prices',
#   'department',
#   'said',
#   'first',
#   'quarter',
#   'exports',
#   'expanded',
#   '60.6',
#   'billion',
#   'baht',
#   '56.6',
#   'billion',
#   'export',
#   'growth',
#   'smaller',
#   'expected',
#   'due',
#   'lower',
#   'earnings',
#   'many',
#   'key',
#   'commodities',
#   'including',
#   'rice',
#   'whose',
#   'earnings',
#   'declined',
#   '18',
#   'pct',
#   'maize',
#   '66',
#   'pct',
#   'sugar',
#   '45',
#   'pct',
#   'tin',
#   '26',
#   'pct',
#   'canned',
#   'pineapples',
#   'seven',
#   'pct',
#   'products',
#   'registering',
#   'high',
#   'export',
#   'growth',
#   'jewellery',
#   '64',
#   'pct',
#   'clothing',
#   '57',
#   'pct',
#   'rubber',
#   '35',
#   'pct'],
#  ['japan',
#   'ministry',
#   'says',
#   'open',
#   'farm',
#   'trade',
#   'would',
#   'hit',
#   'u.s.',
#   'japan',
#   "'s",
#   'agriculture',
#   'ministry',
#   'angered',
#   'u.s.',
#   'demands',
#   'japan',
#   'open',
#   'farm',
#   'products',
#   'market',
#   'tell',
#   'u.s.',
#   'officials',
#   'talks',
#   'later',
#   'month',
#   'liberalisation',
#   'would',
#   'harm',
#   'existing',
#   'u.s.',
#   'farm',
#   'exports',
#   'japan',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   '``',
#   'imports',
#   'u.s.',
#   'would',
#   'drop',
#   'due',
#   'active',
#   'sales',
#   'drives',
#   'suppliers',
#   "''",
#   'official',
#   'declined',
#   'named',
#   'said',
#   '``',
#   'japan',
#   'largest',
#   'customer',
#   'u.s.',
#   'farm',
#   'products',
#   'reasonable',
#   'u.s.',
#   'demand',
#   'japan',
#   'liberalise',
#   'farm',
#   'import',
#   'market',
#   "''",
#   'said',
#   'agriculture',
#   'minister',
#   'mutsuki',
#   'kato',
#   'said',
#   'u.s.',
#   'insists',
#   'japan',
#   'open',
#   'protected',
#   'rice',
#   'market',
#   'also',
#   'open',
#   'wheat',
#   'market',
#   'volume',
#   'origin',
#   'regulated',
#   'protect',
#   'local',
#   'farmers',
#   'australia',
#   'canada',
#   'could',
#   'increase',
#   'wheat',
#   'exports',
#   'competitive',
#   'u.s.',
#   'said',
#   'end-users',
#   'would',
#   'also',
#   'buy',
#   'origins',
#   'grain',
#   'traders',
#   'said',
#   'u.s.',
#   'agriculture',
#   'secretary',
#   'richard',
#   'lyng',
#   'due',
#   'visit',
#   'japan',
#   'talks',
#   'april',
#   '16-27',
#   'said',
#   'ask',
#   'japan',
#   'offer',
#   'share',
#   'rice',
#   'market',
#   'u.s.',
#   'suppliers',
#   'remove',
#   'quotas',
#   'u.s.',
#   'beef',
#   'citrus',
#   'imports',
#   'countries',
#   'already',
#   'cutting',
#   'u.s.',
#   'market',
#   'share',
#   'australia',
#   'largest',
#   'beef',
#   'supplier',
#   'japan',
#   'trying',
#   'boost',
#   'exports',
#   'prior',
#   'expiry',
#   'four-year',
#   'beef',
#   'accord',
#   'next',
#   'march',
#   '31.',
#   'imports',
#   'u.s.',
#   'corn',
#   'fallen',
#   'due',
#   'increased',
#   'sales',
#   'china',
#   'south',
#   'america',
#   'japanese',
#   'soybean',
#   'imports',
#   'brazil',
#   'expected',
#   'rise',
#   'sharply',
#   'year',
#   'although',
#   'u.s.',
#   'remain',
#   'largest',
#   'supplier',
#   'u.s.',
#   'feedgrain',
#   'sales',
#   'also',
#   'drop',
#   'japan',
#   'opens',
#   'beef',
#   'imports',
#   'since',
#   'japan',
#   'depends',
#   'almost',
#   'entirely',
#   'feedgrain',
#   'imports',
#   'mainly',
#   'u.s.',
#   'japanese',
#   'officials',
#   'said',
#   'indication',
#   'u.s.',
#   'position',
#   'came',
#   'last',
#   'december',
#   'secretary',
#   'agriculture',
#   'daniel',
#   'amstutz',
#   'said',
#   'japan',
#   'potential',
#   'provide',
#   'one',
#   'largest',
#   'boosts',
#   'u.s.',
#   'agricultural',
#   'exports',
#   'beef',
#   'market',
#   'alone',
#   'representing',
#   'one',
#   'billion',
#   'dlrs',
#   'new',
#   'business',
#   'u.s.',
#   'also',
#   'asked',
#   'general',
#   'agreement',
#   'tariffs',
#   'trade',
#   'investigate',
#   'legality',
#   'japanese',
#   'import',
#   'controls',
#   '12',
#   'farm',
#   'products',
#   'including',
#   'fruit',
#   'juices',
#   'purees',
#   'pulp',
#   'tomato',
#   'juice',
#   'ketchup',
#   'sauce',
#   'peanuts',
#   'prepared',
#   'beef',
#   'products',
#   'miscellaneous',
#   'beans',
#   'help',
#   'calm',
#   'heated',
#   'trade',
#   'relations',
#   'u.s.',
#   'japan',
#   "'s",
#   'top',
#   'business',
#   'group',
#   'keidanren',
#   'urged',
#   'government',
#   'remove',
#   'residual',
#   'import',
#   'restrictions',
#   'agricultural',
#   'products',
#   'agriculture',
#   'minister',
#   'kato',
#   'ruled',
#   'emotional',
#   'reaction',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   'farm',
#   'issue',
#   'become',
#   'scapegoat',
#   'trade',
#   'pressure',
#   'industrial',
#   'sector',
#   '``',
#   'japan',
#   'largest',
#   'buyer',
#   'u.s.',
#   'farm',
#   'products',
#   'issues',
#   'discussed',
#   'table',
#   "''",
#   'official',
#   'said'],
#  ['south',
#   'korea',
#   'moves',
#   'slow',
#   'growth',
#   'trade',
#   'surplus',
#   'south',
#   'korea',
#   "'s",
#   'trade',
#   'surplus',
#   'growing',
#   'fast',
#   'government',
#   'started',
#   'taking',
#   'steps',
#   'slow',
#   'deputy',
#   'prime',
#   'minister',
#   'kim',
#   'mahn-je',
#   'said',
#   'told',
#   'press',
#   'conference',
#   'government',
#   'planned',
#   'increase',
#   'investment',
#   'speed',
#   'opening',
#   'local',
#   'market',
#   'foreign',
#   'imports',
#   'gradually',
#   'adjust',
#   'currency',
#   'hold',
#   'surplus',
#   '``',
#   'proper',
#   'level',
#   "''",
#   'said',
#   'government',
#   'would',
#   'allow',
#   'appreciate',
#   'much',
#   'short',
#   'period',
#   'time',
#   'south',
#   'korea',
#   'pressure',
#   'washington',
#   'revalue',
#   'u.s.',
#   'wants',
#   'south',
#   'korea',
#   'cut',
#   'trade',
#   'surplus',
#   'u.s.',
#   'rose',
#   '7.4',
#   'billion',
#   'dlrs',
#   '1986',
#   '4.3',
#   'billion',
#   'dlrs',
#   '1985.',
#   'kim',
#   'also',
#   'economic',
#   'planning',
#   'minister',
#   'said',
#   'prospects',
#   'bright',
#   'south',
#   'korean',
#   'economy',
#   'government',
#   'would',
#   'try',
#   'hold',
#   'current',
#   'account',
#   'surplus',
#   'around',
#   'five',
#   'billion',
#   'dlrs',
#   'year',
#   'next',
#   'five',
#   'years',
#   '``',
#   'government',
#   'projections',
#   'eight',
#   'pct',
#   'gnp',
#   'growth',
#   'five',
#   'billion',
#   'dlrs',
#   'current',
#   'account',
#   'surplus',
#   '12',
#   'pct',
#   'growth',
#   'exports',
#   'seemed',
#   'reasonable',
#   'early',
#   'year',
#   'surplus',
#   'growing',
#   'faster',
#   'expected',
#   "''",
#   'said',
#   'trade',
#   'ministry',
#   'officials',
#   'said',
#   'south',
#   'korea',
#   "'s",
#   'exports',
#   'rose',
#   '35',
#   'pct',
#   '9.34',
#   'billion',
#   'dlrs',
#   'first',
#   'three',
#   'months',
#   'year',
#   'imports',
#   'rose',
#   '8.5',
#   'pct',
#   '8.2',
#   'billion',
#   'dlrs',
#   'kim',
#   'said',
#   'swing',
#   'south',
#   'korea',
#   "'s",
#   'current',
#   'account',
#   'surplus',
#   '4.65',
#   'billion',
#   'dlrs',
#   '1986',
#   '890',
#   'mln',
#   'dlr',
#   'deficit',
#   '1985',
#   'significant',
#   'surplus',
#   'enabled',
#   'country',
#   'reduce',
#   'foreign',
#   'debt',
#   'last',
#   'year',
#   'first',
#   'time',
#   'south',
#   'korea',
#   "'s",
#   'foreign',
#   'debt',
#   'fell',
#   '44.5',
#   'billion',
#   'dlrs',
#   '1986',
#   '46.8',
#   'billion',
#   '1985',
#   'still',
#   'among',
#   'largest',
#   'asia',
#   '``',
#   'huge',
#   'amount',
#   'foreign',
#   'debt',
#   'one',
#   'major',
#   'constraints',
#   'development',
#   '...',
#   'last',
#   'year',
#   'major',
#   'turning',
#   'point',
#   'korean',
#   'economy',
#   "''",
#   'kim',
#   'said',
#   'kim',
#   'said',
#   'government',
#   'plannned',
#   'reduce',
#   'ratio',
#   'foreign',
#   'debt',
#   'country',
#   "'s",
#   'gnp',
#   '20',
#   'pct',
#   '1991',
#   '50',
#   'pct',
#   '1986',
#   '``',
#   'government',
#   'however',
#   'want',
#   'accelerate',
#   'reducing',
#   'debt',
#   'making',
#   'excessive',
#   'trade',
#   'surplus',
#   "''",
#   'said',
#   'kim',
#   'said',
#   'sudden',
#   'rise',
#   'surplus',
#   'would',
#   'cause',
#   'inflation',
#   'lead',
#   'trade',
#   'friction',
#   'seoul',
#   "'s",
#   'major',
#   'trading',
#   'partners',
#   'particularly',
#   'united',
#   'states',
#   '``',
#   'need',
#   'surplus',
#   'reduce',
#   'debt',
#   'taking',
#   'measures',
#   'hold',
#   'size',
#   'surplus',
#   'proper',
#   'level',
#   "''",
#   'kim',
#   'said'],
#  ['japan',
#   'given',
#   'little',
#   'hope',
#   'avoiding',
#   'u.s.',
#   'sanctions',
#   'top',
#   'u.s.',
#   'official',
#   'said',
#   'japan',
#   'little',
#   'chance',
#   'convincing',
#   'u.s.',
#   'drop',
#   'threatened',
#   'trade',
#   'sanctions',
#   'despite',
#   'efforts',
#   'japanese',
#   'team',
#   'left',
#   'washington',
#   'today',
#   'michael',
#   'armacost',
#   'secretary',
#   'state',
#   'political',
#   'affairs',
#   'asked',
#   'press',
#   'conference',
#   'whether',
#   'japan',
#   "'s",
#   'moves',
#   'boost',
#   'domestic',
#   'economy',
#   'open',
#   'markets',
#   'could',
#   'persuade',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'japanese',
#   'imports',
#   'said',
#   'replied',
#   '``',
#   '...',
#   'probably',
#   'early',
#   'figures',
#   'demonstrate',
#   'situation',
#   'turned',
#   'around',
#   'permit',
#   'result',
#   'described',
#   "''",
#   'armacost',
#   'said',
#   'u.s.',
#   'hopes',
#   'japan',
#   'take',
#   'steps',
#   'lift',
#   'domestic',
#   'economy',
#   'reduce',
#   'dependence',
#   'exports',
#   'remove',
#   'barriers',
#   'imports',
#   'settle',
#   'outstanding',
#   'trade',
#   'issues',
#   '``',
#   'obvious',
#   'problems',
#   'moment',
#   'trade',
#   'area',
#   'wish',
#   'problems',
#   'divert',
#   'attention',
#   'important',
#   'areas',
#   'cooperation',
#   'continue',
#   'exist',
#   'security',
#   'political',
#   'issues',
#   "''",
#   'said',
#   '``',
#   'question',
#   'whether',
#   'cooperative',
#   'actions',
#   'governments',
#   'reduce',
#   'trade',
#   'imbalance',
#   'whether',
#   'congress',
#   'takes',
#   'action',
#   'reduce',
#   'protectionist',
#   'legislation',
#   "''",
#   'said'],
#  ['japanese',
#   'official',
#   'takes',
#   'data',
#   'microchip',
#   'talks',
#   'ministry',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'vice',
#   'minister',
#   'makoto',
#   'kuroda',
#   'leaves',
#   'washington',
#   'today',
#   'data',
#   'hopes',
#   'refute',
#   'u.s.',
#   'charges',
#   'japan',
#   'violated',
#   'pact',
#   'microchip',
#   'trade',
#   'three-man',
#   'japanese',
#   'trade',
#   'team',
#   'already',
#   'washington',
#   'laying',
#   'groundwork',
#   'talks',
#   'kuroda',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'aimed',
#   'persuading',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'certain',
#   'japanese',
#   'products',
#   'kuroda',
#   'said',
#   'taking',
#   'new',
#   'proposals',
#   '``',
#   'nothing',
#   'briefcase',
#   'except',
#   'explanation',
#   'current',
#   'situation',
#   "''",
#   'kuroda',
#   'told',
#   'daily',
#   'newspaper',
#   'asahi',
#   'shimbun',
#   'kuroda',
#   'said',
#   'u.s.',
#   'decision',
#   'based',
#   'incorrect',
#   'data',
#   'exaggerated',
#   'sense',
#   'miti',
#   "'s",
#   'power',
#   'control',
#   'market',
#   'forces',
#   '``',
#   'u.s.',
#   'excessive',
#   'expectations',
#   'stabilise',
#   'supply-demand',
#   'relations',
#   'disrupted',
#   'excess',
#   'inventories',
#   'since',
#   '1985',
#   'take',
#   'time',
#   "''",
#   'said',
#   'kuroda',
#   'also',
#   'laid',
#   'part',
#   'blame',
#   'low',
#   'u.s.',
#   'chip',
#   'sales',
#   'japan',
#   'lack',
#   'effort',
#   'american',
#   'firms',
#   'said',
#   'fails',
#   'talks',
#   'tomorrow',
#   'friday',
#   'forestall',
#   'sanctions',
#   'seek',
#   'talks',
#   'u.s.',
#   'trade',
#   'representative',
#   'clayton',
#   'yeutter',
#   'u.s.',
#   'officials',
#   'said',
#   'week',
#   "'s",
#   'talks',
#   'unlikely',
#   'delay',
#   'imposition',
#   'tariffs'],
#  ['japan',
#   'given',
#   'little',
#   'hope',
#   'avoiding',
#   'u.s.',
#   'sanctions',
#   'top',
#   'u.s.',
#   'official',
#   'said',
#   'japan',
#   'little',
#   'chance',
#   'persuading',
#   'u.s.',
#   'drop',
#   'threatened',
#   'trade',
#   'sanctions',
#   'despite',
#   'efforts',
#   'japanese',
#   'team',
#   'left',
#   'washington',
#   'today',
#   'michael',
#   'armacost',
#   'secretary',
#   'state',
#   'political',
#   'affairs',
#   'asked',
#   'press',
#   'conference',
#   'whether',
#   'japan',
#   "'s",
#   'moves',
#   'boost',
#   'domestic',
#   'economy',
#   'open',
#   'markets',
#   'could',
#   'persuade',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'japanese',
#   'imports',
#   'said',
#   'replied',
#   '``',
#   '...',
#   'probably',
#   'early',
#   'figures',
#   'demonstrate',
#   'situation',
#   'turned',
#   'around',
#   'permit',
#   'result',
#   'described',
#   "''",
#   'armacost',
#   'said',
#   'u.s.',
#   'hopes',
#   'japan',
#   'take',
#   'steps',
#   'lift',
#   'domestic',
#   'economy',
#   'reduce',
#   'dependence',
#   'exports',
#   'remove',
#   'barriers',
#   'imports',
#   'settle',
#   'outstanding',
#   'trade',
#   'issues',
#   '``',
#   'obvious',
#   'problems',
#   'moment',
#   'trade',
#   'area',
#   'wish',
#   'problems',
#   'divert',
#   'attention',
#   'important',
#   'areas',
#   'cooperation',
#   'continue',
#   'exist',
#   'security',
#   'political',
#   'issues',
#   "''",
#   'said',
#   '``',
#   'question',
#   'whether',
#   'cooperative',
#   'actions',
#   'governments',
#   'reduce',
#   'trade',
#   'imbalance',
#   'whether',
#   'congress',
#   'takes',
#   'action',
#   'reduce',
#   'protectionist',
#   'legislation',
#   "''",
#   'said'],
#  ['japan',
#   'last-ditch',
#   'effort',
#   'avert',
#   'tariffs',
#   'senior',
#   'japanese',
#   'officials',
#   'tomorrow',
#   'open',
#   'talks',
#   'american',
#   'trade',
#   'negotiators',
#   'last-ditch',
#   'effort',
#   'avert',
#   'new',
#   'high',
#   'u.s.',
#   'tariffs',
#   'imposed',
#   'wide',
#   'variety',
#   'japanese',
#   'electronic',
#   'exports',
#   'makoto',
#   'kuroda',
#   'vice',
#   'minister',
#   'japan',
#   "'s",
#   'ministry',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'hold',
#   'two',
#   'days',
#   'meetings',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'secretary',
#   'commerce',
#   'bruce',
#   'smart',
#   'new',
#   'tariffs',
#   'go',
#   'effect',
#   'april',
#   '17',
#   'retaliation',
#   'japan',
#   "'s",
#   'failure',
#   'adhere',
#   'agreement',
#   'end',
#   'dumping',
#   'semiconductors',
#   'world',
#   'markets',
#   'cost',
#   'open',
#   'home',
#   'market',
#   'u.s.',
#   'semiconductor',
#   'shipments',
#   'imposed',
#   'goods',
#   'use',
#   'semiconductors',
#   'including',
#   'television',
#   'audio',
#   'equipment',
#   'computers',
#   'u.s.',
#   'japanese',
#   'officials',
#   'said',
#   'little',
#   'likelihood',
#   'talks',
#   'would',
#   'anything',
#   'avert',
#   '100',
#   'pct',
#   'duties',
#   '300',
#   'mln',
#   'dlrs',
#   'worth',
#   'japanese',
#   'shipments',
#   'president',
#   'reagan',
#   'announced',
#   'planned',
#   'tariffs',
#   'march',
#   '27',
#   'said',
#   'close',
#   'monitoring',
#   'july',
#   '1986',
#   'u.s.-japanese',
#   'semiconductor',
#   'pact',
#   'convinced',
#   'u.s.',
#   'officials',
#   'japan',
#   'honoring',
#   'agreement',
#   'making',
#   'annoucement',
#   'reagan',
#   'said',
#   '``',
#   'committed',
#   'full',
#   'enforcement',
#   'trade',
#   'agreements',
#   'designed',
#   'provide',
#   'american',
#   'industry',
#   'free',
#   'fair',
#   'trade',
#   "''",
#   'trade',
#   'analysts',
#   'said',
#   'move',
#   'aimed',
#   'much',
#   'japan',
#   "'s",
#   'semiconductor',
#   'trade',
#   'practices',
#   'said',
#   'injured',
#   'u.s.',
#   'semiconductor',
#   'industry',
#   'congress',
#   'complained',
#   'presidential',
#   'timidity',
#   'trade',
#   'issues',
#   'congressional',
#   'democrats',
#   'pledged',
#   'enact',
#   'aggressive',
#   'trade',
#   'laws',
#   'counter',
#   'contend',
#   'reagan',
#   "'s",
#   'inaction',
#   'redress',
#   'growing',
#   'u.s.',
#   'trade',
#   'deficit',
#   'last',
#   'year',
#   'reached',
#   '169.8',
#   'billion',
#   'dlrs',
#   'one-third',
#   'deficit',
#   'japan',
#   'reagan',
#   'said',
#   'recent',
#   'signs',
#   'japan',
#   'beginning',
#   'adhere',
#   'pact',
#   'terminating',
#   'kuroda',
#   'said',
#   'leaving',
#   'tokyo',
#   'today',
#   'new',
#   'proposals',
#   'explanation',
#   'semiconductor',
#   'situation',
#   'told',
#   'daily',
#   'newspaper',
#   'ashai',
#   'shimbun',
#   'reagan',
#   "'s",
#   'decision',
#   'based',
#   'inaccurate',
#   'data',
#   'exaggerated',
#   'sense',
#   'miti',
#   "'s",
#   'power',
#   'control',
#   'japanese',
#   'traders',
#   '``',
#   'united',
#   'states',
#   'excessive',
#   'expectations.',
#   "''",
#   'said',
#   'stabilize',
#   'supply-demand',
#   'relations',
#   'disrupted',
#   'excess',
#   'inventories',
#   'since',
#   '1985',
#   'take',
#   'time',
#   "''",
#   'also',
#   'said',
#   'u.s.',
#   'firms',
#   'aggressive',
#   'enough',
#   'trying',
#   'sell',
#   'japanese',
#   'market'],
#  ['white',
#   'house',
#   'standing',
#   'firm',
#   'japanese',
#   'sanctions',
#   'presidential',
#   'spokesman',
#   'marlin',
#   'fitzwater',
#   'said',
#   'u.s.',
#   'trade',
#   'sanctions',
#   'japan',
#   'likely',
#   'take',
#   'effect',
#   'april',
#   '17',
#   'spite',
#   '``',
#   'full',
#   'court',
#   'press',
#   "''",
#   'japanese',
#   'officials',
#   'avoid',
#   '``',
#   'indications',
#   'take',
#   'effect',
#   "''",
#   'said',
#   '``',
#   'would',
#   'say',
#   'japan',
#   'applying',
#   'full',
#   'court',
#   'press',
#   '...',
#   'certainly',
#   'putting',
#   'feet',
#   'forward',
#   'terms',
#   'explaining',
#   'position',
#   "''",
#   'fitzwater',
#   'told',
#   'reporters',
#   'noted',
#   'high',
#   'level',
#   'meetings',
#   'trade',
#   'dispute',
#   'underway',
#   'said',
#   '``',
#   "n't",
#   'think',
#   "'s",
#   'anything',
#   'report',
#   "n't",
#   'believe',
#   "'s",
#   'official',
#   'movement',
#   "''"],
#  ['white',
#   'house',
#   'says',
#   'japanese',
#   'tarriffs',
#   'likely',
#   'white',
#   'house',
#   'said',
#   'high',
#   'u.s.',
#   'tariffs',
#   'japanese',
#   'electronic',
#   'goods',
#   'would',
#   'likely',
#   'imposed',
#   'scheduled',
#   'april',
#   '17',
#   'despite',
#   'all-out',
#   'effort',
#   'japan',
#   'avoid',
#   'presidential',
#   'spokesman',
#   'marlin',
#   'fitzwater',
#   'made',
#   'remark',
#   'one',
#   'day',
#   'u.s.',
#   'japanese',
#   'officials',
#   'meet',
#   'emergency',
#   'provisions',
#   'july',
#   '1986',
#   'semiconductor',
#   'pact',
#   'discuss',
#   'trade',
#   'punitive',
#   'tariffs',
#   'fitzwater',
#   'said',
#   '``',
#   'would',
#   'say',
#   'japan',
#   'applying',
#   'full-court',
#   'press',
#   '...',
#   'certainly',
#   'putting',
#   'feet',
#   'forward',
#   'terms',
#   'explaining',
#   'position',
#   "''",
#   'added',
#   '``',
#   'indications',
#   'tariffs',
#   'take',
#   'effect',
#   "''"],
#  ['canada',
#   'plans',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'trade',
#   'minister',
#   'says',
#   'canada',
#   'plans',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'trade',
#   'minister',
#   'says'],
#  ['canada',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'canada',
#   'plans',
#   'monitor',
#   'steel',
#   'shipments',
#   'flowing',
#   'country',
#   'attempt',
#   'appease',
#   'concerns',
#   'u.s.',
#   'high',
#   'level',
#   'canadian',
#   'steel',
#   'exports',
#   'trade',
#   'minister',
#   'pat',
#   'carney',
#   'said',
#   '``',
#   'help',
#   'maintain',
#   'open',
#   'access',
#   'u.s.',
#   'steel',
#   'market',
#   'government',
#   'taking',
#   'action',
#   'ensure',
#   'accurate',
#   'data',
#   'exports',
#   'imports',
#   'canada',
#   'used',
#   'backdoor',
#   'u.s.',
#   'market',
#   'offshore',
#   'suppliers',
#   "''",
#   'carney',
#   'said',
#   'carney',
#   'also',
#   'said',
#   'canadian',
#   'companies',
#   'asked',
#   'exercise',
#   'prudence',
#   'u.s.',
#   'market',
#   'countries',
#   'considering',
#   'establishing',
#   'joint',
#   'commission',
#   'study',
#   'growing',
#   'steel',
#   'problem',
#   'carney',
#   'told',
#   'house',
#   'commons',
#   'soon',
#   'announce',
#   'amendment',
#   'exports',
#   'imports',
#   'permits',
#   'act',
#   'set',
#   'monitoring',
#   'program',
#   'canadian',
#   'steel',
#   'shipments',
#   'u.s.',
#   'risen',
#   '5.7',
#   'pct',
#   'cent',
#   'u.s.',
#   'market',
#   'recent',
#   'months',
#   'almost',
#   'double',
#   'level',
#   'two',
#   'years',
#   'ago',
#   'canadian',
#   'trade',
#   'officials',
#   'said',
#   'increase',
#   'canadian',
#   'shipments',
#   'comes',
#   'time',
#   'growing',
#   'anger',
#   'u.s.',
#   'rising',
#   'steel',
#   'imports',
#   'several',
#   'countries',
#   'face',
#   'decline',
#   'domestic',
#   'steel',
#   'industry',
#   'u.s.',
#   'lawmakers',
#   'proposed',
#   'canada',
#   "'s",
#   'share',
#   'american',
#   'market',
#   'limited',
#   '2.4',
#   'pct'],
#  ['deficit',
#   'cuts',
#   'seen',
#   'unable',
#   'cure',
#   'trade',
#   'deficit',
#   'financial',
#   'analysts',
#   'say',
#   'pleased',
#   'congressional',
#   'moves',
#   'trim',
#   'next',
#   'year',
#   "'s",
#   'federal',
#   'budget',
#   'deficit',
#   'believe',
#   'actions',
#   'little',
#   'help',
#   'improve',
#   'u.s.',
#   'trade',
#   'deficit',
#   'buoy',
#   'economy',
#   'house',
#   'representatives',
#   'expected',
#   'vote',
#   'tomorrow',
#   'approve',
#   'trillion-dollar',
#   'budget',
#   'blueprint',
#   'coming',
#   'fiscal',
#   'year',
#   'reduces',
#   'deficit',
#   '38',
#   'billion',
#   'dlrs',
#   'similarly',
#   'senate',
#   'budget',
#   'committee',
#   'approved',
#   'plan',
#   'would',
#   'cut',
#   'federal',
#   'red',
#   'ink',
#   '37',
#   'billion',
#   'dlrs',
#   'next',
#   'year',
#   '``',
#   'terms',
#   'economy',
#   '37-38',
#   'billion',
#   'dlrs',
#   'infinitesimal',
#   'cuts',
#   'magnitude',
#   'little',
#   'impact',
#   'economy',
#   'trade',
#   'deficit',
#   "''",
#   'said',
#   'stanley',
#   'collander',
#   'touche',
#   'ross',
#   'federal',
#   'budget',
#   'policy',
#   'analyst',
#   '``',
#   'best',
#   'small',
#   'positive',
#   'effect',
#   "''",
#   'collander',
#   'said',
#   'interview',
#   'federal',
#   'reserve',
#   'board',
#   'chairman',
#   'paul',
#   'volcker',
#   'repeatedly',
#   'told',
#   'congress',
#   'cutting',
#   'federal',
#   'red',
#   'ink',
#   'would',
#   'go',
#   'long',
#   'way',
#   'help',
#   'reduce',
#   'massive',
#   'trade',
#   'deficit',
#   'also',
#   'help',
#   'ease',
#   'downward',
#   'pressure',
#   'value',
#   'dollar',
#   'u.s.',
#   'government',
#   'attempted',
#   'remedy',
#   'trade',
#   'imbalance',
#   'driving',
#   'value',
#   'dollar',
#   'volcker',
#   'warned',
#   'fall',
#   'dollar',
#   "'s",
#   'value',
#   'fraught',
#   'danger',
#   'decline',
#   'said',
#   'could',
#   'refuel',
#   'inflation',
#   'imported',
#   'goods',
#   'become',
#   'expensive',
#   'chase',
#   'away',
#   'foreign',
#   'capital',
#   'needed',
#   'finance',
#   'federal',
#   'budget',
#   'deficit',
#   'addition',
#   'february',
#   'u.s.',
#   'officials',
#   'meeting',
#   'major',
#   'industrialized',
#   'nations',
#   'paris',
#   'agreed',
#   'value',
#   'dollar',
#   'dropped',
#   'enough',
#   'world',
#   'exchange',
#   'rates',
#   'stabilized',
#   'around',
#   'current',
#   'levels',
#   'part',
#   'agreement',
#   'japan',
#   'west',
#   'germany',
#   'agreed',
#   'take',
#   'steps',
#   'stimulate',
#   'economies',
#   'united',
#   'states',
#   'agreed',
#   'cut',
#   'budget',
#   'deficit',
#   'alternative',
#   'driving',
#   'dollar',
#   'way',
#   'deal',
#   'trade',
#   'deficit',
#   'volcker',
#   'said',
#   'recently',
#   'reduce',
#   'u.s.',
#   'consumption',
#   'particularly',
#   'federal',
#   'spending',
#   '``',
#   "n't",
#   'deal',
#   'budget',
#   'deficit',
#   'everything',
#   'else',
#   'going',
#   'counterproductive',
#   "''",
#   'volcker',
#   'said',
#   'recent',
#   'testimony',
#   'senate',
#   'banking',
#   'committee',
#   'volcker',
#   'also',
#   'said',
#   'would',
#   'prefer',
#   'tighten',
#   'government',
#   "'s",
#   'purse',
#   'strings',
#   'fed',
#   'tighten',
#   'credit',
#   'supply',
#   'action',
#   'needed',
#   'fight',
#   'inflationary',
#   'pressures',
#   'assure',
#   'continued',
#   'flow',
#   'foreign',
#   'capital',
#   'united',
#   'states',
#   'analysts',
#   'say',
#   'fed',
#   'tightening',
#   'could',
#   'choke',
#   'current',
#   'modest',
#   'economic',
#   'expansion',
#   'threaten',
#   'recession',
#   'kemper',
#   'financial',
#   'services',
#   'economist',
#   'john',
#   'silvia',
#   'stressed',
#   'deficit',
#   'reduction',
#   'better',
#   'none',
#   'said',
#   'size',
#   'cuts',
#   'consideration',
#   'enough',
#   'give',
#   'federal',
#   'reserve',
#   'board',
#   'flexibility',
#   'needs',
#   'steer',
#   'economy',
#   'keep',
#   'value',
#   'dollar',
#   'plunging',
#   'world',
#   'exchange',
#   'markets',
#   '``',
#   "'s",
#   'doubt',
#   'deficit',
#   'reduction',
#   'helps',
#   'objective',
#   'stabilize',
#   'dollar',
#   'perserve',
#   'fed',
#   "'s",
#   'flexibility',
#   'conduct',
#   'monetary',
#   'policy',
#   'answer',
#   "'s",
#   'enough',
#   "''",
#   'silvia',
#   'told',
#   'reuters',
#   'u.s.',
#   'trade',
#   'deficit',
#   'become',
#   'one',
#   'government',
#   "'s",
#   'vexing',
#   'persistent',
#   'problems',
#   '1986',
#   'deficit',
#   '169.8',
#   'billion',
#   'dlrs',
#   'yet',
#   'little',
#   'indication',
#   'year',
#   "'s",
#   'figure',
#   'lower',
#   'though',
#   'administration',
#   'officials',
#   'predicted',
#   'drop',
#   '20',
#   '30',
#   'billion',
#   'dlrs',
#   'year',
#   "'s",
#   'end',
#   'past',
#   'volcker',
#   'joked',
#   'never',
#   'lost',
#   'sleep',
#   'worrying',
#   'whether',
#   'congress',
#   'would',
#   'cut',
#   'much',
#   'fat',
#   'federal',
#   'budget',
#   'hand',
#   'also',
#   'made',
#   'clear',
#   'attached',
#   'gradually',
#   'declining',
#   'deficit',
#   'ceilings',
#   'set',
#   '1986-1991',
#   'period',
#   'last',
#   'year',
#   "'s",
#   'gramm-rudman',
#   'balanced',
#   'budget',
#   'law',
#   'new',
#   'law',
#   'set',
#   'ceiling',
#   '108',
#   'billion',
#   'dlrs',
#   'next',
#   'year',
#   "'s",
#   'federal',
#   'deficit',
#   'house',
#   'senate',
#   'budget',
#   'committees',
#   'conceded',
#   'budget',
#   'plans',
#   'would',
#   'fall',
#   'short',
#   'deficit',
#   'reduction',
#   'goal',
#   '25',
#   'billion',
#   'dlrs',
#   '``',
#   'political',
#   'reasons',
#   '35',
#   '40',
#   'billion',
#   'dlrs',
#   "'re",
#   'going',
#   'get',
#   "''",
#   'congress',
#   'present',
#   'time',
#   'said',
#   'touche',
#   'ross',
#   "'s",
#   'collander',
#   '``',
#   'something',
#   'would',
#   'extraordinary',
#   'remarkable',
#   'difficult',
#   "''",
#   'collander',
#   'said',
#   'real',
#   'danger',
#   'congress',
#   'end',
#   'short',
#   'deficit',
#   'reduction',
#   'goal',
#   'set',
#   'budget',
#   'panels',
#   '``',
#   'extent',
#   'become',
#   'minimum',
#   'acceptable',
#   'reduction',
#   'level',
#   "''",
#   'explained',
#   '``',
#   'anything',
#   'less',
#   'look',
#   'like',
#   'failure',
#   'wall',
#   'street',
#   "''",
#   'budget',
#   'plan',
#   'debate',
#   'house',
#   'floor',
#   'would',
#   'lower',
#   'estimated',
#   '171',
#   'billion',
#   'dlr',
#   'deficit',
#   'year',
#   'beginning',
#   'october',
#   'one',
#   '133',
#   'billion',
#   'dlrs',
#   'cutting',
#   'defense',
#   'domestic',
#   'programs',
#   '38',
#   'billion',
#   'dlrs',
#   'anticipated',
#   'spending',
#   'levels',
#   'next',
#   'year',
#   'senate',
#   'budget',
#   'committee',
#   'called',
#   'deficit',
#   'nearly',
#   '134',
#   'billion',
#   'dlrs',
#   '18.5',
#   'billion',
#   'dlrs',
#   'new',
#   'taxes',
#   'amount',
#   'spending',
#   'cuts'],
#  ['economic',
#   'spotlight',
#   'telecom',
#   'key',
#   'japan',
#   'ministry',
#   'japan',
#   "'s",
#   'little-known',
#   'ministry',
#   'posts',
#   'telecommunications',
#   'mpt',
#   'emerged',
#   'international',
#   'force',
#   'reckoned',
#   'political',
#   'analysts',
#   'said',
#   'mpt',
#   'thrust',
#   'spotlight',
#   'trade',
#   'rows',
#   'u.s.',
#   'britain',
#   'position',
#   'strength',
#   'due',
#   'control',
#   'lucrative',
#   'industry',
#   'ties',
#   'important',
#   'politicians',
#   'said',
#   '``',
#   'ministry',
#   'standing',
#   'athwart',
#   'regulatory',
#   'control',
#   'key',
#   'industrial',
#   'sector',
#   'telecommunications',
#   'information',
#   "''",
#   'said',
#   'one',
#   'diplomatic',
#   'source',
#   '``',
#   'potent',
#   'political',
#   'force',
#   "''",
#   'diplomatic',
#   'source',
#   'said',
#   'mpt',
#   'finding',
#   'domestic',
#   'political',
#   'prowess',
#   'always',
#   'help',
#   'comes',
#   'trade',
#   'friction',
#   'diplomacy',
#   'analysts',
#   'said',
#   '``',
#   'ministry',
#   'minor',
#   'ministry',
#   'people',
#   'internationalized',
#   "''",
#   'said',
#   'waseda',
#   'university',
#   'professor',
#   'mitsuru',
#   'uchida',
#   '``',
#   'suddenly',
#   "'re",
#   'standing',
#   'centre',
#   'world',
#   'community',
#   'sense',
#   "'re",
#   'loss',
#   'face',
#   'situation',
#   "''",
#   'recently',
#   'ministry',
#   'embroiled',
#   'row',
#   'london',
#   'efforts',
#   'britain',
#   "'s",
#   'cable',
#   'wireless',
#   'plc',
#   'keep',
#   'major',
#   'stake',
#   'one',
#   'two',
#   'consortia',
#   'trying',
#   'compete',
#   'japan',
#   "'s",
#   'lucrative',
#   'overseas',
#   'telephone',
#   'business',
#   'ministry',
#   'favoured',
#   'merger',
#   'two',
#   'rival',
#   'groups',
#   'arguing',
#   'market',
#   'support',
#   'one',
#   'competitor',
#   'kokusai',
#   'denshin',
#   'denwa',
#   'co',
#   'ltd',
#   'monopolizes',
#   'business',
#   'also',
#   'opposed',
#   'major',
#   'management',
#   'role',
#   'planned',
#   'merger',
#   'non-japanese',
#   'overseas',
#   'telecommunications',
#   'firm',
#   'grounds',
#   'international',
#   'precedent',
#   'exists',
#   'ministry',
#   "'s",
#   'stance',
#   'outraged',
#   'london',
#   'threatened',
#   'retaliate',
#   'washington',
#   'says',
#   'merger',
#   'plan',
#   'evidence',
#   'japan',
#   "'s",
#   'failure',
#   'honour',
#   'pledges',
#   'open',
#   'telecommunications',
#   'market',
#   'washington',
#   'also',
#   'angry',
#   'ministry',
#   'moves',
#   'says',
#   'limited',
#   'access',
#   'u.s.',
#   'firms',
#   'japan',
#   "'s",
#   'car',
#   'telephone',
#   'satellite',
#   'communications',
#   'market',
#   'much',
#   'mpt',
#   "'s",
#   'new',
#   'prominence',
#   'stems',
#   'growth',
#   'sector',
#   'regulates',
#   '``',
#   'happening',
#   'important',
#   'shift',
#   'economy',
#   'makes',
#   'ministry',
#   'important',
#   'place',
#   "''",
#   'said',
#   'james',
#   'abegglen',
#   'head',
#   'consulting',
#   'firm',
#   'asia',
#   'advisory',
#   'service',
#   'inc.',
#   'decision',
#   'open',
#   'telecommunications',
#   'industry',
#   'competition',
#   'new',
#   'set',
#   'laws',
#   'passed',
#   '1985',
#   'boosted',
#   'rather',
#   'lessened',
#   'mpt',
#   "'s",
#   'authority',
#   'analysts',
#   'said',
#   '``',
#   'legal',
#   'framework',
#   'eased',
#   'became',
#   'de',
#   'facto',
#   'legal',
#   'framework',
#   "''",
#   'said',
#   'bache',
#   'securities',
#   'japan',
#   'analyst',
#   'darrell',
#   'whitten',
#   'close',
#   'links',
#   'powerful',
#   'political',
#   'faction',
#   'ruling',
#   'liberal',
#   'democratic',
#   'party',
#   'ldp',
#   'nurtured',
#   'former',
#   'prime',
#   'minister',
#   'kakuei',
#   'tanaka',
#   'another',
#   'key',
#   'mpt',
#   "'s",
#   'influence',
#   'analysts',
#   'said',
#   '``',
#   'factions',
#   'ignored',
#   'mpt',
#   '1970s',
#   'tanaka',
#   'faction',
#   'forward',
#   'looking',
#   '...',
#   'recognized',
#   'importance',
#   'mpt',
#   "''",
#   'uchida',
#   'said',
#   'many',
#   'former',
#   'bureaucrats',
#   'became',
#   'members',
#   'influential',
#   'political',
#   'group',
#   'added',
#   'ministry',
#   'also',
#   'power',
#   'financial',
#   'sector',
#   'due',
#   '100,000',
#   'billion',
#   'yen',
#   'worth',
#   'deposits',
#   'postal',
#   'savings',
#   'system',
#   'analysts',
#   'said',
#   'mpt',
#   'helped',
#   'block',
#   'finance',
#   'ministry',
#   'plans',
#   'deregulate',
#   'interest',
#   'rates',
#   'small',
#   'deposits',
#   'key',
#   'element',
#   'financial',
#   'liberalisation',
#   'since',
#   'change',
#   'would',
#   'remove',
#   'postal',
#   'savings',
#   'system',
#   "'s",
#   'ability',
#   'offer',
#   'slightly',
#   'higher',
#   'rates',
#   'banks',
#   'said',
#   'diplomatic',
#   'sources',
#   'frustrated',
#   'see',
#   'mpt',
#   "'s",
#   'obstructionist',
#   'protectionist',
#   'posture',
#   'characterized',
#   'ministry',
#   'feudal',
#   'critics',
#   'charge',
#   'mpt',
#   'protecting',
#   'turf',
#   'limiting',
#   'competition',
#   'sheltering',
#   'former',
#   'monopolies',
#   'wing',
#   'providing',
#   'consumers',
#   'best',
#   'service',
#   'lowest',
#   'price',
#   'takes',
#   'back',
#   'seat',
#   'considerations',
#   'said',
#   'many',
#   'ministry',
#   "'s",
#   'actions',
#   'unlike',
#   'bureaucratic',
#   'counterparts',
#   'much',
#   'western',
#   'world',
#   'including',
#   'britain',
#   'several',
#   'analysts',
#   'said',
#   '``',
#   'united',
#   'states',
#   'really',
#   'odd',
#   'man',
#   "''",
#   'abegglen',
#   'said',
#   '``',
#   'government',
#   'take',
#   'view',
#   'wants',
#   'keep',
#   'order',
#   'utilities',
#   'markets',
#   'unusual',
#   'and/or',
#   'unreasonable',
#   'view',
#   "''",
#   'said'],
#  ['g-7',
#   'issues',
#   'statement',
#   'meeting',
#   'following',
#   'text',
#   'statement',
#   'group',
#   'seven',
#   '--',
#   'u.s.',
#   'japan',
#   'west',
#   'germany',
#   'france',
#   'britain',
#   'italy',
#   'canada',
#   '--',
#   'issued',
#   'washington',
#   'meeting',
#   'yesterday',
#   '1.',
#   'finance',
#   'ministers',
#   'central',
#   'bank',
#   'governors',
#   'seven',
#   'major',
#   'industrial',
#   'countries',
#   'met',
#   'today',
#   'continued',
#   'process',
#   'multilateral',
#   'surveillance',
#   'economies',
#   'pursuant',
#   'arrangements',
#   'strengthened',
#   'economic',
#   'policy',
#   'coordination',
#   'agreed',
#   '1986',
#   'tokyo',
#   'summit',
#   'heads',
#   'state',
#   'government',
#   'managing',
#   'director',
#   'international',
#   'monetary',
#   'fund',
#   'also',
#   'participated',
#   'meeting',
#   '2.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'commitment',
#   'cooperative',
#   'approach',
#   'agreed',
#   'recent',
#   'paris',
#   'meeting',
#   'noted',
#   'progress',
#   'achieved',
#   'implementing',
#   'undertakings',
#   'embodied',
#   'louvre',
#   'agreement',
#   'agreed',
#   'however',
#   'actions',
#   'essential',
#   'resist',
#   'rising',
#   'protectionist',
#   'pressures',
#   'sustain',
#   'global',
#   'economic',
#   'expansion',
#   'reduce',
#   'trade',
#   'imbalances',
#   'connection',
#   'welcomed',
#   'proposals',
#   'announced',
#   'governing',
#   'liberal',
#   'democratic',
#   'party',
#   'japan',
#   'extraordinary',
#   'urgent',
#   'measures',
#   'stimulate',
#   'japan',
#   "'s",
#   'economy',
#   'early',
#   'implementation',
#   'large',
#   'supplementary',
#   'budget',
#   'exceeding',
#   'previous',
#   'years',
#   'well',
#   'unprecedented',
#   'front-end',
#   'loading',
#   'public',
#   'works',
#   'expenditures',
#   'government',
#   'japan',
#   'reaffirmed',
#   'intention',
#   'open',
#   'domestic',
#   'markets',
#   'foreign',
#   'goods',
#   'services',
#   '3.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'view',
#   'around',
#   'current',
#   'levels',
#   'currencies',
#   'within',
#   'ranges',
#   'broadly',
#   'consistent',
#   'economic',
#   'fundamentals',
#   'basic',
#   'policy',
#   'intentions',
#   'outlined',
#   'louvre',
#   'meeting',
#   'connection',
#   'welcomed',
#   'strong',
#   'implementation',
#   'louvre',
#   'agreement',
#   'concluded',
#   'present',
#   'prospective',
#   'progress',
#   'implementing',
#   'policy',
#   'undertakings',
#   'louvre',
#   'statement',
#   'provided',
#   'basis',
#   'continuing',
#   'close',
#   'cooperation',
#   'foster',
#   'stability',
#   'exchange',
#   'rates'],
#  ['soviet',
#   'trade',
#   'deficit',
#   'west',
#   'soars',
#   '1986',
#   'soviet',
#   'trade',
#   'deficit',
#   'west',
#   'almost',
#   'quadrupled',
#   'last',
#   'year',
#   'reaching',
#   '2.72',
#   'billion',
#   'roubles',
#   'compared',
#   '713',
#   'mln',
#   '1985',
#   'official',
#   'figures',
#   'showed',
#   'statistics',
#   'published',
#   'monthly',
#   'journal',
#   'foreign',
#   'trade',
#   'showed',
#   'soviet',
#   'trade',
#   'turnover',
#   '1986',
#   'fell',
#   '130.9',
#   'billion',
#   'roubles',
#   '142.1',
#   'billion',
#   'previous',
#   'year',
#   'drop',
#   '7.8',
#   'pct',
#   'moscow',
#   "'s",
#   'trade',
#   'surplus',
#   'east',
#   'bloc',
#   'countries',
#   'continued',
#   'grow',
#   '1986.',
#   'western',
#   'analysts',
#   'attributed',
#   'deficit',
#   'rise',
#   'west',
#   'world',
#   'oil',
#   'price',
#   'slump',
#   'hit',
#   'moscow',
#   "'s",
#   'main',
#   'export',
#   'cut',
#   'hard',
#   'currency',
#   'earnings',
#   'needed',
#   'purchases',
#   'west'],
#  ['canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'january',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus',
#   'canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'january',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus'],
#  ['canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.2',
#   'billion',
#   'dlrs',
#   'canada',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'february',
#   'compared',
#   'upward',
#   'revised',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus',
#   'january',
#   'statistics',
#   'canada',
#   'said',
#   'january',
#   'surplus',
#   'originally',
#   'reported',
#   '533',
#   'mln',
#   'dlrs',
#   'february',
#   'surplus',
#   'last',
#   'year',
#   '189',
#   'mln',
#   'dlrs',
#   'february',
#   'exports',
#   'seasonally',
#   'adjusted',
#   '10.44',
#   'billion',
#   'dlrs',
#   '9.85',
#   'billion',
#   'january',
#   '10.05',
#   'billion',
#   'february',
#   '1986.',
#   'february',
#   'imports',
#   '9.19',
#   'billion',
#   'dlrs',
#   '9.23',
#   'billion',
#   'january',
#   '9.86',
#   'billion',
#   'february',
#   '1986'],
#  ['ec',
#   'launches',
#   'anti-dumping',
#   'probe',
#   'japanese',
#   'chips',
#   'european',
#   'community',
#   'launched',
#   'investigation',
#   'allegations',
#   'dumping',
#   'japanese',
#   'semiconductor',
#   'makers',
#   'move',
#   'diplomats',
#   'said',
#   'could',
#   'mark',
#   'intensification',
#   'world',
#   'trade',
#   'strains',
#   'tokyo',
#   'already',
#   'faces',
#   'deadline',
#   'april',
#   '17',
#   'washington',
#   'imposition',
#   '300',
#   'mln',
#   'dlrs',
#   'worth',
#   'tariffs',
#   'chips',
#   'imports',
#   'u.s.',
#   'ec',
#   'executive',
#   'commission',
#   'said',
#   'today',
#   'european',
#   'electrical',
#   'component',
#   'manufacturers',
#   'association',
#   'complained',
#   'japanese',
#   'firms',
#   'selling',
#   'high',
#   'capacity',
#   'eprom',
#   'type',
#   'erasable',
#   'programmable',
#   'read',
#   'memory',
#   'chips',
#   'unfairly',
#   'low',
#   'prices',
#   'japan',
#   'last',
#   'year',
#   'took',
#   '78',
#   'pct',
#   '170',
#   'mln',
#   'dlr',
#   'ec',
#   'eprom',
#   'market',
#   '60',
#   'pct',
#   '1984.',
#   'ec',
#   'firms',
#   'said',
#   'forced',
#   'offer',
#   'products',
#   'discount',
#   '30',
#   'pct',
#   'order',
#   'compete',
#   'japanese',
#   'commission',
#   'said',
#   'believed',
#   'association',
#   'given',
#   'sufficient',
#   'elements',
#   'proof',
#   'dumping',
#   'warrant',
#   'investigation',
#   'could',
#   'lead',
#   'impose',
#   'duties',
#   'found',
#   'complaints',
#   'justified',
#   'commission',
#   'claims',
#   'last',
#   'year',
#   "'s",
#   'accord',
#   'u.s.',
#   'japan',
#   'microchip',
#   'pricing',
#   'gives',
#   'u.s.',
#   'firms',
#   'privileged',
#   'access',
#   'japanese',
#   'market'],
#  ['g-7',
#   'issues',
#   'statement',
#   'meeting',
#   'following',
#   'text',
#   'statement',
#   'group',
#   'seven',
#   '--',
#   'u.s.',
#   'japan',
#   'west',
#   'germany',
#   'france',
#   'britain',
#   'italy',
#   'canada',
#   '--',
#   'issued',
#   'washington',
#   'meeting',
#   'yesterday',
#   '1.',
#   'finance',
#   'ministers',
#   'central',
#   'bank',
#   'governors',
#   'seven',
#   'major',
#   'industrial',
#   'countries',
#   'met',
#   'today',
#   'continued',
#   'process',
#   'multilateral',
#   'surveillance',
#   'economies',
#   'pursuant',
#   'arrangements',
#   'strengthened',
#   'economic',
#   'policy',
#   'coordination',
#   'agreed',
#   '1986',
#   'tokyo',
#   'summit',
#   'heads',
#   'state',
#   'government',
#   'managing',
#   'director',
#   'international',
#   'monetary',
#   'fund',
#   'also',
#   'participated',
#   'meeting',
#   '2.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'commitment',
#   'cooperative',
#   'approach',
#   'agreed',
#   'recent',
#   'paris',
#   'meeting',
#   'noted',
#   'progress',
#   'achieved',
#   'implementing',
#   'undertakings',
#   'embodied',
#   'louvre',
#   'agreement',
#   'agreed',
#   'however',
#   'actions',
#   'essential',
#   'resist',
#   'rising',
#   'protectionist',
#   'pressures',
#   'sustain',
#   'global',
#   'economic',
#   'expansion',
#   'reduce',
#   'trade',
#   'imbalances',
#   'connection',
#   'welcomed',
#   'proposals',
#   'announced',
#   'governing',
#   'liberal',
#   'democratic',
#   'party',
#   'japan',
#   'extraordinary',
#   'urgent',
#   'measures',
#   'stimulate',
#   'japan',
#   "'s",
#   'economy',
#   'early',
#   'implementation',
#   'large',
#   'supplementary',
#   'budget',
#   'exceeding',
#   'previous',
#   'years',
#   'well',
#   'unprecedented',
#   'front-end',
#   'loading',
#   'public',
#   'works',
#   'expenditures',
#   'government',
#   'japan',
#   'reaffirmed',
#   'intention',
#   'open',
#   'domestic',
#   'markets',
#   'foreign',
#   'goods',
#   'services',
#   '3.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'view',
#   'around',
#   'current',
#   'levels',
#   'currencies',
#   'within',
#   'ranges',
#   'broadly',
#   'consistent',
#   'economic',
#   'fundamentals',
#   'basic',
#   'policy',
#   'intentions',
#   'outlined',
#   'louvre',
#   'meeting',
#   'connection',
#   'welcomed',
#   'strong',
#   'implementation',
#   'louvre',
#   'agreement',
#   'concluded',
#   'present',
#   'prospective',
#   'progress',
#   'implementing',
#   'policy',
#   'undertakings',
#   'louvre',
#   'statement',
#   'provided',
#   'basis',
#   'continuing',
#   'close',
#   'cooperation',
#   'foster',
#   'stability',
#   'exchange',
#   'rates'],
#  ['spanish',
#   'employers',
#   'worried',
#   'high',
#   'interest',
#   'rates',
#   'head',
#   'spain',
#   "'s",
#   'employers',
#   'federation',
#   'jose',
#   'maria',
#   'cuevas',
#   'said',
#   'employers',
#   'worried',
#   'government',
#   "'s",
#   'monetary',
#   'policies',
#   'high',
#   'real',
#   'interest',
#   'rates',
#   'hampering',
#   'investment',
#   'told',
#   'news',
#   'conference',
#   'wage',
#   'pacts',
#   'signed',
#   'far',
#   'year',
#   'endangering',
#   'government',
#   "'s",
#   'five',
#   'pct',
#   'inflation',
#   'target',
#   'government',
#   "'s",
#   'perceived',
#   'need',
#   'control',
#   'inflation',
#   'keeping',
#   'tight',
#   'rein',
#   'credit',
#   'unnecessary',
#   'said',
#   'high',
#   'real',
#   'interest',
#   'rates',
#   'attracting',
#   'influx',
#   'speculative',
#   'foreign',
#   'capital',
#   'undercutting',
#   'government',
#   "'s",
#   'target',
#   'monetary',
#   'growth',
#   'cuevas',
#   'said',
#   'spain',
#   "'s",
#   'closely-watched',
#   'measure',
#   'money',
#   'supply',
#   'liquid',
#   'assets',
#   'public',
#   'hands',
#   'grew',
#   'annualised',
#   'rate',
#   '17',
#   'pct',
#   'march',
#   '11.4',
#   'pct',
#   'december',
#   'last',
#   'year',
#   'target',
#   'range',
#   '6.5',
#   '9.5',
#   'pct',
#   '1987.',
#   'combat',
#   'bank',
#   'spain',
#   'raised',
#   'call',
#   'money',
#   'rate',
#   '14',
#   'times',
#   'far',
#   'year',
#   '14.5',
#   'pct',
#   'present',
#   '11.8',
#   'end-1986',
#   'cuevas',
#   'said',
#   'employers',
#   'heeding',
#   'government',
#   "'s",
#   'call',
#   'hold',
#   'wage',
#   'increases',
#   'five',
#   'pct',
#   'inflation',
#   'target',
#   'year',
#   'increases',
#   'salary',
#   'reviews',
#   'awarded',
#   'last',
#   'year',
#   'new',
#   'wage',
#   'pacts',
#   'averaging',
#   '5.6',
#   'pct',
#   'first',
#   'quarter',
#   '1987.',
#   'agreements',
#   'covered',
#   'less',
#   '40',
#   'pct',
#   'spanish',
#   'workers',
#   'cuevas',
#   'said',
#   'rest',
#   'still',
#   'wage',
#   'negotiations',
#   'said',
#   'spain',
#   "'s",
#   'current',
#   'wave',
#   'strikes',
#   'mainly',
#   'affected',
#   'state',
#   'sector',
#   'government',
#   'trying',
#   'impose',
#   'five',
#   'pct',
#   'wage',
#   'ceiling',
#   'cuevas',
#   'said',
#   'employers',
#   'also',
#   'worried',
#   'trend',
#   'spain',
#   "'s",
#   'foreign',
#   'trade',
#   'balance',
#   'trade',
#   'deficit',
#   'first',
#   'two',
# ...
#   'said',
#   'exceptionally',
#   'cold',
#   'weather',
#   'january',
#   'reduced',
#   'exports',
#   'month',
#   'element',
#   'catching',
#   'february',
#   'figures',
#   'seasonally',
#   'adjusted',
#   'volume',
#   'index',
#   'base',
#   '1980',
#   'guide',
#   'underlying',
#   'non-oil',
#   'trade',
#   'showed',
#   'exports',
#   'rising',
#   '131.0',
#   '114.6',
#   'january',
#   'imports',
#   'rising',
#   '142.2',
#   '136.5.',
#   'value',
#   'british',
#   'oil',
#   'exports',
#   'february',
#   'rose',
#   '751',
#   'mln',
#   'stg',
#   '723',
#   'mln',
#   'jnauary',
#   'oil',
#   'imports',
#   'rose',
#   '425',
#   'mln',
#   '352',
#   'mln'],
#  ['hong',
#   'kong',
#   'february',
#   'trade',
#   'swings',
#   'deficit',
#   'hong',
#   'kong',
#   'recorded',
#   '3.51',
#   'billion',
#   'h.k',
#   'dlr',
#   'deficit',
#   'february',
#   '2.54',
#   'billion',
#   'dlr',
#   'surplus',
#   'january',
#   'imports',
#   'climbed',
#   'exports',
#   'slid',
#   'census',
#   'statistics',
#   'department',
#   'said',
#   'deficit',
#   'compared',
#   'deficit',
#   '1.76',
#   'billion',
#   'dlrs',
#   'february',
#   '1986.',
#   'imports',
#   'rose',
#   '24.12',
#   'billion',
#   'dlrs',
#   '2.6',
#   'pct',
#   'january',
#   "'s",
#   '23.52',
#   'billion',
#   'dlrs',
#   '42',
#   'pct',
#   '16.98',
#   'billion',
#   'dlrs',
#   'recorded',
#   'february',
#   '1986.',
#   'total',
#   'exports',
#   'month',
#   'fell',
#   '20.9',
#   'pct',
#   '20.61',
#   'billion',
#   'dlrs',
#   '26.06',
#   'billion',
#   'january',
#   'february',
#   'exports',
#   'still',
#   '35.4',
#   'pct',
#   '15.22',
#   'billion',
#   'dlrs',
#   'recorded',
#   'month',
#   'last',
#   'year',
#   're-exports',
#   'territory',
#   "'s",
#   'traditional',
#   'entrepot',
#   'trade',
#   'outpaced',
#   'domestically',
#   'produced',
#   'exports',
#   'first',
#   'time',
#   'since',
#   'march',
#   '1985.',
#   're-exports',
#   'fell',
#   '11.6',
#   'pct',
#   '10.62',
#   'billion',
#   'dlrs',
#   '12.0',
#   'billion',
#   'dlrs',
#   'january',
#   '54',
#   'pct',
#   'february',
#   '1986',
#   "'s",
#   '6.88',
#   'billion',
#   'dlrs',
#   'domestic',
#   'exports',
#   'slid',
#   '28.9',
#   'pct',
#   '9.99',
#   'billion',
#   'dlrs',
#   'january',
#   "'s",
#   '14.05',
#   'billion',
#   'dlrs',
#   '19.7',
#   'pct',
#   '8.35',
#   'billion',
#   'dlrs',
#   'recorded',
#   'february',
#   '1986'],
#  ['british',
#   'politicians',
#   'urge',
#   'japan',
#   'trade',
#   'sanctions',
#   'one',
#   'hundred',
#   'members',
#   'britain',
#   "'s",
#   'ruling',
#   'conservative',
#   'party',
#   'signed',
#   'motion',
#   'calling',
#   'trade',
#   'sanctions',
#   'japan',
#   'force',
#   'tokyo',
#   'open',
#   'domestic',
#   'market',
#   'british',
#   'goods',
#   'government',
#   'announced',
#   'last',
#   'week',
#   'japan',
#   '5.9',
#   'billion',
#   'dlr',
#   'trade',
#   'surplus',
#   'britain',
#   '1986.',
#   'department',
#   'trade',
#   'industry',
#   'said',
#   'government',
#   'drawing',
#   'contingency',
#   'plans',
#   'force',
#   'japan',
#   'opening',
#   'domestic',
#   'markets',
#   'spokesman',
#   'said',
#   'moves',
#   'much',
#   'last',
#   'resort',
#   'ideas',
#   'considered',
#   'included',
#   'blocking',
#   'japanese',
#   'companies',
#   'trading',
#   'britain',
#   'revoking',
#   'licenses',
#   'japanese',
#   'operations',
#   'london',
#   'financial',
#   'district'],
#  ['u.k.',
#   'trade',
#   'figures',
#   'buoy',
#   'hopes',
#   'interest',
#   'rate',
#   'cut',
#   'release',
#   'u.k.',
#   'february',
#   'trade',
#   'data',
#   'showing',
#   'current',
#   'account',
#   'surplus',
#   'provisional',
#   '376',
#   'mln',
#   'stg',
#   '73',
#   'mln',
#   'surplus',
#   'january',
#   'boosted',
#   'hopes',
#   'early',
#   'cut',
#   'interest',
#   'rates',
#   'analysts',
#   'said',
#   'market',
#   'forecasts',
#   'worse',
#   'outcome',
#   'expectations',
#   'deficit',
#   'visible',
#   'trade',
#   'averaging',
#   '750',
#   'mln',
#   'stg',
#   'official',
#   'figure',
#   '224',
#   'mln',
#   'stg',
#   'sharply',
#   'narrower',
#   'january',
#   "'s",
#   '527',
#   'mln',
#   'deficit',
#   '``',
#   'figures',
#   'unreservedly',
#   'good',
#   "''",
#   'chase',
#   'manhattan',
#   'securities',
#   'economist',
#   'andrew',
#   'wroblewski',
#   'said',
#   'sterling',
#   'rebounded',
#   'trade',
#   'figures',
#   'reversing',
#   'weaker',
#   'morning',
#   'trend',
#   'stand',
#   '72.1',
#   'pct',
#   'trade',
#   'weighted',
#   'index',
#   'basket',
#   'currencies',
#   'midday',
#   'unchanged',
#   'yesterday',
#   "'s",
#   'close',
#   '0.3',
#   'points',
#   '1100',
#   'gmt',
#   'level',
#   'market',
#   'feared',
#   'deteriorating',
#   'non-oil',
#   'trade',
#   'pattern',
#   'would',
#   'undermine',
#   'international',
#   'support',
#   'sterling',
#   'motor',
#   'behind',
#   'recent',
#   'fall',
#   'u.k.',
#   'interest',
#   'rates',
#   'money',
#   'market',
#   'sources',
#   'said',
#   'market',
#   'begun',
#   'doubt',
#   'widely',
#   'expected',
#   'drop',
#   'bank',
#   'base',
#   'lending',
#   'rates',
#   '9.5',
#   'pct',
#   'present',
#   '10.0',
#   'pct',
#   'really',
#   'cards',
#   'sentiment',
#   'looks',
#   'turned',
#   'looks',
#   'danger',
#   'chancellor',
#   'exchequer',
#   'nigel',
#   'lawson',
#   "'s",
#   'forecast',
#   '1987',
#   'current',
#   'account',
#   'deficit',
#   '2.5',
#   'billion',
#   'stg',
#   'exceeded',
#   'said',
#   'wroblewski',
#   'seasonally',
#   'adjusted',
#   'figures',
#   'showed',
#   'imports',
#   'rose',
#   'february',
#   '7.16',
#   'billion',
#   'stg',
#   '6.73',
#   'billion',
#   'january',
#   'exports',
#   'rose',
#   'record',
#   '6.93',
#   'billion',
#   '6.20',
#   'billion',
#   'however',
#   'chris',
#   'tinker',
#   'u.k.',
#   'analyst',
#   'brokers',
#   'phillips',
#   'drew',
#   'said',
#   'faster',
#   'rise',
#   'exports',
#   'imports',
#   'would',
#   'prove',
#   'partly',
#   'aberrational',
#   'coming',
#   'months',
#   'forecast',
#   'chancellor',
#   "'s",
#   'budget',
#   'tax',
#   'cuts',
#   'would',
#   'increase',
#   'consumer',
#   'expediture',
#   'imported',
#   'goods',
#   'however',
#   'ian',
#   'harwood',
#   'economist',
#   'warburg',
#   'securities',
#   'said',
#   'firm',
#   'sharply',
#   'revising',
#   '1987',
#   'current',
#   'account',
#   'deficit',
#   'forecast',
#   'light',
#   'latest',
#   'data',
#   'cutting',
#   'one',
#   'billion',
#   'stg',
#   'expected',
#   'full',
#   'year',
#   'total',
#   '1.75',
#   'billion',
#   'stg',
#   'said',
#   'news',
#   'strong',
#   'growth',
#   'exports',
#   'non-oil',
#   'goods',
#   'confirmed',
#   'recent',
#   'bullish',
#   'surveys',
#   'among',
#   'members',
#   'confederation',
#   'british',
#   'industry',
#   'growth',
#   'imports',
#   'appears',
#   'flattening',
#   'even',
#   'january',
#   "'s",
#   'bad',
#   'weather',
#   'curbed',
#   'consumer',
#   'spending',
#   'overseas',
#   'goods',
#   'import-intensive',
#   'stock',
#   'building',
#   'among',
#   'manufactureres',
#   'harwood',
#   'said',
#   'u.k.',
#   'government',
#   'bonds',
#   'gilts',
#   'surged',
#   '1/2',
#   'point',
#   'better-than-expected',
#   'news',
#   'earlier',
#   'worries',
#   'figures',
#   'evaporated',
#   'sterling',
#   'peaked',
#   'high',
#   '1.6075',
#   'dlrs',
#   'settling',
#   'steady',
#   '1.6050',
#   'dlrs',
#   '1300',
#   'gmt',
#   'nearly',
#   'cent',
#   'higher',
#   'european',
#   'low',
#   '1.5960.',
#   'however',
#   'analysts',
#   'noted',
#   'turnabout',
#   'market',
#   'sentiment',
#   'still',
#   'looks',
#   'highly',
#   'vulnerable',
#   'political',
#   'news',
#   'morning',
#   'weakness',
#   'sterling',
#   'gilt',
#   'market',
#   'largely',
#   'attributed',
#   'newspaper',
#   'opinion',
#   'poll',
#   'showing',
#   'conservative',
#   'government',
#   "'s",
#   'support',
#   'slipping',
#   'marplan',
#   'poll',
#   'published',
#   '``',
#   'today',
#   "''",
#   'showed',
#   'conservative',
#   'support',
#   'fallen',
#   '36',
#   'pct',
#   '38',
#   'pct',
#   'last',
#   'month',
#   'alliance',
#   'liberals',
#   'social',
#   'democrats',
#   'rallied',
#   '31',
#   'pct',
#   '21',
#   'pct',
#   'run',
#   'neck',
#   'neck',
#   'labour',
#   'party',
#   'whose',
#   'support',
#   'fell',
#   '38',
#   'pct',
#   'poll',
#   'taken',
#   'budget',
#   'greeted',
#   'enthusiastically',
#   'financial',
#   'markets',
#   'seems',
#   'left',
#   'voters',
#   'indifferent',
#   'political',
#   'observers',
#   'said',
#   'another',
#   'regular',
#   'poll',
#   'due',
#   'tomorrow',
#   'eonomists',
#   'warn',
#   'today',
#   "'s",
#   'improved',
#   'sentiment',
#   'could',
#   'dented',
#   'support',
#   'prime',
#   'minister',
#   'margaret',
#   'thatcher',
#   'slips',
#   'upsetting',
#   'markets',
#   'political',
#   'perceptions',
#   'discounting',
#   'conservative',
#   'victory',
#   'upcoming',
#   'general',
#   'election',
#   'made',
#   'sensitive',
#   'trade',
#   'data',
#   'harwood',
#   'said',
#   '``',
#   'news',
#   'come',
#   'substantial',
#   'relief',
#   "''",
#   'said',
#   'however',
#   'interest',
#   'rate',
#   'front',
#   'economists',
#   'caution',
#   'lawson',
#   'might',
#   'wary',
#   'leaving',
#   'sterling',
#   'vulnerable',
#   'encouraging',
#   'another',
#   'base',
#   'rate',
#   'fall',
#   'noted',
#   'lawson',
#   'already',
#   'got',
#   'inflation-reducing',
#   'cut',
#   'mortgage',
#   'rates',
#   'response',
#   'lower',
#   'base',
#   'rates',
#   'domestic',
#   'political',
#   'reasons',
#   'lower',
#   'rates',
#   'curtailed'],
#  ['s.',
#   'korea',
#   'may',
#   'buy',
#   'u.s.',
#   'oil',
#   'aid',
#   'trade',
#   'balance',
#   'south',
#   'korea',
#   'studying',
#   'plan',
#   'buy',
#   'coal',
#   'united',
#   'states',
#   'start',
#   'importing',
#   'alaskan',
#   'crude',
#   'oil',
#   'help',
#   'reduce',
#   'huge',
#   'trade',
#   'surplus',
#   'united',
#   'states',
#   'energy',
#   'ministry',
#   'officials',
#   'said',
#   'today',
#   'said',
#   'plan',
#   'would',
#   'dominate',
#   'discussions',
#   'two-day',
#   'energy',
#   'talks',
#   'officials',
#   'two',
#   'countries',
#   'washington',
#   'april',
#   '1.',
#   'huh',
#   'sun-yong',
#   'attend',
#   'talks',
#   'three',
#   'seoul',
#   'government',
#   'officials',
#   'told',
#   'reuters',
#   'seoul',
#   '``',
#   'positively',
#   'considering',
#   'buying',
#   'certain',
#   'amount',
#   'alaskan',
#   'oil',
#   'beginning',
#   'year',
#   'part',
#   'government',
#   "'s",
#   'overall',
#   'plan',
#   'reduce',
#   'widening',
#   'trade',
#   'gap',
#   'two',
#   'countries',
#   "''",
#   'huh',
#   'said',
#   'however',
#   'south',
#   'korean',
#   'refineries',
#   'considered',
#   'alaskan',
#   'oil',
#   'economically',
#   'uncompetitive'],
#  ['u.s',
#   'treasury',
#   "'s",
#   'mulford',
#   'reaffirms',
#   'g-6',
#   'agreement',
#   'treasury',
#   'assistant',
#   'secretary',
#   'david',
#   'mulford',
#   'reaffirmed',
#   'u.s.',
#   'backing',
#   'paris',
#   'agreement',
#   'among',
#   'six',
#   'industrial',
#   'nations',
#   'cooperate',
#   'closely',
#   'foster',
#   'exchange',
#   'rate',
#   'stability',
#   'around',
#   'current',
#   'levels',
#   'testimony',
#   'prepared',
#   'delivery',
#   'senate',
#   'banking',
#   'subcommittee',
#   'mulford',
#   'said',
#   'broad',
#   'recognition',
#   'paris',
#   '``',
#   'substantial',
#   'exchange',
#   'rate',
#   'shifts',
#   'could',
#   'damage',
#   'growth',
#   'adjustment',
#   'prospects',
#   "''",
#   'also',
#   'said',
#   'clear',
#   'understandings',
#   'among',
#   'countries',
#   'regarding',
#   'cooperation',
#   '``',
#   'refrained',
#   'establishing',
#   'system',
#   'target',
#   'zones',
#   'ranges',
#   "''",
#   'mulford',
#   'also',
#   'said',
#   'six',
#   'nations',
#   'spelled',
#   'way',
#   'intend',
#   'deal',
#   'possible',
#   'market',
#   'developments',
#   'said',
#   'governments',
#   'must',
#   'retain',
#   'flexibility',
#   'dealing',
#   'exchange',
#   'market',
#   'pressures',
#   'efforts',
#   'establish',
#   'rigid',
#   'exchange',
#   'rate',
#   'objectives',
#   '``',
#   'specify',
#   'precisely',
#   'goals',
#   'intervention',
#   "''",
#   'would',
#   'hurt',
#   'official',
#   'attempts',
#   'react',
#   'market',
#   'pressures',
#   'said',
#   'accordingly',
#   'mulford',
#   'said',
#   'setting',
#   'specific',
#   'currency',
#   'objectives',
#   'intervention',
#   'achieve',
#   'objectives',
#   'would',
#   'counterproductive',
#   'commenting',
#   'trade',
#   'deficit',
#   'mulford',
#   'reiterated',
#   'treasury',
#   'position',
#   'current',
#   'account',
#   'deficit',
#   'decline',
#   '148',
#   'billion',
#   'dlrs',
#   'last',
#   'year',
#   'around',
#   '130',
#   'billion',
#   'dlrs',
#   'year',
#   'due',
#   'exchange',
#   'rate',
#   'adjustments',
#   'past',
#   '18',
#   'months',
#   'added',
#   'trade',
#   'imbalances',
#   'would',
#   'also',
#   'corrected',
#   'commitments',
#   'west',
#   'germany',
#   'japan',
#   'stimulate',
#   'economies',
#   'u.s.',
#   'efforts',
#   'cut',
#   'budget',
#   'deficit',
#   'enhance',
#   'u.s.',
#   'competitiveness',
#   'also',
#   'said',
#   'newly',
#   'industrialized',
#   'countries',
#   'let',
#   'currencies',
#   'appreciate'],
#  ['keating',
#   'revises',
#   'australian',
#   'growth',
#   'forecast',
#   'treasurer',
#   'paul',
#   'keating',
#   'forecast',
#   'economic',
#   'growth',
#   'slightly',
#   'two',
#   'pct',
#   'financial',
#   'year',
#   'ending',
#   'june',
#   'year',
#   '2.25',
#   'pct',
#   'forecast',
#   'contained',
#   '1986/87',
#   'budget',
#   'delivered',
#   'last',
#   'august',
#   'australia',
#   "'s",
#   'terms',
#   'trade',
#   'also',
#   'fell',
#   '18',
#   'pct',
#   'past',
#   'two',
#   'years',
#   'told',
#   'parliament',
#   'terms',
#   'trade',
#   'difference',
#   'import',
#   'export',
#   'price',
#   'indexes',
#   'despite',
#   'figures',
#   'budget',
#   'forecast',
#   '1.75',
#   'pct',
#   'annual',
#   'growth',
#   'employment',
#   'would',
#   'met',
#   'keating',
#   'said',
#   'unemployment',
#   'currently',
#   '8.2',
#   'pct',
#   'workforce',
#   '``',
#   'government',
#   'dragging',
#   'australia',
#   'trading',
#   'holocaust',
#   'kind',
#   'seen',
#   'since',
#   'second',
#   'world',
#   'war',
#   "''",
#   'keating',
#   'said',
#   '``',
#   'pushing',
#   'place',
#   'recession',
#   'holding',
#   'gains',
#   'unemployment',
#   'bringing',
#   'unemployment',
#   "''",
#   'said',
#   'adding',
#   'government',
#   'help',
#   'country',
#   'avoid',
#   'recession'],
#  ['u.s.',
#   'asks',
#   'japan',
#   'end',
#   'agriculture',
#   'import',
#   'controls',
#   'u.s.',
#   'wants',
#   'japan',
#   'eliminate',
#   'import',
#   'controls',
#   'agricultural',
#   'products',
#   'within',
#   'three',
#   'years',
#   'visiting',
#   'u.s.',
#   'under-secretary',
#   'state',
#   'economic',
#   'affairs',
#   'allen',
#   'wallis',
#   'told',
#   'eishiro',
#   'saito',
#   'chairman',
#   'federation',
#   'economic',
#   'organisations',
#   'keidanren',
#   'spokesman',
#   'keidanren',
#   'said',
#   'spokesman',
#   'quoted',
#   'wallis',
#   'saying',
#   'drastic',
#   'measures',
#   'would',
#   'needed',
#   'stave',
#   'protectionist',
#   'legislation',
#   'congress',
#   'wallis',
#   'attending',
#   'sub-cabinet-level',
#   'bilateral',
#   'trade',
#   'meeting',
#   'made',
#   'remark',
#   'yesterday',
#   'talks',
#   'saito',
#   'wallis',
#   'quoted',
#   'saying',
#   'reagan',
#   'administration',
#   'wants',
#   'japanese',
#   'cooperation',
#   'white',
#   'house',
#   'ensure',
#   'u.s.',
#   'trade',
#   'bill',
#   'moderate',
#   'one',
#   'rather',
#   'containing',
#   'retaliatory',
#   'measures',
#   'antagonising',
#   'particular',
#   'country',
#   'also',
#   'quoted',
#   'saying',
#   'u.s.',
#   'would',
#   'pleased',
#   'japan',
#   'halve',
#   'restrictions',
#   'agricultural',
#   'imports',
#   'within',
#   'five',
#   'years',
#   'country',
#   'cope',
#   'abolition',
#   'within',
#   'three',
#   'spokesman',
#   'said',
#   'japan',
#   'currently',
#   'restricts',
#   'imports',
#   '22',
#   'agricultural',
#   'products',
#   'ban',
#   'rice',
#   'imports',
#   'triggered',
#   'recent',
#   'u.s.',
#   'complaints',
#   'japan',
#   "'s",
#   'agricultural',
#   'policy'],
#  ['mulford',
#   'says',
#   'germany',
#   'japan',
#   'treasury',
#   'assistant',
#   'secretary',
#   'david',
#   'mulford',
#   'said',
#   'believe',
#   'west',
#   'germany',
#   'japan',
#   'yet',
#   'carried',
#   'international',
#   'responsibilities',
#   '``',
#   'believe',
#   'time',
#   "''",
#   'mulford',
#   'told',
#   'senate',
#   'banking',
#   'subcommittee',
#   'said',
#   'u.s.',
#   'trade',
#   'deficit',
#   'continue',
#   'improving',
#   'next',
#   'two',
#   'years',
#   '``',
#   'need',
#   'policy',
#   'actions',
#   "''",
#   'across',
#   'entire',
#   'front',
#   'u.s.',
#   'trade',
#   'relations',
#   'including',
#   'canada',
#   'newly-industrialized',
#   'countries',
#   'nics',
#   'particular',
#   'said',
#   'efforts',
#   'south',
#   'korea',
#   'taiwan',
#   'strengthen',
#   'currencies',
#   'still',
#   'disappointing',
#   'mulford',
#   'also',
#   'said',
#   'oecd',
#   'nations',
#   'need',
#   'grow',
#   'average',
#   'three',
#   'pct',
#   'help',
#   'resolve',
#   'international',
#   'debt',
#   'crisis',
#   'noted',
#   'japanese',
#   'european',
#   'imports',
#   'latin',
#   'nations',
#   'significantly',
#   'smaller',
#   'imports',
#   'u.s.',
#   'stressed',
#   'germany',
#   'japan',
#   'must',
#   'continue',
#   'take',
#   'economic',
#   'structural',
#   'measures',
#   'ensure',
#   'stronger',
#   'sustained',
#   'economic',
#   'growth']]

# %%
len(preprocessed_docs)
# Out:
# 485

# %%
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(preprocessed_docs)))
print(vocab)
# Out:
# ['noted', 'jurisdiction', 'suffers', 'positions', 'engine', 'although', 'anita', '202', 'plunging', 'affected', 'attend', 'accounted', 'philippine', 'set', 'instructed', 'verging', '9.58', 'wartenberg', '220', 'allies', 'realized', '9', 'quarters', 'helmut', 'round', 'uniform', 'counsellor', 'intervene', 'potent', 'impeded', '1.132', 'illinois', 'disagreements', 'voyage', 'inflation-reducing', 'harmonious', '130.9', 'presented', '14.5', 'giving', 'cap', 'shipowners', 'concerns', 'cancer', 'barrier', 'bear', 'slowness', 'wonnacott', '26.7', 'compare', '37-38', 'stressed', 'pound', 'gatt-approved', 'adequately', '10.2', 'steve', 'clayton', 'gems', 'mid-february', 'communism', '209.4', 'one-fifth', 'fiscal', 'cause', 'pressuring', 'accusations', 'squeeze', '24', 'spanish', 'narrower', 'brothers', 'vengeance', 'democrat-controlled', 'tripled', 'burdens', 'embassy', 'mcgroarty', 'moneyline', 'emergency', 'displaced', 'scant', 'dampen', '156', '7.69', 'cuurent', 'sumatran', 'sentiment', 'errors', 'approves', '324', 'sword', 'molasses', 'canada/u.s', 'signaled', 'imply', 'misunderstanding', 'expectations.', 'asbestos', 'brink', 'stimulated', '146.50', 'poehl', 'tanzania', 'apply', 'subsidized', '30', 're-exports', 'r-miss', 'cargoes', 'aerospace', 'trade', 'brightened', 'demonstrated', 'lowered', 'incompatible', 'engering', 'militarily', 'standards', 'harmony', 'temporary', 'assigns', '3.23', 'fails', 'ingrained', 'bargaining', '65.1', 'greatly', 'nesi.t', 'regarding', 'post-detente', 'thomas', 'postpone', '629.7', 'add', 'formally', 'wendt', 'rei', 'swiss', 'inward', 'hailed', 'perspective', 'kirkland', 'occurred', 'quietly', 'montero', '36.28', 'taught', 'forego', 'move', 'peak', 'rica', 'multitude', '118.6', '7.857', 'tantamount', '133', 'manager', 'haq', '1.33', '203', '410', '1986.', 'criticising', 'paul', 'exports', 'boosts', '100.75', '23-1', 'embargoes', 'gakuen', 'bfg', 'unrealistic', '34', 'belgian', 'amazing', 'education', '169.03', 'exception', 'reacting', 'bringing', 'membership', 'release', 'commodities', 'sight', 'jenkins', 'iran', 'probably', 'breaks', 'status', 'heading', 'minoru', 'morocco', 'generous', 'conclusion', 'non-oil', 'travelled', 'purchased', 'prominence', 'mpt', 'promotional', 'minsiter', 'insuring', 'bold', 'pryor', '368', 'moment', 'necessary', 'figure', 'hamind', 'dicuss', 'withhold', 'confirm', 'forms', 'motion', 'actively', 'elements', 'unilateral', 'waived', 'paemen', '436', 'plantings', 'broadly', '50-odd', 'hand', 'departnment', 'financial', 'discouragement', '5', 'doors', 'wants', 'complained', 'unsettled', 'japan/u.s', 'possibly', 'profit-taking', 'usx', 'questionable', 'pigmeat', 'itc', '32.11', '40th', 'profound', 'couple', 'disclosed', 'reacted', '110', '2.1', '1.12', 'short-covering', 'ecuador', 'reduced', 'become', 'protectionist', '135', 'dams', 'arifin', 'peru', 'processors', 'expected', 'collective', 'motors', 'staff', 'distributors', 'question', 'denominated', 'earthquake', '196.27', 'guaranty', 'anz', 'mid-may', 'emirates', 'mulford', '6.95', 'suggestions', 'exceeding', 'insurance', '962,360', 'borrowing', 'revisions', 'undermining', 'predatory', 'upper', 'samuels', 'meant', 'hint', 'pickup', 'normally', 'government-run', 'voluntarily', 'measured', 'actual', 'disappointing', '7.7', 'likewise', 'raps', 'acid', 'modified', 'zealand', 'wordwide', 'finding', 'feels', 'nigerian', '18.1', 'suspicion', 'envisaged', 'undercut', 'foreseeable', 'thoroughly', 'rose', 'waning', 'circumstances', '225,000', 'giant', 'nonsensical', 'extend', 'circle', 'faces', 'amendments', 'feedgrain', 'aware', 'kim', 'investigate', '14.65', 'eligible', 'clouded', 'spokesman', 'overproduction', 'showing', 'chance', 'mexico', '17.48', 'puts', 'stein', '15,000', 'coordination', 'minimise', 'schemes', 'spain', 'heavily', 'role', 'categories', 'establishment', 'indiana', 'two', 'intervention', 'gives', 'worldwide', '34.38', '4.68', 'siregar', 'harmonized', 'noboru', 'tran', 'latin', '6-8', 'maintaining', '4.11', '1982. ...

# %%
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'noted': 0, 'jurisdiction': 1, 'suffers': 2, 'positions': 3, 'engine': 4, 'although': 5, 'anita': 6, '202': 7, 'plunging': 8, 'affected': 9, 'attend': 10, 'accounted': 11, 'philippine': 12, 'set': 13, 'instructed': 14, 'verging': 15, '9.58': 16, 'wartenberg': 17, '220': 18, 'allies': 19, 'realized': 20, '9': 21, 'quarters': 22, 'helmut': 23, 'round': 24, 'uniform': 25, 'counsellor': 26, 'intervene': 27, 'potent': 28, 'impeded': 29, '1.132': 30, 'illinois': 31, 'disagreements': 32, 'voyage': 33, 'inflation-reducing': 34, 'harmonious': 35, '130.9': 36, 'presented': 37, '14.5': 38, 'giving': 39, 'cap': 40, 'shipowners': 41, 'concerns': 42, 'cancer': 43, 'barrier': 44, 'bear': 45, 'slowness': 46, 'wonnacott': 47, '26.7': 48, 'compare': 49, '37-38': 50, 'stressed': 51, 'pound': 52, 'gatt-approved': 53, 'adequately': 54, '10.2': 55, 'steve': 56, 'clayton': 57, 'gems': 58, 'mid-february': 59, 'communism': 60, '209.4': 61, 'one-fifth': 62, 'fiscal': 63, 'cause': 64, 'pressuring': 65, 'accusations': 66, 'squeeze': 67, '24': 68, 'spanish': 69, 'narrower': 70, 'brothers': 71, 'vengeance': 72, 'democrat-controlled': 73, 'tripled': 74, 'burdens': 75, 'embassy': 76, 'mcgroarty': 77, 'moneyline': 78, 'emergency': 79, 'displaced': 80, 'scant': 81, 'dampen': 82, '156': 83, '7.69': 84, 'cuurent': 85, 'sumatran': 86, 'sentiment': 87, 'errors': 88, 'approves': 89, '324': 90, 'sword': 91, 'molasses': 92, 'canada/u.s': 93, 'signaled': 94, 'imply': 95, 'misunderstanding': 96, 'expectations.': 97, 'asbestos': 98, 'brink': 99, 'stimulated': 100, '146.50': 101, 'poehl': 102, 'tanzania': 103, 'apply': 104, 'subsidized': 105, '30': 106, 're-exports': 107, 'r-miss': 108, 'cargoes': 109, 'aerospace': 110, 'trade': 111, 'brightened': 112, 'demonstrated': 113, 'lowered': 114, 'incompatible': 115, 'engering': 116, 'militarily': 117, 'standards': 118, 'harmony': 119, 'temporary': 120, 'assigns': 121, '3.23': 122, 'fails': 123, 'ingrained': 124, 'bargaining': 125, '65.1': 126, 'greatly': 127, 'nesi.t': 128, 'regarding': 129, 'post-detente': 130, 'thomas': 131, 'postpone': 132, '629.7': 133, 'add': 134, 'formally': 135, 'wendt': 136, 'rei': 137, 'swiss': 138, 'inward': 139, 'hailed': 140, 'perspective': 141, 'kirkland': 142, 'occurred': 143, 'quietly': 144, 'montero': 145, '36.28': 146, 'taught': 147, 'forego': 148, 'move': 149, 'peak': 150, 'rica': 151, 'multitude': 152, '118.6': 153, '7.857': 154, 'tantamount': 155, '133': 156, 'manager': 157, 'haq': 158, '1.33': 159, '203': 160, '410': 161, '1986.': 162, 'criticising': 163, 'paul': 164, 'exports': 165, 'boosts': 166, '100.75': 167, '23-1': 168, 'embargoes': 169, 'gakuen': 170, 'bfg': 171, 'unrealistic': 172, '34': 173, 'belgian': 174, 'amazing': 175, 'education': 176, '169.03': 177, 'exception': 178, 'reacting': 179, 'bringing': 180, 'membership': 181, 'release': 182, 'commodities': 183, 'sight': 184, 'jenkins': 185, 'iran': 186, 'probably': 187, 'breaks': 188, 'status': 189, 'heading': 190, 'minoru': 191, 'morocco': 192, 'generous': 193, 'conclusion': 194, 'non-oil': 195, 'travelled': 196, 'purchased': 197, 'prominence': 198, 'mpt': 199, 'promotional': 200, 'minsiter': 201, 'insuring': 202, 'bold': 203, 'pryor': 204, '368': 205, 'moment': 206, 'necessary': 207, 'figure': 208, 'hamind': 209, 'dicuss': 210, 'withhold': 211, 'confirm': 212, 'forms': 213, 'motion': 214, 'actively': 215, 'elements': 216, 'unilateral': 217, 'waived': 218, 'paemen': 219, '436': 220, 'plantings': 221, 'broadly': 222, '50-odd': 223, 'hand': 224, 'departnment': 225, 'financial': 226, 'discouragement': 227, '5': 228, 'doors': 229, 'wants': 230, 'complained': 231, 'unsettled': 232, 'japan/u.s': 233, 'possibly': 234, 'profit-taking': 235, 'usx': 236, 'questionable': 237, 'pigmeat': 238, 'itc': 239, '32.11': 240, '40th': 241, 'profound': 242, 'couple': 243, 'disclosed': 244, 'reacted': 245, '110': 246, '2.1': 247, '1.12': 248, 'short-covering': 249, 'ecuador': 250, 'reduced': 251, 'become': 252, 'protectionist': 253, '135': 254, 'dams':  ...

# %%
index2word = {v:k for k, v in word2index.items()} 
print(index2word)
# Out:
# {0: 'noted', 1: 'jurisdiction', 2: 'suffers', 3: 'positions', 4: 'engine', 5: 'although', 6: 'anita', 7: '202', 8: 'plunging', 9: 'affected', 10: 'attend', 11: 'accounted', 12: 'philippine', 13: 'set', 14: 'instructed', 15: 'verging', 16: '9.58', 17: 'wartenberg', 18: '220', 19: 'allies', 20: 'realized', 21: '9', 22: 'quarters', 23: 'helmut', 24: 'round', 25: 'uniform', 26: 'counsellor', 27: 'intervene', 28: 'potent', 29: 'impeded', 30: '1.132', 31: 'illinois', 32: 'disagreements', 33: 'voyage', 34: 'inflation-reducing', 35: 'harmonious', 36: '130.9', 37: 'presented', 38: '14.5', 39: 'giving', 40: 'cap', 41: 'shipowners', 42: 'concerns', 43: 'cancer', 44: 'barrier', 45: 'bear', 46: 'slowness', 47: 'wonnacott', 48: '26.7', 49: 'compare', 50: '37-38', 51: 'stressed', 52: 'pound', 53: 'gatt-approved', 54: 'adequately', 55: '10.2', 56: 'steve', 57: 'clayton', 58: 'gems', 59: 'mid-february', 60: 'communism', 61: '209.4', 62: 'one-fifth', 63: 'fiscal', 64: 'cause', 65: 'pressuring', 66: 'accusations', 67: 'squeeze', 68: '24', 69: 'spanish', 70: 'narrower', 71: 'brothers', 72: 'vengeance', 73: 'democrat-controlled', 74: 'tripled', 75: 'burdens', 76: 'embassy', 77: 'mcgroarty', 78: 'moneyline', 79: 'emergency', 80: 'displaced', 81: 'scant', 82: 'dampen', 83: '156', 84: '7.69', 85: 'cuurent', 86: 'sumatran', 87: 'sentiment', 88: 'errors', 89: 'approves', 90: '324', 91: 'sword', 92: 'molasses', 93: 'canada/u.s', 94: 'signaled', 95: 'imply', 96: 'misunderstanding', 97: 'expectations.', 98: 'asbestos', 99: 'brink', 100: 'stimulated', 101: '146.50', 102: 'poehl', 103: 'tanzania', 104: 'apply', 105: 'subsidized', 106: '30', 107: 're-exports', 108: 'r-miss', 109: 'cargoes', 110: 'aerospace', 111: 'trade', 112: 'brightened', 113: 'demonstrated', 114: 'lowered', 115: 'incompatible', 116: 'engering', 117: 'militarily', 118: 'standards', 119: 'harmony', 120: 'temporary', 121: 'assigns', 122: '3.23', 123: 'fails', 124: 'ingrained', 125: 'bargaining', 126: '65.1', 127: 'greatly', 128: 'nesi.t', 129: 'regarding', 130: 'post-detente', 131: 'thomas', 132: 'postpone', 133: '629.7', 134: 'add', 135: 'formally', 136: 'wendt', 137: 'rei', 138: 'swiss', 139: 'inward', 140: 'hailed', 141: 'perspective', 142: 'kirkland', 143: 'occurred', 144: 'quietly', 145: 'montero', 146: '36.28', 147: 'taught', 148: 'forego', 149: 'move', 150: 'peak', 151: 'rica', 152: 'multitude', 153: '118.6', 154: '7.857', 155: 'tantamount', 156: '133', 157: 'manager', 158: 'haq', 159: '1.33', 160: '203', 161: '410', 162: '1986.', 163: 'criticising', 164: 'paul', 165: 'exports', 166: 'boosts', 167: '100.75', 168: '23-1', 169: 'embargoes', 170: 'gakuen', 171: 'bfg', 172: 'unrealistic', 173: '34', 174: 'belgian', 175: 'amazing', 176: 'education', 177: '169.03', 178: 'exception', 179: 'reacting', 180: 'bringing', 181: 'membership', 182: 'release', 183: 'commodities', 184: 'sight', 185: 'jenkins', 186: 'iran', 187: 'probably', 188: 'breaks', 189: 'status', 190: 'heading', 191: 'minoru', 192: 'morocco', 193: 'generous', 194: 'conclusion', 195: 'non-oil', 196: 'travelled', 197: 'purchased', 198: 'prominence', 199: 'mpt', 200: 'promotional', 201: 'minsiter', 202: 'insuring', 203: 'bold', 204: 'pryor', 205: '368', 206: 'moment', 207: 'necessary', 208: 'figure', 209: 'hamind', 210: 'dicuss', 211: 'withhold', 212: 'confirm', 213: 'forms', 214: 'motion', 215: 'actively', 216: 'elements', 217: 'unilateral', 218: 'waived', 219: 'paemen', 220: '436', 221: 'plantings', 222: 'broadly', 223: '50-odd', 224: 'hand', 225: 'departnment', 226: 'financial', 227: 'discouragement', 228: '5', 229: 'doors', 230: 'wants', 231: 'complained', 232: 'unsettled', 233: 'japan/u.s', 234: 'possibly', 235: 'profit-taking', 236: 'usx', 237: 'questionable', 238: 'pigmeat', 239: 'itc', 240: '32.11', 241: '40th', 242: 'profound', 243: 'couple', 244: 'disclosed', 245: 'reacted', 246: '110', 247: '2.1', 248: '1.12', 249: 'short-covering', 250: 'ecuador', 251: 'reduced', 252: 'become', 253: 'protectionist', 254: '135', 255: 'da ...

# %%
voc_size = len(vocab)
print(voc_size)
# Out:
# 8163

# %% [markdown]
# ## Define Helper Functions

# %%
import numpy as np
from scipy import spatial
from scipy.stats import spearmanr


def cos_sim(a, b):
    return 1 - spatial.distance.cosine(
        a, b
    )  # distance = 1 - similarlity, because scipy only gives distance


def load_specific_categories(file_path, semantic_category, syntactic_category):
    semantic = []
    syntactic = []
    current_group = None

    with open(file_path, "r") as f:
        for line in f:
            if line.startswith(":"):
                if semantic_category in line.lower():
                    current_group = semantic
                elif syntactic_category in line.lower():
                    current_group = syntactic
                else:
                    current_group = None
            elif current_group is not None:
                words = line.strip().split()
                if len(words) == 4:
                    current_group.append(words)

    return semantic, syntactic


def find_closest_word(vec, embeddings, exclude_ids):
    max_similarity = -float("inf")
    best_idx = -1

    for idx, emb in enumerate(embeddings):
        if idx in exclude_ids:
            continue
        similarity = cos_sim(vec, emb)
        if similarity > max_similarity:
            max_similarity = similarity
            best_idx = idx

    return best_idx


def evaluate_analogies(analogy_data, word_to_idx, embeddings):
    correct = 0
    total = 0

    for word1, word2, word3, word4 in analogy_data:
        if all(word in word_to_idx for word in [word1, word2, word3, word4]):
            idx1 = word_to_idx[word1]
            idx2 = word_to_idx[word2]
            idx3 = word_to_idx[word3]
            idx4 = word_to_idx[word4]

            vec = embeddings[idx2] - embeddings[idx1] + embeddings[idx3]
            predicted_idx = find_closest_word(vec, embeddings, {idx1, idx2, idx3})
            if predicted_idx == idx4:
                correct += 1
            total += 1

    return correct / total if total > 0 else 0


def get_query_vector(query_word, model, word2index):
    if query_word not in word2index:
        raise ValueError(f"Word '{query_word}' not in vocabulary.")

    word_idx = word2index[query_word]
    query_vector = model.embedding_v.weight[word_idx].data.cpu().numpy()
    return query_vector


def get_corpus_vectors(model):
    return model.embedding_v.weight.data.cpu().numpy()


def compute_top_k_dot_product(query_vector, corpus_vectors, k=10):
    # get dot product between the query and all corpus vectors
    dot_products = np.dot(corpus_vectors, query_vector)

    # get the top k indices and scores
    top_k_indices = np.argsort(dot_products)[-k:][::-1]
    top_k_scores = dot_products[top_k_indices]

    return top_k_indices.tolist(), top_k_scores.tolist()


def load_wordsim353(file_path):
    word_pairs = []
    human_scores = []

    with open(file_path, "r") as f:
        next(f)
        for line in f:
            word1, word2, score = line.strip().split()
            word_pairs.append((word1, word2))
            human_scores.append(float(score))

    return word_pairs, human_scores


def calculate_model_similarity(word_pairs, model, word_to_idx):
    model_scores = []
    embeddings = model.embedding_v.weight.data.cpu().numpy()

    for word1, word2 in word_pairs:
        if word1 in word_to_idx and word2 in word_to_idx:
            idx1 = word_to_idx[word1]
            idx2 = word_to_idx[word2]
            dot_product = np.dot(embeddings[idx1], embeddings[idx2])
            model_scores.append(dot_product)
        else:
            model_scores.append(None)  # Handle OOV (out-of-vocabulary) words
    return model_scores


def compute_spearman_correlation(human_scores, model_scores):
    valid_scores = [(h, m) for h, m in zip(human_scores, model_scores) if m is not None]
    filtered_human_scores, filtered_model_scores = zip(*valid_scores)

    correlation, _ = spearmanr(filtered_human_scores, filtered_model_scores)
    return correlation

def compute_mse(human_scores, model_scores):
    #remove null values from model_scores
    valid_scores = [(h, m) for h, m in zip(human_scores, model_scores) if m is not None]
    filtered_human_scores, filtered_model_scores = zip(*valid_scores)

    mse = np.mean((np.array(filtered_model_scores) - np.array(filtered_human_scores)) ** 2)
    return mse

def compute_average_human_score(human_scores):
    return sum(human_scores) / len(human_scores)

# %%
dataset_path = 'word-analogies.txt'
semantic_category = 'capital-common-countries'
syntactic_category = 'past-tense'
semantic, syntactic = load_specific_categories(dataset_path, semantic_category, syntactic_category)
embedding_size = 2

# %% [markdown]
# ## Word2Vec (Skipgram)

# %%
from torch import nn

class Skipgram(nn.Module):
    def __init__(self, vocab_size, emb_size):
        super().__init__()
        self.embedding_v = nn.Embedding(vocab_size, emb_size)
        self.embedding_u = nn.Embedding(vocab_size, emb_size)


    def forward(self, center_words, target_words, all_vocabs):
        center_embeds = self.embedding_v(center_words)  # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words)  # [batch_size, window_size, emb_size]
        all_embeds = self.embedding_u(all_vocabs)  # [batch_size, voc_size, emb_size]

        # [batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, window_size]
        scores = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)

        # [batch_size, voc_size, emb_size] @ [batch_size, emb_size, 1] = [batch_size, voc_size, 1] = [batch_size, voc_size]
        norm_scores = all_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)

        # scalar (loss must be scalar)
        nll = -torch.mean(
            torch.log(
                torch.exp(scores) / torch.sum(torch.exp(norm_scores), 1).unsqueeze(1)
            )
        )

        return nll  # negative log likelihood

# %%
word2vec_skipgram = Skipgram(vocab_size=voc_size, emb_size=embedding_size)
word2vec_skipgram.load_state_dict(torch.load('models/word2vec_skipgram.pth'))
word2vec_skipgram.to(device)
word2vec_skipgram.eval()
print("Model loaded successfully.")
# Out:
# C:\Users\neucl\AppData\Local\Temp\ipykernel_14968\2073443929.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   word2vec_skipgram.load_state_dict(torch.load('models/word2vec_skipgram.pth'))
# Model loaded successfully.

# %% [markdown]
# ### syntactic and semantic accuracy Word2Vec(Skipgram)

# %%
embeddings_word2vec_skipgram = word2vec_skipgram.embedding_v.weight.data.cpu().numpy()
semantic_accuracy_word2vec_skipgram = evaluate_analogies(semantic, word2index, embeddings_word2vec_skipgram)
syntactic_accuracy_word2vec_skipgram = evaluate_analogies(syntactic, word2index, embeddings_word2vec_skipgram)
print(f'semantic_accuracy_word2vec_skipgram: {semantic_accuracy_word2vec_skipgram}')
print(f'syntactic_accuracy_word2vec_skipgram: {syntactic_accuracy_word2vec_skipgram}')
# Out:
# semantic_accuracy_word2vec_skipgram: 0
# syntactic_accuracy_word2vec_skipgram: 0.0

# %% [markdown]
# ### correlation between the models’ dot product and the provided similarity metrics Word2Vec(Skipgram)

# %%
word_pairs, human_scores = load_wordsim353('wordsim353/wordsim_similarity_goldstandard.txt')
model_scores = calculate_model_similarity(word_pairs, word2vec_skipgram, word2index)
correlation = compute_spearman_correlation(human_scores, model_scores)
print(f"Word2Vec(Skipgram) spearman correlation: {correlation:.4f}")
# Out:
# Word2Vec(Skipgram) spearman correlation: -0.0982

# %% [markdown]
# The model barely ranks word pairs in the exact opposite order of human judgment or roughly no correlation, which means that the model’s rankings are completely unrelated to human judgments

# %% [markdown]
# ### MSE Word2Vec (Skipgram)

# %%
mse = compute_mse(human_scores, model_scores)
print(f"Word2Vec (Skipgram) MSE: {mse}")
# Out:
# Word2Vec (Skipgram) MSE: 26.60272801674853

# %% [markdown]
# ### Top 10 most similar context Word2Vec(Skipgram)

# %%
# get top 10 most similar context Word2Vec(Skipgram)

query_vector = get_query_vector('money', word2vec_skipgram, word2index)
corpus_vector = get_corpus_vectors(word2vec_skipgram)   

top_k_indices, top_k_scores = compute_top_k_dot_product(query_vector, corpus_vector, k=10)
for idx in top_k_indices:
    print(index2word[idx])
# Out:
# 34.76
# lesser
# out-of-date
# views
# detail
# attractive
# existing
# govenment
# students
# pass

# %% [markdown]
# ## Word2Vec (Negative Sampling)

# %%
class SkipgramNegSampling(nn.Module):
    
    def __init__(self, vocab_size, emb_size):
        super(SkipgramNegSampling, self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, emb_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, emb_size) # out embedding
        self.logsigmoid = nn.LogSigmoid()
                    
    def forward(self, center_words, target_words, negative_words):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, window_size, emb_size]
        neg_embeds    = -self.embedding_u(negative_words) # [batch_size, window_size * num_neg, emb_size]
        
        positive_score = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #[batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, window_size]
        
        negative_score = neg_embeds.bmm(center_embeds.transpose(1, 2))
        #[batch_size, k, emb_size] @ [batch_size, emb_size, 1] = [batch_size, k, 1]
        
        loss = self.logsigmoid(positive_score) + torch.sum(self.logsigmoid(negative_score), 1)
                
        return -torch.mean(loss)
    
    def prediction(self, inputs):
        embeds = self.embedding_v(inputs)
        
        return embeds

# %%
word2vec_negativesampling = SkipgramNegSampling(vocab_size=voc_size, emb_size=embedding_size)
word2vec_negativesampling.load_state_dict(torch.load('models/word2vec_negativesampling.pth'))
word2vec_negativesampling.to(device)
word2vec_negativesampling.eval()
print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\neucl\AppData\Local\Temp\ipykernel_14968\3606289487.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   word2vec_negativesampling.load_state_dict(torch.load('models/word2vec_negativesampling.pth'))

# %% [markdown]
# ### syntactic and semantic accuracy

# %%
# get semantic and syntacic accuracy for Word2Vec negative sampling

embeddings_word2vec_negativesampling = word2vec_negativesampling.embedding_v.weight.data.cpu().numpy()
semantic_accuracy_word2vec_negativesampling = evaluate_analogies(semantic, word2index, embeddings_word2vec_negativesampling)
syntactic_accuracy_word2vec_negativesampling = evaluate_analogies(syntactic, word2index, embeddings_word2vec_negativesampling)
print(f'semantic_accuracy_word2vec_negativesampling: {semantic_accuracy_word2vec_negativesampling}')
print(f'syntactic_accuracy_word2vec_negativesampling: {syntactic_accuracy_word2vec_negativesampling}')
# Out:
# semantic_accuracy_word2vec_negativesampling: 0
# syntactic_accuracy_word2vec_negativesampling: 0.0

# %% [markdown]
# ### correlation between the models’ dot product and the provided similarity metrics Word2Vec(Negative Sampling)

# %%
word_pairs, human_scores = load_wordsim353('wordsim353/wordsim_similarity_goldstandard.txt')
model_scores = calculate_model_similarity(word_pairs, word2vec_negativesampling, word2index)
correlation = compute_spearman_correlation(human_scores, model_scores)
print(f"Word2Vec (Negativesampling) spearman correlation: {correlation:.4f}")
# Out:
# Word2Vec (Negativesampling) spearman correlation: -0.0976

# %% [markdown]
# The model barely ranks word pairs in the exact opposite order of human judgment or roughly no correlation, which means that the model’s rankings are completely unrelated to human judgments

# %% [markdown]
# ### MSE Word2Vec Negative Sampling

# %%
mse = compute_mse(human_scores, model_scores)
print(f"Word2Vec (Skipgram) MSE: {mse}")
# Out:
# Word2Vec (Skipgram) MSE: 29.36627531053967

# %% [markdown]
# ### Top 10 most similar context Word2Vec(Negative Sampling)

# %%
# get top 10 most similar context for Word2Vec(Megative Sampling)

query_vector = get_query_vector('money', word2vec_negativesampling, word2index)
corpus_vector = get_corpus_vectors(word2vec_negativesampling)   

top_k_indices, top_k_scores = compute_top_k_dot_product(query_vector, corpus_vector, k=10)
for idx in top_k_indices:
    print(index2word[idx])
# Out:
# 12.38
# tables
# scheme
# choke
# scored
# proposals
# respectively
# rasmussen
# featured
# dealers

# %% [markdown]
# ## Glove from Scratch

# %%
class GloVe(nn.Module):
    
    def __init__(self, vocab_size,embed_size):
        super(GloVe,self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, embed_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, embed_size) # out embedding
        
        self.v_bias = nn.Embedding(vocab_size, 1)
        self.u_bias = nn.Embedding(vocab_size, 1)
        
    def forward(self, center_words, target_words, coocs, weighting):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, window_size, emb_size]
        
        center_bias = self.v_bias(center_words).squeeze(1) 
        target_bias = self.u_bias(target_words).squeeze(1)
        
        inner_product = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        
        #note that coocs already got log
        loss = weighting*torch.pow(inner_product +center_bias + target_bias - coocs, 2) # [batch_size, window_size]
        
        return torch.sum(loss) # scalar

# %%
glove = GloVe(vocab_size=voc_size, embed_size=embedding_size)
glove.load_state_dict(torch.load('models/glove_scratch.pth'))
glove.to(device)
glove.eval()
print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\neucl\AppData\Local\Temp\ipykernel_14968\3739864851.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   glove.load_state_dict(torch.load('models/glove_scratch.pth'))

# %% [markdown]
# ### syntactic and semantic accuracy GloVe

# %%
embeddings_glove = glove.embedding_v.weight.data.cpu().numpy()
semantic_accuracy_glove = evaluate_analogies(semantic, word2index, embeddings_glove)
syntactic_accuracy_glove = evaluate_analogies(syntactic, word2index, embeddings_glove)
print(f'semantic_accuracy_glove: {semantic_accuracy_glove}')
print(f'syntactic_accuracy_glove: {syntactic_accuracy_glove}')
# Out:
# semantic_accuracy_glove: 0
# syntactic_accuracy_glove: 0.0

# %% [markdown]
# ### correlation between the models’ dot product and the provided similarity metrics Word2Vec(Skipgram)

# %%
word_pairs, human_scores = load_wordsim353('wordsim353/wordsim_similarity_goldstandard.txt')
model_scores = calculate_model_similarity(word_pairs, glove, word2index)
correlation = compute_spearman_correlation(human_scores, model_scores)
print(f"GloVe spearman correlation: {correlation:.4f}")
# Out:
# GloVe spearman correlation: -0.0921

# %% [markdown]
# The model barely ranks word pairs in the exact opposite order of human judgment or roughly no correlation, which means that the model’s rankings are completely unrelated to human judgments

# %% [markdown]
# ### MSE GloVe

# %%
mse = compute_mse(human_scores, model_scores)
print(f"Word2Vec (Skipgram) MSE: {mse}")
# Out:
# Word2Vec (Skipgram) MSE: 28.35736177676441

# %% [markdown]
# ### Top 10 most similar context GloVe

# %%
# get top 10 most similar context for GloVe

query_vector = get_query_vector('money', glove, word2index)
corpus_vector = get_corpus_vectors(glove)   

top_k_indices, top_k_scores = compute_top_k_dot_product(query_vector, corpus_vector, k=10)
for idx in top_k_indices:
    print(index2word[idx])
# Out:
# verging
# 1988.
# wrapped
# effective
# dresdner
# threatened
# 10.85
# manufacturer
# weinberger
# 83

# %%
y_true = compute_average_human_score(human_scores)
print(f'y_true Word Similarity: {y_true}')
# Out:
# y_true Word Similarity: 5.121584158415842
