# %% [markdown]
# ## Set torch.device to CUDA

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available. Using GPU.")
else:
    device = torch.device("cpu")
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. Using GPU.

# %% [markdown]
# ## Download NLTK

# %%
import nltk
import os
CUSTOM_DIR = './nltk_data/'

nltk.data.path.append(CUSTOM_DIR)

resources = [
    ('reuters.zip', os.path.join(CUSTOM_DIR, 'corpora', 'reuters')),
    ('punkt.zip', os.path.join(CUSTOM_DIR, 'tokenizers', 'punkt')),
    ('punkt_tab.zip', os.path.join(CUSTOM_DIR, 'tokenizers', 'punkt_tab')),
    ('stopwords.zip', os.path.join(CUSTOM_DIR, 'corpora', 'stopwords')),
]

for resource, path in resources:
    try:
        nltk.data.find(resource)
    except LookupError:
        if not os.path.exists(path):
            nltk.download(resource.split('.')[0], download_dir=CUSTOM_DIR)
# Out:
# [nltk_data] Downloading package reuters to ./nltk_data/...
# [nltk_data]   Package reuters is already up-to-date!

# %%
from nltk.corpus import reuters

category = "trade"
category_fileids = reuters.fileids(category)
category_docs = [reuters.raw(fileids) for fileids in category_fileids]

print(f"# of documents in category '{category}': {len(category_docs)}")
print(f"1st document:\n{category_docs[0][:500]}")
# Out:
# # of documents in category 'trade': 485
# 1st document:
# ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT
#   Mounting trade friction between the
#   U.S. And Japan has raised fears among many of Asia's exporting
#   nations that the row could inflict far-reaching economic
#   damage, businessmen and officials said.
#       They told Reuter correspondents in Asian capitals a U.S.
#   Move against Japan might boost protectionist sentiment in the
#   U.S. And lead to curbs on American imports of their products.
#       But some exporters said that while the conflict wo

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words and word not in string.punctuation]
    return tokens

# %%
preprocessed_docs = [preprocess_text(doc) for doc in category_docs]
preprocessed_docs
# Out:
# [['asian',
#   'exporters',
#   'fear',
#   'damage',
#   'u.s.-japan',
#   'rift',
#   'mounting',
#   'trade',
#   'friction',
#   'u.s.',
#   'japan',
#   'raised',
#   'fears',
#   'among',
#   'many',
#   'asia',
#   "'s",
#   'exporting',
#   'nations',
#   'row',
#   'could',
#   'inflict',
#   'far-reaching',
#   'economic',
#   'damage',
#   'businessmen',
#   'officials',
#   'said',
#   'told',
#   'reuter',
#   'correspondents',
#   'asian',
#   'capitals',
#   'u.s.',
#   'move',
#   'japan',
#   'might',
#   'boost',
#   'protectionist',
#   'sentiment',
#   'u.s.',
#   'lead',
#   'curbs',
#   'american',
#   'imports',
#   'products',
#   'exporters',
#   'said',
#   'conflict',
#   'would',
#   'hurt',
#   'long-run',
#   'short-term',
#   'tokyo',
#   "'s",
#   'loss',
#   'might',
#   'gain',
#   'u.s.',
#   'said',
#   'impose',
#   '300',
#   'mln',
#   'dlrs',
#   'tariffs',
#   'imports',
#   'japanese',
#   'electronics',
#   'goods',
#   'april',
#   '17',
#   'retaliation',
#   'japan',
#   "'s",
#   'alleged',
#   'failure',
#   'stick',
#   'pact',
#   'sell',
#   'semiconductors',
#   'world',
#   'markets',
#   'cost',
#   'unofficial',
#   'japanese',
#   'estimates',
#   'put',
#   'impact',
#   'tariffs',
#   '10',
#   'billion',
#   'dlrs',
#   'spokesmen',
#   'major',
#   'electronics',
#   'firms',
#   'said',
#   'would',
#   'virtually',
#   'halt',
#   'exports',
#   'products',
#   'hit',
#   'new',
#   'taxes',
#   '``',
#   'would',
#   "n't",
#   'able',
#   'business',
#   "''",
#   'said',
#   'spokesman',
#   'leading',
#   'japanese',
#   'electronics',
#   'firm',
#   'matsushita',
#   'electric',
#   'industrial',
#   'co',
#   'ltd',
#   'lt',
#   'mc.t',
#   '``',
#   'tariffs',
#   'remain',
#   'place',
#   'length',
#   'time',
#   'beyond',
#   'months',
#   'mean',
#   'complete',
#   'erosion',
#   'exports',
#   'goods',
#   'subject',
#   'tariffs',
#   'u.s.',
#   "''",
#   'said',
#   'tom',
#   'murtha',
#   'stock',
#   'analyst',
#   'tokyo',
#   'office',
#   'broker',
#   'lt',
#   'james',
#   'capel',
#   'co',
#   'taiwan',
#   'businessmen',
#   'officials',
#   'also',
#   'worried',
#   '``',
#   'aware',
#   'seriousness',
#   'u.s.',
#   'threat',
#   'japan',
#   'serves',
#   'warning',
#   'us',
#   "''",
#   'said',
#   'senior',
#   'taiwanese',
#   'trade',
#   'official',
#   'asked',
#   'named',
#   'taiwan',
#   'trade',
#   'trade',
#   'surplus',
#   '15.6',
#   'billion',
#   'dlrs',
#   'last',
#   'year',
#   '95',
#   'pct',
#   'u.s.',
#   'surplus',
#   'helped',
#   'swell',
#   'taiwan',
#   "'s",
#   'foreign',
#   'exchange',
#   'reserves',
#   '53',
#   'billion',
#   'dlrs',
#   'among',
#   'world',
#   "'s",
#   'largest',
#   '``',
#   'must',
#   'quickly',
#   'open',
#   'markets',
#   'remove',
#   'trade',
#   'barriers',
#   'cut',
#   'import',
#   'tariffs',
#   'allow',
#   'imports',
#   'u.s.',
#   'products',
#   'want',
#   'defuse',
#   'problems',
#   'possible',
#   'u.s.',
#   'retaliation',
#   "''",
#   'said',
#   'paul',
#   'sheen',
#   'chairman',
#   'textile',
#   'exporters',
#   'lt',
#   'taiwan',
#   'safe',
#   'group',
#   'senior',
#   'official',
#   'south',
#   'korea',
#   "'s",
#   'trade',
#   'promotion',
#   'association',
#   'said',
#   'trade',
#   'dispute',
#   'u.s.',
#   'japan',
#   'might',
#   'also',
#   'lead',
#   'pressure',
#   'south',
#   'korea',
#   'whose',
#   'chief',
#   'exports',
#   'similar',
#   'japan',
#   'last',
#   'year',
#   'south',
#   'korea',
#   'trade',
#   'surplus',
#   '7.1',
#   'billion',
#   'dlrs',
#   'u.s.',
#   '4.9',
#   'billion',
#   'dlrs',
#   '1985.',
#   'malaysia',
#   'trade',
#   'officers',
#   'businessmen',
#   'said',
#   'tough',
#   'curbs',
#   'japan',
#   'might',
#   'allow',
#   'hard-hit',
#   'producers',
#   'semiconductors',
#   'third',
#   'countries',
#   'expand',
#   'sales',
#   'u.s.',
#   'hong',
#   'kong',
#   'newspapers',
#   'alleged',
#   'japan',
#   'selling',
#   'below-cost',
#   'semiconductors',
#   'electronics',
#   'manufacturers',
#   'share',
#   'view',
#   'businessmen',
#   'said',
#   'short-term',
#   'commercial',
#   'advantage',
#   'would',
#   'outweighed',
#   'u.s.',
#   'pressure',
#   'block',
#   'imports',
#   '``',
#   'short-term',
#   'view',
#   "''",
#   'said',
#   'lawrence',
#   'mills',
#   'director-general',
#   'federation',
#   'hong',
#   'kong',
#   'industry',
#   '``',
#   'whole',
#   'purpose',
#   'prevent',
#   'imports',
#   'one',
#   'day',
#   'extended',
#   'sources',
#   'much',
#   'serious',
#   'hong',
#   'kong',
#   'disadvantage',
#   'action',
#   'restraining',
#   'trade',
#   "''",
#   'said',
#   'u.s.',
#   'last',
#   'year',
#   'hong',
#   'kong',
#   "'s",
#   'biggest',
#   'export',
#   'market',
#   'accounting',
#   '30',
#   'pct',
#   'domestically',
#   'produced',
#   'exports',
#   'australian',
#   'government',
#   'awaiting',
#   'outcome',
#   'trade',
#   'talks',
#   'u.s.',
#   'japan',
#   'interest',
#   'concern',
#   'industry',
#   'minister',
#   'john',
#   'button',
#   'said',
#   'canberra',
#   'last',
#   'friday',
#   '``',
#   'kind',
#   'deterioration',
#   'trade',
#   'relations',
#   'two',
#   'countries',
#   'major',
#   'trading',
#   'partners',
#   'serious',
#   'matter',
#   "''",
#   'button',
#   'said',
#   'said',
#   'australia',
#   "'s",
#   'concerns',
#   'centred',
#   'coal',
#   'beef',
#   'australia',
#   "'s",
#   'two',
#   'largest',
#   'exports',
#   'japan',
#   'also',
#   'significant',
#   'u.s.',
#   'exports',
#   'country',
#   'meanwhile',
#   'u.s.-japanese',
#   'diplomatic',
#   'manoeuvres',
#   'solve',
#   'trade',
#   'stand-off',
#   'continue',
#   'japan',
#   "'s",
#   'ruling',
#   'liberal',
#   'democratic',
#   'party',
#   'yesterday',
#   'outlined',
#   'package',
#   'economic',
#   'measures',
#   'boost',
#   'japanese',
#   'economy',
#   'measures',
#   'proposed',
#   'include',
#   'large',
#   'supplementary',
#   'budget',
#   'record',
#   'public',
#   'works',
#   'spending',
#   'first',
#   'half',
#   'financial',
#   'year',
#   'also',
#   'call',
#   'stepped-up',
#   'spending',
#   'emergency',
#   'measure',
#   'stimulate',
#   'economy',
#   'despite',
#   'prime',
#   'minister',
#   'yasuhiro',
#   'nakasone',
#   "'s",
#   'avowed',
#   'fiscal',
#   'reform',
#   'program',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'makoto',
#   'kuroda',
#   'japan',
#   "'s",
#   'deputy',
#   'minister',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'due',
#   'meet',
#   'washington',
#   'week',
#   'effort',
#   'end',
#   'dispute'],
#  ['thai',
#   'trade',
#   'deficit',
#   'widens',
#   'first',
#   'quarter',
#   'thailand',
#   "'s",
#   'trade',
#   'deficit',
#   'widened',
#   '4.5',
#   'billion',
#   'baht',
#   'first',
#   'quarter',
#   '1987',
#   '2.1',
#   'billion',
#   'year',
#   'ago',
#   'business',
#   'economics',
#   'department',
#   'said',
#   'said',
#   'janunary/march',
#   'imports',
#   'rose',
#   '65.1',
#   'billion',
#   'baht',
#   '58.7',
#   'billion',
#   'thailand',
#   "'s",
#   'improved',
#   'business',
#   'climate',
#   'year',
#   'resulted',
#   '27',
#   'pct',
#   'increase',
#   'imports',
#   'raw',
#   'materials',
#   'semi-finished',
#   'products',
#   'country',
#   "'s",
#   'oil',
#   'import',
#   'bill',
#   'however',
#   'fell',
#   '23',
#   'pct',
#   'first',
#   'quarter',
#   'due',
#   'lower',
#   'oil',
#   'prices',
#   'department',
#   'said',
#   'first',
#   'quarter',
#   'exports',
#   'expanded',
#   '60.6',
#   'billion',
#   'baht',
#   '56.6',
#   'billion',
#   'export',
#   'growth',
#   'smaller',
#   'expected',
#   'due',
#   'lower',
#   'earnings',
#   'many',
#   'key',
#   'commodities',
#   'including',
#   'rice',
#   'whose',
#   'earnings',
#   'declined',
#   '18',
#   'pct',
#   'maize',
#   '66',
#   'pct',
#   'sugar',
#   '45',
#   'pct',
#   'tin',
#   '26',
#   'pct',
#   'canned',
#   'pineapples',
#   'seven',
#   'pct',
#   'products',
#   'registering',
#   'high',
#   'export',
#   'growth',
#   'jewellery',
#   '64',
#   'pct',
#   'clothing',
#   '57',
#   'pct',
#   'rubber',
#   '35',
#   'pct'],
#  ['japan',
#   'ministry',
#   'says',
#   'open',
#   'farm',
#   'trade',
#   'would',
#   'hit',
#   'u.s.',
#   'japan',
#   "'s",
#   'agriculture',
#   'ministry',
#   'angered',
#   'u.s.',
#   'demands',
#   'japan',
#   'open',
#   'farm',
#   'products',
#   'market',
#   'tell',
#   'u.s.',
#   'officials',
#   'talks',
#   'later',
#   'month',
#   'liberalisation',
#   'would',
#   'harm',
#   'existing',
#   'u.s.',
#   'farm',
#   'exports',
#   'japan',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   '``',
#   'imports',
#   'u.s.',
#   'would',
#   'drop',
#   'due',
#   'active',
#   'sales',
#   'drives',
#   'suppliers',
#   "''",
#   'official',
#   'declined',
#   'named',
#   'said',
#   '``',
#   'japan',
#   'largest',
#   'customer',
#   'u.s.',
#   'farm',
#   'products',
#   'reasonable',
#   'u.s.',
#   'demand',
#   'japan',
#   'liberalise',
#   'farm',
#   'import',
#   'market',
#   "''",
#   'said',
#   'agriculture',
#   'minister',
#   'mutsuki',
#   'kato',
#   'said',
#   'u.s.',
#   'insists',
#   'japan',
#   'open',
#   'protected',
#   'rice',
#   'market',
#   'also',
#   'open',
#   'wheat',
#   'market',
#   'volume',
#   'origin',
#   'regulated',
#   'protect',
#   'local',
#   'farmers',
#   'australia',
#   'canada',
#   'could',
#   'increase',
#   'wheat',
#   'exports',
#   'competitive',
#   'u.s.',
#   'said',
#   'end-users',
#   'would',
#   'also',
#   'buy',
#   'origins',
#   'grain',
#   'traders',
#   'said',
#   'u.s.',
#   'agriculture',
#   'secretary',
#   'richard',
#   'lyng',
#   'due',
#   'visit',
#   'japan',
#   'talks',
#   'april',
#   '16-27',
#   'said',
#   'ask',
#   'japan',
#   'offer',
#   'share',
#   'rice',
#   'market',
#   'u.s.',
#   'suppliers',
#   'remove',
#   'quotas',
#   'u.s.',
#   'beef',
#   'citrus',
#   'imports',
#   'countries',
#   'already',
#   'cutting',
#   'u.s.',
#   'market',
#   'share',
#   'australia',
#   'largest',
#   'beef',
#   'supplier',
#   'japan',
#   'trying',
#   'boost',
#   'exports',
#   'prior',
#   'expiry',
#   'four-year',
#   'beef',
#   'accord',
#   'next',
#   'march',
#   '31.',
#   'imports',
#   'u.s.',
#   'corn',
#   'fallen',
#   'due',
#   'increased',
#   'sales',
#   'china',
#   'south',
#   'america',
#   'japanese',
#   'soybean',
#   'imports',
#   'brazil',
#   'expected',
#   'rise',
#   'sharply',
#   'year',
#   'although',
#   'u.s.',
#   'remain',
#   'largest',
#   'supplier',
#   'u.s.',
#   'feedgrain',
#   'sales',
#   'also',
#   'drop',
#   'japan',
#   'opens',
#   'beef',
#   'imports',
#   'since',
#   'japan',
#   'depends',
#   'almost',
#   'entirely',
#   'feedgrain',
#   'imports',
#   'mainly',
#   'u.s.',
#   'japanese',
#   'officials',
#   'said',
#   'indication',
#   'u.s.',
#   'position',
#   'came',
#   'last',
#   'december',
#   'secretary',
#   'agriculture',
#   'daniel',
#   'amstutz',
#   'said',
#   'japan',
#   'potential',
#   'provide',
#   'one',
#   'largest',
#   'boosts',
#   'u.s.',
#   'agricultural',
#   'exports',
#   'beef',
#   'market',
#   'alone',
#   'representing',
#   'one',
#   'billion',
#   'dlrs',
#   'new',
#   'business',
#   'u.s.',
#   'also',
#   'asked',
#   'general',
#   'agreement',
#   'tariffs',
#   'trade',
#   'investigate',
#   'legality',
#   'japanese',
#   'import',
#   'controls',
#   '12',
#   'farm',
#   'products',
#   'including',
#   'fruit',
#   'juices',
#   'purees',
#   'pulp',
#   'tomato',
#   'juice',
#   'ketchup',
#   'sauce',
#   'peanuts',
#   'prepared',
#   'beef',
#   'products',
#   'miscellaneous',
#   'beans',
#   'help',
#   'calm',
#   'heated',
#   'trade',
#   'relations',
#   'u.s.',
#   'japan',
#   "'s",
#   'top',
#   'business',
#   'group',
#   'keidanren',
#   'urged',
#   'government',
#   'remove',
#   'residual',
#   'import',
#   'restrictions',
#   'agricultural',
#   'products',
#   'agriculture',
#   'minister',
#   'kato',
#   'ruled',
#   'emotional',
#   'reaction',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   'farm',
#   'issue',
#   'become',
#   'scapegoat',
#   'trade',
#   'pressure',
#   'industrial',
#   'sector',
#   '``',
#   'japan',
#   'largest',
#   'buyer',
#   'u.s.',
#   'farm',
#   'products',
#   'issues',
#   'discussed',
#   'table',
#   "''",
#   'official',
#   'said'],
#  ['south',
#   'korea',
#   'moves',
#   'slow',
#   'growth',
#   'trade',
#   'surplus',
#   'south',
#   'korea',
#   "'s",
#   'trade',
#   'surplus',
#   'growing',
#   'fast',
#   'government',
#   'started',
#   'taking',
#   'steps',
#   'slow',
#   'deputy',
#   'prime',
#   'minister',
#   'kim',
#   'mahn-je',
#   'said',
#   'told',
#   'press',
#   'conference',
#   'government',
#   'planned',
#   'increase',
#   'investment',
#   'speed',
#   'opening',
#   'local',
#   'market',
#   'foreign',
#   'imports',
#   'gradually',
#   'adjust',
#   'currency',
#   'hold',
#   'surplus',
#   '``',
#   'proper',
#   'level',
#   "''",
#   'said',
#   'government',
#   'would',
#   'allow',
#   'appreciate',
#   'much',
#   'short',
#   'period',
#   'time',
#   'south',
#   'korea',
#   'pressure',
#   'washington',
#   'revalue',
#   'u.s.',
#   'wants',
#   'south',
#   'korea',
#   'cut',
#   'trade',
#   'surplus',
#   'u.s.',
#   'rose',
#   '7.4',
#   'billion',
#   'dlrs',
#   '1986',
#   '4.3',
#   'billion',
#   'dlrs',
#   '1985.',
#   'kim',
#   'also',
#   'economic',
#   'planning',
#   'minister',
#   'said',
#   'prospects',
#   'bright',
#   'south',
#   'korean',
#   'economy',
#   'government',
#   'would',
#   'try',
#   'hold',
#   'current',
#   'account',
#   'surplus',
#   'around',
#   'five',
#   'billion',
#   'dlrs',
#   'year',
#   'next',
#   'five',
#   'years',
#   '``',
#   'government',
#   'projections',
#   'eight',
#   'pct',
#   'gnp',
#   'growth',
#   'five',
#   'billion',
#   'dlrs',
#   'current',
#   'account',
#   'surplus',
#   '12',
#   'pct',
#   'growth',
#   'exports',
#   'seemed',
#   'reasonable',
#   'early',
#   'year',
#   'surplus',
#   'growing',
#   'faster',
#   'expected',
#   "''",
#   'said',
#   'trade',
#   'ministry',
#   'officials',
#   'said',
#   'south',
#   'korea',
#   "'s",
#   'exports',
#   'rose',
#   '35',
#   'pct',
#   '9.34',
#   'billion',
#   'dlrs',
#   'first',
#   'three',
#   'months',
#   'year',
#   'imports',
#   'rose',
#   '8.5',
#   'pct',
#   '8.2',
#   'billion',
#   'dlrs',
#   'kim',
#   'said',
#   'swing',
#   'south',
#   'korea',
#   "'s",
#   'current',
#   'account',
#   'surplus',
#   '4.65',
#   'billion',
#   'dlrs',
#   '1986',
#   '890',
#   'mln',
#   'dlr',
#   'deficit',
#   '1985',
#   'significant',
#   'surplus',
#   'enabled',
#   'country',
#   'reduce',
#   'foreign',
#   'debt',
#   'last',
#   'year',
#   'first',
#   'time',
#   'south',
#   'korea',
#   "'s",
#   'foreign',
#   'debt',
#   'fell',
#   '44.5',
#   'billion',
#   'dlrs',
#   '1986',
#   '46.8',
#   'billion',
#   '1985',
#   'still',
#   'among',
#   'largest',
#   'asia',
#   '``',
#   'huge',
#   'amount',
#   'foreign',
#   'debt',
#   'one',
#   'major',
#   'constraints',
#   'development',
#   '...',
#   'last',
#   'year',
#   'major',
#   'turning',
#   'point',
#   'korean',
#   'economy',
#   "''",
#   'kim',
#   'said',
#   'kim',
#   'said',
#   'government',
#   'plannned',
#   'reduce',
#   'ratio',
#   'foreign',
#   'debt',
#   'country',
#   "'s",
#   'gnp',
#   '20',
#   'pct',
#   '1991',
#   '50',
#   'pct',
#   '1986',
#   '``',
#   'government',
#   'however',
#   'want',
#   'accelerate',
#   'reducing',
#   'debt',
#   'making',
#   'excessive',
#   'trade',
#   'surplus',
#   "''",
#   'said',
#   'kim',
#   'said',
#   'sudden',
#   'rise',
#   'surplus',
#   'would',
#   'cause',
#   'inflation',
#   'lead',
#   'trade',
#   'friction',
#   'seoul',
#   "'s",
#   'major',
#   'trading',
#   'partners',
#   'particularly',
#   'united',
#   'states',
#   '``',
#   'need',
#   'surplus',
#   'reduce',
#   'debt',
#   'taking',
#   'measures',
#   'hold',
#   'size',
#   'surplus',
#   'proper',
#   'level',
#   "''",
#   'kim',
#   'said'],
#  ['japan',
#   'given',
#   'little',
#   'hope',
#   'avoiding',
#   'u.s.',
#   'sanctions',
#   'top',
#   'u.s.',
#   'official',
#   'said',
#   'japan',
#   'little',
#   'chance',
#   'convincing',
#   'u.s.',
#   'drop',
#   'threatened',
#   'trade',
#   'sanctions',
#   'despite',
#   'efforts',
#   'japanese',
#   'team',
#   'left',
#   'washington',
#   'today',
#   'michael',
#   'armacost',
#   'secretary',
#   'state',
#   'political',
#   'affairs',
#   'asked',
#   'press',
#   'conference',
#   'whether',
#   'japan',
#   "'s",
#   'moves',
#   'boost',
#   'domestic',
#   'economy',
#   'open',
#   'markets',
#   'could',
#   'persuade',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'japanese',
#   'imports',
#   'said',
#   'replied',
#   '``',
#   '...',
#   'probably',
#   'early',
#   'figures',
#   'demonstrate',
#   'situation',
#   'turned',
#   'around',
#   'permit',
#   'result',
#   'described',
#   "''",
#   'armacost',
#   'said',
#   'u.s.',
#   'hopes',
#   'japan',
#   'take',
#   'steps',
#   'lift',
#   'domestic',
#   'economy',
#   'reduce',
#   'dependence',
#   'exports',
#   'remove',
#   'barriers',
#   'imports',
#   'settle',
#   'outstanding',
#   'trade',
#   'issues',
#   '``',
#   'obvious',
#   'problems',
#   'moment',
#   'trade',
#   'area',
#   'wish',
#   'problems',
#   'divert',
#   'attention',
#   'important',
#   'areas',
#   'cooperation',
#   'continue',
#   'exist',
#   'security',
#   'political',
#   'issues',
#   "''",
#   'said',
#   '``',
#   'question',
#   'whether',
#   'cooperative',
#   'actions',
#   'governments',
#   'reduce',
#   'trade',
#   'imbalance',
#   'whether',
#   'congress',
#   'takes',
#   'action',
#   'reduce',
#   'protectionist',
#   'legislation',
#   "''",
#   'said'],
#  ['japanese',
#   'official',
#   'takes',
#   'data',
#   'microchip',
#   'talks',
#   'ministry',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'vice',
#   'minister',
#   'makoto',
#   'kuroda',
#   'leaves',
#   'washington',
#   'today',
#   'data',
#   'hopes',
#   'refute',
#   'u.s.',
#   'charges',
#   'japan',
#   'violated',
#   'pact',
#   'microchip',
#   'trade',
#   'three-man',
#   'japanese',
#   'trade',
#   'team',
#   'already',
#   'washington',
#   'laying',
#   'groundwork',
#   'talks',
#   'kuroda',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'aimed',
#   'persuading',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'certain',
#   'japanese',
#   'products',
#   'kuroda',
#   'said',
#   'taking',
#   'new',
#   'proposals',
#   '``',
#   'nothing',
#   'briefcase',
#   'except',
#   'explanation',
#   'current',
#   'situation',
#   "''",
#   'kuroda',
#   'told',
#   'daily',
#   'newspaper',
#   'asahi',
#   'shimbun',
#   'kuroda',
#   'said',
#   'u.s.',
#   'decision',
#   'based',
#   'incorrect',
#   'data',
#   'exaggerated',
#   'sense',
#   'miti',
#   "'s",
#   'power',
#   'control',
#   'market',
#   'forces',
#   '``',
#   'u.s.',
#   'excessive',
#   'expectations',
#   'stabilise',
#   'supply-demand',
#   'relations',
#   'disrupted',
#   'excess',
#   'inventories',
#   'since',
#   '1985',
#   'take',
#   'time',
#   "''",
#   'said',
#   'kuroda',
#   'also',
#   'laid',
#   'part',
#   'blame',
#   'low',
#   'u.s.',
#   'chip',
#   'sales',
#   'japan',
#   'lack',
#   'effort',
#   'american',
#   'firms',
#   'said',
#   'fails',
#   'talks',
#   'tomorrow',
#   'friday',
#   'forestall',
#   'sanctions',
#   'seek',
#   'talks',
#   'u.s.',
#   'trade',
#   'representative',
#   'clayton',
#   'yeutter',
#   'u.s.',
#   'officials',
#   'said',
#   'week',
#   "'s",
#   'talks',
#   'unlikely',
#   'delay',
#   'imposition',
#   'tariffs'],
#  ['japan',
#   'given',
#   'little',
#   'hope',
#   'avoiding',
#   'u.s.',
#   'sanctions',
#   'top',
#   'u.s.',
#   'official',
#   'said',
#   'japan',
#   'little',
#   'chance',
#   'persuading',
#   'u.s.',
#   'drop',
#   'threatened',
#   'trade',
#   'sanctions',
#   'despite',
#   'efforts',
#   'japanese',
#   'team',
#   'left',
#   'washington',
#   'today',
#   'michael',
#   'armacost',
#   'secretary',
#   'state',
#   'political',
#   'affairs',
#   'asked',
#   'press',
#   'conference',
#   'whether',
#   'japan',
#   "'s",
#   'moves',
#   'boost',
#   'domestic',
#   'economy',
#   'open',
#   'markets',
#   'could',
#   'persuade',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'japanese',
#   'imports',
#   'said',
#   'replied',
#   '``',
#   '...',
#   'probably',
#   'early',
#   'figures',
#   'demonstrate',
#   'situation',
#   'turned',
#   'around',
#   'permit',
#   'result',
#   'described',
#   "''",
#   'armacost',
#   'said',
#   'u.s.',
#   'hopes',
#   'japan',
#   'take',
#   'steps',
#   'lift',
#   'domestic',
#   'economy',
#   'reduce',
#   'dependence',
#   'exports',
#   'remove',
#   'barriers',
#   'imports',
#   'settle',
#   'outstanding',
#   'trade',
#   'issues',
#   '``',
#   'obvious',
#   'problems',
#   'moment',
#   'trade',
#   'area',
#   'wish',
#   'problems',
#   'divert',
#   'attention',
#   'important',
#   'areas',
#   'cooperation',
#   'continue',
#   'exist',
#   'security',
#   'political',
#   'issues',
#   "''",
#   'said',
#   '``',
#   'question',
#   'whether',
#   'cooperative',
#   'actions',
#   'governments',
#   'reduce',
#   'trade',
#   'imbalance',
#   'whether',
#   'congress',
#   'takes',
#   'action',
#   'reduce',
#   'protectionist',
#   'legislation',
#   "''",
#   'said'],
#  ['japan',
#   'last-ditch',
#   'effort',
#   'avert',
#   'tariffs',
#   'senior',
#   'japanese',
#   'officials',
#   'tomorrow',
#   'open',
#   'talks',
#   'american',
#   'trade',
#   'negotiators',
#   'last-ditch',
#   'effort',
#   'avert',
#   'new',
#   'high',
#   'u.s.',
#   'tariffs',
#   'imposed',
#   'wide',
#   'variety',
#   'japanese',
#   'electronic',
#   'exports',
#   'makoto',
#   'kuroda',
#   'vice',
#   'minister',
#   'japan',
#   "'s",
#   'ministry',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'hold',
#   'two',
#   'days',
#   'meetings',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'secretary',
#   'commerce',
#   'bruce',
#   'smart',
#   'new',
#   'tariffs',
#   'go',
#   'effect',
#   'april',
#   '17',
#   'retaliation',
#   'japan',
#   "'s",
#   'failure',
#   'adhere',
#   'agreement',
#   'end',
#   'dumping',
#   'semiconductors',
#   'world',
#   'markets',
#   'cost',
#   'open',
#   'home',
#   'market',
#   'u.s.',
#   'semiconductor',
#   'shipments',
#   'imposed',
#   'goods',
#   'use',
#   'semiconductors',
#   'including',
#   'television',
#   'audio',
#   'equipment',
#   'computers',
#   'u.s.',
#   'japanese',
#   'officials',
#   'said',
#   'little',
#   'likelihood',
#   'talks',
#   'would',
#   'anything',
#   'avert',
#   '100',
#   'pct',
#   'duties',
#   '300',
#   'mln',
#   'dlrs',
#   'worth',
#   'japanese',
#   'shipments',
#   'president',
#   'reagan',
#   'announced',
#   'planned',
#   'tariffs',
#   'march',
#   '27',
#   'said',
#   'close',
#   'monitoring',
#   'july',
#   '1986',
#   'u.s.-japanese',
#   'semiconductor',
#   'pact',
#   'convinced',
#   'u.s.',
#   'officials',
#   'japan',
#   'honoring',
#   'agreement',
#   'making',
#   'annoucement',
#   'reagan',
#   'said',
#   '``',
#   'committed',
#   'full',
#   'enforcement',
#   'trade',
#   'agreements',
#   'designed',
#   'provide',
#   'american',
#   'industry',
#   'free',
#   'fair',
#   'trade',
#   "''",
#   'trade',
#   'analysts',
#   'said',
#   'move',
#   'aimed',
#   'much',
#   'japan',
#   "'s",
#   'semiconductor',
#   'trade',
#   'practices',
#   'said',
#   'injured',
#   'u.s.',
#   'semiconductor',
#   'industry',
#   'congress',
#   'complained',
#   'presidential',
#   'timidity',
#   'trade',
#   'issues',
#   'congressional',
#   'democrats',
#   'pledged',
#   'enact',
#   'aggressive',
#   'trade',
#   'laws',
#   'counter',
#   'contend',
#   'reagan',
#   "'s",
#   'inaction',
#   'redress',
#   'growing',
#   'u.s.',
#   'trade',
#   'deficit',
#   'last',
#   'year',
#   'reached',
#   '169.8',
#   'billion',
#   'dlrs',
#   'one-third',
#   'deficit',
#   'japan',
#   'reagan',
#   'said',
#   'recent',
#   'signs',
#   'japan',
#   'beginning',
#   'adhere',
#   'pact',
#   'terminating',
#   'kuroda',
#   'said',
#   'leaving',
#   'tokyo',
#   'today',
#   'new',
#   'proposals',
#   'explanation',
#   'semiconductor',
#   'situation',
#   'told',
#   'daily',
#   'newspaper',
#   'ashai',
#   'shimbun',
#   'reagan',
#   "'s",
#   'decision',
#   'based',
#   'inaccurate',
#   'data',
#   'exaggerated',
#   'sense',
#   'miti',
#   "'s",
#   'power',
#   'control',
#   'japanese',
#   'traders',
#   '``',
#   'united',
#   'states',
#   'excessive',
#   'expectations.',
#   "''",
#   'said',
#   'stabilize',
#   'supply-demand',
#   'relations',
#   'disrupted',
#   'excess',
#   'inventories',
#   'since',
#   '1985',
#   'take',
#   'time',
#   "''",
#   'also',
#   'said',
#   'u.s.',
#   'firms',
#   'aggressive',
#   'enough',
#   'trying',
#   'sell',
#   'japanese',
#   'market'],
#  ['white',
#   'house',
#   'standing',
#   'firm',
#   'japanese',
#   'sanctions',
#   'presidential',
#   'spokesman',
#   'marlin',
#   'fitzwater',
#   'said',
#   'u.s.',
#   'trade',
#   'sanctions',
#   'japan',
#   'likely',
#   'take',
#   'effect',
#   'april',
#   '17',
#   'spite',
#   '``',
#   'full',
#   'court',
#   'press',
#   "''",
#   'japanese',
#   'officials',
#   'avoid',
#   '``',
#   'indications',
#   'take',
#   'effect',
#   "''",
#   'said',
#   '``',
#   'would',
#   'say',
#   'japan',
#   'applying',
#   'full',
#   'court',
#   'press',
#   '...',
#   'certainly',
#   'putting',
#   'feet',
#   'forward',
#   'terms',
#   'explaining',
#   'position',
#   "''",
#   'fitzwater',
#   'told',
#   'reporters',
#   'noted',
#   'high',
#   'level',
#   'meetings',
#   'trade',
#   'dispute',
#   'underway',
#   'said',
#   '``',
#   "n't",
#   'think',
#   "'s",
#   'anything',
#   'report',
#   "n't",
#   'believe',
#   "'s",
#   'official',
#   'movement',
#   "''"],
#  ['white',
#   'house',
#   'says',
#   'japanese',
#   'tarriffs',
#   'likely',
#   'white',
#   'house',
#   'said',
#   'high',
#   'u.s.',
#   'tariffs',
#   'japanese',
#   'electronic',
#   'goods',
#   'would',
#   'likely',
#   'imposed',
#   'scheduled',
#   'april',
#   '17',
#   'despite',
#   'all-out',
#   'effort',
#   'japan',
#   'avoid',
#   'presidential',
#   'spokesman',
#   'marlin',
#   'fitzwater',
#   'made',
#   'remark',
#   'one',
#   'day',
#   'u.s.',
#   'japanese',
#   'officials',
#   'meet',
#   'emergency',
#   'provisions',
#   'july',
#   '1986',
#   'semiconductor',
#   'pact',
#   'discuss',
#   'trade',
#   'punitive',
#   'tariffs',
#   'fitzwater',
#   'said',
#   '``',
#   'would',
#   'say',
#   'japan',
#   'applying',
#   'full-court',
#   'press',
#   '...',
#   'certainly',
#   'putting',
#   'feet',
#   'forward',
#   'terms',
#   'explaining',
#   'position',
#   "''",
#   'added',
#   '``',
#   'indications',
#   'tariffs',
#   'take',
#   'effect',
#   "''"],
#  ['canada',
#   'plans',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'trade',
#   'minister',
#   'says',
#   'canada',
#   'plans',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'trade',
#   'minister',
#   'says'],
#  ['canada',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'canada',
#   'plans',
#   'monitor',
#   'steel',
#   'shipments',
#   'flowing',
#   'country',
#   'attempt',
#   'appease',
#   'concerns',
#   'u.s.',
#   'high',
#   'level',
#   'canadian',
#   'steel',
#   'exports',
#   'trade',
#   'minister',
#   'pat',
#   'carney',
#   'said',
#   '``',
#   'help',
#   'maintain',
#   'open',
#   'access',
#   'u.s.',
#   'steel',
#   'market',
#   'government',
#   'taking',
#   'action',
#   'ensure',
#   'accurate',
#   'data',
#   'exports',
#   'imports',
#   'canada',
#   'used',
#   'backdoor',
#   'u.s.',
#   'market',
#   'offshore',
#   'suppliers',
#   "''",
#   'carney',
#   'said',
#   'carney',
#   'also',
#   'said',
#   'canadian',
#   'companies',
#   'asked',
#   'exercise',
#   'prudence',
#   'u.s.',
#   'market',
#   'countries',
#   'considering',
#   'establishing',
#   'joint',
#   'commission',
#   'study',
#   'growing',
#   'steel',
#   'problem',
#   'carney',
#   'told',
#   'house',
#   'commons',
#   'soon',
#   'announce',
#   'amendment',
#   'exports',
#   'imports',
#   'permits',
#   'act',
#   'set',
#   'monitoring',
#   'program',
#   'canadian',
#   'steel',
#   'shipments',
#   'u.s.',
#   'risen',
#   '5.7',
#   'pct',
#   'cent',
#   'u.s.',
#   'market',
#   'recent',
#   'months',
#   'almost',
#   'double',
#   'level',
#   'two',
#   'years',
#   'ago',
#   'canadian',
#   'trade',
#   'officials',
#   'said',
#   'increase',
#   'canadian',
#   'shipments',
#   'comes',
#   'time',
#   'growing',
#   'anger',
#   'u.s.',
#   'rising',
#   'steel',
#   'imports',
#   'several',
#   'countries',
#   'face',
#   'decline',
#   'domestic',
#   'steel',
#   'industry',
#   'u.s.',
#   'lawmakers',
#   'proposed',
#   'canada',
#   "'s",
#   'share',
#   'american',
#   'market',
#   'limited',
#   '2.4',
#   'pct'],
#  ['deficit',
#   'cuts',
#   'seen',
#   'unable',
#   'cure',
#   'trade',
#   'deficit',
#   'financial',
#   'analysts',
#   'say',
#   'pleased',
#   'congressional',
#   'moves',
#   'trim',
#   'next',
#   'year',
#   "'s",
#   'federal',
#   'budget',
#   'deficit',
#   'believe',
#   'actions',
#   'little',
#   'help',
#   'improve',
#   'u.s.',
#   'trade',
#   'deficit',
#   'buoy',
#   'economy',
#   'house',
#   'representatives',
#   'expected',
#   'vote',
#   'tomorrow',
#   'approve',
#   'trillion-dollar',
#   'budget',
#   'blueprint',
#   'coming',
#   'fiscal',
#   'year',
#   'reduces',
#   'deficit',
#   '38',
#   'billion',
#   'dlrs',
#   'similarly',
#   'senate',
#   'budget',
#   'committee',
#   'approved',
#   'plan',
#   'would',
#   'cut',
#   'federal',
#   'red',
#   'ink',
#   '37',
#   'billion',
#   'dlrs',
#   'next',
#   'year',
#   '``',
#   'terms',
#   'economy',
#   '37-38',
#   'billion',
#   'dlrs',
#   'infinitesimal',
#   'cuts',
#   'magnitude',
#   'little',
#   'impact',
#   'economy',
#   'trade',
#   'deficit',
#   "''",
#   'said',
#   'stanley',
#   'collander',
#   'touche',
#   'ross',
#   'federal',
#   'budget',
#   'policy',
#   'analyst',
#   '``',
#   'best',
#   'small',
#   'positive',
#   'effect',
#   "''",
#   'collander',
#   'said',
#   'interview',
#   'federal',
#   'reserve',
#   'board',
#   'chairman',
#   'paul',
#   'volcker',
#   'repeatedly',
#   'told',
#   'congress',
#   'cutting',
#   'federal',
#   'red',
#   'ink',
#   'would',
#   'go',
#   'long',
#   'way',
#   'help',
#   'reduce',
#   'massive',
#   'trade',
#   'deficit',
#   'also',
#   'help',
#   'ease',
#   'downward',
#   'pressure',
#   'value',
#   'dollar',
#   'u.s.',
#   'government',
#   'attempted',
#   'remedy',
#   'trade',
#   'imbalance',
#   'driving',
#   'value',
#   'dollar',
#   'volcker',
#   'warned',
#   'fall',
#   'dollar',
#   "'s",
#   'value',
#   'fraught',
#   'danger',
#   'decline',
#   'said',
#   'could',
#   'refuel',
#   'inflation',
#   'imported',
#   'goods',
#   'become',
#   'expensive',
#   'chase',
#   'away',
#   'foreign',
#   'capital',
#   'needed',
#   'finance',
#   'federal',
#   'budget',
#   'deficit',
#   'addition',
#   'february',
#   'u.s.',
#   'officials',
#   'meeting',
#   'major',
#   'industrialized',
#   'nations',
#   'paris',
#   'agreed',
#   'value',
#   'dollar',
#   'dropped',
#   'enough',
#   'world',
#   'exchange',
#   'rates',
#   'stabilized',
#   'around',
#   'current',
#   'levels',
#   'part',
#   'agreement',
#   'japan',
#   'west',
#   'germany',
#   'agreed',
#   'take',
#   'steps',
#   'stimulate',
#   'economies',
#   'united',
#   'states',
#   'agreed',
#   'cut',
#   'budget',
#   'deficit',
#   'alternative',
#   'driving',
#   'dollar',
#   'way',
#   'deal',
#   'trade',
#   'deficit',
#   'volcker',
#   'said',
#   'recently',
#   'reduce',
#   'u.s.',
#   'consumption',
#   'particularly',
#   'federal',
#   'spending',
#   '``',
#   "n't",
#   'deal',
#   'budget',
#   'deficit',
#   'everything',
#   'else',
#   'going',
#   'counterproductive',
#   "''",
#   'volcker',
#   'said',
#   'recent',
#   'testimony',
#   'senate',
#   'banking',
#   'committee',
#   'volcker',
#   'also',
#   'said',
#   'would',
#   'prefer',
#   'tighten',
#   'government',
#   "'s",
#   'purse',
#   'strings',
#   'fed',
#   'tighten',
#   'credit',
#   'supply',
#   'action',
#   'needed',
#   'fight',
#   'inflationary',
#   'pressures',
#   'assure',
#   'continued',
#   'flow',
#   'foreign',
#   'capital',
#   'united',
#   'states',
#   'analysts',
#   'say',
#   'fed',
#   'tightening',
#   'could',
#   'choke',
#   'current',
#   'modest',
#   'economic',
#   'expansion',
#   'threaten',
#   'recession',
#   'kemper',
#   'financial',
#   'services',
#   'economist',
#   'john',
#   'silvia',
#   'stressed',
#   'deficit',
#   'reduction',
#   'better',
#   'none',
#   'said',
#   'size',
#   'cuts',
#   'consideration',
#   'enough',
#   'give',
#   'federal',
#   'reserve',
#   'board',
#   'flexibility',
#   'needs',
#   'steer',
#   'economy',
#   'keep',
#   'value',
#   'dollar',
#   'plunging',
#   'world',
#   'exchange',
#   'markets',
#   '``',
#   "'s",
#   'doubt',
#   'deficit',
#   'reduction',
#   'helps',
#   'objective',
#   'stabilize',
#   'dollar',
#   'perserve',
#   'fed',
#   "'s",
#   'flexibility',
#   'conduct',
#   'monetary',
#   'policy',
#   'answer',
#   "'s",
#   'enough',
#   "''",
#   'silvia',
#   'told',
#   'reuters',
#   'u.s.',
#   'trade',
#   'deficit',
#   'become',
#   'one',
#   'government',
#   "'s",
#   'vexing',
#   'persistent',
#   'problems',
#   '1986',
#   'deficit',
#   '169.8',
#   'billion',
#   'dlrs',
#   'yet',
#   'little',
#   'indication',
#   'year',
#   "'s",
#   'figure',
#   'lower',
#   'though',
#   'administration',
#   'officials',
#   'predicted',
#   'drop',
#   '20',
#   '30',
#   'billion',
#   'dlrs',
#   'year',
#   "'s",
#   'end',
#   'past',
#   'volcker',
#   'joked',
#   'never',
#   'lost',
#   'sleep',
#   'worrying',
#   'whether',
#   'congress',
#   'would',
#   'cut',
#   'much',
#   'fat',
#   'federal',
#   'budget',
#   'hand',
#   'also',
#   'made',
#   'clear',
#   'attached',
#   'gradually',
#   'declining',
#   'deficit',
#   'ceilings',
#   'set',
#   '1986-1991',
#   'period',
#   'last',
#   'year',
#   "'s",
#   'gramm-rudman',
#   'balanced',
#   'budget',
#   'law',
#   'new',
#   'law',
#   'set',
#   'ceiling',
#   '108',
#   'billion',
#   'dlrs',
#   'next',
#   'year',
#   "'s",
#   'federal',
#   'deficit',
#   'house',
#   'senate',
#   'budget',
#   'committees',
#   'conceded',
#   'budget',
#   'plans',
#   'would',
#   'fall',
#   'short',
#   'deficit',
#   'reduction',
#   'goal',
#   '25',
#   'billion',
#   'dlrs',
#   '``',
#   'political',
#   'reasons',
#   '35',
#   '40',
#   'billion',
#   'dlrs',
#   "'re",
#   'going',
#   'get',
#   "''",
#   'congress',
#   'present',
#   'time',
#   'said',
#   'touche',
#   'ross',
#   "'s",
#   'collander',
#   '``',
#   'something',
#   'would',
#   'extraordinary',
#   'remarkable',
#   'difficult',
#   "''",
#   'collander',
#   'said',
#   'real',
#   'danger',
#   'congress',
#   'end',
#   'short',
#   'deficit',
#   'reduction',
#   'goal',
#   'set',
#   'budget',
#   'panels',
#   '``',
#   'extent',
#   'become',
#   'minimum',
#   'acceptable',
#   'reduction',
#   'level',
#   "''",
#   'explained',
#   '``',
#   'anything',
#   'less',
#   'look',
#   'like',
#   'failure',
#   'wall',
#   'street',
#   "''",
#   'budget',
#   'plan',
#   'debate',
#   'house',
#   'floor',
#   'would',
#   'lower',
#   'estimated',
#   '171',
#   'billion',
#   'dlr',
#   'deficit',
#   'year',
#   'beginning',
#   'october',
#   'one',
#   '133',
#   'billion',
#   'dlrs',
#   'cutting',
#   'defense',
#   'domestic',
#   'programs',
#   '38',
#   'billion',
#   'dlrs',
#   'anticipated',
#   'spending',
#   'levels',
#   'next',
#   'year',
#   'senate',
#   'budget',
#   'committee',
#   'called',
#   'deficit',
#   'nearly',
#   '134',
#   'billion',
#   'dlrs',
#   '18.5',
#   'billion',
#   'dlrs',
#   'new',
#   'taxes',
#   'amount',
#   'spending',
#   'cuts'],
#  ['economic',
#   'spotlight',
#   'telecom',
#   'key',
#   'japan',
#   'ministry',
#   'japan',
#   "'s",
#   'little-known',
#   'ministry',
#   'posts',
#   'telecommunications',
#   'mpt',
#   'emerged',
#   'international',
#   'force',
#   'reckoned',
#   'political',
#   'analysts',
#   'said',
#   'mpt',
#   'thrust',
#   'spotlight',
#   'trade',
#   'rows',
#   'u.s.',
#   'britain',
#   'position',
#   'strength',
#   'due',
#   'control',
#   'lucrative',
#   'industry',
#   'ties',
#   'important',
#   'politicians',
#   'said',
#   '``',
#   'ministry',
#   'standing',
#   'athwart',
#   'regulatory',
#   'control',
#   'key',
#   'industrial',
#   'sector',
#   'telecommunications',
#   'information',
#   "''",
#   'said',
#   'one',
#   'diplomatic',
#   'source',
#   '``',
#   'potent',
#   'political',
#   'force',
#   "''",
#   'diplomatic',
#   'source',
#   'said',
#   'mpt',
#   'finding',
#   'domestic',
#   'political',
#   'prowess',
#   'always',
#   'help',
#   'comes',
#   'trade',
#   'friction',
#   'diplomacy',
#   'analysts',
#   'said',
#   '``',
#   'ministry',
#   'minor',
#   'ministry',
#   'people',
#   'internationalized',
#   "''",
#   'said',
#   'waseda',
#   'university',
#   'professor',
#   'mitsuru',
#   'uchida',
#   '``',
#   'suddenly',
#   "'re",
#   'standing',
#   'centre',
#   'world',
#   'community',
#   'sense',
#   "'re",
#   'loss',
#   'face',
#   'situation',
#   "''",
#   'recently',
#   'ministry',
#   'embroiled',
#   'row',
#   'london',
#   'efforts',
#   'britain',
#   "'s",
#   'cable',
#   'wireless',
#   'plc',
#   'keep',
#   'major',
#   'stake',
#   'one',
#   'two',
#   'consortia',
#   'trying',
#   'compete',
#   'japan',
#   "'s",
#   'lucrative',
#   'overseas',
#   'telephone',
#   'business',
#   'ministry',
#   'favoured',
#   'merger',
#   'two',
#   'rival',
#   'groups',
#   'arguing',
#   'market',
#   'support',
#   'one',
#   'competitor',
#   'kokusai',
#   'denshin',
#   'denwa',
#   'co',
#   'ltd',
#   'monopolizes',
#   'business',
#   'also',
#   'opposed',
#   'major',
#   'management',
#   'role',
#   'planned',
#   'merger',
#   'non-japanese',
#   'overseas',
#   'telecommunications',
#   'firm',
#   'grounds',
#   'international',
#   'precedent',
#   'exists',
#   'ministry',
#   "'s",
#   'stance',
#   'outraged',
#   'london',
#   'threatened',
#   'retaliate',
#   'washington',
#   'says',
#   'merger',
#   'plan',
#   'evidence',
#   'japan',
#   "'s",
#   'failure',
#   'honour',
#   'pledges',
#   'open',
#   'telecommunications',
#   'market',
#   'washington',
#   'also',
#   'angry',
#   'ministry',
#   'moves',
#   'says',
#   'limited',
#   'access',
#   'u.s.',
#   'firms',
#   'japan',
#   "'s",
#   'car',
#   'telephone',
#   'satellite',
#   'communications',
#   'market',
#   'much',
#   'mpt',
#   "'s",
#   'new',
#   'prominence',
#   'stems',
#   'growth',
#   'sector',
#   'regulates',
#   '``',
#   'happening',
#   'important',
#   'shift',
#   'economy',
#   'makes',
#   'ministry',
#   'important',
#   'place',
#   "''",
#   'said',
#   'james',
#   'abegglen',
#   'head',
#   'consulting',
#   'firm',
#   'asia',
#   'advisory',
#   'service',
#   'inc.',
#   'decision',
#   'open',
#   'telecommunications',
#   'industry',
#   'competition',
#   'new',
#   'set',
#   'laws',
#   'passed',
#   '1985',
#   'boosted',
#   'rather',
#   'lessened',
#   'mpt',
#   "'s",
#   'authority',
#   'analysts',
#   'said',
#   '``',
#   'legal',
#   'framework',
#   'eased',
#   'became',
#   'de',
#   'facto',
#   'legal',
#   'framework',
#   "''",
#   'said',
#   'bache',
#   'securities',
#   'japan',
#   'analyst',
#   'darrell',
#   'whitten',
#   'close',
#   'links',
#   'powerful',
#   'political',
#   'faction',
#   'ruling',
#   'liberal',
#   'democratic',
#   'party',
#   'ldp',
#   'nurtured',
#   'former',
#   'prime',
#   'minister',
#   'kakuei',
#   'tanaka',
#   'another',
#   'key',
#   'mpt',
#   "'s",
#   'influence',
#   'analysts',
#   'said',
#   '``',
#   'factions',
#   'ignored',
#   'mpt',
#   '1970s',
#   'tanaka',
#   'faction',
#   'forward',
#   'looking',
#   '...',
#   'recognized',
#   'importance',
#   'mpt',
#   "''",
#   'uchida',
#   'said',
#   'many',
#   'former',
#   'bureaucrats',
#   'became',
#   'members',
#   'influential',
#   'political',
#   'group',
#   'added',
#   'ministry',
#   'also',
#   'power',
#   'financial',
#   'sector',
#   'due',
#   '100,000',
#   'billion',
#   'yen',
#   'worth',
#   'deposits',
#   'postal',
#   'savings',
#   'system',
#   'analysts',
#   'said',
#   'mpt',
#   'helped',
#   'block',
#   'finance',
#   'ministry',
#   'plans',
#   'deregulate',
#   'interest',
#   'rates',
#   'small',
#   'deposits',
#   'key',
#   'element',
#   'financial',
#   'liberalisation',
#   'since',
#   'change',
#   'would',
#   'remove',
#   'postal',
#   'savings',
#   'system',
#   "'s",
#   'ability',
#   'offer',
#   'slightly',
#   'higher',
#   'rates',
#   'banks',
#   'said',
#   'diplomatic',
#   'sources',
#   'frustrated',
#   'see',
#   'mpt',
#   "'s",
#   'obstructionist',
#   'protectionist',
#   'posture',
#   'characterized',
#   'ministry',
#   'feudal',
#   'critics',
#   'charge',
#   'mpt',
#   'protecting',
#   'turf',
#   'limiting',
#   'competition',
#   'sheltering',
#   'former',
#   'monopolies',
#   'wing',
#   'providing',
#   'consumers',
#   'best',
#   'service',
#   'lowest',
#   'price',
#   'takes',
#   'back',
#   'seat',
#   'considerations',
#   'said',
#   'many',
#   'ministry',
#   "'s",
#   'actions',
#   'unlike',
#   'bureaucratic',
#   'counterparts',
#   'much',
#   'western',
#   'world',
#   'including',
#   'britain',
#   'several',
#   'analysts',
#   'said',
#   '``',
#   'united',
#   'states',
#   'really',
#   'odd',
#   'man',
#   "''",
#   'abegglen',
#   'said',
#   '``',
#   'government',
#   'take',
#   'view',
#   'wants',
#   'keep',
#   'order',
#   'utilities',
#   'markets',
#   'unusual',
#   'and/or',
#   'unreasonable',
#   'view',
#   "''",
#   'said'],
#  ['g-7',
#   'issues',
#   'statement',
#   'meeting',
#   'following',
#   'text',
#   'statement',
#   'group',
#   'seven',
#   '--',
#   'u.s.',
#   'japan',
#   'west',
#   'germany',
#   'france',
#   'britain',
#   'italy',
#   'canada',
#   '--',
#   'issued',
#   'washington',
#   'meeting',
#   'yesterday',
#   '1.',
#   'finance',
#   'ministers',
#   'central',
#   'bank',
#   'governors',
#   'seven',
#   'major',
#   'industrial',
#   'countries',
#   'met',
#   'today',
#   'continued',
#   'process',
#   'multilateral',
#   'surveillance',
#   'economies',
#   'pursuant',
#   'arrangements',
#   'strengthened',
#   'economic',
#   'policy',
#   'coordination',
#   'agreed',
#   '1986',
#   'tokyo',
#   'summit',
#   'heads',
#   'state',
#   'government',
#   'managing',
#   'director',
#   'international',
#   'monetary',
#   'fund',
#   'also',
#   'participated',
#   'meeting',
#   '2.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'commitment',
#   'cooperative',
#   'approach',
#   'agreed',
#   'recent',
#   'paris',
#   'meeting',
#   'noted',
#   'progress',
#   'achieved',
#   'implementing',
#   'undertakings',
#   'embodied',
#   'louvre',
#   'agreement',
#   'agreed',
#   'however',
#   'actions',
#   'essential',
#   'resist',
#   'rising',
#   'protectionist',
#   'pressures',
#   'sustain',
#   'global',
#   'economic',
#   'expansion',
#   'reduce',
#   'trade',
#   'imbalances',
#   'connection',
#   'welcomed',
#   'proposals',
#   'announced',
#   'governing',
#   'liberal',
#   'democratic',
#   'party',
#   'japan',
#   'extraordinary',
#   'urgent',
#   'measures',
#   'stimulate',
#   'japan',
#   "'s",
#   'economy',
#   'early',
#   'implementation',
#   'large',
#   'supplementary',
#   'budget',
#   'exceeding',
#   'previous',
#   'years',
#   'well',
#   'unprecedented',
#   'front-end',
#   'loading',
#   'public',
#   'works',
#   'expenditures',
#   'government',
#   'japan',
#   'reaffirmed',
#   'intention',
#   'open',
#   'domestic',
#   'markets',
#   'foreign',
#   'goods',
#   'services',
#   '3.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'view',
#   'around',
#   'current',
#   'levels',
#   'currencies',
#   'within',
#   'ranges',
#   'broadly',
#   'consistent',
#   'economic',
#   'fundamentals',
#   'basic',
#   'policy',
#   'intentions',
#   'outlined',
#   'louvre',
#   'meeting',
#   'connection',
#   'welcomed',
#   'strong',
#   'implementation',
#   'louvre',
#   'agreement',
#   'concluded',
#   'present',
#   'prospective',
#   'progress',
#   'implementing',
#   'policy',
#   'undertakings',
#   'louvre',
#   'statement',
#   'provided',
#   'basis',
#   'continuing',
#   'close',
#   'cooperation',
#   'foster',
#   'stability',
#   'exchange',
#   'rates'],
#  ['soviet',
#   'trade',
#   'deficit',
#   'west',
#   'soars',
#   '1986',
#   'soviet',
#   'trade',
#   'deficit',
#   'west',
#   'almost',
#   'quadrupled',
#   'last',
#   'year',
#   'reaching',
#   '2.72',
#   'billion',
#   'roubles',
#   'compared',
#   '713',
#   'mln',
#   '1985',
#   'official',
#   'figures',
#   'showed',
#   'statistics',
#   'published',
#   'monthly',
#   'journal',
#   'foreign',
#   'trade',
#   'showed',
#   'soviet',
#   'trade',
#   'turnover',
#   '1986',
#   'fell',
#   '130.9',
#   'billion',
#   'roubles',
#   '142.1',
#   'billion',
#   'previous',
#   'year',
#   'drop',
#   '7.8',
#   'pct',
#   'moscow',
#   "'s",
#   'trade',
#   'surplus',
#   'east',
#   'bloc',
#   'countries',
#   'continued',
#   'grow',
#   '1986.',
#   'western',
#   'analysts',
#   'attributed',
#   'deficit',
#   'rise',
#   'west',
#   'world',
#   'oil',
#   'price',
#   'slump',
#   'hit',
#   'moscow',
#   "'s",
#   'main',
#   'export',
#   'cut',
#   'hard',
#   'currency',
#   'earnings',
#   'needed',
#   'purchases',
#   'west'],
#  ['canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'january',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus',
#   'canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'january',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus'],
#  ['canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.2',
#   'billion',
#   'dlrs',
#   'canada',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'february',
#   'compared',
#   'upward',
#   'revised',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus',
#   'january',
#   'statistics',
#   'canada',
#   'said',
#   'january',
#   'surplus',
#   'originally',
#   'reported',
#   '533',
#   'mln',
#   'dlrs',
#   'february',
#   'surplus',
#   'last',
#   'year',
#   '189',
#   'mln',
#   'dlrs',
#   'february',
#   'exports',
#   'seasonally',
#   'adjusted',
#   '10.44',
#   'billion',
#   'dlrs',
#   '9.85',
#   'billion',
#   'january',
#   '10.05',
#   'billion',
#   'february',
#   '1986.',
#   'february',
#   'imports',
#   '9.19',
#   'billion',
#   'dlrs',
#   '9.23',
#   'billion',
#   'january',
#   '9.86',
#   'billion',
#   'february',
#   '1986'],
#  ['ec',
#   'launches',
#   'anti-dumping',
#   'probe',
#   'japanese',
#   'chips',
#   'european',
#   'community',
#   'launched',
#   'investigation',
#   'allegations',
#   'dumping',
#   'japanese',
#   'semiconductor',
#   'makers',
#   'move',
#   'diplomats',
#   'said',
#   'could',
#   'mark',
#   'intensification',
#   'world',
#   'trade',
#   'strains',
#   'tokyo',
#   'already',
#   'faces',
#   'deadline',
#   'april',
#   '17',
#   'washington',
#   'imposition',
#   '300',
#   'mln',
#   'dlrs',
#   'worth',
#   'tariffs',
#   'chips',
#   'imports',
#   'u.s.',
#   'ec',
#   'executive',
#   'commission',
#   'said',
#   'today',
#   'european',
#   'electrical',
#   'component',
#   'manufacturers',
#   'association',
#   'complained',
#   'japanese',
#   'firms',
#   'selling',
#   'high',
#   'capacity',
#   'eprom',
#   'type',
#   'erasable',
#   'programmable',
#   'read',
#   'memory',
#   'chips',
#   'unfairly',
#   'low',
#   'prices',
#   'japan',
#   'last',
#   'year',
#   'took',
#   '78',
#   'pct',
#   '170',
#   'mln',
#   'dlr',
#   'ec',
#   'eprom',
#   'market',
#   '60',
#   'pct',
#   '1984.',
#   'ec',
#   'firms',
#   'said',
#   'forced',
#   'offer',
#   'products',
#   'discount',
#   '30',
#   'pct',
#   'order',
#   'compete',
#   'japanese',
#   'commission',
#   'said',
#   'believed',
#   'association',
#   'given',
#   'sufficient',
#   'elements',
#   'proof',
#   'dumping',
#   'warrant',
#   'investigation',
#   'could',
#   'lead',
#   'impose',
#   'duties',
#   'found',
#   'complaints',
#   'justified',
#   'commission',
#   'claims',
#   'last',
#   'year',
#   "'s",
#   'accord',
#   'u.s.',
#   'japan',
#   'microchip',
#   'pricing',
#   'gives',
#   'u.s.',
#   'firms',
#   'privileged',
#   'access',
#   'japanese',
#   'market'],
#  ['g-7',
#   'issues',
#   'statement',
#   'meeting',
#   'following',
#   'text',
#   'statement',
#   'group',
#   'seven',
#   '--',
#   'u.s.',
#   'japan',
#   'west',
#   'germany',
#   'france',
#   'britain',
#   'italy',
#   'canada',
#   '--',
#   'issued',
#   'washington',
#   'meeting',
#   'yesterday',
#   '1.',
#   'finance',
#   'ministers',
#   'central',
#   'bank',
#   'governors',
#   'seven',
#   'major',
#   'industrial',
#   'countries',
#   'met',
#   'today',
#   'continued',
#   'process',
#   'multilateral',
#   'surveillance',
#   'economies',
#   'pursuant',
#   'arrangements',
#   'strengthened',
#   'economic',
#   'policy',
#   'coordination',
#   'agreed',
#   '1986',
#   'tokyo',
#   'summit',
#   'heads',
#   'state',
#   'government',
#   'managing',
#   'director',
#   'international',
#   'monetary',
#   'fund',
#   'also',
#   'participated',
#   'meeting',
#   '2.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'commitment',
#   'cooperative',
#   'approach',
#   'agreed',
#   'recent',
#   'paris',
#   'meeting',
#   'noted',
#   'progress',
#   'achieved',
#   'implementing',
#   'undertakings',
#   'embodied',
#   'louvre',
#   'agreement',
#   'agreed',
#   'however',
#   'actions',
#   'essential',
#   'resist',
#   'rising',
#   'protectionist',
#   'pressures',
#   'sustain',
#   'global',
#   'economic',
#   'expansion',
#   'reduce',
#   'trade',
#   'imbalances',
#   'connection',
#   'welcomed',
#   'proposals',
#   'announced',
#   'governing',
#   'liberal',
#   'democratic',
#   'party',
#   'japan',
#   'extraordinary',
#   'urgent',
#   'measures',
#   'stimulate',
#   'japan',
#   "'s",
#   'economy',
#   'early',
#   'implementation',
#   'large',
#   'supplementary',
#   'budget',
#   'exceeding',
#   'previous',
#   'years',
#   'well',
#   'unprecedented',
#   'front-end',
#   'loading',
#   'public',
#   'works',
#   'expenditures',
#   'government',
#   'japan',
#   'reaffirmed',
#   'intention',
#   'open',
#   'domestic',
#   'markets',
#   'foreign',
#   'goods',
#   'services',
#   '3.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'view',
#   'around',
#   'current',
#   'levels',
#   'currencies',
#   'within',
#   'ranges',
#   'broadly',
#   'consistent',
#   'economic',
#   'fundamentals',
#   'basic',
#   'policy',
#   'intentions',
#   'outlined',
#   'louvre',
#   'meeting',
#   'connection',
#   'welcomed',
#   'strong',
#   'implementation',
#   'louvre',
#   'agreement',
#   'concluded',
#   'present',
#   'prospective',
#   'progress',
#   'implementing',
#   'policy',
#   'undertakings',
#   'louvre',
#   'statement',
#   'provided',
#   'basis',
#   'continuing',
#   'close',
#   'cooperation',
#   'foster',
#   'stability',
#   'exchange',
#   'rates'],
#  ['spanish',
#   'employers',
#   'worried',
#   'high',
#   'interest',
#   'rates',
#   'head',
#   'spain',
#   "'s",
#   'employers',
#   'federation',
#   'jose',
#   'maria',
#   'cuevas',
#   'said',
#   'employers',
#   'worried',
#   'government',
#   "'s",
#   'monetary',
#   'policies',
#   'high',
#   'real',
#   'interest',
#   'rates',
#   'hampering',
#   'investment',
#   'told',
#   'news',
#   'conference',
#   'wage',
#   'pacts',
#   'signed',
#   'far',
#   'year',
#   'endangering',
#   'government',
#   "'s",
#   'five',
#   'pct',
#   'inflation',
#   'target',
#   'government',
#   "'s",
#   'perceived',
#   'need',
#   'control',
#   'inflation',
#   'keeping',
#   'tight',
#   'rein',
#   'credit',
#   'unnecessary',
#   'said',
#   'high',
#   'real',
#   'interest',
#   'rates',
#   'attracting',
#   'influx',
#   'speculative',
#   'foreign',
#   'capital',
#   'undercutting',
#   'government',
#   "'s",
#   'target',
#   'monetary',
#   'growth',
#   'cuevas',
#   'said',
#   'spain',
#   "'s",
#   'closely-watched',
#   'measure',
#   'money',
#   'supply',
#   'liquid',
#   'assets',
#   'public',
#   'hands',
#   'grew',
#   'annualised',
#   'rate',
#   '17',
#   'pct',
#   'march',
#   '11.4',
#   'pct',
#   'december',
#   'last',
#   'year',
#   'target',
#   'range',
#   '6.5',
#   '9.5',
#   'pct',
#   '1987.',
#   'combat',
#   'bank',
#   'spain',
#   'raised',
#   'call',
#   'money',
#   'rate',
#   '14',
#   'times',
#   'far',
#   'year',
#   '14.5',
#   'pct',
#   'present',
#   '11.8',
#   'end-1986',
#   'cuevas',
#   'said',
#   'employers',
#   'heeding',
#   'government',
#   "'s",
#   'call',
#   'hold',
#   'wage',
#   'increases',
#   'five',
#   'pct',
#   'inflation',
#   'target',
#   'year',
#   'increases',
#   'salary',
#   'reviews',
#   'awarded',
#   'last',
#   'year',
#   'new',
#   'wage',
#   'pacts',
#   'averaging',
#   '5.6',
#   'pct',
#   'first',
#   'quarter',
#   '1987.',
#   'agreements',
#   'covered',
#   'less',
#   '40',
#   'pct',
#   'spanish',
#   'workers',
#   'cuevas',
#   'said',
#   'rest',
#   'still',
#   'wage',
#   'negotiations',
#   'said',
#   'spain',
#   "'s",
#   'current',
#   'wave',
#   'strikes',
#   'mainly',
#   'affected',
#   'state',
#   'sector',
#   'government',
#   'trying',
#   'impose',
#   'five',
#   'pct',
#   'wage',
#   'ceiling',
#   'cuevas',
#   'said',
#   'employers',
#   'also',
#   'worried',
#   'trend',
#   'spain',
#   "'s",
#   'foreign',
#   'trade',
#   'balance',
#   'trade',
#   'deficit',
#   'first',
#   'two',
# ...
#   'said',
#   'exceptionally',
#   'cold',
#   'weather',
#   'january',
#   'reduced',
#   'exports',
#   'month',
#   'element',
#   'catching',
#   'february',
#   'figures',
#   'seasonally',
#   'adjusted',
#   'volume',
#   'index',
#   'base',
#   '1980',
#   'guide',
#   'underlying',
#   'non-oil',
#   'trade',
#   'showed',
#   'exports',
#   'rising',
#   '131.0',
#   '114.6',
#   'january',
#   'imports',
#   'rising',
#   '142.2',
#   '136.5.',
#   'value',
#   'british',
#   'oil',
#   'exports',
#   'february',
#   'rose',
#   '751',
#   'mln',
#   'stg',
#   '723',
#   'mln',
#   'jnauary',
#   'oil',
#   'imports',
#   'rose',
#   '425',
#   'mln',
#   '352',
#   'mln'],
#  ['hong',
#   'kong',
#   'february',
#   'trade',
#   'swings',
#   'deficit',
#   'hong',
#   'kong',
#   'recorded',
#   '3.51',
#   'billion',
#   'h.k',
#   'dlr',
#   'deficit',
#   'february',
#   '2.54',
#   'billion',
#   'dlr',
#   'surplus',
#   'january',
#   'imports',
#   'climbed',
#   'exports',
#   'slid',
#   'census',
#   'statistics',
#   'department',
#   'said',
#   'deficit',
#   'compared',
#   'deficit',
#   '1.76',
#   'billion',
#   'dlrs',
#   'february',
#   '1986.',
#   'imports',
#   'rose',
#   '24.12',
#   'billion',
#   'dlrs',
#   '2.6',
#   'pct',
#   'january',
#   "'s",
#   '23.52',
#   'billion',
#   'dlrs',
#   '42',
#   'pct',
#   '16.98',
#   'billion',
#   'dlrs',
#   'recorded',
#   'february',
#   '1986.',
#   'total',
#   'exports',
#   'month',
#   'fell',
#   '20.9',
#   'pct',
#   '20.61',
#   'billion',
#   'dlrs',
#   '26.06',
#   'billion',
#   'january',
#   'february',
#   'exports',
#   'still',
#   '35.4',
#   'pct',
#   '15.22',
#   'billion',
#   'dlrs',
#   'recorded',
#   'month',
#   'last',
#   'year',
#   're-exports',
#   'territory',
#   "'s",
#   'traditional',
#   'entrepot',
#   'trade',
#   'outpaced',
#   'domestically',
#   'produced',
#   'exports',
#   'first',
#   'time',
#   'since',
#   'march',
#   '1985.',
#   're-exports',
#   'fell',
#   '11.6',
#   'pct',
#   '10.62',
#   'billion',
#   'dlrs',
#   '12.0',
#   'billion',
#   'dlrs',
#   'january',
#   '54',
#   'pct',
#   'february',
#   '1986',
#   "'s",
#   '6.88',
#   'billion',
#   'dlrs',
#   'domestic',
#   'exports',
#   'slid',
#   '28.9',
#   'pct',
#   '9.99',
#   'billion',
#   'dlrs',
#   'january',
#   "'s",
#   '14.05',
#   'billion',
#   'dlrs',
#   '19.7',
#   'pct',
#   '8.35',
#   'billion',
#   'dlrs',
#   'recorded',
#   'february',
#   '1986'],
#  ['british',
#   'politicians',
#   'urge',
#   'japan',
#   'trade',
#   'sanctions',
#   'one',
#   'hundred',
#   'members',
#   'britain',
#   "'s",
#   'ruling',
#   'conservative',
#   'party',
#   'signed',
#   'motion',
#   'calling',
#   'trade',
#   'sanctions',
#   'japan',
#   'force',
#   'tokyo',
#   'open',
#   'domestic',
#   'market',
#   'british',
#   'goods',
#   'government',
#   'announced',
#   'last',
#   'week',
#   'japan',
#   '5.9',
#   'billion',
#   'dlr',
#   'trade',
#   'surplus',
#   'britain',
#   '1986.',
#   'department',
#   'trade',
#   'industry',
#   'said',
#   'government',
#   'drawing',
#   'contingency',
#   'plans',
#   'force',
#   'japan',
#   'opening',
#   'domestic',
#   'markets',
#   'spokesman',
#   'said',
#   'moves',
#   'much',
#   'last',
#   'resort',
#   'ideas',
#   'considered',
#   'included',
#   'blocking',
#   'japanese',
#   'companies',
#   'trading',
#   'britain',
#   'revoking',
#   'licenses',
#   'japanese',
#   'operations',
#   'london',
#   'financial',
#   'district'],
#  ['u.k.',
#   'trade',
#   'figures',
#   'buoy',
#   'hopes',
#   'interest',
#   'rate',
#   'cut',
#   'release',
#   'u.k.',
#   'february',
#   'trade',
#   'data',
#   'showing',
#   'current',
#   'account',
#   'surplus',
#   'provisional',
#   '376',
#   'mln',
#   'stg',
#   '73',
#   'mln',
#   'surplus',
#   'january',
#   'boosted',
#   'hopes',
#   'early',
#   'cut',
#   'interest',
#   'rates',
#   'analysts',
#   'said',
#   'market',
#   'forecasts',
#   'worse',
#   'outcome',
#   'expectations',
#   'deficit',
#   'visible',
#   'trade',
#   'averaging',
#   '750',
#   'mln',
#   'stg',
#   'official',
#   'figure',
#   '224',
#   'mln',
#   'stg',
#   'sharply',
#   'narrower',
#   'january',
#   "'s",
#   '527',
#   'mln',
#   'deficit',
#   '``',
#   'figures',
#   'unreservedly',
#   'good',
#   "''",
#   'chase',
#   'manhattan',
#   'securities',
#   'economist',
#   'andrew',
#   'wroblewski',
#   'said',
#   'sterling',
#   'rebounded',
#   'trade',
#   'figures',
#   'reversing',
#   'weaker',
#   'morning',
#   'trend',
#   'stand',
#   '72.1',
#   'pct',
#   'trade',
#   'weighted',
#   'index',
#   'basket',
#   'currencies',
#   'midday',
#   'unchanged',
#   'yesterday',
#   "'s",
#   'close',
#   '0.3',
#   'points',
#   '1100',
#   'gmt',
#   'level',
#   'market',
#   'feared',
#   'deteriorating',
#   'non-oil',
#   'trade',
#   'pattern',
#   'would',
#   'undermine',
#   'international',
#   'support',
#   'sterling',
#   'motor',
#   'behind',
#   'recent',
#   'fall',
#   'u.k.',
#   'interest',
#   'rates',
#   'money',
#   'market',
#   'sources',
#   'said',
#   'market',
#   'begun',
#   'doubt',
#   'widely',
#   'expected',
#   'drop',
#   'bank',
#   'base',
#   'lending',
#   'rates',
#   '9.5',
#   'pct',
#   'present',
#   '10.0',
#   'pct',
#   'really',
#   'cards',
#   'sentiment',
#   'looks',
#   'turned',
#   'looks',
#   'danger',
#   'chancellor',
#   'exchequer',
#   'nigel',
#   'lawson',
#   "'s",
#   'forecast',
#   '1987',
#   'current',
#   'account',
#   'deficit',
#   '2.5',
#   'billion',
#   'stg',
#   'exceeded',
#   'said',
#   'wroblewski',
#   'seasonally',
#   'adjusted',
#   'figures',
#   'showed',
#   'imports',
#   'rose',
#   'february',
#   '7.16',
#   'billion',
#   'stg',
#   '6.73',
#   'billion',
#   'january',
#   'exports',
#   'rose',
#   'record',
#   '6.93',
#   'billion',
#   '6.20',
#   'billion',
#   'however',
#   'chris',
#   'tinker',
#   'u.k.',
#   'analyst',
#   'brokers',
#   'phillips',
#   'drew',
#   'said',
#   'faster',
#   'rise',
#   'exports',
#   'imports',
#   'would',
#   'prove',
#   'partly',
#   'aberrational',
#   'coming',
#   'months',
#   'forecast',
#   'chancellor',
#   "'s",
#   'budget',
#   'tax',
#   'cuts',
#   'would',
#   'increase',
#   'consumer',
#   'expediture',
#   'imported',
#   'goods',
#   'however',
#   'ian',
#   'harwood',
#   'economist',
#   'warburg',
#   'securities',
#   'said',
#   'firm',
#   'sharply',
#   'revising',
#   '1987',
#   'current',
#   'account',
#   'deficit',
#   'forecast',
#   'light',
#   'latest',
#   'data',
#   'cutting',
#   'one',
#   'billion',
#   'stg',
#   'expected',
#   'full',
#   'year',
#   'total',
#   '1.75',
#   'billion',
#   'stg',
#   'said',
#   'news',
#   'strong',
#   'growth',
#   'exports',
#   'non-oil',
#   'goods',
#   'confirmed',
#   'recent',
#   'bullish',
#   'surveys',
#   'among',
#   'members',
#   'confederation',
#   'british',
#   'industry',
#   'growth',
#   'imports',
#   'appears',
#   'flattening',
#   'even',
#   'january',
#   "'s",
#   'bad',
#   'weather',
#   'curbed',
#   'consumer',
#   'spending',
#   'overseas',
#   'goods',
#   'import-intensive',
#   'stock',
#   'building',
#   'among',
#   'manufactureres',
#   'harwood',
#   'said',
#   'u.k.',
#   'government',
#   'bonds',
#   'gilts',
#   'surged',
#   '1/2',
#   'point',
#   'better-than-expected',
#   'news',
#   'earlier',
#   'worries',
#   'figures',
#   'evaporated',
#   'sterling',
#   'peaked',
#   'high',
#   '1.6075',
#   'dlrs',
#   'settling',
#   'steady',
#   '1.6050',
#   'dlrs',
#   '1300',
#   'gmt',
#   'nearly',
#   'cent',
#   'higher',
#   'european',
#   'low',
#   '1.5960.',
#   'however',
#   'analysts',
#   'noted',
#   'turnabout',
#   'market',
#   'sentiment',
#   'still',
#   'looks',
#   'highly',
#   'vulnerable',
#   'political',
#   'news',
#   'morning',
#   'weakness',
#   'sterling',
#   'gilt',
#   'market',
#   'largely',
#   'attributed',
#   'newspaper',
#   'opinion',
#   'poll',
#   'showing',
#   'conservative',
#   'government',
#   "'s",
#   'support',
#   'slipping',
#   'marplan',
#   'poll',
#   'published',
#   '``',
#   'today',
#   "''",
#   'showed',
#   'conservative',
#   'support',
#   'fallen',
#   '36',
#   'pct',
#   '38',
#   'pct',
#   'last',
#   'month',
#   'alliance',
#   'liberals',
#   'social',
#   'democrats',
#   'rallied',
#   '31',
#   'pct',
#   '21',
#   'pct',
#   'run',
#   'neck',
#   'neck',
#   'labour',
#   'party',
#   'whose',
#   'support',
#   'fell',
#   '38',
#   'pct',
#   'poll',
#   'taken',
#   'budget',
#   'greeted',
#   'enthusiastically',
#   'financial',
#   'markets',
#   'seems',
#   'left',
#   'voters',
#   'indifferent',
#   'political',
#   'observers',
#   'said',
#   'another',
#   'regular',
#   'poll',
#   'due',
#   'tomorrow',
#   'eonomists',
#   'warn',
#   'today',
#   "'s",
#   'improved',
#   'sentiment',
#   'could',
#   'dented',
#   'support',
#   'prime',
#   'minister',
#   'margaret',
#   'thatcher',
#   'slips',
#   'upsetting',
#   'markets',
#   'political',
#   'perceptions',
#   'discounting',
#   'conservative',
#   'victory',
#   'upcoming',
#   'general',
#   'election',
#   'made',
#   'sensitive',
#   'trade',
#   'data',
#   'harwood',
#   'said',
#   '``',
#   'news',
#   'come',
#   'substantial',
#   'relief',
#   "''",
#   'said',
#   'however',
#   'interest',
#   'rate',
#   'front',
#   'economists',
#   'caution',
#   'lawson',
#   'might',
#   'wary',
#   'leaving',
#   'sterling',
#   'vulnerable',
#   'encouraging',
#   'another',
#   'base',
#   'rate',
#   'fall',
#   'noted',
#   'lawson',
#   'already',
#   'got',
#   'inflation-reducing',
#   'cut',
#   'mortgage',
#   'rates',
#   'response',
#   'lower',
#   'base',
#   'rates',
#   'domestic',
#   'political',
#   'reasons',
#   'lower',
#   'rates',
#   'curtailed'],
#  ['s.',
#   'korea',
#   'may',
#   'buy',
#   'u.s.',
#   'oil',
#   'aid',
#   'trade',
#   'balance',
#   'south',
#   'korea',
#   'studying',
#   'plan',
#   'buy',
#   'coal',
#   'united',
#   'states',
#   'start',
#   'importing',
#   'alaskan',
#   'crude',
#   'oil',
#   'help',
#   'reduce',
#   'huge',
#   'trade',
#   'surplus',
#   'united',
#   'states',
#   'energy',
#   'ministry',
#   'officials',
#   'said',
#   'today',
#   'said',
#   'plan',
#   'would',
#   'dominate',
#   'discussions',
#   'two-day',
#   'energy',
#   'talks',
#   'officials',
#   'two',
#   'countries',
#   'washington',
#   'april',
#   '1.',
#   'huh',
#   'sun-yong',
#   'attend',
#   'talks',
#   'three',
#   'seoul',
#   'government',
#   'officials',
#   'told',
#   'reuters',
#   'seoul',
#   '``',
#   'positively',
#   'considering',
#   'buying',
#   'certain',
#   'amount',
#   'alaskan',
#   'oil',
#   'beginning',
#   'year',
#   'part',
#   'government',
#   "'s",
#   'overall',
#   'plan',
#   'reduce',
#   'widening',
#   'trade',
#   'gap',
#   'two',
#   'countries',
#   "''",
#   'huh',
#   'said',
#   'however',
#   'south',
#   'korean',
#   'refineries',
#   'considered',
#   'alaskan',
#   'oil',
#   'economically',
#   'uncompetitive'],
#  ['u.s',
#   'treasury',
#   "'s",
#   'mulford',
#   'reaffirms',
#   'g-6',
#   'agreement',
#   'treasury',
#   'assistant',
#   'secretary',
#   'david',
#   'mulford',
#   'reaffirmed',
#   'u.s.',
#   'backing',
#   'paris',
#   'agreement',
#   'among',
#   'six',
#   'industrial',
#   'nations',
#   'cooperate',
#   'closely',
#   'foster',
#   'exchange',
#   'rate',
#   'stability',
#   'around',
#   'current',
#   'levels',
#   'testimony',
#   'prepared',
#   'delivery',
#   'senate',
#   'banking',
#   'subcommittee',
#   'mulford',
#   'said',
#   'broad',
#   'recognition',
#   'paris',
#   '``',
#   'substantial',
#   'exchange',
#   'rate',
#   'shifts',
#   'could',
#   'damage',
#   'growth',
#   'adjustment',
#   'prospects',
#   "''",
#   'also',
#   'said',
#   'clear',
#   'understandings',
#   'among',
#   'countries',
#   'regarding',
#   'cooperation',
#   '``',
#   'refrained',
#   'establishing',
#   'system',
#   'target',
#   'zones',
#   'ranges',
#   "''",
#   'mulford',
#   'also',
#   'said',
#   'six',
#   'nations',
#   'spelled',
#   'way',
#   'intend',
#   'deal',
#   'possible',
#   'market',
#   'developments',
#   'said',
#   'governments',
#   'must',
#   'retain',
#   'flexibility',
#   'dealing',
#   'exchange',
#   'market',
#   'pressures',
#   'efforts',
#   'establish',
#   'rigid',
#   'exchange',
#   'rate',
#   'objectives',
#   '``',
#   'specify',
#   'precisely',
#   'goals',
#   'intervention',
#   "''",
#   'would',
#   'hurt',
#   'official',
#   'attempts',
#   'react',
#   'market',
#   'pressures',
#   'said',
#   'accordingly',
#   'mulford',
#   'said',
#   'setting',
#   'specific',
#   'currency',
#   'objectives',
#   'intervention',
#   'achieve',
#   'objectives',
#   'would',
#   'counterproductive',
#   'commenting',
#   'trade',
#   'deficit',
#   'mulford',
#   'reiterated',
#   'treasury',
#   'position',
#   'current',
#   'account',
#   'deficit',
#   'decline',
#   '148',
#   'billion',
#   'dlrs',
#   'last',
#   'year',
#   'around',
#   '130',
#   'billion',
#   'dlrs',
#   'year',
#   'due',
#   'exchange',
#   'rate',
#   'adjustments',
#   'past',
#   '18',
#   'months',
#   'added',
#   'trade',
#   'imbalances',
#   'would',
#   'also',
#   'corrected',
#   'commitments',
#   'west',
#   'germany',
#   'japan',
#   'stimulate',
#   'economies',
#   'u.s.',
#   'efforts',
#   'cut',
#   'budget',
#   'deficit',
#   'enhance',
#   'u.s.',
#   'competitiveness',
#   'also',
#   'said',
#   'newly',
#   'industrialized',
#   'countries',
#   'let',
#   'currencies',
#   'appreciate'],
#  ['keating',
#   'revises',
#   'australian',
#   'growth',
#   'forecast',
#   'treasurer',
#   'paul',
#   'keating',
#   'forecast',
#   'economic',
#   'growth',
#   'slightly',
#   'two',
#   'pct',
#   'financial',
#   'year',
#   'ending',
#   'june',
#   'year',
#   '2.25',
#   'pct',
#   'forecast',
#   'contained',
#   '1986/87',
#   'budget',
#   'delivered',
#   'last',
#   'august',
#   'australia',
#   "'s",
#   'terms',
#   'trade',
#   'also',
#   'fell',
#   '18',
#   'pct',
#   'past',
#   'two',
#   'years',
#   'told',
#   'parliament',
#   'terms',
#   'trade',
#   'difference',
#   'import',
#   'export',
#   'price',
#   'indexes',
#   'despite',
#   'figures',
#   'budget',
#   'forecast',
#   '1.75',
#   'pct',
#   'annual',
#   'growth',
#   'employment',
#   'would',
#   'met',
#   'keating',
#   'said',
#   'unemployment',
#   'currently',
#   '8.2',
#   'pct',
#   'workforce',
#   '``',
#   'government',
#   'dragging',
#   'australia',
#   'trading',
#   'holocaust',
#   'kind',
#   'seen',
#   'since',
#   'second',
#   'world',
#   'war',
#   "''",
#   'keating',
#   'said',
#   '``',
#   'pushing',
#   'place',
#   'recession',
#   'holding',
#   'gains',
#   'unemployment',
#   'bringing',
#   'unemployment',
#   "''",
#   'said',
#   'adding',
#   'government',
#   'help',
#   'country',
#   'avoid',
#   'recession'],
#  ['u.s.',
#   'asks',
#   'japan',
#   'end',
#   'agriculture',
#   'import',
#   'controls',
#   'u.s.',
#   'wants',
#   'japan',
#   'eliminate',
#   'import',
#   'controls',
#   'agricultural',
#   'products',
#   'within',
#   'three',
#   'years',
#   'visiting',
#   'u.s.',
#   'under-secretary',
#   'state',
#   'economic',
#   'affairs',
#   'allen',
#   'wallis',
#   'told',
#   'eishiro',
#   'saito',
#   'chairman',
#   'federation',
#   'economic',
#   'organisations',
#   'keidanren',
#   'spokesman',
#   'keidanren',
#   'said',
#   'spokesman',
#   'quoted',
#   'wallis',
#   'saying',
#   'drastic',
#   'measures',
#   'would',
#   'needed',
#   'stave',
#   'protectionist',
#   'legislation',
#   'congress',
#   'wallis',
#   'attending',
#   'sub-cabinet-level',
#   'bilateral',
#   'trade',
#   'meeting',
#   'made',
#   'remark',
#   'yesterday',
#   'talks',
#   'saito',
#   'wallis',
#   'quoted',
#   'saying',
#   'reagan',
#   'administration',
#   'wants',
#   'japanese',
#   'cooperation',
#   'white',
#   'house',
#   'ensure',
#   'u.s.',
#   'trade',
#   'bill',
#   'moderate',
#   'one',
#   'rather',
#   'containing',
#   'retaliatory',
#   'measures',
#   'antagonising',
#   'particular',
#   'country',
#   'also',
#   'quoted',
#   'saying',
#   'u.s.',
#   'would',
#   'pleased',
#   'japan',
#   'halve',
#   'restrictions',
#   'agricultural',
#   'imports',
#   'within',
#   'five',
#   'years',
#   'country',
#   'cope',
#   'abolition',
#   'within',
#   'three',
#   'spokesman',
#   'said',
#   'japan',
#   'currently',
#   'restricts',
#   'imports',
#   '22',
#   'agricultural',
#   'products',
#   'ban',
#   'rice',
#   'imports',
#   'triggered',
#   'recent',
#   'u.s.',
#   'complaints',
#   'japan',
#   "'s",
#   'agricultural',
#   'policy'],
#  ['mulford',
#   'says',
#   'germany',
#   'japan',
#   'treasury',
#   'assistant',
#   'secretary',
#   'david',
#   'mulford',
#   'said',
#   'believe',
#   'west',
#   'germany',
#   'japan',
#   'yet',
#   'carried',
#   'international',
#   'responsibilities',
#   '``',
#   'believe',
#   'time',
#   "''",
#   'mulford',
#   'told',
#   'senate',
#   'banking',
#   'subcommittee',
#   'said',
#   'u.s.',
#   'trade',
#   'deficit',
#   'continue',
#   'improving',
#   'next',
#   'two',
#   'years',
#   '``',
#   'need',
#   'policy',
#   'actions',
#   "''",
#   'across',
#   'entire',
#   'front',
#   'u.s.',
#   'trade',
#   'relations',
#   'including',
#   'canada',
#   'newly-industrialized',
#   'countries',
#   'nics',
#   'particular',
#   'said',
#   'efforts',
#   'south',
#   'korea',
#   'taiwan',
#   'strengthen',
#   'currencies',
#   'still',
#   'disappointing',
#   'mulford',
#   'also',
#   'said',
#   'oecd',
#   'nations',
#   'need',
#   'grow',
#   'average',
#   'three',
#   'pct',
#   'help',
#   'resolve',
#   'international',
#   'debt',
#   'crisis',
#   'noted',
#   'japanese',
#   'european',
#   'imports',
#   'latin',
#   'nations',
#   'significantly',
#   'smaller',
#   'imports',
#   'u.s.',
#   'stressed',
#   'germany',
#   'japan',
#   'must',
#   'continue',
#   'take',
#   'economic',
#   'structural',
#   'measures',
#   'ensure',
#   'stronger',
#   'sustained',
#   'economic',
#   'growth']]

# %%
len(preprocessed_docs)
# Out:
# 485

# %%
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(preprocessed_docs)))
print(vocab)
# Out:
# ['months', 'anwar', 'issued', '1950', 'morning', 'mca', 'deficit', '150', '117.68', 'cast', 'stem', 'h.', 'tetsuo', 'issue', 'criticises', 'defended', 'spaghetti', 'adviser', 'wideranging', 'regimes', 'strengthening', '6.88', 'addis', 'ho', 'aldo', 'pushed', '816', 'accumulated', '628.3', 'removed', 'met', 'commuity', 'one-seventh', '10.9', 'cent', 'assured', 'conformed', 'liberalised', 'berlin', 'cold', 'high-ranking', 'background', 'lobby', 'fendt', 'delors', 'remained', 'fibres', 'shrank', 'discredit', 'actual', 'semiconductors', 'usual', 'shape', 'departure', 'export-led', 'eight-month', 'certainly', 'rights', 'poorer', 'involves', 'pointing', 'balance-of-payments', 'diesel', 'non-canadians', 'hopefully', 'release', '104.68', '16.50', 'renegotiate', 'convern', 'murakhovsky', '3.39', 'impression', '21.6', 'murphy', 'inseperable', 'grace', 'brisk', 'argentina-brazil', 'headache', '1984.', '928', 'storage', 'basic', 'fold', 'luxury', 'authorised', 'sudden', 'manhattan', 'pays', 'helped', 'goals', 'line', 'ida', '92.7', 'favourably', 'microprocessor', 'earmarked', 'easy', 'debtor', 'cancer', 'desperate', '2.13', 'end-september', 'bank', '290', 'owned', 'solved', 'residential', 'd-vt.', 'feel', 'rift', 'pledged', 'lap-top', '40-year', 'backs', 'isolate', 'baldrige', 'someone', 'urging', 'strain', 'ag', 'poses', 'coordination', '70.5', 'germans', 'faction', '8.2', 'purchases', 'democrat-controlled', '34.76', 'penalty', 'animal', 'licenses', 'instructing', 'trip', 'non-discriminatory', 'malcolm', 'additionally', 'pretty', 'generate', 'looks', 'lessened', 'internal', 'lately', 'sounded', 'reverse', 'mainly', 'establishment', 'amendments', 'fault', 'motivate', '4.29', '1.71', 'reserved', 'electronic', 'marshall', 'paraguay', 'luxembourg', 'misalignment', 'favour', 'uproar', 'eight-billion-dlr', 'heartening', 'friends', 'taiwanese', 'caution', 'involvement', '196.27', 'drilling', '1992.', 'ordering', 'flows', 'brokers', 'bringing', 'anza.s', 'linkages', 'knock-down', 'import-intensive', 'rock-bottom', 'promotion', 'informal', 'provincial', 'remain', 'explanation', 'findings', 'declaration', 'twice', 'lesotho', 'recently', 'longer-term', 'autos', 'opium', 'combat', 'guarantees', 'reorganization', 'liquid', 'sincerely', 'melicias', 'eonomists', '15.67', 'members', 'distortions', 'danger', 'home', 'assistance', 'separate', 'mayor', '58', 'rash', 'priority', 'unanimous', 'opening', '19.7', 'colour', 'silicon', 'micron', 'passed', 'plant', 'extrapolated', 'inc.', 'chile', 'reconstruction', '5.09', 'assurances', 'transitory', '208.6', '16.65.', 'deny', 'greenmail', 'pipeline', 'distorted', 'undervalued', '42.56', 'economy', 'tourism', '5.', 'steelmakers', 'sources', 'rwanda', 'visit', 'fine', 'habits', 'hides', '7.79', '3,000', 'voiced', 'spread', 'evelyn', 'ban', 'egon', 'brings', '958.9', 'illiberal', 'obvious', 'monday', 'offshore', 'cso', 'detials', 'border', 'pressures', '10.89', 'liberalization', '11.6', 'challenging', 'capitalisation', 'managers', 'exchanges', 'bans', 'sadat', 'ortner', 'item', 'byrd', 'power', 'therefore', 'focus', '6.31', 'import', 'fed', 'universal', 'pickup', 'modernising', '1.19', 'three-point', 'warburg', '202', 'driving', 'extract', 'peanuts', 'makes', 'slash', 'carries', 'cross-border', 'existing', 'topics', '2.64', 'poorest', 'revenue', 'remaining', 'constituencies', 'herman', 'meat', 'whatever', 'rattled', 'u.s.-european', 'clouded', 'envisages', 'ask', 'quarterly', 'clearly', 'bangladesh', 'grain', 'openness', 'something', '0.5', 'redouble', 'represented', 'hook', 'stayed', 'watanabe', 'sustained', '3.18', 'singapore', 'belgrade', 'discriminatory', 'hilke', 'disturbed', 'category', '1982.', 'feedgrain', 'rubber', 'engine', 'continent', 'fraction', '4.9', 'half', 'contribution', 'gad', 'science', 'skeptical', 'separately', 'libyan', 'concerted', 'prohibit', 'embraced', 'stand-off', 'east-west', 'similarly', 'moving', 'shareholder', 'linked', 'bloc', '74.3', 'mostly', 'refund', 'require', 'climbed', 'simil ...

# %%
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'months': 0, 'anwar': 1, 'issued': 2, '1950': 3, 'morning': 4, 'mca': 5, 'deficit': 6, '150': 7, '117.68': 8, 'cast': 9, 'stem': 10, 'h.': 11, 'tetsuo': 12, 'issue': 13, 'criticises': 14, 'defended': 15, 'spaghetti': 16, 'adviser': 17, 'wideranging': 18, 'regimes': 19, 'strengthening': 20, '6.88': 21, 'addis': 22, 'ho': 23, 'aldo': 24, 'pushed': 25, '816': 26, 'accumulated': 27, '628.3': 28, 'removed': 29, 'met': 30, 'commuity': 31, 'one-seventh': 32, '10.9': 33, 'cent': 34, 'assured': 35, 'conformed': 36, 'liberalised': 37, 'berlin': 38, 'cold': 39, 'high-ranking': 40, 'background': 41, 'lobby': 42, 'fendt': 43, 'delors': 44, 'remained': 45, 'fibres': 46, 'shrank': 47, 'discredit': 48, 'actual': 49, 'semiconductors': 50, 'usual': 51, 'shape': 52, 'departure': 53, 'export-led': 54, 'eight-month': 55, 'certainly': 56, 'rights': 57, 'poorer': 58, 'involves': 59, 'pointing': 60, 'balance-of-payments': 61, 'diesel': 62, 'non-canadians': 63, 'hopefully': 64, 'release': 65, '104.68': 66, '16.50': 67, 'renegotiate': 68, 'convern': 69, 'murakhovsky': 70, '3.39': 71, 'impression': 72, '21.6': 73, 'murphy': 74, 'inseperable': 75, 'grace': 76, 'brisk': 77, 'argentina-brazil': 78, 'headache': 79, '1984.': 80, '928': 81, 'storage': 82, 'basic': 83, 'fold': 84, 'luxury': 85, 'authorised': 86, 'sudden': 87, 'manhattan': 88, 'pays': 89, 'helped': 90, 'goals': 91, 'line': 92, 'ida': 93, '92.7': 94, 'favourably': 95, 'microprocessor': 96, 'earmarked': 97, 'easy': 98, 'debtor': 99, 'cancer': 100, 'desperate': 101, '2.13': 102, 'end-september': 103, 'bank': 104, '290': 105, 'owned': 106, 'solved': 107, 'residential': 108, 'd-vt.': 109, 'feel': 110, 'rift': 111, 'pledged': 112, 'lap-top': 113, '40-year': 114, 'backs': 115, 'isolate': 116, 'baldrige': 117, 'someone': 118, 'urging': 119, 'strain': 120, 'ag': 121, 'poses': 122, 'coordination': 123, '70.5': 124, 'germans': 125, 'faction': 126, '8.2': 127, 'purchases': 128, 'democrat-controlled': 129, '34.76': 130, 'penalty': 131, 'animal': 132, 'licenses': 133, 'instructing': 134, 'trip': 135, 'non-discriminatory': 136, 'malcolm': 137, 'additionally': 138, 'pretty': 139, 'generate': 140, 'looks': 141, 'lessened': 142, 'internal': 143, 'lately': 144, 'sounded': 145, 'reverse': 146, 'mainly': 147, 'establishment': 148, 'amendments': 149, 'fault': 150, 'motivate': 151, '4.29': 152, '1.71': 153, 'reserved': 154, 'electronic': 155, 'marshall': 156, 'paraguay': 157, 'luxembourg': 158, 'misalignment': 159, 'favour': 160, 'uproar': 161, 'eight-billion-dlr': 162, 'heartening': 163, 'friends': 164, 'taiwanese': 165, 'caution': 166, 'involvement': 167, '196.27': 168, 'drilling': 169, '1992.': 170, 'ordering': 171, 'flows': 172, 'brokers': 173, 'bringing': 174, 'anza.s': 175, 'linkages': 176, 'knock-down': 177, 'import-intensive': 178, 'rock-bottom': 179, 'promotion': 180, 'informal': 181, 'provincial': 182, 'remain': 183, 'explanation': 184, 'findings': 185, 'declaration': 186, 'twice': 187, 'lesotho': 188, 'recently': 189, 'longer-term': 190, 'autos': 191, 'opium': 192, 'combat': 193, 'guarantees': 194, 'reorganization': 195, 'liquid': 196, 'sincerely': 197, 'melicias': 198, 'eonomists': 199, '15.67': 200, 'members': 201, 'distortions': 202, 'danger': 203, 'home': 204, 'assistance': 205, 'separate': 206, 'mayor': 207, '58': 208, 'rash': 209, 'priority': 210, 'unanimous': 211, 'opening': 212, '19.7': 213, 'colour': 214, 'silicon': 215, 'micron': 216, 'passed': 217, 'plant': 218, 'extrapolated': 219, 'inc.': 220, 'chile': 221, 'reconstruction': 222, '5.09': 223, 'assurances': 224, 'transitory': 225, '208.6': 226, '16.65.': 227, 'deny': 228, 'greenmail': 229, 'pipeline': 230, 'distorted': 231, 'undervalued': 232, '42.56': 233, 'economy': 234, 'tourism': 235, '5.': 236, 'steelmakers': 237, 'sources': 238, 'rwanda': 239, 'visit': 240, 'fine': 241, 'habits': 242, 'hides': 243, '7.79': 244, '3,000': 245, 'voiced': 246, 'spread': 247, 'evelyn': 248, 'ban': 249, 'egon': 250, 'brings': 251, '958.9': 252, 'illiberal': 25 ...

# %%
index2word = {v:k for k, v in word2index.items()} 
print(index2word)
# Out:
# {0: 'months', 1: 'anwar', 2: 'issued', 3: '1950', 4: 'morning', 5: 'mca', 6: 'deficit', 7: '150', 8: '117.68', 9: 'cast', 10: 'stem', 11: 'h.', 12: 'tetsuo', 13: 'issue', 14: 'criticises', 15: 'defended', 16: 'spaghetti', 17: 'adviser', 18: 'wideranging', 19: 'regimes', 20: 'strengthening', 21: '6.88', 22: 'addis', 23: 'ho', 24: 'aldo', 25: 'pushed', 26: '816', 27: 'accumulated', 28: '628.3', 29: 'removed', 30: 'met', 31: 'commuity', 32: 'one-seventh', 33: '10.9', 34: 'cent', 35: 'assured', 36: 'conformed', 37: 'liberalised', 38: 'berlin', 39: 'cold', 40: 'high-ranking', 41: 'background', 42: 'lobby', 43: 'fendt', 44: 'delors', 45: 'remained', 46: 'fibres', 47: 'shrank', 48: 'discredit', 49: 'actual', 50: 'semiconductors', 51: 'usual', 52: 'shape', 53: 'departure', 54: 'export-led', 55: 'eight-month', 56: 'certainly', 57: 'rights', 58: 'poorer', 59: 'involves', 60: 'pointing', 61: 'balance-of-payments', 62: 'diesel', 63: 'non-canadians', 64: 'hopefully', 65: 'release', 66: '104.68', 67: '16.50', 68: 'renegotiate', 69: 'convern', 70: 'murakhovsky', 71: '3.39', 72: 'impression', 73: '21.6', 74: 'murphy', 75: 'inseperable', 76: 'grace', 77: 'brisk', 78: 'argentina-brazil', 79: 'headache', 80: '1984.', 81: '928', 82: 'storage', 83: 'basic', 84: 'fold', 85: 'luxury', 86: 'authorised', 87: 'sudden', 88: 'manhattan', 89: 'pays', 90: 'helped', 91: 'goals', 92: 'line', 93: 'ida', 94: '92.7', 95: 'favourably', 96: 'microprocessor', 97: 'earmarked', 98: 'easy', 99: 'debtor', 100: 'cancer', 101: 'desperate', 102: '2.13', 103: 'end-september', 104: 'bank', 105: '290', 106: 'owned', 107: 'solved', 108: 'residential', 109: 'd-vt.', 110: 'feel', 111: 'rift', 112: 'pledged', 113: 'lap-top', 114: '40-year', 115: 'backs', 116: 'isolate', 117: 'baldrige', 118: 'someone', 119: 'urging', 120: 'strain', 121: 'ag', 122: 'poses', 123: 'coordination', 124: '70.5', 125: 'germans', 126: 'faction', 127: '8.2', 128: 'purchases', 129: 'democrat-controlled', 130: '34.76', 131: 'penalty', 132: 'animal', 133: 'licenses', 134: 'instructing', 135: 'trip', 136: 'non-discriminatory', 137: 'malcolm', 138: 'additionally', 139: 'pretty', 140: 'generate', 141: 'looks', 142: 'lessened', 143: 'internal', 144: 'lately', 145: 'sounded', 146: 'reverse', 147: 'mainly', 148: 'establishment', 149: 'amendments', 150: 'fault', 151: 'motivate', 152: '4.29', 153: '1.71', 154: 'reserved', 155: 'electronic', 156: 'marshall', 157: 'paraguay', 158: 'luxembourg', 159: 'misalignment', 160: 'favour', 161: 'uproar', 162: 'eight-billion-dlr', 163: 'heartening', 164: 'friends', 165: 'taiwanese', 166: 'caution', 167: 'involvement', 168: '196.27', 169: 'drilling', 170: '1992.', 171: 'ordering', 172: 'flows', 173: 'brokers', 174: 'bringing', 175: 'anza.s', 176: 'linkages', 177: 'knock-down', 178: 'import-intensive', 179: 'rock-bottom', 180: 'promotion', 181: 'informal', 182: 'provincial', 183: 'remain', 184: 'explanation', 185: 'findings', 186: 'declaration', 187: 'twice', 188: 'lesotho', 189: 'recently', 190: 'longer-term', 191: 'autos', 192: 'opium', 193: 'combat', 194: 'guarantees', 195: 'reorganization', 196: 'liquid', 197: 'sincerely', 198: 'melicias', 199: 'eonomists', 200: '15.67', 201: 'members', 202: 'distortions', 203: 'danger', 204: 'home', 205: 'assistance', 206: 'separate', 207: 'mayor', 208: '58', 209: 'rash', 210: 'priority', 211: 'unanimous', 212: 'opening', 213: '19.7', 214: 'colour', 215: 'silicon', 216: 'micron', 217: 'passed', 218: 'plant', 219: 'extrapolated', 220: 'inc.', 221: 'chile', 222: 'reconstruction', 223: '5.09', 224: 'assurances', 225: 'transitory', 226: '208.6', 227: '16.65.', 228: 'deny', 229: 'greenmail', 230: 'pipeline', 231: 'distorted', 232: 'undervalued', 233: '42.56', 234: 'economy', 235: 'tourism', 236: '5.', 237: 'steelmakers', 238: 'sources', 239: 'rwanda', 240: 'visit', 241: 'fine', 242: 'habits', 243: 'hides', 244: '7.79', 245: '3,000', 246: 'voiced', 247: 'spread', 248: 'evelyn', 249: 'ban', 250: 'egon', 251: 'brings', 252: '958.9', 253: 'illiberal ...

# %%
voc_size = len(vocab)
print(voc_size)
# Out:
# 8163

# %% [markdown]
# ## Define Helper Functions

# %%
import numpy as np
from scipy import spatial
from scipy.stats import spearmanr


def cos_sim(a, b):
    return 1 - spatial.distance.cosine(
        a, b
    )  # distance = 1 - similarlity, because scipy only gives distance


def load_specific_categories(file_path, semantic_category, syntactic_category):
    semantic = []
    syntactic = []
    current_group = None

    with open(file_path, "r") as f:
        for line in f:
            if line.startswith(":"):
                if semantic_category in line.lower():
                    current_group = semantic
                elif syntactic_category in line.lower():
                    current_group = syntactic
                else:
                    current_group = None
            elif current_group is not None:
                words = line.strip().split()
                if len(words) == 4:
                    current_group.append(words)

    return semantic, syntactic


def find_closest_word(vec, embeddings, exclude_ids):
    max_similarity = -float("inf")
    best_idx = -1

    for idx, emb in enumerate(embeddings):
        if idx in exclude_ids:
            continue
        similarity = cos_sim(vec, emb)
        if similarity > max_similarity:
            max_similarity = similarity
            best_idx = idx

    return best_idx


def evaluate_analogies(analogy_data, word_to_idx, embeddings):
    correct = 0
    total = 0

    for word1, word2, word3, word4 in analogy_data:
        if all(word in word_to_idx for word in [word1, word2, word3, word4]):
            idx1 = word_to_idx[word1]
            idx2 = word_to_idx[word2]
            idx3 = word_to_idx[word3]
            idx4 = word_to_idx[word4]

            vec = embeddings[idx2] - embeddings[idx1] + embeddings[idx3]
            predicted_idx = find_closest_word(vec, embeddings, {idx1, idx2, idx3})
            if predicted_idx == idx4:
                correct += 1
            total += 1

    return correct / total if total > 0 else 0


def get_query_vector(query_word, model, word2index):
    if query_word not in word2index:
        raise ValueError(f"Word '{query_word}' not in vocabulary.")

    word_idx = word2index[query_word]
    query_vector = model.embedding_v.weight[word_idx].data.cpu().numpy()
    return query_vector


def get_corpus_vectors(model):
    return model.embedding_v.weight.data.cpu().numpy()


def compute_top_k_dot_product(query_vector, corpus_vectors, k=10):
    # get dot product between the query and all corpus vectors
    dot_products = np.dot(corpus_vectors, query_vector)

    # get the top k indices and scores
    top_k_indices = np.argsort(dot_products)[-k:][::-1]
    top_k_scores = dot_products[top_k_indices]

    return top_k_indices.tolist(), top_k_scores.tolist()


def load_wordsim353(file_path):
    word_pairs = []
    human_scores = []

    with open(file_path, "r") as f:
        next(f)
        for line in f:
            word1, word2, score = line.strip().split()
            word_pairs.append((word1, word2))
            human_scores.append(float(score))

    return word_pairs, human_scores


def calculate_model_similarity(word_pairs, model, word_to_idx):
    model_scores = []
    embeddings = model.embedding_v.weight.data.cpu().numpy()

    for word1, word2 in word_pairs:
        if word1 in word_to_idx and word2 in word_to_idx:
            idx1 = word_to_idx[word1]
            idx2 = word_to_idx[word2]
            dot_product = np.dot(embeddings[idx1], embeddings[idx2])
            model_scores.append(dot_product)
        else:
            model_scores.append(None)  # Handle OOV (out-of-vocabulary) words
    return model_scores


def compute_spearman_correlation(human_scores, model_scores):
    valid_scores = [(h, m) for h, m in zip(human_scores, model_scores) if m is not None]
    filtered_human_scores, filtered_model_scores = zip(*valid_scores)

    correlation, _ = spearmanr(filtered_human_scores, filtered_model_scores)
    return correlation

def compute_mse(human_scores, model_scores):
    #remove null values from model_scores
    valid_scores = [(h, m) for h, m in zip(human_scores, model_scores) if m is not None]
    filtered_human_scores, filtered_model_scores = zip(*valid_scores)

    mse = np.mean((np.array(filtered_model_scores) - np.array(filtered_human_scores)) ** 2)
    return mse

# %%
dataset_path = 'word-analogies.txt'
semantic_category = 'capital-common-countries'
syntactic_category = 'past-tense'
semantic, syntactic = load_specific_categories(dataset_path, semantic_category, syntactic_category)
embedding_size = 2

# %% [markdown]
# ## Word2Vec (Skipgram)

# %%
from torch import nn

class Skipgram(nn.Module):
    def __init__(self, vocab_size, emb_size):
        super().__init__()
        self.embedding_v = nn.Embedding(vocab_size, emb_size)
        self.embedding_u = nn.Embedding(vocab_size, emb_size)


    def forward(self, center_words, target_words, all_vocabs):
        center_embeds = self.embedding_v(center_words)  # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words)  # [batch_size, window_size, emb_size]
        all_embeds = self.embedding_u(all_vocabs)  # [batch_size, voc_size, emb_size]

        # [batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, window_size]
        scores = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)

        # [batch_size, voc_size, emb_size] @ [batch_size, emb_size, 1] = [batch_size, voc_size, 1] = [batch_size, voc_size]
        norm_scores = all_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)

        # scalar (loss must be scalar)
        nll = -torch.mean(
            torch.log(
                torch.exp(scores) / torch.sum(torch.exp(norm_scores), 1).unsqueeze(1)
            )
        )

        return nll  # negative log likelihood

# %%
word2vec_skipgram = Skipgram(vocab_size=voc_size, emb_size=embedding_size)
word2vec_skipgram.load_state_dict(torch.load('models/word2vec_skipgram.pth'))
word2vec_skipgram.to(device)
word2vec_skipgram.eval()
print("Model loaded successfully.")
# Out:
# C:\Users\neucl\AppData\Local\Temp\ipykernel_2220\2073443929.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   word2vec_skipgram.load_state_dict(torch.load('models/word2vec_skipgram.pth'))
# Model loaded successfully.

# %% [markdown]
# ### syntactic and semantic accuracy Word2Vec(Skipgram)

# %%
embeddings_word2vec_skipgram = word2vec_skipgram.embedding_v.weight.data.cpu().numpy()
semantic_accuracy_word2vec_skipgram = evaluate_analogies(semantic, word2index, embeddings_word2vec_skipgram)
syntactic_accuracy_word2vec_skipgram = evaluate_analogies(syntactic, word2index, embeddings_word2vec_skipgram)
print(f'semantic_accuracy_word2vec_skipgram: {semantic_accuracy_word2vec_skipgram}')
print(f'syntactic_accuracy_word2vec_skipgram: {syntactic_accuracy_word2vec_skipgram}')
# Out:
# semantic_accuracy_word2vec_skipgram: 0
# syntactic_accuracy_word2vec_skipgram: 0.0018115942028985507

# %% [markdown]
# ### correlation between the models’ dot product and the provided similarity metrics Word2Vec(Skipgram)

# %%
word_pairs, human_scores = load_wordsim353('wordsim353/wordsim_similarity_goldstandard.txt')
model_scores = calculate_model_similarity(word_pairs, word2vec_skipgram, word2index)
correlation = compute_spearman_correlation(human_scores, model_scores)
print(f"Word2Vec(Skipgram) spearman correlation: {correlation:.4f}")
# Out:
# Word2Vec(Skipgram) spearman correlation: 0.0287

# %% [markdown]
# The model barely ranks word pairs in the exact opposite order of human judgment or roughly no correlation, which means that the model’s rankings are completely unrelated to human judgments

# %% [markdown]
# ### MSE Word2Vec (Skipgram)

# %%
mse = compute_mse(human_scores, model_scores)
print(f"Word2Vec (Skipgram) MSE: {mse}")
# Out:
# Word2Vec (Skipgram) MSE: 28.21854054991453

# %% [markdown]
# ### Top 10 most similar context Word2Vec(Skipgram)

# %%
# get top 10 most similar context Word2Vec(Skipgram)

query_vector = get_query_vector('money', word2vec_skipgram, word2index)
corpus_vector = get_corpus_vectors(word2vec_skipgram)   

top_k_indices, top_k_scores = compute_top_k_dot_product(query_vector, corpus_vector, k=10)
for idx in top_k_indices:
    print(index2word[idx])
# Out:
# chew
# gilt
# eastern
# johnson
# counter-offer
# unrealistic
# portfolios
# pushed
# american-israel
# 1.81

# %% [markdown]
# ## Word2Vec (Negative Sampling)

# %%
class SkipgramNegSampling(nn.Module):
    
    def __init__(self, vocab_size, emb_size):
        super(SkipgramNegSampling, self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, emb_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, emb_size) # out embedding
        self.logsigmoid = nn.LogSigmoid()
                    
    def forward(self, center_words, target_words, negative_words):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, window_size, emb_size]
        neg_embeds    = -self.embedding_u(negative_words) # [batch_size, window_size * num_neg, emb_size]
        
        positive_score = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #[batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, window_size]
        
        negative_score = neg_embeds.bmm(center_embeds.transpose(1, 2))
        #[batch_size, k, emb_size] @ [batch_size, emb_size, 1] = [batch_size, k, 1]
        
        loss = self.logsigmoid(positive_score) + torch.sum(self.logsigmoid(negative_score), 1)
                
        return -torch.mean(loss)
    
    def prediction(self, inputs):
        embeds = self.embedding_v(inputs)
        
        return embeds

# %%
word2vec_negativesampling = SkipgramNegSampling(vocab_size=voc_size, emb_size=embedding_size)
word2vec_negativesampling.load_state_dict(torch.load('models/word2vec_negativesampling.pth'))
word2vec_negativesampling.to(device)
word2vec_negativesampling.eval()
print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\neucl\AppData\Local\Temp\ipykernel_2220\3606289487.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   word2vec_negativesampling.load_state_dict(torch.load('models/word2vec_negativesampling.pth'))

# %% [markdown]
# ### syntactic and semantic accuracy

# %%
# get semantic and syntacic accuracy for Word2Vec negative sampling

embeddings_word2vec_negativesampling = word2vec_negativesampling.embedding_v.weight.data.cpu().numpy()
semantic_accuracy_word2vec_negativesampling = evaluate_analogies(semantic, word2index, embeddings_word2vec_negativesampling)
syntactic_accuracy_word2vec_negativesampling = evaluate_analogies(syntactic, word2index, embeddings_word2vec_negativesampling)
print(f'semantic_accuracy_word2vec_negativesampling: {semantic_accuracy_word2vec_negativesampling}')
print(f'syntactic_accuracy_word2vec_negativesampling: {syntactic_accuracy_word2vec_negativesampling}')
# Out:
# semantic_accuracy_word2vec_negativesampling: 0
# syntactic_accuracy_word2vec_negativesampling: 0.0

# %% [markdown]
# ### correlation between the models’ dot product and the provided similarity metrics Word2Vec(Negative Sampling)

# %%
word_pairs, human_scores = load_wordsim353('wordsim353/wordsim_similarity_goldstandard.txt')
model_scores = calculate_model_similarity(word_pairs, word2vec_negativesampling, word2index)
correlation = compute_spearman_correlation(human_scores, model_scores)
print(f"Word2Vec (Negativesampling) spearman correlation: {correlation:.4f}")
# Out:
# Word2Vec (Negativesampling) spearman correlation: 0.1665

# %% [markdown]
# The model barely ranks word pairs in the exact opposite order of human judgment or roughly no correlation, which means that the model’s rankings are completely unrelated to human judgments

# %% [markdown]
# ### MSE Word2Vec Negative Sampling

# %%
mse = compute_mse(human_scores, model_scores)
print(f"Word2Vec (Skipgram) MSE: {mse}")
# Out:
# Word2Vec (Skipgram) MSE: 27.60999063662475

# %% [markdown]
# ### Top 10 most similar context Word2Vec(Negative Sampling)

# %%
# get top 10 most similar context for Word2Vec(Megative Sampling)

query_vector = get_query_vector('money', word2vec_negativesampling, word2index)
corpus_vector = get_corpus_vectors(word2vec_negativesampling)   

top_k_indices, top_k_scores = compute_top_k_dot_product(query_vector, corpus_vector, k=10)
for idx in top_k_indices:
    print(index2word[idx])
# Out:
# 3,163.7
# adopting
# loading
# baka
# belgolux
# lacks
# illegal
# 628
# ignoring
# danish

# %% [markdown]
# ## Glove from Scratch

# %%
class GloVe(nn.Module):
    
    def __init__(self, vocab_size,embed_size):
        super(GloVe,self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, embed_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, embed_size) # out embedding
        
        self.v_bias = nn.Embedding(vocab_size, 1)
        self.u_bias = nn.Embedding(vocab_size, 1)
        
    def forward(self, center_words, target_words, coocs, weighting):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, window_size, emb_size]
        
        center_bias = self.v_bias(center_words).squeeze(1) 
        target_bias = self.u_bias(target_words).squeeze(1)
        
        inner_product = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        
        #note that coocs already got log
        loss = weighting*torch.pow(inner_product +center_bias + target_bias - coocs, 2) # [batch_size, window_size]
        
        return torch.sum(loss) # scalar

# %%
glove = GloVe(vocab_size=voc_size, embed_size=embedding_size)
glove.load_state_dict(torch.load('models/glove_scratch.pth'))
glove.to(device)
glove.eval()
print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\neucl\AppData\Local\Temp\ipykernel_2220\3739864851.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   glove.load_state_dict(torch.load('models/glove_scratch.pth'))

# %% [markdown]
# ### syntactic and semantic accuracy GloVe

# %%
embeddings_glove = glove.embedding_v.weight.data.cpu().numpy()
semantic_accuracy_glove = evaluate_analogies(semantic, word2index, embeddings_glove)
syntactic_accuracy_glove = evaluate_analogies(syntactic, word2index, embeddings_glove)
print(f'semantic_accuracy_glove: {semantic_accuracy_glove}')
print(f'syntactic_accuracy_glove: {syntactic_accuracy_glove}')
# Out:
# semantic_accuracy_glove: 0
# syntactic_accuracy_glove: 0.0

# %% [markdown]
# ### correlation between the models’ dot product and the provided similarity metrics Word2Vec(Skipgram)

# %%
word_pairs, human_scores = load_wordsim353('wordsim353/wordsim_similarity_goldstandard.txt')
model_scores = calculate_model_similarity(word_pairs, glove, word2index)
correlation = compute_spearman_correlation(human_scores, model_scores)
print(f"GloVe spearman correlation: {correlation:.4f}")
# Out:
# GloVe spearman correlation: -0.2350

# %% [markdown]
# The model barely ranks word pairs in the exact opposite order of human judgment or roughly no correlation, which means that the model’s rankings are completely unrelated to human judgments

# %% [markdown]
# ### MSC GloVe

# %%
mse = compute_mse(human_scores, model_scores)
print(f"Word2Vec (Skipgram) MSE: {mse}")
# Out:
# Word2Vec (Skipgram) MSE: 28.589507876074844

# %% [markdown]
# ### Top 10 most similar context GloVe

# %%
# get top 10 most similar context for GloVe

query_vector = get_query_vector('money', glove, word2index)
corpus_vector = get_corpus_vectors(glove)   

top_k_indices, top_k_scores = compute_top_k_dot_product(query_vector, corpus_vector, k=10)
for idx in top_k_indices:
    print(index2word[idx])
# Out:
# 62
# annually
# spirits
# democrat
# overrall
# resurrected
# maize
# lasting
# belgolux
# always
