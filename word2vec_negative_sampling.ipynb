# %% [markdown]
# ## Set torch.device to CUDA

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available. Using GPU.")
else:
    device = torch.device("cpu")
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. Using GPU.

# %% [markdown]
# ## Download NLTK

# %%
import nltk
import os
CUSTOM_DIR = './nltk_data/'

nltk.data.path.append(CUSTOM_DIR)

resources = [
    ('reuters.zip', os.path.join(CUSTOM_DIR, 'corpora', 'reuters')),
    ('punkt.zip', os.path.join(CUSTOM_DIR, 'tokenizers', 'punkt')),
    ('punkt_tab.zip', os.path.join(CUSTOM_DIR, 'tokenizers', 'punkt_tab')),
    ('stopwords.zip', os.path.join(CUSTOM_DIR, 'corpora', 'stopwords')),
]

for resource, path in resources:
    try:
        nltk.data.find(resource)
    except LookupError:
        if not os.path.exists(path):
            nltk.download(resource.split('.')[0], download_dir=CUSTOM_DIR)
# Out:
# [nltk_data] Downloading package reuters to ./nltk_data/...
# [nltk_data]   Package reuters is already up-to-date!

# %%
from nltk.corpus import reuters

category = "trade"
category_fileids = reuters.fileids(category)
category_docs = [reuters.raw(fileids) for fileids in category_fileids]

print(f"# of documents in category '{category}': {len(category_docs)}")
print(f"1st document:\n{category_docs[0][:500]}")
# Out:
# # of documents in category 'trade': 485
# 1st document:
# ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT
#   Mounting trade friction between the
#   U.S. And Japan has raised fears among many of Asia's exporting
#   nations that the row could inflict far-reaching economic
#   damage, businessmen and officials said.
#       They told Reuter correspondents in Asian capitals a U.S.
#   Move against Japan might boost protectionist sentiment in the
#   U.S. And lead to curbs on American imports of their products.
#       But some exporters said that while the conflict wo

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words and word not in string.punctuation]
    return tokens

# %%
preprocessed_docs = [preprocess_text(doc) for doc in category_docs]
preprocessed_docs
# Out:
# [['asian',
#   'exporters',
#   'fear',
#   'damage',
#   'u.s.-japan',
#   'rift',
#   'mounting',
#   'trade',
#   'friction',
#   'u.s.',
#   'japan',
#   'raised',
#   'fears',
#   'among',
#   'many',
#   'asia',
#   "'s",
#   'exporting',
#   'nations',
#   'row',
#   'could',
#   'inflict',
#   'far-reaching',
#   'economic',
#   'damage',
#   'businessmen',
#   'officials',
#   'said',
#   'told',
#   'reuter',
#   'correspondents',
#   'asian',
#   'capitals',
#   'u.s.',
#   'move',
#   'japan',
#   'might',
#   'boost',
#   'protectionist',
#   'sentiment',
#   'u.s.',
#   'lead',
#   'curbs',
#   'american',
#   'imports',
#   'products',
#   'exporters',
#   'said',
#   'conflict',
#   'would',
#   'hurt',
#   'long-run',
#   'short-term',
#   'tokyo',
#   "'s",
#   'loss',
#   'might',
#   'gain',
#   'u.s.',
#   'said',
#   'impose',
#   '300',
#   'mln',
#   'dlrs',
#   'tariffs',
#   'imports',
#   'japanese',
#   'electronics',
#   'goods',
#   'april',
#   '17',
#   'retaliation',
#   'japan',
#   "'s",
#   'alleged',
#   'failure',
#   'stick',
#   'pact',
#   'sell',
#   'semiconductors',
#   'world',
#   'markets',
#   'cost',
#   'unofficial',
#   'japanese',
#   'estimates',
#   'put',
#   'impact',
#   'tariffs',
#   '10',
#   'billion',
#   'dlrs',
#   'spokesmen',
#   'major',
#   'electronics',
#   'firms',
#   'said',
#   'would',
#   'virtually',
#   'halt',
#   'exports',
#   'products',
#   'hit',
#   'new',
#   'taxes',
#   '``',
#   'would',
#   "n't",
#   'able',
#   'business',
#   "''",
#   'said',
#   'spokesman',
#   'leading',
#   'japanese',
#   'electronics',
#   'firm',
#   'matsushita',
#   'electric',
#   'industrial',
#   'co',
#   'ltd',
#   'lt',
#   'mc.t',
#   '``',
#   'tariffs',
#   'remain',
#   'place',
#   'length',
#   'time',
#   'beyond',
#   'months',
#   'mean',
#   'complete',
#   'erosion',
#   'exports',
#   'goods',
#   'subject',
#   'tariffs',
#   'u.s.',
#   "''",
#   'said',
#   'tom',
#   'murtha',
#   'stock',
#   'analyst',
#   'tokyo',
#   'office',
#   'broker',
#   'lt',
#   'james',
#   'capel',
#   'co',
#   'taiwan',
#   'businessmen',
#   'officials',
#   'also',
#   'worried',
#   '``',
#   'aware',
#   'seriousness',
#   'u.s.',
#   'threat',
#   'japan',
#   'serves',
#   'warning',
#   'us',
#   "''",
#   'said',
#   'senior',
#   'taiwanese',
#   'trade',
#   'official',
#   'asked',
#   'named',
#   'taiwan',
#   'trade',
#   'trade',
#   'surplus',
#   '15.6',
#   'billion',
#   'dlrs',
#   'last',
#   'year',
#   '95',
#   'pct',
#   'u.s.',
#   'surplus',
#   'helped',
#   'swell',
#   'taiwan',
#   "'s",
#   'foreign',
#   'exchange',
#   'reserves',
#   '53',
#   'billion',
#   'dlrs',
#   'among',
#   'world',
#   "'s",
#   'largest',
#   '``',
#   'must',
#   'quickly',
#   'open',
#   'markets',
#   'remove',
#   'trade',
#   'barriers',
#   'cut',
#   'import',
#   'tariffs',
#   'allow',
#   'imports',
#   'u.s.',
#   'products',
#   'want',
#   'defuse',
#   'problems',
#   'possible',
#   'u.s.',
#   'retaliation',
#   "''",
#   'said',
#   'paul',
#   'sheen',
#   'chairman',
#   'textile',
#   'exporters',
#   'lt',
#   'taiwan',
#   'safe',
#   'group',
#   'senior',
#   'official',
#   'south',
#   'korea',
#   "'s",
#   'trade',
#   'promotion',
#   'association',
#   'said',
#   'trade',
#   'dispute',
#   'u.s.',
#   'japan',
#   'might',
#   'also',
#   'lead',
#   'pressure',
#   'south',
#   'korea',
#   'whose',
#   'chief',
#   'exports',
#   'similar',
#   'japan',
#   'last',
#   'year',
#   'south',
#   'korea',
#   'trade',
#   'surplus',
#   '7.1',
#   'billion',
#   'dlrs',
#   'u.s.',
#   '4.9',
#   'billion',
#   'dlrs',
#   '1985.',
#   'malaysia',
#   'trade',
#   'officers',
#   'businessmen',
#   'said',
#   'tough',
#   'curbs',
#   'japan',
#   'might',
#   'allow',
#   'hard-hit',
#   'producers',
#   'semiconductors',
#   'third',
#   'countries',
#   'expand',
#   'sales',
#   'u.s.',
#   'hong',
#   'kong',
#   'newspapers',
#   'alleged',
#   'japan',
#   'selling',
#   'below-cost',
#   'semiconductors',
#   'electronics',
#   'manufacturers',
#   'share',
#   'view',
#   'businessmen',
#   'said',
#   'short-term',
#   'commercial',
#   'advantage',
#   'would',
#   'outweighed',
#   'u.s.',
#   'pressure',
#   'block',
#   'imports',
#   '``',
#   'short-term',
#   'view',
#   "''",
#   'said',
#   'lawrence',
#   'mills',
#   'director-general',
#   'federation',
#   'hong',
#   'kong',
#   'industry',
#   '``',
#   'whole',
#   'purpose',
#   'prevent',
#   'imports',
#   'one',
#   'day',
#   'extended',
#   'sources',
#   'much',
#   'serious',
#   'hong',
#   'kong',
#   'disadvantage',
#   'action',
#   'restraining',
#   'trade',
#   "''",
#   'said',
#   'u.s.',
#   'last',
#   'year',
#   'hong',
#   'kong',
#   "'s",
#   'biggest',
#   'export',
#   'market',
#   'accounting',
#   '30',
#   'pct',
#   'domestically',
#   'produced',
#   'exports',
#   'australian',
#   'government',
#   'awaiting',
#   'outcome',
#   'trade',
#   'talks',
#   'u.s.',
#   'japan',
#   'interest',
#   'concern',
#   'industry',
#   'minister',
#   'john',
#   'button',
#   'said',
#   'canberra',
#   'last',
#   'friday',
#   '``',
#   'kind',
#   'deterioration',
#   'trade',
#   'relations',
#   'two',
#   'countries',
#   'major',
#   'trading',
#   'partners',
#   'serious',
#   'matter',
#   "''",
#   'button',
#   'said',
#   'said',
#   'australia',
#   "'s",
#   'concerns',
#   'centred',
#   'coal',
#   'beef',
#   'australia',
#   "'s",
#   'two',
#   'largest',
#   'exports',
#   'japan',
#   'also',
#   'significant',
#   'u.s.',
#   'exports',
#   'country',
#   'meanwhile',
#   'u.s.-japanese',
#   'diplomatic',
#   'manoeuvres',
#   'solve',
#   'trade',
#   'stand-off',
#   'continue',
#   'japan',
#   "'s",
#   'ruling',
#   'liberal',
#   'democratic',
#   'party',
#   'yesterday',
#   'outlined',
#   'package',
#   'economic',
#   'measures',
#   'boost',
#   'japanese',
#   'economy',
#   'measures',
#   'proposed',
#   'include',
#   'large',
#   'supplementary',
#   'budget',
#   'record',
#   'public',
#   'works',
#   'spending',
#   'first',
#   'half',
#   'financial',
#   'year',
#   'also',
#   'call',
#   'stepped-up',
#   'spending',
#   'emergency',
#   'measure',
#   'stimulate',
#   'economy',
#   'despite',
#   'prime',
#   'minister',
#   'yasuhiro',
#   'nakasone',
#   "'s",
#   'avowed',
#   'fiscal',
#   'reform',
#   'program',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'makoto',
#   'kuroda',
#   'japan',
#   "'s",
#   'deputy',
#   'minister',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'due',
#   'meet',
#   'washington',
#   'week',
#   'effort',
#   'end',
#   'dispute'],
#  ['thai',
#   'trade',
#   'deficit',
#   'widens',
#   'first',
#   'quarter',
#   'thailand',
#   "'s",
#   'trade',
#   'deficit',
#   'widened',
#   '4.5',
#   'billion',
#   'baht',
#   'first',
#   'quarter',
#   '1987',
#   '2.1',
#   'billion',
#   'year',
#   'ago',
#   'business',
#   'economics',
#   'department',
#   'said',
#   'said',
#   'janunary/march',
#   'imports',
#   'rose',
#   '65.1',
#   'billion',
#   'baht',
#   '58.7',
#   'billion',
#   'thailand',
#   "'s",
#   'improved',
#   'business',
#   'climate',
#   'year',
#   'resulted',
#   '27',
#   'pct',
#   'increase',
#   'imports',
#   'raw',
#   'materials',
#   'semi-finished',
#   'products',
#   'country',
#   "'s",
#   'oil',
#   'import',
#   'bill',
#   'however',
#   'fell',
#   '23',
#   'pct',
#   'first',
#   'quarter',
#   'due',
#   'lower',
#   'oil',
#   'prices',
#   'department',
#   'said',
#   'first',
#   'quarter',
#   'exports',
#   'expanded',
#   '60.6',
#   'billion',
#   'baht',
#   '56.6',
#   'billion',
#   'export',
#   'growth',
#   'smaller',
#   'expected',
#   'due',
#   'lower',
#   'earnings',
#   'many',
#   'key',
#   'commodities',
#   'including',
#   'rice',
#   'whose',
#   'earnings',
#   'declined',
#   '18',
#   'pct',
#   'maize',
#   '66',
#   'pct',
#   'sugar',
#   '45',
#   'pct',
#   'tin',
#   '26',
#   'pct',
#   'canned',
#   'pineapples',
#   'seven',
#   'pct',
#   'products',
#   'registering',
#   'high',
#   'export',
#   'growth',
#   'jewellery',
#   '64',
#   'pct',
#   'clothing',
#   '57',
#   'pct',
#   'rubber',
#   '35',
#   'pct'],
#  ['japan',
#   'ministry',
#   'says',
#   'open',
#   'farm',
#   'trade',
#   'would',
#   'hit',
#   'u.s.',
#   'japan',
#   "'s",
#   'agriculture',
#   'ministry',
#   'angered',
#   'u.s.',
#   'demands',
#   'japan',
#   'open',
#   'farm',
#   'products',
#   'market',
#   'tell',
#   'u.s.',
#   'officials',
#   'talks',
#   'later',
#   'month',
#   'liberalisation',
#   'would',
#   'harm',
#   'existing',
#   'u.s.',
#   'farm',
#   'exports',
#   'japan',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   '``',
#   'imports',
#   'u.s.',
#   'would',
#   'drop',
#   'due',
#   'active',
#   'sales',
#   'drives',
#   'suppliers',
#   "''",
#   'official',
#   'declined',
#   'named',
#   'said',
#   '``',
#   'japan',
#   'largest',
#   'customer',
#   'u.s.',
#   'farm',
#   'products',
#   'reasonable',
#   'u.s.',
#   'demand',
#   'japan',
#   'liberalise',
#   'farm',
#   'import',
#   'market',
#   "''",
#   'said',
#   'agriculture',
#   'minister',
#   'mutsuki',
#   'kato',
#   'said',
#   'u.s.',
#   'insists',
#   'japan',
#   'open',
#   'protected',
#   'rice',
#   'market',
#   'also',
#   'open',
#   'wheat',
#   'market',
#   'volume',
#   'origin',
#   'regulated',
#   'protect',
#   'local',
#   'farmers',
#   'australia',
#   'canada',
#   'could',
#   'increase',
#   'wheat',
#   'exports',
#   'competitive',
#   'u.s.',
#   'said',
#   'end-users',
#   'would',
#   'also',
#   'buy',
#   'origins',
#   'grain',
#   'traders',
#   'said',
#   'u.s.',
#   'agriculture',
#   'secretary',
#   'richard',
#   'lyng',
#   'due',
#   'visit',
#   'japan',
#   'talks',
#   'april',
#   '16-27',
#   'said',
#   'ask',
#   'japan',
#   'offer',
#   'share',
#   'rice',
#   'market',
#   'u.s.',
#   'suppliers',
#   'remove',
#   'quotas',
#   'u.s.',
#   'beef',
#   'citrus',
#   'imports',
#   'countries',
#   'already',
#   'cutting',
#   'u.s.',
#   'market',
#   'share',
#   'australia',
#   'largest',
#   'beef',
#   'supplier',
#   'japan',
#   'trying',
#   'boost',
#   'exports',
#   'prior',
#   'expiry',
#   'four-year',
#   'beef',
#   'accord',
#   'next',
#   'march',
#   '31.',
#   'imports',
#   'u.s.',
#   'corn',
#   'fallen',
#   'due',
#   'increased',
#   'sales',
#   'china',
#   'south',
#   'america',
#   'japanese',
#   'soybean',
#   'imports',
#   'brazil',
#   'expected',
#   'rise',
#   'sharply',
#   'year',
#   'although',
#   'u.s.',
#   'remain',
#   'largest',
#   'supplier',
#   'u.s.',
#   'feedgrain',
#   'sales',
#   'also',
#   'drop',
#   'japan',
#   'opens',
#   'beef',
#   'imports',
#   'since',
#   'japan',
#   'depends',
#   'almost',
#   'entirely',
#   'feedgrain',
#   'imports',
#   'mainly',
#   'u.s.',
#   'japanese',
#   'officials',
#   'said',
#   'indication',
#   'u.s.',
#   'position',
#   'came',
#   'last',
#   'december',
#   'secretary',
#   'agriculture',
#   'daniel',
#   'amstutz',
#   'said',
#   'japan',
#   'potential',
#   'provide',
#   'one',
#   'largest',
#   'boosts',
#   'u.s.',
#   'agricultural',
#   'exports',
#   'beef',
#   'market',
#   'alone',
#   'representing',
#   'one',
#   'billion',
#   'dlrs',
#   'new',
#   'business',
#   'u.s.',
#   'also',
#   'asked',
#   'general',
#   'agreement',
#   'tariffs',
#   'trade',
#   'investigate',
#   'legality',
#   'japanese',
#   'import',
#   'controls',
#   '12',
#   'farm',
#   'products',
#   'including',
#   'fruit',
#   'juices',
#   'purees',
#   'pulp',
#   'tomato',
#   'juice',
#   'ketchup',
#   'sauce',
#   'peanuts',
#   'prepared',
#   'beef',
#   'products',
#   'miscellaneous',
#   'beans',
#   'help',
#   'calm',
#   'heated',
#   'trade',
#   'relations',
#   'u.s.',
#   'japan',
#   "'s",
#   'top',
#   'business',
#   'group',
#   'keidanren',
#   'urged',
#   'government',
#   'remove',
#   'residual',
#   'import',
#   'restrictions',
#   'agricultural',
#   'products',
#   'agriculture',
#   'minister',
#   'kato',
#   'ruled',
#   'emotional',
#   'reaction',
#   'senior',
#   'ministry',
#   'official',
#   'said',
#   'farm',
#   'issue',
#   'become',
#   'scapegoat',
#   'trade',
#   'pressure',
#   'industrial',
#   'sector',
#   '``',
#   'japan',
#   'largest',
#   'buyer',
#   'u.s.',
#   'farm',
#   'products',
#   'issues',
#   'discussed',
#   'table',
#   "''",
#   'official',
#   'said'],
#  ['south',
#   'korea',
#   'moves',
#   'slow',
#   'growth',
#   'trade',
#   'surplus',
#   'south',
#   'korea',
#   "'s",
#   'trade',
#   'surplus',
#   'growing',
#   'fast',
#   'government',
#   'started',
#   'taking',
#   'steps',
#   'slow',
#   'deputy',
#   'prime',
#   'minister',
#   'kim',
#   'mahn-je',
#   'said',
#   'told',
#   'press',
#   'conference',
#   'government',
#   'planned',
#   'increase',
#   'investment',
#   'speed',
#   'opening',
#   'local',
#   'market',
#   'foreign',
#   'imports',
#   'gradually',
#   'adjust',
#   'currency',
#   'hold',
#   'surplus',
#   '``',
#   'proper',
#   'level',
#   "''",
#   'said',
#   'government',
#   'would',
#   'allow',
#   'appreciate',
#   'much',
#   'short',
#   'period',
#   'time',
#   'south',
#   'korea',
#   'pressure',
#   'washington',
#   'revalue',
#   'u.s.',
#   'wants',
#   'south',
#   'korea',
#   'cut',
#   'trade',
#   'surplus',
#   'u.s.',
#   'rose',
#   '7.4',
#   'billion',
#   'dlrs',
#   '1986',
#   '4.3',
#   'billion',
#   'dlrs',
#   '1985.',
#   'kim',
#   'also',
#   'economic',
#   'planning',
#   'minister',
#   'said',
#   'prospects',
#   'bright',
#   'south',
#   'korean',
#   'economy',
#   'government',
#   'would',
#   'try',
#   'hold',
#   'current',
#   'account',
#   'surplus',
#   'around',
#   'five',
#   'billion',
#   'dlrs',
#   'year',
#   'next',
#   'five',
#   'years',
#   '``',
#   'government',
#   'projections',
#   'eight',
#   'pct',
#   'gnp',
#   'growth',
#   'five',
#   'billion',
#   'dlrs',
#   'current',
#   'account',
#   'surplus',
#   '12',
#   'pct',
#   'growth',
#   'exports',
#   'seemed',
#   'reasonable',
#   'early',
#   'year',
#   'surplus',
#   'growing',
#   'faster',
#   'expected',
#   "''",
#   'said',
#   'trade',
#   'ministry',
#   'officials',
#   'said',
#   'south',
#   'korea',
#   "'s",
#   'exports',
#   'rose',
#   '35',
#   'pct',
#   '9.34',
#   'billion',
#   'dlrs',
#   'first',
#   'three',
#   'months',
#   'year',
#   'imports',
#   'rose',
#   '8.5',
#   'pct',
#   '8.2',
#   'billion',
#   'dlrs',
#   'kim',
#   'said',
#   'swing',
#   'south',
#   'korea',
#   "'s",
#   'current',
#   'account',
#   'surplus',
#   '4.65',
#   'billion',
#   'dlrs',
#   '1986',
#   '890',
#   'mln',
#   'dlr',
#   'deficit',
#   '1985',
#   'significant',
#   'surplus',
#   'enabled',
#   'country',
#   'reduce',
#   'foreign',
#   'debt',
#   'last',
#   'year',
#   'first',
#   'time',
#   'south',
#   'korea',
#   "'s",
#   'foreign',
#   'debt',
#   'fell',
#   '44.5',
#   'billion',
#   'dlrs',
#   '1986',
#   '46.8',
#   'billion',
#   '1985',
#   'still',
#   'among',
#   'largest',
#   'asia',
#   '``',
#   'huge',
#   'amount',
#   'foreign',
#   'debt',
#   'one',
#   'major',
#   'constraints',
#   'development',
#   '...',
#   'last',
#   'year',
#   'major',
#   'turning',
#   'point',
#   'korean',
#   'economy',
#   "''",
#   'kim',
#   'said',
#   'kim',
#   'said',
#   'government',
#   'plannned',
#   'reduce',
#   'ratio',
#   'foreign',
#   'debt',
#   'country',
#   "'s",
#   'gnp',
#   '20',
#   'pct',
#   '1991',
#   '50',
#   'pct',
#   '1986',
#   '``',
#   'government',
#   'however',
#   'want',
#   'accelerate',
#   'reducing',
#   'debt',
#   'making',
#   'excessive',
#   'trade',
#   'surplus',
#   "''",
#   'said',
#   'kim',
#   'said',
#   'sudden',
#   'rise',
#   'surplus',
#   'would',
#   'cause',
#   'inflation',
#   'lead',
#   'trade',
#   'friction',
#   'seoul',
#   "'s",
#   'major',
#   'trading',
#   'partners',
#   'particularly',
#   'united',
#   'states',
#   '``',
#   'need',
#   'surplus',
#   'reduce',
#   'debt',
#   'taking',
#   'measures',
#   'hold',
#   'size',
#   'surplus',
#   'proper',
#   'level',
#   "''",
#   'kim',
#   'said'],
#  ['japan',
#   'given',
#   'little',
#   'hope',
#   'avoiding',
#   'u.s.',
#   'sanctions',
#   'top',
#   'u.s.',
#   'official',
#   'said',
#   'japan',
#   'little',
#   'chance',
#   'convincing',
#   'u.s.',
#   'drop',
#   'threatened',
#   'trade',
#   'sanctions',
#   'despite',
#   'efforts',
#   'japanese',
#   'team',
#   'left',
#   'washington',
#   'today',
#   'michael',
#   'armacost',
#   'secretary',
#   'state',
#   'political',
#   'affairs',
#   'asked',
#   'press',
#   'conference',
#   'whether',
#   'japan',
#   "'s",
#   'moves',
#   'boost',
#   'domestic',
#   'economy',
#   'open',
#   'markets',
#   'could',
#   'persuade',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'japanese',
#   'imports',
#   'said',
#   'replied',
#   '``',
#   '...',
#   'probably',
#   'early',
#   'figures',
#   'demonstrate',
#   'situation',
#   'turned',
#   'around',
#   'permit',
#   'result',
#   'described',
#   "''",
#   'armacost',
#   'said',
#   'u.s.',
#   'hopes',
#   'japan',
#   'take',
#   'steps',
#   'lift',
#   'domestic',
#   'economy',
#   'reduce',
#   'dependence',
#   'exports',
#   'remove',
#   'barriers',
#   'imports',
#   'settle',
#   'outstanding',
#   'trade',
#   'issues',
#   '``',
#   'obvious',
#   'problems',
#   'moment',
#   'trade',
#   'area',
#   'wish',
#   'problems',
#   'divert',
#   'attention',
#   'important',
#   'areas',
#   'cooperation',
#   'continue',
#   'exist',
#   'security',
#   'political',
#   'issues',
#   "''",
#   'said',
#   '``',
#   'question',
#   'whether',
#   'cooperative',
#   'actions',
#   'governments',
#   'reduce',
#   'trade',
#   'imbalance',
#   'whether',
#   'congress',
#   'takes',
#   'action',
#   'reduce',
#   'protectionist',
#   'legislation',
#   "''",
#   'said'],
#  ['japanese',
#   'official',
#   'takes',
#   'data',
#   'microchip',
#   'talks',
#   'ministry',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'vice',
#   'minister',
#   'makoto',
#   'kuroda',
#   'leaves',
#   'washington',
#   'today',
#   'data',
#   'hopes',
#   'refute',
#   'u.s.',
#   'charges',
#   'japan',
#   'violated',
#   'pact',
#   'microchip',
#   'trade',
#   'three-man',
#   'japanese',
#   'trade',
#   'team',
#   'already',
#   'washington',
#   'laying',
#   'groundwork',
#   'talks',
#   'kuroda',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'aimed',
#   'persuading',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'certain',
#   'japanese',
#   'products',
#   'kuroda',
#   'said',
#   'taking',
#   'new',
#   'proposals',
#   '``',
#   'nothing',
#   'briefcase',
#   'except',
#   'explanation',
#   'current',
#   'situation',
#   "''",
#   'kuroda',
#   'told',
#   'daily',
#   'newspaper',
#   'asahi',
#   'shimbun',
#   'kuroda',
#   'said',
#   'u.s.',
#   'decision',
#   'based',
#   'incorrect',
#   'data',
#   'exaggerated',
#   'sense',
#   'miti',
#   "'s",
#   'power',
#   'control',
#   'market',
#   'forces',
#   '``',
#   'u.s.',
#   'excessive',
#   'expectations',
#   'stabilise',
#   'supply-demand',
#   'relations',
#   'disrupted',
#   'excess',
#   'inventories',
#   'since',
#   '1985',
#   'take',
#   'time',
#   "''",
#   'said',
#   'kuroda',
#   'also',
#   'laid',
#   'part',
#   'blame',
#   'low',
#   'u.s.',
#   'chip',
#   'sales',
#   'japan',
#   'lack',
#   'effort',
#   'american',
#   'firms',
#   'said',
#   'fails',
#   'talks',
#   'tomorrow',
#   'friday',
#   'forestall',
#   'sanctions',
#   'seek',
#   'talks',
#   'u.s.',
#   'trade',
#   'representative',
#   'clayton',
#   'yeutter',
#   'u.s.',
#   'officials',
#   'said',
#   'week',
#   "'s",
#   'talks',
#   'unlikely',
#   'delay',
#   'imposition',
#   'tariffs'],
#  ['japan',
#   'given',
#   'little',
#   'hope',
#   'avoiding',
#   'u.s.',
#   'sanctions',
#   'top',
#   'u.s.',
#   'official',
#   'said',
#   'japan',
#   'little',
#   'chance',
#   'persuading',
#   'u.s.',
#   'drop',
#   'threatened',
#   'trade',
#   'sanctions',
#   'despite',
#   'efforts',
#   'japanese',
#   'team',
#   'left',
#   'washington',
#   'today',
#   'michael',
#   'armacost',
#   'secretary',
#   'state',
#   'political',
#   'affairs',
#   'asked',
#   'press',
#   'conference',
#   'whether',
#   'japan',
#   "'s",
#   'moves',
#   'boost',
#   'domestic',
#   'economy',
#   'open',
#   'markets',
#   'could',
#   'persuade',
#   'u.s.',
#   'impose',
#   'tariffs',
#   'japanese',
#   'imports',
#   'said',
#   'replied',
#   '``',
#   '...',
#   'probably',
#   'early',
#   'figures',
#   'demonstrate',
#   'situation',
#   'turned',
#   'around',
#   'permit',
#   'result',
#   'described',
#   "''",
#   'armacost',
#   'said',
#   'u.s.',
#   'hopes',
#   'japan',
#   'take',
#   'steps',
#   'lift',
#   'domestic',
#   'economy',
#   'reduce',
#   'dependence',
#   'exports',
#   'remove',
#   'barriers',
#   'imports',
#   'settle',
#   'outstanding',
#   'trade',
#   'issues',
#   '``',
#   'obvious',
#   'problems',
#   'moment',
#   'trade',
#   'area',
#   'wish',
#   'problems',
#   'divert',
#   'attention',
#   'important',
#   'areas',
#   'cooperation',
#   'continue',
#   'exist',
#   'security',
#   'political',
#   'issues',
#   "''",
#   'said',
#   '``',
#   'question',
#   'whether',
#   'cooperative',
#   'actions',
#   'governments',
#   'reduce',
#   'trade',
#   'imbalance',
#   'whether',
#   'congress',
#   'takes',
#   'action',
#   'reduce',
#   'protectionist',
#   'legislation',
#   "''",
#   'said'],
#  ['japan',
#   'last-ditch',
#   'effort',
#   'avert',
#   'tariffs',
#   'senior',
#   'japanese',
#   'officials',
#   'tomorrow',
#   'open',
#   'talks',
#   'american',
#   'trade',
#   'negotiators',
#   'last-ditch',
#   'effort',
#   'avert',
#   'new',
#   'high',
#   'u.s.',
#   'tariffs',
#   'imposed',
#   'wide',
#   'variety',
#   'japanese',
#   'electronic',
#   'exports',
#   'makoto',
#   'kuroda',
#   'vice',
#   'minister',
#   'japan',
#   "'s",
#   'ministry',
#   'international',
#   'trade',
#   'industry',
#   'miti',
#   'hold',
#   'two',
#   'days',
#   'meetings',
#   'deputy',
#   'u.s.',
#   'trade',
#   'representative',
#   'michael',
#   'smith',
#   'secretary',
#   'commerce',
#   'bruce',
#   'smart',
#   'new',
#   'tariffs',
#   'go',
#   'effect',
#   'april',
#   '17',
#   'retaliation',
#   'japan',
#   "'s",
#   'failure',
#   'adhere',
#   'agreement',
#   'end',
#   'dumping',
#   'semiconductors',
#   'world',
#   'markets',
#   'cost',
#   'open',
#   'home',
#   'market',
#   'u.s.',
#   'semiconductor',
#   'shipments',
#   'imposed',
#   'goods',
#   'use',
#   'semiconductors',
#   'including',
#   'television',
#   'audio',
#   'equipment',
#   'computers',
#   'u.s.',
#   'japanese',
#   'officials',
#   'said',
#   'little',
#   'likelihood',
#   'talks',
#   'would',
#   'anything',
#   'avert',
#   '100',
#   'pct',
#   'duties',
#   '300',
#   'mln',
#   'dlrs',
#   'worth',
#   'japanese',
#   'shipments',
#   'president',
#   'reagan',
#   'announced',
#   'planned',
#   'tariffs',
#   'march',
#   '27',
#   'said',
#   'close',
#   'monitoring',
#   'july',
#   '1986',
#   'u.s.-japanese',
#   'semiconductor',
#   'pact',
#   'convinced',
#   'u.s.',
#   'officials',
#   'japan',
#   'honoring',
#   'agreement',
#   'making',
#   'annoucement',
#   'reagan',
#   'said',
#   '``',
#   'committed',
#   'full',
#   'enforcement',
#   'trade',
#   'agreements',
#   'designed',
#   'provide',
#   'american',
#   'industry',
#   'free',
#   'fair',
#   'trade',
#   "''",
#   'trade',
#   'analysts',
#   'said',
#   'move',
#   'aimed',
#   'much',
#   'japan',
#   "'s",
#   'semiconductor',
#   'trade',
#   'practices',
#   'said',
#   'injured',
#   'u.s.',
#   'semiconductor',
#   'industry',
#   'congress',
#   'complained',
#   'presidential',
#   'timidity',
#   'trade',
#   'issues',
#   'congressional',
#   'democrats',
#   'pledged',
#   'enact',
#   'aggressive',
#   'trade',
#   'laws',
#   'counter',
#   'contend',
#   'reagan',
#   "'s",
#   'inaction',
#   'redress',
#   'growing',
#   'u.s.',
#   'trade',
#   'deficit',
#   'last',
#   'year',
#   'reached',
#   '169.8',
#   'billion',
#   'dlrs',
#   'one-third',
#   'deficit',
#   'japan',
#   'reagan',
#   'said',
#   'recent',
#   'signs',
#   'japan',
#   'beginning',
#   'adhere',
#   'pact',
#   'terminating',
#   'kuroda',
#   'said',
#   'leaving',
#   'tokyo',
#   'today',
#   'new',
#   'proposals',
#   'explanation',
#   'semiconductor',
#   'situation',
#   'told',
#   'daily',
#   'newspaper',
#   'ashai',
#   'shimbun',
#   'reagan',
#   "'s",
#   'decision',
#   'based',
#   'inaccurate',
#   'data',
#   'exaggerated',
#   'sense',
#   'miti',
#   "'s",
#   'power',
#   'control',
#   'japanese',
#   'traders',
#   '``',
#   'united',
#   'states',
#   'excessive',
#   'expectations.',
#   "''",
#   'said',
#   'stabilize',
#   'supply-demand',
#   'relations',
#   'disrupted',
#   'excess',
#   'inventories',
#   'since',
#   '1985',
#   'take',
#   'time',
#   "''",
#   'also',
#   'said',
#   'u.s.',
#   'firms',
#   'aggressive',
#   'enough',
#   'trying',
#   'sell',
#   'japanese',
#   'market'],
#  ['white',
#   'house',
#   'standing',
#   'firm',
#   'japanese',
#   'sanctions',
#   'presidential',
#   'spokesman',
#   'marlin',
#   'fitzwater',
#   'said',
#   'u.s.',
#   'trade',
#   'sanctions',
#   'japan',
#   'likely',
#   'take',
#   'effect',
#   'april',
#   '17',
#   'spite',
#   '``',
#   'full',
#   'court',
#   'press',
#   "''",
#   'japanese',
#   'officials',
#   'avoid',
#   '``',
#   'indications',
#   'take',
#   'effect',
#   "''",
#   'said',
#   '``',
#   'would',
#   'say',
#   'japan',
#   'applying',
#   'full',
#   'court',
#   'press',
#   '...',
#   'certainly',
#   'putting',
#   'feet',
#   'forward',
#   'terms',
#   'explaining',
#   'position',
#   "''",
#   'fitzwater',
#   'told',
#   'reporters',
#   'noted',
#   'high',
#   'level',
#   'meetings',
#   'trade',
#   'dispute',
#   'underway',
#   'said',
#   '``',
#   "n't",
#   'think',
#   "'s",
#   'anything',
#   'report',
#   "n't",
#   'believe',
#   "'s",
#   'official',
#   'movement',
#   "''"],
#  ['white',
#   'house',
#   'says',
#   'japanese',
#   'tarriffs',
#   'likely',
#   'white',
#   'house',
#   'said',
#   'high',
#   'u.s.',
#   'tariffs',
#   'japanese',
#   'electronic',
#   'goods',
#   'would',
#   'likely',
#   'imposed',
#   'scheduled',
#   'april',
#   '17',
#   'despite',
#   'all-out',
#   'effort',
#   'japan',
#   'avoid',
#   'presidential',
#   'spokesman',
#   'marlin',
#   'fitzwater',
#   'made',
#   'remark',
#   'one',
#   'day',
#   'u.s.',
#   'japanese',
#   'officials',
#   'meet',
#   'emergency',
#   'provisions',
#   'july',
#   '1986',
#   'semiconductor',
#   'pact',
#   'discuss',
#   'trade',
#   'punitive',
#   'tariffs',
#   'fitzwater',
#   'said',
#   '``',
#   'would',
#   'say',
#   'japan',
#   'applying',
#   'full-court',
#   'press',
#   '...',
#   'certainly',
#   'putting',
#   'feet',
#   'forward',
#   'terms',
#   'explaining',
#   'position',
#   "''",
#   'added',
#   '``',
#   'indications',
#   'tariffs',
#   'take',
#   'effect',
#   "''"],
#  ['canada',
#   'plans',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'trade',
#   'minister',
#   'says',
#   'canada',
#   'plans',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'trade',
#   'minister',
#   'says'],
#  ['canada',
#   'monitor',
#   'steel',
#   'imports',
#   'exports',
#   'canada',
#   'plans',
#   'monitor',
#   'steel',
#   'shipments',
#   'flowing',
#   'country',
#   'attempt',
#   'appease',
#   'concerns',
#   'u.s.',
#   'high',
#   'level',
#   'canadian',
#   'steel',
#   'exports',
#   'trade',
#   'minister',
#   'pat',
#   'carney',
#   'said',
#   '``',
#   'help',
#   'maintain',
#   'open',
#   'access',
#   'u.s.',
#   'steel',
#   'market',
#   'government',
#   'taking',
#   'action',
#   'ensure',
#   'accurate',
#   'data',
#   'exports',
#   'imports',
#   'canada',
#   'used',
#   'backdoor',
#   'u.s.',
#   'market',
#   'offshore',
#   'suppliers',
#   "''",
#   'carney',
#   'said',
#   'carney',
#   'also',
#   'said',
#   'canadian',
#   'companies',
#   'asked',
#   'exercise',
#   'prudence',
#   'u.s.',
#   'market',
#   'countries',
#   'considering',
#   'establishing',
#   'joint',
#   'commission',
#   'study',
#   'growing',
#   'steel',
#   'problem',
#   'carney',
#   'told',
#   'house',
#   'commons',
#   'soon',
#   'announce',
#   'amendment',
#   'exports',
#   'imports',
#   'permits',
#   'act',
#   'set',
#   'monitoring',
#   'program',
#   'canadian',
#   'steel',
#   'shipments',
#   'u.s.',
#   'risen',
#   '5.7',
#   'pct',
#   'cent',
#   'u.s.',
#   'market',
#   'recent',
#   'months',
#   'almost',
#   'double',
#   'level',
#   'two',
#   'years',
#   'ago',
#   'canadian',
#   'trade',
#   'officials',
#   'said',
#   'increase',
#   'canadian',
#   'shipments',
#   'comes',
#   'time',
#   'growing',
#   'anger',
#   'u.s.',
#   'rising',
#   'steel',
#   'imports',
#   'several',
#   'countries',
#   'face',
#   'decline',
#   'domestic',
#   'steel',
#   'industry',
#   'u.s.',
#   'lawmakers',
#   'proposed',
#   'canada',
#   "'s",
#   'share',
#   'american',
#   'market',
#   'limited',
#   '2.4',
#   'pct'],
#  ['deficit',
#   'cuts',
#   'seen',
#   'unable',
#   'cure',
#   'trade',
#   'deficit',
#   'financial',
#   'analysts',
#   'say',
#   'pleased',
#   'congressional',
#   'moves',
#   'trim',
#   'next',
#   'year',
#   "'s",
#   'federal',
#   'budget',
#   'deficit',
#   'believe',
#   'actions',
#   'little',
#   'help',
#   'improve',
#   'u.s.',
#   'trade',
#   'deficit',
#   'buoy',
#   'economy',
#   'house',
#   'representatives',
#   'expected',
#   'vote',
#   'tomorrow',
#   'approve',
#   'trillion-dollar',
#   'budget',
#   'blueprint',
#   'coming',
#   'fiscal',
#   'year',
#   'reduces',
#   'deficit',
#   '38',
#   'billion',
#   'dlrs',
#   'similarly',
#   'senate',
#   'budget',
#   'committee',
#   'approved',
#   'plan',
#   'would',
#   'cut',
#   'federal',
#   'red',
#   'ink',
#   '37',
#   'billion',
#   'dlrs',
#   'next',
#   'year',
#   '``',
#   'terms',
#   'economy',
#   '37-38',
#   'billion',
#   'dlrs',
#   'infinitesimal',
#   'cuts',
#   'magnitude',
#   'little',
#   'impact',
#   'economy',
#   'trade',
#   'deficit',
#   "''",
#   'said',
#   'stanley',
#   'collander',
#   'touche',
#   'ross',
#   'federal',
#   'budget',
#   'policy',
#   'analyst',
#   '``',
#   'best',
#   'small',
#   'positive',
#   'effect',
#   "''",
#   'collander',
#   'said',
#   'interview',
#   'federal',
#   'reserve',
#   'board',
#   'chairman',
#   'paul',
#   'volcker',
#   'repeatedly',
#   'told',
#   'congress',
#   'cutting',
#   'federal',
#   'red',
#   'ink',
#   'would',
#   'go',
#   'long',
#   'way',
#   'help',
#   'reduce',
#   'massive',
#   'trade',
#   'deficit',
#   'also',
#   'help',
#   'ease',
#   'downward',
#   'pressure',
#   'value',
#   'dollar',
#   'u.s.',
#   'government',
#   'attempted',
#   'remedy',
#   'trade',
#   'imbalance',
#   'driving',
#   'value',
#   'dollar',
#   'volcker',
#   'warned',
#   'fall',
#   'dollar',
#   "'s",
#   'value',
#   'fraught',
#   'danger',
#   'decline',
#   'said',
#   'could',
#   'refuel',
#   'inflation',
#   'imported',
#   'goods',
#   'become',
#   'expensive',
#   'chase',
#   'away',
#   'foreign',
#   'capital',
#   'needed',
#   'finance',
#   'federal',
#   'budget',
#   'deficit',
#   'addition',
#   'february',
#   'u.s.',
#   'officials',
#   'meeting',
#   'major',
#   'industrialized',
#   'nations',
#   'paris',
#   'agreed',
#   'value',
#   'dollar',
#   'dropped',
#   'enough',
#   'world',
#   'exchange',
#   'rates',
#   'stabilized',
#   'around',
#   'current',
#   'levels',
#   'part',
#   'agreement',
#   'japan',
#   'west',
#   'germany',
#   'agreed',
#   'take',
#   'steps',
#   'stimulate',
#   'economies',
#   'united',
#   'states',
#   'agreed',
#   'cut',
#   'budget',
#   'deficit',
#   'alternative',
#   'driving',
#   'dollar',
#   'way',
#   'deal',
#   'trade',
#   'deficit',
#   'volcker',
#   'said',
#   'recently',
#   'reduce',
#   'u.s.',
#   'consumption',
#   'particularly',
#   'federal',
#   'spending',
#   '``',
#   "n't",
#   'deal',
#   'budget',
#   'deficit',
#   'everything',
#   'else',
#   'going',
#   'counterproductive',
#   "''",
#   'volcker',
#   'said',
#   'recent',
#   'testimony',
#   'senate',
#   'banking',
#   'committee',
#   'volcker',
#   'also',
#   'said',
#   'would',
#   'prefer',
#   'tighten',
#   'government',
#   "'s",
#   'purse',
#   'strings',
#   'fed',
#   'tighten',
#   'credit',
#   'supply',
#   'action',
#   'needed',
#   'fight',
#   'inflationary',
#   'pressures',
#   'assure',
#   'continued',
#   'flow',
#   'foreign',
#   'capital',
#   'united',
#   'states',
#   'analysts',
#   'say',
#   'fed',
#   'tightening',
#   'could',
#   'choke',
#   'current',
#   'modest',
#   'economic',
#   'expansion',
#   'threaten',
#   'recession',
#   'kemper',
#   'financial',
#   'services',
#   'economist',
#   'john',
#   'silvia',
#   'stressed',
#   'deficit',
#   'reduction',
#   'better',
#   'none',
#   'said',
#   'size',
#   'cuts',
#   'consideration',
#   'enough',
#   'give',
#   'federal',
#   'reserve',
#   'board',
#   'flexibility',
#   'needs',
#   'steer',
#   'economy',
#   'keep',
#   'value',
#   'dollar',
#   'plunging',
#   'world',
#   'exchange',
#   'markets',
#   '``',
#   "'s",
#   'doubt',
#   'deficit',
#   'reduction',
#   'helps',
#   'objective',
#   'stabilize',
#   'dollar',
#   'perserve',
#   'fed',
#   "'s",
#   'flexibility',
#   'conduct',
#   'monetary',
#   'policy',
#   'answer',
#   "'s",
#   'enough',
#   "''",
#   'silvia',
#   'told',
#   'reuters',
#   'u.s.',
#   'trade',
#   'deficit',
#   'become',
#   'one',
#   'government',
#   "'s",
#   'vexing',
#   'persistent',
#   'problems',
#   '1986',
#   'deficit',
#   '169.8',
#   'billion',
#   'dlrs',
#   'yet',
#   'little',
#   'indication',
#   'year',
#   "'s",
#   'figure',
#   'lower',
#   'though',
#   'administration',
#   'officials',
#   'predicted',
#   'drop',
#   '20',
#   '30',
#   'billion',
#   'dlrs',
#   'year',
#   "'s",
#   'end',
#   'past',
#   'volcker',
#   'joked',
#   'never',
#   'lost',
#   'sleep',
#   'worrying',
#   'whether',
#   'congress',
#   'would',
#   'cut',
#   'much',
#   'fat',
#   'federal',
#   'budget',
#   'hand',
#   'also',
#   'made',
#   'clear',
#   'attached',
#   'gradually',
#   'declining',
#   'deficit',
#   'ceilings',
#   'set',
#   '1986-1991',
#   'period',
#   'last',
#   'year',
#   "'s",
#   'gramm-rudman',
#   'balanced',
#   'budget',
#   'law',
#   'new',
#   'law',
#   'set',
#   'ceiling',
#   '108',
#   'billion',
#   'dlrs',
#   'next',
#   'year',
#   "'s",
#   'federal',
#   'deficit',
#   'house',
#   'senate',
#   'budget',
#   'committees',
#   'conceded',
#   'budget',
#   'plans',
#   'would',
#   'fall',
#   'short',
#   'deficit',
#   'reduction',
#   'goal',
#   '25',
#   'billion',
#   'dlrs',
#   '``',
#   'political',
#   'reasons',
#   '35',
#   '40',
#   'billion',
#   'dlrs',
#   "'re",
#   'going',
#   'get',
#   "''",
#   'congress',
#   'present',
#   'time',
#   'said',
#   'touche',
#   'ross',
#   "'s",
#   'collander',
#   '``',
#   'something',
#   'would',
#   'extraordinary',
#   'remarkable',
#   'difficult',
#   "''",
#   'collander',
#   'said',
#   'real',
#   'danger',
#   'congress',
#   'end',
#   'short',
#   'deficit',
#   'reduction',
#   'goal',
#   'set',
#   'budget',
#   'panels',
#   '``',
#   'extent',
#   'become',
#   'minimum',
#   'acceptable',
#   'reduction',
#   'level',
#   "''",
#   'explained',
#   '``',
#   'anything',
#   'less',
#   'look',
#   'like',
#   'failure',
#   'wall',
#   'street',
#   "''",
#   'budget',
#   'plan',
#   'debate',
#   'house',
#   'floor',
#   'would',
#   'lower',
#   'estimated',
#   '171',
#   'billion',
#   'dlr',
#   'deficit',
#   'year',
#   'beginning',
#   'october',
#   'one',
#   '133',
#   'billion',
#   'dlrs',
#   'cutting',
#   'defense',
#   'domestic',
#   'programs',
#   '38',
#   'billion',
#   'dlrs',
#   'anticipated',
#   'spending',
#   'levels',
#   'next',
#   'year',
#   'senate',
#   'budget',
#   'committee',
#   'called',
#   'deficit',
#   'nearly',
#   '134',
#   'billion',
#   'dlrs',
#   '18.5',
#   'billion',
#   'dlrs',
#   'new',
#   'taxes',
#   'amount',
#   'spending',
#   'cuts'],
#  ['economic',
#   'spotlight',
#   'telecom',
#   'key',
#   'japan',
#   'ministry',
#   'japan',
#   "'s",
#   'little-known',
#   'ministry',
#   'posts',
#   'telecommunications',
#   'mpt',
#   'emerged',
#   'international',
#   'force',
#   'reckoned',
#   'political',
#   'analysts',
#   'said',
#   'mpt',
#   'thrust',
#   'spotlight',
#   'trade',
#   'rows',
#   'u.s.',
#   'britain',
#   'position',
#   'strength',
#   'due',
#   'control',
#   'lucrative',
#   'industry',
#   'ties',
#   'important',
#   'politicians',
#   'said',
#   '``',
#   'ministry',
#   'standing',
#   'athwart',
#   'regulatory',
#   'control',
#   'key',
#   'industrial',
#   'sector',
#   'telecommunications',
#   'information',
#   "''",
#   'said',
#   'one',
#   'diplomatic',
#   'source',
#   '``',
#   'potent',
#   'political',
#   'force',
#   "''",
#   'diplomatic',
#   'source',
#   'said',
#   'mpt',
#   'finding',
#   'domestic',
#   'political',
#   'prowess',
#   'always',
#   'help',
#   'comes',
#   'trade',
#   'friction',
#   'diplomacy',
#   'analysts',
#   'said',
#   '``',
#   'ministry',
#   'minor',
#   'ministry',
#   'people',
#   'internationalized',
#   "''",
#   'said',
#   'waseda',
#   'university',
#   'professor',
#   'mitsuru',
#   'uchida',
#   '``',
#   'suddenly',
#   "'re",
#   'standing',
#   'centre',
#   'world',
#   'community',
#   'sense',
#   "'re",
#   'loss',
#   'face',
#   'situation',
#   "''",
#   'recently',
#   'ministry',
#   'embroiled',
#   'row',
#   'london',
#   'efforts',
#   'britain',
#   "'s",
#   'cable',
#   'wireless',
#   'plc',
#   'keep',
#   'major',
#   'stake',
#   'one',
#   'two',
#   'consortia',
#   'trying',
#   'compete',
#   'japan',
#   "'s",
#   'lucrative',
#   'overseas',
#   'telephone',
#   'business',
#   'ministry',
#   'favoured',
#   'merger',
#   'two',
#   'rival',
#   'groups',
#   'arguing',
#   'market',
#   'support',
#   'one',
#   'competitor',
#   'kokusai',
#   'denshin',
#   'denwa',
#   'co',
#   'ltd',
#   'monopolizes',
#   'business',
#   'also',
#   'opposed',
#   'major',
#   'management',
#   'role',
#   'planned',
#   'merger',
#   'non-japanese',
#   'overseas',
#   'telecommunications',
#   'firm',
#   'grounds',
#   'international',
#   'precedent',
#   'exists',
#   'ministry',
#   "'s",
#   'stance',
#   'outraged',
#   'london',
#   'threatened',
#   'retaliate',
#   'washington',
#   'says',
#   'merger',
#   'plan',
#   'evidence',
#   'japan',
#   "'s",
#   'failure',
#   'honour',
#   'pledges',
#   'open',
#   'telecommunications',
#   'market',
#   'washington',
#   'also',
#   'angry',
#   'ministry',
#   'moves',
#   'says',
#   'limited',
#   'access',
#   'u.s.',
#   'firms',
#   'japan',
#   "'s",
#   'car',
#   'telephone',
#   'satellite',
#   'communications',
#   'market',
#   'much',
#   'mpt',
#   "'s",
#   'new',
#   'prominence',
#   'stems',
#   'growth',
#   'sector',
#   'regulates',
#   '``',
#   'happening',
#   'important',
#   'shift',
#   'economy',
#   'makes',
#   'ministry',
#   'important',
#   'place',
#   "''",
#   'said',
#   'james',
#   'abegglen',
#   'head',
#   'consulting',
#   'firm',
#   'asia',
#   'advisory',
#   'service',
#   'inc.',
#   'decision',
#   'open',
#   'telecommunications',
#   'industry',
#   'competition',
#   'new',
#   'set',
#   'laws',
#   'passed',
#   '1985',
#   'boosted',
#   'rather',
#   'lessened',
#   'mpt',
#   "'s",
#   'authority',
#   'analysts',
#   'said',
#   '``',
#   'legal',
#   'framework',
#   'eased',
#   'became',
#   'de',
#   'facto',
#   'legal',
#   'framework',
#   "''",
#   'said',
#   'bache',
#   'securities',
#   'japan',
#   'analyst',
#   'darrell',
#   'whitten',
#   'close',
#   'links',
#   'powerful',
#   'political',
#   'faction',
#   'ruling',
#   'liberal',
#   'democratic',
#   'party',
#   'ldp',
#   'nurtured',
#   'former',
#   'prime',
#   'minister',
#   'kakuei',
#   'tanaka',
#   'another',
#   'key',
#   'mpt',
#   "'s",
#   'influence',
#   'analysts',
#   'said',
#   '``',
#   'factions',
#   'ignored',
#   'mpt',
#   '1970s',
#   'tanaka',
#   'faction',
#   'forward',
#   'looking',
#   '...',
#   'recognized',
#   'importance',
#   'mpt',
#   "''",
#   'uchida',
#   'said',
#   'many',
#   'former',
#   'bureaucrats',
#   'became',
#   'members',
#   'influential',
#   'political',
#   'group',
#   'added',
#   'ministry',
#   'also',
#   'power',
#   'financial',
#   'sector',
#   'due',
#   '100,000',
#   'billion',
#   'yen',
#   'worth',
#   'deposits',
#   'postal',
#   'savings',
#   'system',
#   'analysts',
#   'said',
#   'mpt',
#   'helped',
#   'block',
#   'finance',
#   'ministry',
#   'plans',
#   'deregulate',
#   'interest',
#   'rates',
#   'small',
#   'deposits',
#   'key',
#   'element',
#   'financial',
#   'liberalisation',
#   'since',
#   'change',
#   'would',
#   'remove',
#   'postal',
#   'savings',
#   'system',
#   "'s",
#   'ability',
#   'offer',
#   'slightly',
#   'higher',
#   'rates',
#   'banks',
#   'said',
#   'diplomatic',
#   'sources',
#   'frustrated',
#   'see',
#   'mpt',
#   "'s",
#   'obstructionist',
#   'protectionist',
#   'posture',
#   'characterized',
#   'ministry',
#   'feudal',
#   'critics',
#   'charge',
#   'mpt',
#   'protecting',
#   'turf',
#   'limiting',
#   'competition',
#   'sheltering',
#   'former',
#   'monopolies',
#   'wing',
#   'providing',
#   'consumers',
#   'best',
#   'service',
#   'lowest',
#   'price',
#   'takes',
#   'back',
#   'seat',
#   'considerations',
#   'said',
#   'many',
#   'ministry',
#   "'s",
#   'actions',
#   'unlike',
#   'bureaucratic',
#   'counterparts',
#   'much',
#   'western',
#   'world',
#   'including',
#   'britain',
#   'several',
#   'analysts',
#   'said',
#   '``',
#   'united',
#   'states',
#   'really',
#   'odd',
#   'man',
#   "''",
#   'abegglen',
#   'said',
#   '``',
#   'government',
#   'take',
#   'view',
#   'wants',
#   'keep',
#   'order',
#   'utilities',
#   'markets',
#   'unusual',
#   'and/or',
#   'unreasonable',
#   'view',
#   "''",
#   'said'],
#  ['g-7',
#   'issues',
#   'statement',
#   'meeting',
#   'following',
#   'text',
#   'statement',
#   'group',
#   'seven',
#   '--',
#   'u.s.',
#   'japan',
#   'west',
#   'germany',
#   'france',
#   'britain',
#   'italy',
#   'canada',
#   '--',
#   'issued',
#   'washington',
#   'meeting',
#   'yesterday',
#   '1.',
#   'finance',
#   'ministers',
#   'central',
#   'bank',
#   'governors',
#   'seven',
#   'major',
#   'industrial',
#   'countries',
#   'met',
#   'today',
#   'continued',
#   'process',
#   'multilateral',
#   'surveillance',
#   'economies',
#   'pursuant',
#   'arrangements',
#   'strengthened',
#   'economic',
#   'policy',
#   'coordination',
#   'agreed',
#   '1986',
#   'tokyo',
#   'summit',
#   'heads',
#   'state',
#   'government',
#   'managing',
#   'director',
#   'international',
#   'monetary',
#   'fund',
#   'also',
#   'participated',
#   'meeting',
#   '2.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'commitment',
#   'cooperative',
#   'approach',
#   'agreed',
#   'recent',
#   'paris',
#   'meeting',
#   'noted',
#   'progress',
#   'achieved',
#   'implementing',
#   'undertakings',
#   'embodied',
#   'louvre',
#   'agreement',
#   'agreed',
#   'however',
#   'actions',
#   'essential',
#   'resist',
#   'rising',
#   'protectionist',
#   'pressures',
#   'sustain',
#   'global',
#   'economic',
#   'expansion',
#   'reduce',
#   'trade',
#   'imbalances',
#   'connection',
#   'welcomed',
#   'proposals',
#   'announced',
#   'governing',
#   'liberal',
#   'democratic',
#   'party',
#   'japan',
#   'extraordinary',
#   'urgent',
#   'measures',
#   'stimulate',
#   'japan',
#   "'s",
#   'economy',
#   'early',
#   'implementation',
#   'large',
#   'supplementary',
#   'budget',
#   'exceeding',
#   'previous',
#   'years',
#   'well',
#   'unprecedented',
#   'front-end',
#   'loading',
#   'public',
#   'works',
#   'expenditures',
#   'government',
#   'japan',
#   'reaffirmed',
#   'intention',
#   'open',
#   'domestic',
#   'markets',
#   'foreign',
#   'goods',
#   'services',
#   '3.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'view',
#   'around',
#   'current',
#   'levels',
#   'currencies',
#   'within',
#   'ranges',
#   'broadly',
#   'consistent',
#   'economic',
#   'fundamentals',
#   'basic',
#   'policy',
#   'intentions',
#   'outlined',
#   'louvre',
#   'meeting',
#   'connection',
#   'welcomed',
#   'strong',
#   'implementation',
#   'louvre',
#   'agreement',
#   'concluded',
#   'present',
#   'prospective',
#   'progress',
#   'implementing',
#   'policy',
#   'undertakings',
#   'louvre',
#   'statement',
#   'provided',
#   'basis',
#   'continuing',
#   'close',
#   'cooperation',
#   'foster',
#   'stability',
#   'exchange',
#   'rates'],
#  ['soviet',
#   'trade',
#   'deficit',
#   'west',
#   'soars',
#   '1986',
#   'soviet',
#   'trade',
#   'deficit',
#   'west',
#   'almost',
#   'quadrupled',
#   'last',
#   'year',
#   'reaching',
#   '2.72',
#   'billion',
#   'roubles',
#   'compared',
#   '713',
#   'mln',
#   '1985',
#   'official',
#   'figures',
#   'showed',
#   'statistics',
#   'published',
#   'monthly',
#   'journal',
#   'foreign',
#   'trade',
#   'showed',
#   'soviet',
#   'trade',
#   'turnover',
#   '1986',
#   'fell',
#   '130.9',
#   'billion',
#   'roubles',
#   '142.1',
#   'billion',
#   'previous',
#   'year',
#   'drop',
#   '7.8',
#   'pct',
#   'moscow',
#   "'s",
#   'trade',
#   'surplus',
#   'east',
#   'bloc',
#   'countries',
#   'continued',
#   'grow',
#   '1986.',
#   'western',
#   'analysts',
#   'attributed',
#   'deficit',
#   'rise',
#   'west',
#   'world',
#   'oil',
#   'price',
#   'slump',
#   'hit',
#   'moscow',
#   "'s",
#   'main',
#   'export',
#   'cut',
#   'hard',
#   'currency',
#   'earnings',
#   'needed',
#   'purchases',
#   'west'],
#  ['canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'january',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus',
#   'canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'january',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus'],
#  ['canada',
#   'february',
#   'trade',
#   'surplus',
#   '1.2',
#   'billion',
#   'dlrs',
#   'canada',
#   'trade',
#   'surplus',
#   '1.25',
#   'billion',
#   'dlrs',
#   'february',
#   'compared',
#   'upward',
#   'revised',
#   '623',
#   'mln',
#   'dlrs',
#   'surplus',
#   'january',
#   'statistics',
#   'canada',
#   'said',
#   'january',
#   'surplus',
#   'originally',
#   'reported',
#   '533',
#   'mln',
#   'dlrs',
#   'february',
#   'surplus',
#   'last',
#   'year',
#   '189',
#   'mln',
#   'dlrs',
#   'february',
#   'exports',
#   'seasonally',
#   'adjusted',
#   '10.44',
#   'billion',
#   'dlrs',
#   '9.85',
#   'billion',
#   'january',
#   '10.05',
#   'billion',
#   'february',
#   '1986.',
#   'february',
#   'imports',
#   '9.19',
#   'billion',
#   'dlrs',
#   '9.23',
#   'billion',
#   'january',
#   '9.86',
#   'billion',
#   'february',
#   '1986'],
#  ['ec',
#   'launches',
#   'anti-dumping',
#   'probe',
#   'japanese',
#   'chips',
#   'european',
#   'community',
#   'launched',
#   'investigation',
#   'allegations',
#   'dumping',
#   'japanese',
#   'semiconductor',
#   'makers',
#   'move',
#   'diplomats',
#   'said',
#   'could',
#   'mark',
#   'intensification',
#   'world',
#   'trade',
#   'strains',
#   'tokyo',
#   'already',
#   'faces',
#   'deadline',
#   'april',
#   '17',
#   'washington',
#   'imposition',
#   '300',
#   'mln',
#   'dlrs',
#   'worth',
#   'tariffs',
#   'chips',
#   'imports',
#   'u.s.',
#   'ec',
#   'executive',
#   'commission',
#   'said',
#   'today',
#   'european',
#   'electrical',
#   'component',
#   'manufacturers',
#   'association',
#   'complained',
#   'japanese',
#   'firms',
#   'selling',
#   'high',
#   'capacity',
#   'eprom',
#   'type',
#   'erasable',
#   'programmable',
#   'read',
#   'memory',
#   'chips',
#   'unfairly',
#   'low',
#   'prices',
#   'japan',
#   'last',
#   'year',
#   'took',
#   '78',
#   'pct',
#   '170',
#   'mln',
#   'dlr',
#   'ec',
#   'eprom',
#   'market',
#   '60',
#   'pct',
#   '1984.',
#   'ec',
#   'firms',
#   'said',
#   'forced',
#   'offer',
#   'products',
#   'discount',
#   '30',
#   'pct',
#   'order',
#   'compete',
#   'japanese',
#   'commission',
#   'said',
#   'believed',
#   'association',
#   'given',
#   'sufficient',
#   'elements',
#   'proof',
#   'dumping',
#   'warrant',
#   'investigation',
#   'could',
#   'lead',
#   'impose',
#   'duties',
#   'found',
#   'complaints',
#   'justified',
#   'commission',
#   'claims',
#   'last',
#   'year',
#   "'s",
#   'accord',
#   'u.s.',
#   'japan',
#   'microchip',
#   'pricing',
#   'gives',
#   'u.s.',
#   'firms',
#   'privileged',
#   'access',
#   'japanese',
#   'market'],
#  ['g-7',
#   'issues',
#   'statement',
#   'meeting',
#   'following',
#   'text',
#   'statement',
#   'group',
#   'seven',
#   '--',
#   'u.s.',
#   'japan',
#   'west',
#   'germany',
#   'france',
#   'britain',
#   'italy',
#   'canada',
#   '--',
#   'issued',
#   'washington',
#   'meeting',
#   'yesterday',
#   '1.',
#   'finance',
#   'ministers',
#   'central',
#   'bank',
#   'governors',
#   'seven',
#   'major',
#   'industrial',
#   'countries',
#   'met',
#   'today',
#   'continued',
#   'process',
#   'multilateral',
#   'surveillance',
#   'economies',
#   'pursuant',
#   'arrangements',
#   'strengthened',
#   'economic',
#   'policy',
#   'coordination',
#   'agreed',
#   '1986',
#   'tokyo',
#   'summit',
#   'heads',
#   'state',
#   'government',
#   'managing',
#   'director',
#   'international',
#   'monetary',
#   'fund',
#   'also',
#   'participated',
#   'meeting',
#   '2.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'commitment',
#   'cooperative',
#   'approach',
#   'agreed',
#   'recent',
#   'paris',
#   'meeting',
#   'noted',
#   'progress',
#   'achieved',
#   'implementing',
#   'undertakings',
#   'embodied',
#   'louvre',
#   'agreement',
#   'agreed',
#   'however',
#   'actions',
#   'essential',
#   'resist',
#   'rising',
#   'protectionist',
#   'pressures',
#   'sustain',
#   'global',
#   'economic',
#   'expansion',
#   'reduce',
#   'trade',
#   'imbalances',
#   'connection',
#   'welcomed',
#   'proposals',
#   'announced',
#   'governing',
#   'liberal',
#   'democratic',
#   'party',
#   'japan',
#   'extraordinary',
#   'urgent',
#   'measures',
#   'stimulate',
#   'japan',
#   "'s",
#   'economy',
#   'early',
#   'implementation',
#   'large',
#   'supplementary',
#   'budget',
#   'exceeding',
#   'previous',
#   'years',
#   'well',
#   'unprecedented',
#   'front-end',
#   'loading',
#   'public',
#   'works',
#   'expenditures',
#   'government',
#   'japan',
#   'reaffirmed',
#   'intention',
#   'open',
#   'domestic',
#   'markets',
#   'foreign',
#   'goods',
#   'services',
#   '3.',
#   'ministers',
#   'governors',
#   'reaffirmed',
#   'view',
#   'around',
#   'current',
#   'levels',
#   'currencies',
#   'within',
#   'ranges',
#   'broadly',
#   'consistent',
#   'economic',
#   'fundamentals',
#   'basic',
#   'policy',
#   'intentions',
#   'outlined',
#   'louvre',
#   'meeting',
#   'connection',
#   'welcomed',
#   'strong',
#   'implementation',
#   'louvre',
#   'agreement',
#   'concluded',
#   'present',
#   'prospective',
#   'progress',
#   'implementing',
#   'policy',
#   'undertakings',
#   'louvre',
#   'statement',
#   'provided',
#   'basis',
#   'continuing',
#   'close',
#   'cooperation',
#   'foster',
#   'stability',
#   'exchange',
#   'rates'],
#  ['spanish',
#   'employers',
#   'worried',
#   'high',
#   'interest',
#   'rates',
#   'head',
#   'spain',
#   "'s",
#   'employers',
#   'federation',
#   'jose',
#   'maria',
#   'cuevas',
#   'said',
#   'employers',
#   'worried',
#   'government',
#   "'s",
#   'monetary',
#   'policies',
#   'high',
#   'real',
#   'interest',
#   'rates',
#   'hampering',
#   'investment',
#   'told',
#   'news',
#   'conference',
#   'wage',
#   'pacts',
#   'signed',
#   'far',
#   'year',
#   'endangering',
#   'government',
#   "'s",
#   'five',
#   'pct',
#   'inflation',
#   'target',
#   'government',
#   "'s",
#   'perceived',
#   'need',
#   'control',
#   'inflation',
#   'keeping',
#   'tight',
#   'rein',
#   'credit',
#   'unnecessary',
#   'said',
#   'high',
#   'real',
#   'interest',
#   'rates',
#   'attracting',
#   'influx',
#   'speculative',
#   'foreign',
#   'capital',
#   'undercutting',
#   'government',
#   "'s",
#   'target',
#   'monetary',
#   'growth',
#   'cuevas',
#   'said',
#   'spain',
#   "'s",
#   'closely-watched',
#   'measure',
#   'money',
#   'supply',
#   'liquid',
#   'assets',
#   'public',
#   'hands',
#   'grew',
#   'annualised',
#   'rate',
#   '17',
#   'pct',
#   'march',
#   '11.4',
#   'pct',
#   'december',
#   'last',
#   'year',
#   'target',
#   'range',
#   '6.5',
#   '9.5',
#   'pct',
#   '1987.',
#   'combat',
#   'bank',
#   'spain',
#   'raised',
#   'call',
#   'money',
#   'rate',
#   '14',
#   'times',
#   'far',
#   'year',
#   '14.5',
#   'pct',
#   'present',
#   '11.8',
#   'end-1986',
#   'cuevas',
#   'said',
#   'employers',
#   'heeding',
#   'government',
#   "'s",
#   'call',
#   'hold',
#   'wage',
#   'increases',
#   'five',
#   'pct',
#   'inflation',
#   'target',
#   'year',
#   'increases',
#   'salary',
#   'reviews',
#   'awarded',
#   'last',
#   'year',
#   'new',
#   'wage',
#   'pacts',
#   'averaging',
#   '5.6',
#   'pct',
#   'first',
#   'quarter',
#   '1987.',
#   'agreements',
#   'covered',
#   'less',
#   '40',
#   'pct',
#   'spanish',
#   'workers',
#   'cuevas',
#   'said',
#   'rest',
#   'still',
#   'wage',
#   'negotiations',
#   'said',
#   'spain',
#   "'s",
#   'current',
#   'wave',
#   'strikes',
#   'mainly',
#   'affected',
#   'state',
#   'sector',
#   'government',
#   'trying',
#   'impose',
#   'five',
#   'pct',
#   'wage',
#   'ceiling',
#   'cuevas',
#   'said',
#   'employers',
#   'also',
#   'worried',
#   'trend',
#   'spain',
#   "'s",
#   'foreign',
#   'trade',
#   'balance',
#   'trade',
#   'deficit',
#   'first',
#   'two',
# ...
#   'said',
#   'exceptionally',
#   'cold',
#   'weather',
#   'january',
#   'reduced',
#   'exports',
#   'month',
#   'element',
#   'catching',
#   'february',
#   'figures',
#   'seasonally',
#   'adjusted',
#   'volume',
#   'index',
#   'base',
#   '1980',
#   'guide',
#   'underlying',
#   'non-oil',
#   'trade',
#   'showed',
#   'exports',
#   'rising',
#   '131.0',
#   '114.6',
#   'january',
#   'imports',
#   'rising',
#   '142.2',
#   '136.5.',
#   'value',
#   'british',
#   'oil',
#   'exports',
#   'february',
#   'rose',
#   '751',
#   'mln',
#   'stg',
#   '723',
#   'mln',
#   'jnauary',
#   'oil',
#   'imports',
#   'rose',
#   '425',
#   'mln',
#   '352',
#   'mln'],
#  ['hong',
#   'kong',
#   'february',
#   'trade',
#   'swings',
#   'deficit',
#   'hong',
#   'kong',
#   'recorded',
#   '3.51',
#   'billion',
#   'h.k',
#   'dlr',
#   'deficit',
#   'february',
#   '2.54',
#   'billion',
#   'dlr',
#   'surplus',
#   'january',
#   'imports',
#   'climbed',
#   'exports',
#   'slid',
#   'census',
#   'statistics',
#   'department',
#   'said',
#   'deficit',
#   'compared',
#   'deficit',
#   '1.76',
#   'billion',
#   'dlrs',
#   'february',
#   '1986.',
#   'imports',
#   'rose',
#   '24.12',
#   'billion',
#   'dlrs',
#   '2.6',
#   'pct',
#   'january',
#   "'s",
#   '23.52',
#   'billion',
#   'dlrs',
#   '42',
#   'pct',
#   '16.98',
#   'billion',
#   'dlrs',
#   'recorded',
#   'february',
#   '1986.',
#   'total',
#   'exports',
#   'month',
#   'fell',
#   '20.9',
#   'pct',
#   '20.61',
#   'billion',
#   'dlrs',
#   '26.06',
#   'billion',
#   'january',
#   'february',
#   'exports',
#   'still',
#   '35.4',
#   'pct',
#   '15.22',
#   'billion',
#   'dlrs',
#   'recorded',
#   'month',
#   'last',
#   'year',
#   're-exports',
#   'territory',
#   "'s",
#   'traditional',
#   'entrepot',
#   'trade',
#   'outpaced',
#   'domestically',
#   'produced',
#   'exports',
#   'first',
#   'time',
#   'since',
#   'march',
#   '1985.',
#   're-exports',
#   'fell',
#   '11.6',
#   'pct',
#   '10.62',
#   'billion',
#   'dlrs',
#   '12.0',
#   'billion',
#   'dlrs',
#   'january',
#   '54',
#   'pct',
#   'february',
#   '1986',
#   "'s",
#   '6.88',
#   'billion',
#   'dlrs',
#   'domestic',
#   'exports',
#   'slid',
#   '28.9',
#   'pct',
#   '9.99',
#   'billion',
#   'dlrs',
#   'january',
#   "'s",
#   '14.05',
#   'billion',
#   'dlrs',
#   '19.7',
#   'pct',
#   '8.35',
#   'billion',
#   'dlrs',
#   'recorded',
#   'february',
#   '1986'],
#  ['british',
#   'politicians',
#   'urge',
#   'japan',
#   'trade',
#   'sanctions',
#   'one',
#   'hundred',
#   'members',
#   'britain',
#   "'s",
#   'ruling',
#   'conservative',
#   'party',
#   'signed',
#   'motion',
#   'calling',
#   'trade',
#   'sanctions',
#   'japan',
#   'force',
#   'tokyo',
#   'open',
#   'domestic',
#   'market',
#   'british',
#   'goods',
#   'government',
#   'announced',
#   'last',
#   'week',
#   'japan',
#   '5.9',
#   'billion',
#   'dlr',
#   'trade',
#   'surplus',
#   'britain',
#   '1986.',
#   'department',
#   'trade',
#   'industry',
#   'said',
#   'government',
#   'drawing',
#   'contingency',
#   'plans',
#   'force',
#   'japan',
#   'opening',
#   'domestic',
#   'markets',
#   'spokesman',
#   'said',
#   'moves',
#   'much',
#   'last',
#   'resort',
#   'ideas',
#   'considered',
#   'included',
#   'blocking',
#   'japanese',
#   'companies',
#   'trading',
#   'britain',
#   'revoking',
#   'licenses',
#   'japanese',
#   'operations',
#   'london',
#   'financial',
#   'district'],
#  ['u.k.',
#   'trade',
#   'figures',
#   'buoy',
#   'hopes',
#   'interest',
#   'rate',
#   'cut',
#   'release',
#   'u.k.',
#   'february',
#   'trade',
#   'data',
#   'showing',
#   'current',
#   'account',
#   'surplus',
#   'provisional',
#   '376',
#   'mln',
#   'stg',
#   '73',
#   'mln',
#   'surplus',
#   'january',
#   'boosted',
#   'hopes',
#   'early',
#   'cut',
#   'interest',
#   'rates',
#   'analysts',
#   'said',
#   'market',
#   'forecasts',
#   'worse',
#   'outcome',
#   'expectations',
#   'deficit',
#   'visible',
#   'trade',
#   'averaging',
#   '750',
#   'mln',
#   'stg',
#   'official',
#   'figure',
#   '224',
#   'mln',
#   'stg',
#   'sharply',
#   'narrower',
#   'january',
#   "'s",
#   '527',
#   'mln',
#   'deficit',
#   '``',
#   'figures',
#   'unreservedly',
#   'good',
#   "''",
#   'chase',
#   'manhattan',
#   'securities',
#   'economist',
#   'andrew',
#   'wroblewski',
#   'said',
#   'sterling',
#   'rebounded',
#   'trade',
#   'figures',
#   'reversing',
#   'weaker',
#   'morning',
#   'trend',
#   'stand',
#   '72.1',
#   'pct',
#   'trade',
#   'weighted',
#   'index',
#   'basket',
#   'currencies',
#   'midday',
#   'unchanged',
#   'yesterday',
#   "'s",
#   'close',
#   '0.3',
#   'points',
#   '1100',
#   'gmt',
#   'level',
#   'market',
#   'feared',
#   'deteriorating',
#   'non-oil',
#   'trade',
#   'pattern',
#   'would',
#   'undermine',
#   'international',
#   'support',
#   'sterling',
#   'motor',
#   'behind',
#   'recent',
#   'fall',
#   'u.k.',
#   'interest',
#   'rates',
#   'money',
#   'market',
#   'sources',
#   'said',
#   'market',
#   'begun',
#   'doubt',
#   'widely',
#   'expected',
#   'drop',
#   'bank',
#   'base',
#   'lending',
#   'rates',
#   '9.5',
#   'pct',
#   'present',
#   '10.0',
#   'pct',
#   'really',
#   'cards',
#   'sentiment',
#   'looks',
#   'turned',
#   'looks',
#   'danger',
#   'chancellor',
#   'exchequer',
#   'nigel',
#   'lawson',
#   "'s",
#   'forecast',
#   '1987',
#   'current',
#   'account',
#   'deficit',
#   '2.5',
#   'billion',
#   'stg',
#   'exceeded',
#   'said',
#   'wroblewski',
#   'seasonally',
#   'adjusted',
#   'figures',
#   'showed',
#   'imports',
#   'rose',
#   'february',
#   '7.16',
#   'billion',
#   'stg',
#   '6.73',
#   'billion',
#   'january',
#   'exports',
#   'rose',
#   'record',
#   '6.93',
#   'billion',
#   '6.20',
#   'billion',
#   'however',
#   'chris',
#   'tinker',
#   'u.k.',
#   'analyst',
#   'brokers',
#   'phillips',
#   'drew',
#   'said',
#   'faster',
#   'rise',
#   'exports',
#   'imports',
#   'would',
#   'prove',
#   'partly',
#   'aberrational',
#   'coming',
#   'months',
#   'forecast',
#   'chancellor',
#   "'s",
#   'budget',
#   'tax',
#   'cuts',
#   'would',
#   'increase',
#   'consumer',
#   'expediture',
#   'imported',
#   'goods',
#   'however',
#   'ian',
#   'harwood',
#   'economist',
#   'warburg',
#   'securities',
#   'said',
#   'firm',
#   'sharply',
#   'revising',
#   '1987',
#   'current',
#   'account',
#   'deficit',
#   'forecast',
#   'light',
#   'latest',
#   'data',
#   'cutting',
#   'one',
#   'billion',
#   'stg',
#   'expected',
#   'full',
#   'year',
#   'total',
#   '1.75',
#   'billion',
#   'stg',
#   'said',
#   'news',
#   'strong',
#   'growth',
#   'exports',
#   'non-oil',
#   'goods',
#   'confirmed',
#   'recent',
#   'bullish',
#   'surveys',
#   'among',
#   'members',
#   'confederation',
#   'british',
#   'industry',
#   'growth',
#   'imports',
#   'appears',
#   'flattening',
#   'even',
#   'january',
#   "'s",
#   'bad',
#   'weather',
#   'curbed',
#   'consumer',
#   'spending',
#   'overseas',
#   'goods',
#   'import-intensive',
#   'stock',
#   'building',
#   'among',
#   'manufactureres',
#   'harwood',
#   'said',
#   'u.k.',
#   'government',
#   'bonds',
#   'gilts',
#   'surged',
#   '1/2',
#   'point',
#   'better-than-expected',
#   'news',
#   'earlier',
#   'worries',
#   'figures',
#   'evaporated',
#   'sterling',
#   'peaked',
#   'high',
#   '1.6075',
#   'dlrs',
#   'settling',
#   'steady',
#   '1.6050',
#   'dlrs',
#   '1300',
#   'gmt',
#   'nearly',
#   'cent',
#   'higher',
#   'european',
#   'low',
#   '1.5960.',
#   'however',
#   'analysts',
#   'noted',
#   'turnabout',
#   'market',
#   'sentiment',
#   'still',
#   'looks',
#   'highly',
#   'vulnerable',
#   'political',
#   'news',
#   'morning',
#   'weakness',
#   'sterling',
#   'gilt',
#   'market',
#   'largely',
#   'attributed',
#   'newspaper',
#   'opinion',
#   'poll',
#   'showing',
#   'conservative',
#   'government',
#   "'s",
#   'support',
#   'slipping',
#   'marplan',
#   'poll',
#   'published',
#   '``',
#   'today',
#   "''",
#   'showed',
#   'conservative',
#   'support',
#   'fallen',
#   '36',
#   'pct',
#   '38',
#   'pct',
#   'last',
#   'month',
#   'alliance',
#   'liberals',
#   'social',
#   'democrats',
#   'rallied',
#   '31',
#   'pct',
#   '21',
#   'pct',
#   'run',
#   'neck',
#   'neck',
#   'labour',
#   'party',
#   'whose',
#   'support',
#   'fell',
#   '38',
#   'pct',
#   'poll',
#   'taken',
#   'budget',
#   'greeted',
#   'enthusiastically',
#   'financial',
#   'markets',
#   'seems',
#   'left',
#   'voters',
#   'indifferent',
#   'political',
#   'observers',
#   'said',
#   'another',
#   'regular',
#   'poll',
#   'due',
#   'tomorrow',
#   'eonomists',
#   'warn',
#   'today',
#   "'s",
#   'improved',
#   'sentiment',
#   'could',
#   'dented',
#   'support',
#   'prime',
#   'minister',
#   'margaret',
#   'thatcher',
#   'slips',
#   'upsetting',
#   'markets',
#   'political',
#   'perceptions',
#   'discounting',
#   'conservative',
#   'victory',
#   'upcoming',
#   'general',
#   'election',
#   'made',
#   'sensitive',
#   'trade',
#   'data',
#   'harwood',
#   'said',
#   '``',
#   'news',
#   'come',
#   'substantial',
#   'relief',
#   "''",
#   'said',
#   'however',
#   'interest',
#   'rate',
#   'front',
#   'economists',
#   'caution',
#   'lawson',
#   'might',
#   'wary',
#   'leaving',
#   'sterling',
#   'vulnerable',
#   'encouraging',
#   'another',
#   'base',
#   'rate',
#   'fall',
#   'noted',
#   'lawson',
#   'already',
#   'got',
#   'inflation-reducing',
#   'cut',
#   'mortgage',
#   'rates',
#   'response',
#   'lower',
#   'base',
#   'rates',
#   'domestic',
#   'political',
#   'reasons',
#   'lower',
#   'rates',
#   'curtailed'],
#  ['s.',
#   'korea',
#   'may',
#   'buy',
#   'u.s.',
#   'oil',
#   'aid',
#   'trade',
#   'balance',
#   'south',
#   'korea',
#   'studying',
#   'plan',
#   'buy',
#   'coal',
#   'united',
#   'states',
#   'start',
#   'importing',
#   'alaskan',
#   'crude',
#   'oil',
#   'help',
#   'reduce',
#   'huge',
#   'trade',
#   'surplus',
#   'united',
#   'states',
#   'energy',
#   'ministry',
#   'officials',
#   'said',
#   'today',
#   'said',
#   'plan',
#   'would',
#   'dominate',
#   'discussions',
#   'two-day',
#   'energy',
#   'talks',
#   'officials',
#   'two',
#   'countries',
#   'washington',
#   'april',
#   '1.',
#   'huh',
#   'sun-yong',
#   'attend',
#   'talks',
#   'three',
#   'seoul',
#   'government',
#   'officials',
#   'told',
#   'reuters',
#   'seoul',
#   '``',
#   'positively',
#   'considering',
#   'buying',
#   'certain',
#   'amount',
#   'alaskan',
#   'oil',
#   'beginning',
#   'year',
#   'part',
#   'government',
#   "'s",
#   'overall',
#   'plan',
#   'reduce',
#   'widening',
#   'trade',
#   'gap',
#   'two',
#   'countries',
#   "''",
#   'huh',
#   'said',
#   'however',
#   'south',
#   'korean',
#   'refineries',
#   'considered',
#   'alaskan',
#   'oil',
#   'economically',
#   'uncompetitive'],
#  ['u.s',
#   'treasury',
#   "'s",
#   'mulford',
#   'reaffirms',
#   'g-6',
#   'agreement',
#   'treasury',
#   'assistant',
#   'secretary',
#   'david',
#   'mulford',
#   'reaffirmed',
#   'u.s.',
#   'backing',
#   'paris',
#   'agreement',
#   'among',
#   'six',
#   'industrial',
#   'nations',
#   'cooperate',
#   'closely',
#   'foster',
#   'exchange',
#   'rate',
#   'stability',
#   'around',
#   'current',
#   'levels',
#   'testimony',
#   'prepared',
#   'delivery',
#   'senate',
#   'banking',
#   'subcommittee',
#   'mulford',
#   'said',
#   'broad',
#   'recognition',
#   'paris',
#   '``',
#   'substantial',
#   'exchange',
#   'rate',
#   'shifts',
#   'could',
#   'damage',
#   'growth',
#   'adjustment',
#   'prospects',
#   "''",
#   'also',
#   'said',
#   'clear',
#   'understandings',
#   'among',
#   'countries',
#   'regarding',
#   'cooperation',
#   '``',
#   'refrained',
#   'establishing',
#   'system',
#   'target',
#   'zones',
#   'ranges',
#   "''",
#   'mulford',
#   'also',
#   'said',
#   'six',
#   'nations',
#   'spelled',
#   'way',
#   'intend',
#   'deal',
#   'possible',
#   'market',
#   'developments',
#   'said',
#   'governments',
#   'must',
#   'retain',
#   'flexibility',
#   'dealing',
#   'exchange',
#   'market',
#   'pressures',
#   'efforts',
#   'establish',
#   'rigid',
#   'exchange',
#   'rate',
#   'objectives',
#   '``',
#   'specify',
#   'precisely',
#   'goals',
#   'intervention',
#   "''",
#   'would',
#   'hurt',
#   'official',
#   'attempts',
#   'react',
#   'market',
#   'pressures',
#   'said',
#   'accordingly',
#   'mulford',
#   'said',
#   'setting',
#   'specific',
#   'currency',
#   'objectives',
#   'intervention',
#   'achieve',
#   'objectives',
#   'would',
#   'counterproductive',
#   'commenting',
#   'trade',
#   'deficit',
#   'mulford',
#   'reiterated',
#   'treasury',
#   'position',
#   'current',
#   'account',
#   'deficit',
#   'decline',
#   '148',
#   'billion',
#   'dlrs',
#   'last',
#   'year',
#   'around',
#   '130',
#   'billion',
#   'dlrs',
#   'year',
#   'due',
#   'exchange',
#   'rate',
#   'adjustments',
#   'past',
#   '18',
#   'months',
#   'added',
#   'trade',
#   'imbalances',
#   'would',
#   'also',
#   'corrected',
#   'commitments',
#   'west',
#   'germany',
#   'japan',
#   'stimulate',
#   'economies',
#   'u.s.',
#   'efforts',
#   'cut',
#   'budget',
#   'deficit',
#   'enhance',
#   'u.s.',
#   'competitiveness',
#   'also',
#   'said',
#   'newly',
#   'industrialized',
#   'countries',
#   'let',
#   'currencies',
#   'appreciate'],
#  ['keating',
#   'revises',
#   'australian',
#   'growth',
#   'forecast',
#   'treasurer',
#   'paul',
#   'keating',
#   'forecast',
#   'economic',
#   'growth',
#   'slightly',
#   'two',
#   'pct',
#   'financial',
#   'year',
#   'ending',
#   'june',
#   'year',
#   '2.25',
#   'pct',
#   'forecast',
#   'contained',
#   '1986/87',
#   'budget',
#   'delivered',
#   'last',
#   'august',
#   'australia',
#   "'s",
#   'terms',
#   'trade',
#   'also',
#   'fell',
#   '18',
#   'pct',
#   'past',
#   'two',
#   'years',
#   'told',
#   'parliament',
#   'terms',
#   'trade',
#   'difference',
#   'import',
#   'export',
#   'price',
#   'indexes',
#   'despite',
#   'figures',
#   'budget',
#   'forecast',
#   '1.75',
#   'pct',
#   'annual',
#   'growth',
#   'employment',
#   'would',
#   'met',
#   'keating',
#   'said',
#   'unemployment',
#   'currently',
#   '8.2',
#   'pct',
#   'workforce',
#   '``',
#   'government',
#   'dragging',
#   'australia',
#   'trading',
#   'holocaust',
#   'kind',
#   'seen',
#   'since',
#   'second',
#   'world',
#   'war',
#   "''",
#   'keating',
#   'said',
#   '``',
#   'pushing',
#   'place',
#   'recession',
#   'holding',
#   'gains',
#   'unemployment',
#   'bringing',
#   'unemployment',
#   "''",
#   'said',
#   'adding',
#   'government',
#   'help',
#   'country',
#   'avoid',
#   'recession'],
#  ['u.s.',
#   'asks',
#   'japan',
#   'end',
#   'agriculture',
#   'import',
#   'controls',
#   'u.s.',
#   'wants',
#   'japan',
#   'eliminate',
#   'import',
#   'controls',
#   'agricultural',
#   'products',
#   'within',
#   'three',
#   'years',
#   'visiting',
#   'u.s.',
#   'under-secretary',
#   'state',
#   'economic',
#   'affairs',
#   'allen',
#   'wallis',
#   'told',
#   'eishiro',
#   'saito',
#   'chairman',
#   'federation',
#   'economic',
#   'organisations',
#   'keidanren',
#   'spokesman',
#   'keidanren',
#   'said',
#   'spokesman',
#   'quoted',
#   'wallis',
#   'saying',
#   'drastic',
#   'measures',
#   'would',
#   'needed',
#   'stave',
#   'protectionist',
#   'legislation',
#   'congress',
#   'wallis',
#   'attending',
#   'sub-cabinet-level',
#   'bilateral',
#   'trade',
#   'meeting',
#   'made',
#   'remark',
#   'yesterday',
#   'talks',
#   'saito',
#   'wallis',
#   'quoted',
#   'saying',
#   'reagan',
#   'administration',
#   'wants',
#   'japanese',
#   'cooperation',
#   'white',
#   'house',
#   'ensure',
#   'u.s.',
#   'trade',
#   'bill',
#   'moderate',
#   'one',
#   'rather',
#   'containing',
#   'retaliatory',
#   'measures',
#   'antagonising',
#   'particular',
#   'country',
#   'also',
#   'quoted',
#   'saying',
#   'u.s.',
#   'would',
#   'pleased',
#   'japan',
#   'halve',
#   'restrictions',
#   'agricultural',
#   'imports',
#   'within',
#   'five',
#   'years',
#   'country',
#   'cope',
#   'abolition',
#   'within',
#   'three',
#   'spokesman',
#   'said',
#   'japan',
#   'currently',
#   'restricts',
#   'imports',
#   '22',
#   'agricultural',
#   'products',
#   'ban',
#   'rice',
#   'imports',
#   'triggered',
#   'recent',
#   'u.s.',
#   'complaints',
#   'japan',
#   "'s",
#   'agricultural',
#   'policy'],
#  ['mulford',
#   'says',
#   'germany',
#   'japan',
#   'treasury',
#   'assistant',
#   'secretary',
#   'david',
#   'mulford',
#   'said',
#   'believe',
#   'west',
#   'germany',
#   'japan',
#   'yet',
#   'carried',
#   'international',
#   'responsibilities',
#   '``',
#   'believe',
#   'time',
#   "''",
#   'mulford',
#   'told',
#   'senate',
#   'banking',
#   'subcommittee',
#   'said',
#   'u.s.',
#   'trade',
#   'deficit',
#   'continue',
#   'improving',
#   'next',
#   'two',
#   'years',
#   '``',
#   'need',
#   'policy',
#   'actions',
#   "''",
#   'across',
#   'entire',
#   'front',
#   'u.s.',
#   'trade',
#   'relations',
#   'including',
#   'canada',
#   'newly-industrialized',
#   'countries',
#   'nics',
#   'particular',
#   'said',
#   'efforts',
#   'south',
#   'korea',
#   'taiwan',
#   'strengthen',
#   'currencies',
#   'still',
#   'disappointing',
#   'mulford',
#   'also',
#   'said',
#   'oecd',
#   'nations',
#   'need',
#   'grow',
#   'average',
#   'three',
#   'pct',
#   'help',
#   'resolve',
#   'international',
#   'debt',
#   'crisis',
#   'noted',
#   'japanese',
#   'european',
#   'imports',
#   'latin',
#   'nations',
#   'significantly',
#   'smaller',
#   'imports',
#   'u.s.',
#   'stressed',
#   'germany',
#   'japan',
#   'must',
#   'continue',
#   'take',
#   'economic',
#   'structural',
#   'measures',
#   'ensure',
#   'stronger',
#   'sustained',
#   'economic',
#   'growth']]

# %%
len(preprocessed_docs)
# Out:
# 485

# %%
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(preprocessed_docs)))
vocab
# Out:
# ['managers',
#  '93.76',
#  'deliberate',
#  'stretching',
#  'topple',
#  'products',
#  'mainly',
#  'woong',
#  'refuse',
#  'jobless',
#  '120.9',
#  'discussing',
#  'prevarication',
#  'p.s',
#  '675,000',
#  'breakdown',
#  'lufkin',
#  'mid-may',
#  'bypass',
#  '3.6',
#  'donation',
#  'commerzbank',
#  'persists',
#  'entertain',
#  'bid',
#  '42',
#  'sophisticated',
#  '48.8',
#  'citing',
#  'moore',
#  'confrontations',
#  '12.2',
#  'pure',
#  '152.32',
#  'advanced',
#  'ill-advised',
#  'cpi',
#  '7.33',
#  '20.4',
#  '16.65.',
#  '1.20',
#  'frustration',
#  '11.1',
#  '104.68',
#  'closely',
#  'scapegoat',
#  'tolerating',
#  'months',
#  'saskatchewan',
#  'comes',
#  'markka',
#  '76',
#  'radio',
#  'substituting',
#  'surpassing',
#  '95',
#  '771',
#  'declarations',
#  'places',
#  'prior',
#  '670,000',
#  '1.74',
#  'load',
#  'vulnerable',
#  'inspectors',
#  '90.2',
#  'doubtful',
#  'dumped',
#  'metal',
#  '1.81',
#  'insurers',
#  'affecting',
#  'immorally',
#  '109',
#  'requests',
#  'worried',
#  'recognized',
#  'hardware',
#  'assistance',
#  'recklessly',
#  'bucharest',
#  'r-iowa',
#  '14.6',
#  'imf',
#  'uniform',
#  'appearance',
#  'according',
#  'member',
#  'one-sixth',
#  'grows',
#  'identifying',
#  'celebrating',
#  'telling',
#  'econometrics',
#  'attendance',
#  'counter',
#  'linking',
#  '20.61',
#  'feedgrain',
#  'payable',
#  'barrels',
#  '3.34',
#  '67',
#  'relax',
#  'dominant',
#  '9.99',
#  'named',
#  'space',
#  'exporters',
#  'benefited',
#  'export',
#  'areas',
#  'guide',
#  'define',
#  'edwards',
#  'transitory',
#  '11.8',
#  'educational',
#  'solved',
#  '14.65',
#  '112',
#  'aided',
#  'dubious',
#  'expectations',
#  'threshhold',
#  '157',
#  'asks',
#  'arms',
#  'assure',
#  'shareholder',
#  'intervene',
#  'january/march',
#  'unsellable',
#  'stoltenberg',
#  'operating',
#  '189',
#  'wedd',
#  'paris',
#  'tunisia',
#  '11.91',
#  'picks',
#  'tremendous',
#  '18.5',
#  'adequate',
#  'tune',
#  'consumption',
#  '181.23',
#  'creation',
#  'competitor',
#  'michel',
#  'restraint',
#  'end-',
#  'random',
#  'fulfilled',
#  'redeemed',
#  'strong-armed',
#  'brand',
#  'followed',
#  'makin',
#  'behalf',
#  'positive',
#  'dollars',
#  'withdraw',
#  'getting',
#  'world',
#  'neighbor',
#  'telecommunications',
#  'undesirable',
#  'tabling',
#  '3.61',
#  'tom',
#  'distributors',
#  'kilobit',
#  'constraints',
#  'chamber',
#  'traumatic',
#  'ruiz',
#  'legislate',
#  'asking',
#  'reports',
#  'warnings',
#  'category',
#  'peak',
#  'zero',
#  'enable',
#  'tied-aid',
#  'superiority',
#  'damage',
#  'mad',
#  'laying',
#  'surplus',
#  'priced',
#  '/ompany',
#  'interests',
#  'chunk',
#  'fuelling',
#  'banque',
#  'nomination',
#  'denied',
#  '879.4',
#  'sections',
#  'accordingly',
#  'swift',
#  'effot',
#  'remove',
#  'abided',
#  'furious',
#  'left',
#  'avoid',
#  'auspices',
#  'non-productive',
#  'closed-minister',
#  '7.38',
#  'caldwell',
#  'earmarked',
#  'strained',
#  'freed',
#  'end-1987',
#  '7.6',
#  'evelyn',
#  'worry',
#  'water',
#  'constitute',
#  'quite',
#  'contributed',
#  'diw',
#  'liberalised',
#  'rodriguez',
#  'high-ranking',
#  'unconvinced',
#  'offsetting',
#  'welcoming',
#  'jumped',
#  'potash',
#  'apply',
#  'offered',
#  'exercise',
#  'replacements',
#  'denmark',
#  'whichever',
#  'estimating',
#  'commonwealth',
#  'prompted',
#  'weekend',
#  'warned',
#  '7.79',
#  '6.64',
#  'forfeit',
#  '928',
#  'name',
#  'sheltered',
#  '24.6',
#  'open-trade',
#  '25.5',
#  'fast-changing',
#  'ignored',
#  '760',
#  '324',
#  '352',
#  'cope',
#  'withdrawing',
#  'newfoundlanders',
#  'suicide',
#  'telephone',
#  '10.45',
#  '70.5',
#  'aquino',
#  'denominated',
#  'conform',
#  '1985-1986',
#  'cause',
#  'dams',
#  'value-added',
#  'chang-ming',
#  'corporate',
#  'dropped',
#  '1.29',
#  'laboratory',
#  '1/2',
#  'bywater',
#  'strength',
#  '261',
#  'canadians',
#  'faster',
#  'commitments',
#  'hosted',
#  'thinh',
#  'terrible',
#  'heavy-handed',
#  'replied',
#  'prauge',
#  'harsh',
#  'unambiguous',
#  'enough',
#  '1.65',
#  'home',
#  'sprinkel',
#  'marks',
#  'spurs',
#  'stopped',
#  'passionate',
#  '1.8',
#  'smouldering',
#  'exported',
#  'commerce',
#  '22.4',
#  'territorial',
#  'questions',
#  '38.37',
#  'engaged',
#  'lynch',
#  '50',
#  'quotas',
#  'intitiate',
#  'ended',
#  'accelerated',
#  'puchases',
#  'administration',
#  'endangered',
#  'inexpensive',
#  'inc',
#  'gains',
#  'computors',
#  'globe',
#  'coal',
#  '1.204',
#  'distinctly',
#  'revenue',
#  'reply',
#  'neither',
#  'eiu',
#  'regards',
#  'possibly',
#  'october/december',
#  'alarm',
#  'timetable',
#  'intervening',
#  'knock-down',
#  'identify',
#  '1.6',
#  'said.basically',
#  'social',
#  'common',
#  'non-farm',
#  'severely',
#  'slowed',
#  'peru',
#  'cutbacks',
#  '100,000',
#  'minimizing',
#  'slumped',
#  'antitrust',
#  'jardine',
#  'plays',
#  'appeals',
#  'karl',
#  'notice',
#  'hogs',
#  'turf',
#  'remained',
#  'facilities',
#  'roads',
#  'dinosaur',
#  'lined',
#  "'re",
#  'recoup',
#  'gramm-rudman',
#  'price-cutting',
#  'moscow',
#  'adding',
#  'urgent',
#  '880',
#  'holding',
#  'forestall',
#  'contain',
#  'offices',
#  'target',
#  'viability',
#  'sustained',
#  'enforcement',
#  '73.1',
#  'martial',
#  '22.94',
#  'dauster',
#  'independent',
#  'infant',
#  'much',
#  'cereal',
#  'half-yearly',
#  'seasonally-adjusted',
#  'livestock',
#  '3,061.8',
#  'countertrading',
#  'privately',
#  'broad-ranging',
#  'expecting',
#  'plantation',
#  'slapped',
#  'majority',
#  '1.62',
#  'department',
#  'outcome',
#  'resume',
#  'enormous',
#  'practices',
#  'minor',
#  'danes',
#  'production',
#  'hinder',
#  'differences',
#  'routed',
#  'predicted',
#  '862',
#  '912',
#  'comeback',
#  '1987/88',
#  'beset',
#  'pledged',
#  'invoices',
#  '39.6',
#  '34.59.',
#  'poland',
#  'washington-led',
#  'enterprise',
#  'telecom',
#  'halt',
#  'heller',
#  'dan',
#  'suzanne',
#  'thought',
#  'fruitful',
#  'lire',
#  'seoul',
#  'profound',
#  '2.83',
#  'flight',
#  'widespread',
#  'greenshields',
#  '3.25',
#  '77.4',
#  'printed',
#  'bob',
#  'locate',
#  'stipulated',
#  'convince',
#  'wish',
#  'chiefly',
#  'prohibited',
#  'wave',
#  'balance-of-payments',
#  'toned',
#  'instance',
#  'office',
#  'mid-1986',
#  'let',
#  'reviews',
#  'video',
#  'participant',
#  'manufactured',
#  '1983',
#  'wonder',
#  'route',
#  'disappointing',
#  'frame',
#  'enhancement',
#  'shipped',
#  '641',
#  '2.72',
#  'dicuss',
#  '17.48',
#  'force',
#  'flowing',
#  'agencies',
#  'health',
#  'limit',
#  'spotted',
#  'wolf',
#  'pennock',
#  'commit',
#  '16.42-16.45',
#  'easy',
#  'providing',
#  'argument',
#  'unified',
#  'furniture',
#  'exchequer',
#  'non-discriminatory',
#  '2.49',
#  'dynamism',
#  '890',
#  'suspension',
#  'acquire',
#  '10.6',
#  'indefinitely',
#  'licences',
#  'objection',
#  'objected',
#  '31',
#  'downward',
#  'democracies',
#  'southerners',
#  'draconian',
#  'preference',
#  'decision-making',
#  'contribution',
#  'leeway',
#  'regional',
#  'owed',
#  'koss',
#  '543',
#  'convertible',
#  'yaccobi',
#  'sarney',
#  'yeutter',
#  '6.67',
#  'asian',
#  '13.',
#  'jose',
#  '6.05',
#  'categories',
#  'noted',
#  '14.1',
#  '56.6',
#  'frankfurt',
#  'rah',
#  '1.05',
#  'director',
#  'bundesbank',
#  'foodgrains',
#  'yes',
#  'sometime',
#  'ryavec',
#  'discriminated',
#  'bumbled',
#  'misfortune',
#  'stephens',
#  'policymaker',
#  'goverment',
#  'long',
#  'numbers',
#  '3.51',
#  'risk',
#  'disruptions',
#  'culprits',
#  'create',
#  'conflict',
#  'stiff',
#  '4.4',
#  'root',
#  'yesterday',
#  'slower',
#  'commodities',
#  'may',
#  'orange',
#  'establishment',
#  'certificates',
#  '8.7',
#  'red',
#  'dispute',
#  '5.4',
#  '971',
#  'facto',
#  'indexation',
#  'hesitate',
#  'getty',
#  'rules',
#  'arguing',
#  'offshoot',
#  'failure',
#  'bodies',
#  '340',
#  'stabilize',
#  'deficiency',
#  'healthy',
#  'concerned',
#  'realize',
#  'equipment',
#  'item',
#  '1,700',
#  'overwhelmed',
#  '1.113',
#  '417',
#  'm-1',
#  '16.6',
#  'accommodation',
#  'butcher',
#  'economy-wide',
#  'entities',
#  'oil',
#  '8,285',
#  'average',
#  'hardening',
#  '2.694',
#  'subdued',
#  'swing',
#  '4.12',
#  'stages',
#  'firms',
#  'apartheid',
#  'invite',
#  'hissene',
#  'preferences',
#  'underscoring',
#  'two-day',
#  'norway',
#  'yields',
#  'negative',
#  'patent',
#  'pye',
#  '1.50',
#  '7.2',
#  'african',
#  'levels',
#  'delayed',
#  '3,066.6',
#  '1989.',
#  'raiders',
#  'unleashed',
#  'forthcoming',
#  'directors',
#  'nelson',
#  'friday',
#  'keys',
#  'bethlehem',
#  'sir',
#  'factory',
#  'shipping',
#  'integration',
#  'balanced',
#  '344',
#  'overall',
#  'dole',
#  'aggravation',
#  'program',
#  'taste',
#  'refiners',
#  'benderley',
#  'comprised',
#  'huge',
#  'plant',
#  'sen.',
#  'intervened',
#  '142.2',
#  'der-hwa',
#  'bentsen',
#  '``',
#  'senators',
#  'learning',
#  'anti-japanese',
#  'anyone',
#  'finalised',
#  'reform',
#  'marlin',
#  'issuance',
#  'wide',
#  'troubled',
#  'specialist',
#  'authorised',
#  'gesture',
#  'ongpin',
#  'memorandum',
#  '10.69',
#  'masaji',
#  'opens',
#  'wine',
#  'maslen',
#  'interested',
#  'opinion',
#  'editorial',
#  'cerier',
#  'evaluate',
#  's.',
#  'adverserial',
#  'pesetas',
#  'taka',
#  'surviving',
#  '104',
#  '0.6800',
#  'bank',
#  'sustain',
#  'drives',
#  '102.2',
#  'seeks',
#  '59-billion-dlr',
#  'junichiro',
#  'push',
#  'session',
#  '12-member',
#  'lap-top',
#  'struck',
#  'ensure',
#  'reluctance',
#  'industries',
#  'broaden',
#  'dept',
#  'repayment',
#  'abiding',
#  'overreacted',
#  '2.7',
#  '720',
#  'mind',
#  'osaka',
#  'non-dollar',
#  'ncso',
#  'hopefully',
#  'hunger',
#  'armistice',
#  'relieving',
#  '3.0',
#  'slowing',
#  'recognition',
#  '0.2.',
#  'action',
#  'economy',
#  'lock',
#  'wing',
#  'banco',
#  'weather',
#  '5.37',
#  '181',
#  'liberalising',
#  'shigeru',
#  'thirdly',
#  '155',
#  'german',
#  '246',
#  '233',
#  'bit',
#  'roy',
#  'restricts',
#  '147.71',
#  'idle',
#  'power',
#  'vengeance',
#  'textile-state',
#  'imec',
#  'fall',
#  'manila',
#  'fisheries',
#  'diminish',
#  'apholte',
#  'compete',
#  '6.5',
#  'received',
#  'tariffs',
#  'minute',
#  '43.8',
#  'younger',
#  'defend',
#  'oriented',
#  'borrow',
#  'carney',
#  'dinars',
#  'translated',
#  'tea',
#  'likewise',
#  'none',
#  '751',
#  '11.11',
#  'circle',
#  '72',
#  'subsidization',
#  'size',
#  'u.s.-israeli',
#  'autos',
#  'function',
#  'hence',
#  'undersecretary',
#  'shifts',
#  '3.5',
#  'anti-u.s.',
#  'privileged',
#  'pointing',
#  'barney',
#  'least',
#  'guidelines',
#  'choices',
#  'dutch',
#  'momentum',
#  'budgetary',
#  'afford',
#  'gilts',
#  'habre',
#  'minsiter',
#  'pressed',
#  'staged',
#  'emerge',
#  'measurement',
#  'geneva',
#  'stick',
#  'ingenuity',
#  'late',
#  '24-nation',
#  '723.2',
#  'spectre',
#  'real',
#  'plunging',
#  '46.8',
#  'april-june',
#  'rid',
#  'masaharu',
#  'injected',
#  'ruled',
#  '145',
#  'middle',
#  'toughen',
#  'conciliation',
#  '210',
#  'exist',
#  '5.23',
#  'admitted',
#  '101.2',
#  'upcoming',
#  'tight-fisted',
#  '0.6864/69',
#  'appear',
#  'exempt',
#  'trademarks',
#  'applied',
#  'punte',
#  'teams',
#  'developments',
#  'certificate',
#  'offshore',
#  'clear',
#  'rectified',
#  'indian',
#  'ammunition',
#  'members',
#  'old',
#  'draw',
#  'significant',
#  'instead',
#  'including',
#  'henry',
#  'jack',
#  'manufactures',
#  'artificial',
#  'driving',
#  'emerged',
#  'withdrawal',
#  'georgia',
#  'insist',
#  'merely',
#  'fukukawa',
#  'univerity',
#  'worthwhile',
#  '6.8',
#  'korea',
#  'anti-dumping',
#  'uruguay',
#  'drive',
#  'included',
#  'deflationary',
#  'diminishing',
#  'conservations',
#  'solutions',
#  'ic',
#  'drugs',
#  'brokerage',
#  'udagawa',
#  'wide-ranging',
#  'briskly',
#  'prepaying',
#  '1991.',
#  'tankers',
#  'lee',
#  'fruits',
#  'cuevas',
#  'like',
#  'equip',
#  '235',
#  'embark',
#  'replace',
#  'jestin',
#  'judge',
#  'anytime',
#  'chief',
#  'schedules',
#  'assessment',
#  'covers',
#  'dlrs',
#  'sector',
#  'everyone',
#  'barber',
#  'machinery',
#  'heritage',
#  'consider',
#  '1986-1991',
#  '1.32',
#  'barclays',
#  'finding',
#  'represents',
#  'banking',
#  'today',
#  '9.63',
#  'ideal',
#  'informally',
#  'after-effect',
#  'rupees',
#  'winds',
#  'bonn',
#  '218-page',
#  '2.65',
#  'pattern',
#  'companies',
#  'origins',
#  '1.434',
#  'processing',
#  'ordered',
#  'sympathise',
#  'donations',
#  'genuinely',
#  'revising',
#  'fibre',
#  'discriminatory',
#  'toshiba',
#  'thus',
#  'quantitative',
#  'shape',
#  'kept',
#  'room',
#  'presence',
#  'team',
#  'treatment',
#  'students',
#  'honda',
#  'stock',
#  'needs',
#  'britain',
#  'suffering',
#  'wasted',
#  'zhao',
#  '2.52',
#  '146.40/50',
#  'erosion',
#  'assigns',
#  'loaned',
#  'yugoslavia',
#  '13.82',
#  'emphasis',
#  'sumitomo',
#  'lunch',
#  'metals',
#  'supercomputer',
#  'commented',
#  'archer',
#  'dealt',
#  'ceremony',
#  '7.28',
#  'august',
#  'linked',
#  'strong',
#  'heart',
#  'producers',
#  'europeans',
#  'formalized',
#  'yasuhiro',
#  'floating',
#  'extra',
#  'tolerate',
#  'entering',
#  'exclude',
#  'minoru',
#  '7.04',
#  '200',
#  'observers',
#  'puts',
#  'echoes',
#  'definitely',
#  '1.46',
#  'inaccurate',
#  'priority',
#  'mission',
#  'comparable',
#  'crushing',
#  'inseperable',
#  'destination',
#  '146.50',
#  'applications',
#  '15-member',
#  'ceilings',
#  'touch',
#  'writing',
#  'vested',
#  'passenger',
#  '629.7',
#  'slifer',
#  'explanation',
#  '43',
#  'concentrate',
#  'endo',
#  'fertilizer',
#  'economies',
#  'miet.t',
#  'means',
#  'discounts',
#  'appeal',
#  'cautious',
#  'incompatible',
#  ...]

# %%
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'managers': 0, '93.76': 1, 'deliberate': 2, 'stretching': 3, 'topple': 4, 'products': 5, 'mainly': 6, 'woong': 7, 'refuse': 8, 'jobless': 9, '120.9': 10, 'discussing': 11, 'prevarication': 12, 'p.s': 13, '675,000': 14, 'breakdown': 15, 'lufkin': 16, 'mid-may': 17, 'bypass': 18, '3.6': 19, 'donation': 20, 'commerzbank': 21, 'persists': 22, 'entertain': 23, 'bid': 24, '42': 25, 'sophisticated': 26, '48.8': 27, 'citing': 28, 'moore': 29, 'confrontations': 30, '12.2': 31, 'pure': 32, '152.32': 33, 'advanced': 34, 'ill-advised': 35, 'cpi': 36, '7.33': 37, '20.4': 38, '16.65.': 39, '1.20': 40, 'frustration': 41, '11.1': 42, '104.68': 43, 'closely': 44, 'scapegoat': 45, 'tolerating': 46, 'months': 47, 'saskatchewan': 48, 'comes': 49, 'markka': 50, '76': 51, 'radio': 52, 'substituting': 53, 'surpassing': 54, '95': 55, '771': 56, 'declarations': 57, 'places': 58, 'prior': 59, '670,000': 60, '1.74': 61, 'load': 62, 'vulnerable': 63, 'inspectors': 64, '90.2': 65, 'doubtful': 66, 'dumped': 67, 'metal': 68, '1.81': 69, 'insurers': 70, 'affecting': 71, 'immorally': 72, '109': 73, 'requests': 74, 'worried': 75, 'recognized': 76, 'hardware': 77, 'assistance': 78, 'recklessly': 79, 'bucharest': 80, 'r-iowa': 81, '14.6': 82, 'imf': 83, 'uniform': 84, 'appearance': 85, 'according': 86, 'member': 87, 'one-sixth': 88, 'grows': 89, 'identifying': 90, 'celebrating': 91, 'telling': 92, 'econometrics': 93, 'attendance': 94, 'counter': 95, 'linking': 96, '20.61': 97, 'feedgrain': 98, 'payable': 99, 'barrels': 100, '3.34': 101, '67': 102, 'relax': 103, 'dominant': 104, '9.99': 105, 'named': 106, 'space': 107, 'exporters': 108, 'benefited': 109, 'export': 110, 'areas': 111, 'guide': 112, 'define': 113, 'edwards': 114, 'transitory': 115, '11.8': 116, 'educational': 117, 'solved': 118, '14.65': 119, '112': 120, 'aided': 121, 'dubious': 122, 'expectations': 123, 'threshhold': 124, '157': 125, 'asks': 126, 'arms': 127, 'assure': 128, 'shareholder': 129, 'intervene': 130, 'january/march': 131, 'unsellable': 132, 'stoltenberg': 133, 'operating': 134, '189': 135, 'wedd': 136, 'paris': 137, 'tunisia': 138, '11.91': 139, 'picks': 140, 'tremendous': 141, '18.5': 142, 'adequate': 143, 'tune': 144, 'consumption': 145, '181.23': 146, 'creation': 147, 'competitor': 148, 'michel': 149, 'restraint': 150, 'end-': 151, 'random': 152, 'fulfilled': 153, 'redeemed': 154, 'strong-armed': 155, 'brand': 156, 'followed': 157, 'makin': 158, 'behalf': 159, 'positive': 160, 'dollars': 161, 'withdraw': 162, 'getting': 163, 'world': 164, 'neighbor': 165, 'telecommunications': 166, 'undesirable': 167, 'tabling': 168, '3.61': 169, 'tom': 170, 'distributors': 171, 'kilobit': 172, 'constraints': 173, 'chamber': 174, 'traumatic': 175, 'ruiz': 176, 'legislate': 177, 'asking': 178, 'reports': 179, 'warnings': 180, 'category': 181, 'peak': 182, 'zero': 183, 'enable': 184, 'tied-aid': 185, 'superiority': 186, 'damage': 187, 'mad': 188, 'laying': 189, 'surplus': 190, 'priced': 191, '/ompany': 192, 'interests': 193, 'chunk': 194, 'fuelling': 195, 'banque': 196, 'nomination': 197, 'denied': 198, '879.4': 199, 'sections': 200, 'accordingly': 201, 'swift': 202, 'effot': 203, 'remove': 204, 'abided': 205, 'furious': 206, 'left': 207, 'avoid': 208, 'auspices': 209, 'non-productive': 210, 'closed-minister': 211, '7.38': 212, 'caldwell': 213, 'earmarked': 214, 'strained': 215, 'freed': 216, 'end-1987': 217, '7.6': 218, 'evelyn': 219, 'worry': 220, 'water': 221, 'constitute': 222, 'quite': 223, 'contributed': 224, 'diw': 225, 'liberalised': 226, 'rodriguez': 227, 'high-ranking': 228, 'unconvinced': 229, 'offsetting': 230, 'welcoming': 231, 'jumped': 232, 'potash': 233, 'apply': 234, 'offered': 235, 'exercise': 236, 'replacements': 237, 'denmark': 238, 'whichever': 239, 'estimating': 240, 'commonwealth': 241, 'prompted': 242, 'weekend': 243, 'warned': 244, '7.79': 245, '6.64': 246, 'forfeit': 247, '928': 248, 'name': 249, 'sheltered': 250, '24.6': 251, 'open-trade': 252, '25.5': 253, 'fast-changing': 2 ...

# %%
voc_size = len(vocab)
print(voc_size)
# Out:
# 8163

# %%
index2word = {v:k for k, v in word2index.items()} 
index2word
# Out:
# {0: 'managers',
#  1: '93.76',
#  2: 'deliberate',
#  3: 'stretching',
#  4: 'topple',
#  5: 'products',
#  6: 'mainly',
#  7: 'woong',
#  8: 'refuse',
#  9: 'jobless',
#  10: '120.9',
#  11: 'discussing',
#  12: 'prevarication',
#  13: 'p.s',
#  14: '675,000',
#  15: 'breakdown',
#  16: 'lufkin',
#  17: 'mid-may',
#  18: 'bypass',
#  19: '3.6',
#  20: 'donation',
#  21: 'commerzbank',
#  22: 'persists',
#  23: 'entertain',
#  24: 'bid',
#  25: '42',
#  26: 'sophisticated',
#  27: '48.8',
#  28: 'citing',
#  29: 'moore',
#  30: 'confrontations',
#  31: '12.2',
#  32: 'pure',
#  33: '152.32',
#  34: 'advanced',
#  35: 'ill-advised',
#  36: 'cpi',
#  37: '7.33',
#  38: '20.4',
#  39: '16.65.',
#  40: '1.20',
#  41: 'frustration',
#  42: '11.1',
#  43: '104.68',
#  44: 'closely',
#  45: 'scapegoat',
#  46: 'tolerating',
#  47: 'months',
#  48: 'saskatchewan',
#  49: 'comes',
#  50: 'markka',
#  51: '76',
#  52: 'radio',
#  53: 'substituting',
#  54: 'surpassing',
#  55: '95',
#  56: '771',
#  57: 'declarations',
#  58: 'places',
#  59: 'prior',
#  60: '670,000',
#  61: '1.74',
#  62: 'load',
#  63: 'vulnerable',
#  64: 'inspectors',
#  65: '90.2',
#  66: 'doubtful',
#  67: 'dumped',
#  68: 'metal',
#  69: '1.81',
#  70: 'insurers',
#  71: 'affecting',
#  72: 'immorally',
#  73: '109',
#  74: 'requests',
#  75: 'worried',
#  76: 'recognized',
#  77: 'hardware',
#  78: 'assistance',
#  79: 'recklessly',
#  80: 'bucharest',
#  81: 'r-iowa',
#  82: '14.6',
#  83: 'imf',
#  84: 'uniform',
#  85: 'appearance',
#  86: 'according',
#  87: 'member',
#  88: 'one-sixth',
#  89: 'grows',
#  90: 'identifying',
#  91: 'celebrating',
#  92: 'telling',
#  93: 'econometrics',
#  94: 'attendance',
#  95: 'counter',
#  96: 'linking',
#  97: '20.61',
#  98: 'feedgrain',
#  99: 'payable',
#  100: 'barrels',
#  101: '3.34',
#  102: '67',
#  103: 'relax',
#  104: 'dominant',
#  105: '9.99',
#  106: 'named',
#  107: 'space',
#  108: 'exporters',
#  109: 'benefited',
#  110: 'export',
#  111: 'areas',
#  112: 'guide',
#  113: 'define',
#  114: 'edwards',
#  115: 'transitory',
#  116: '11.8',
#  117: 'educational',
#  118: 'solved',
#  119: '14.65',
#  120: '112',
#  121: 'aided',
#  122: 'dubious',
#  123: 'expectations',
#  124: 'threshhold',
#  125: '157',
#  126: 'asks',
#  127: 'arms',
#  128: 'assure',
#  129: 'shareholder',
#  130: 'intervene',
#  131: 'january/march',
#  132: 'unsellable',
#  133: 'stoltenberg',
#  134: 'operating',
#  135: '189',
#  136: 'wedd',
#  137: 'paris',
#  138: 'tunisia',
#  139: '11.91',
#  140: 'picks',
#  141: 'tremendous',
#  142: '18.5',
#  143: 'adequate',
#  144: 'tune',
#  145: 'consumption',
#  146: '181.23',
#  147: 'creation',
#  148: 'competitor',
#  149: 'michel',
#  150: 'restraint',
#  151: 'end-',
#  152: 'random',
#  153: 'fulfilled',
#  154: 'redeemed',
#  155: 'strong-armed',
#  156: 'brand',
#  157: 'followed',
#  158: 'makin',
#  159: 'behalf',
#  160: 'positive',
#  161: 'dollars',
#  162: 'withdraw',
#  163: 'getting',
#  164: 'world',
#  165: 'neighbor',
#  166: 'telecommunications',
#  167: 'undesirable',
#  168: 'tabling',
#  169: '3.61',
#  170: 'tom',
#  171: 'distributors',
#  172: 'kilobit',
#  173: 'constraints',
#  174: 'chamber',
#  175: 'traumatic',
#  176: 'ruiz',
#  177: 'legislate',
#  178: 'asking',
#  179: 'reports',
#  180: 'warnings',
#  181: 'category',
#  182: 'peak',
#  183: 'zero',
#  184: 'enable',
#  185: 'tied-aid',
#  186: 'superiority',
#  187: 'damage',
#  188: 'mad',
#  189: 'laying',
#  190: 'surplus',
#  191: 'priced',
#  192: '/ompany',
#  193: 'interests',
#  194: 'chunk',
#  195: 'fuelling',
#  196: 'banque',
#  197: 'nomination',
#  198: 'denied',
#  199: '879.4',
#  200: 'sections',
#  201: 'accordingly',
#  202: 'swift',
#  203: 'effot',
#  204: 'remove',
#  205: 'abided',
#  206: 'furious',
#  207: 'left',
#  208: 'avoid',
#  209: 'auspices',
#  210: 'non-productive',
#  211: 'closed-minister',
#  212: '7.38',
#  213: 'caldwell',
#  214: 'earmarked',
#  215: 'strained',
#  216: 'freed',
#  217: 'end-1987',
#  218: '7.6',
#  219: 'evelyn',
#  220: 'worry',
#  221: 'water',
#  222: 'constitute',
#  223: 'quite',
#  224: 'contributed',
#  225: 'diw',
#  226: 'liberalised',
#  227: 'rodriguez',
#  228: 'high-ranking',
#  229: 'unconvinced',
#  230: 'offsetting',
#  231: 'welcoming',
#  232: 'jumped',
#  233: 'potash',
#  234: 'apply',
#  235: 'offered',
#  236: 'exercise',
#  237: 'replacements',
#  238: 'denmark',
#  239: 'whichever',
#  240: 'estimating',
#  241: 'commonwealth',
#  242: 'prompted',
#  243: 'weekend',
#  244: 'warned',
#  245: '7.79',
#  246: '6.64',
#  247: 'forfeit',
#  248: '928',
#  249: 'name',
#  250: 'sheltered',
#  251: '24.6',
#  252: 'open-trade',
#  253: '25.5',
#  254: 'fast-changing',
#  255: 'ignored',
#  256: '760',
#  257: '324',
#  258: '352',
#  259: 'cope',
#  260: 'withdrawing',
#  261: 'newfoundlanders',
#  262: 'suicide',
#  263: 'telephone',
#  264: '10.45',
#  265: '70.5',
#  266: 'aquino',
#  267: 'denominated',
#  268: 'conform',
#  269: '1985-1986',
#  270: 'cause',
#  271: 'dams',
#  272: 'value-added',
#  273: 'chang-ming',
#  274: 'corporate',
#  275: 'dropped',
#  276: '1.29',
#  277: 'laboratory',
#  278: '1/2',
#  279: 'bywater',
#  280: 'strength',
#  281: '261',
#  282: 'canadians',
#  283: 'faster',
#  284: 'commitments',
#  285: 'hosted',
#  286: 'thinh',
#  287: 'terrible',
#  288: 'heavy-handed',
#  289: 'replied',
#  290: 'prauge',
#  291: 'harsh',
#  292: 'unambiguous',
#  293: 'enough',
#  294: '1.65',
#  295: 'home',
#  296: 'sprinkel',
#  297: 'marks',
#  298: 'spurs',
#  299: 'stopped',
#  300: 'passionate',
#  301: '1.8',
#  302: 'smouldering',
#  303: 'exported',
#  304: 'commerce',
#  305: '22.4',
#  306: 'territorial',
#  307: 'questions',
#  308: '38.37',
#  309: 'engaged',
#  310: 'lynch',
#  311: '50',
#  312: 'quotas',
#  313: 'intitiate',
#  314: 'ended',
#  315: 'accelerated',
#  316: 'puchases',
#  317: 'administration',
#  318: 'endangered',
#  319: 'inexpensive',
#  320: 'inc',
#  321: 'gains',
#  322: 'computors',
#  323: 'globe',
#  324: 'coal',
#  325: '1.204',
#  326: 'distinctly',
#  327: 'revenue',
#  328: 'reply',
#  329: 'neither',
#  330: 'eiu',
#  331: 'regards',
#  332: 'possibly',
#  333: 'october/december',
#  334: 'alarm',
#  335: 'timetable',
#  336: 'intervening',
#  337: 'knock-down',
#  338: 'identify',
#  339: '1.6',
#  340: 'said.basically',
#  341: 'social',
#  342: 'common',
#  343: 'non-farm',
#  344: 'severely',
#  345: 'slowed',
#  346: 'peru',
#  347: 'cutbacks',
#  348: '100,000',
#  349: 'minimizing',
#  350: 'slumped',
#  351: 'antitrust',
#  352: 'jardine',
#  353: 'plays',
#  354: 'appeals',
#  355: 'karl',
#  356: 'notice',
#  357: 'hogs',
#  358: 'turf',
#  359: 'remained',
#  360: 'facilities',
#  361: 'roads',
#  362: 'dinosaur',
#  363: 'lined',
#  364: "'re",
#  365: 'recoup',
#  366: 'gramm-rudman',
#  367: 'price-cutting',
#  368: 'moscow',
#  369: 'adding',
#  370: 'urgent',
#  371: '880',
#  372: 'holding',
#  373: 'forestall',
#  374: 'contain',
#  375: 'offices',
#  376: 'target',
#  377: 'viability',
#  378: 'sustained',
#  379: 'enforcement',
#  380: '73.1',
#  381: 'martial',
#  382: '22.94',
#  383: 'dauster',
#  384: 'independent',
#  385: 'infant',
#  386: 'much',
#  387: 'cereal',
#  388: 'half-yearly',
#  389: 'seasonally-adjusted',
#  390: 'livestock',
#  391: '3,061.8',
#  392: 'countertrading',
#  393: 'privately',
#  394: 'broad-ranging',
#  395: 'expecting',
#  396: 'plantation',
#  397: 'slapped',
#  398: 'majority',
#  399: '1.62',
#  400: 'department',
#  401: 'outcome',
#  402: 'resume',
#  403: 'enormous',
#  404: 'practices',
#  405: 'minor',
#  406: 'danes',
#  407: 'production',
#  408: 'hinder',
#  409: 'differences',
#  410: 'routed',
#  411: 'predicted',
#  412: '862',
#  413: '912',
#  414: 'comeback',
#  415: '1987/88',
#  416: 'beset',
#  417: 'pledged',
#  418: 'invoices',
#  419: '39.6',
#  420: '34.59.',
#  421: 'poland',
#  422: 'washington-led',
#  423: 'enterprise',
#  424: 'telecom',
#  425: 'halt',
#  426: 'heller',
#  427: 'dan',
#  428: 'suzanne',
#  429: 'thought',
#  430: 'fruitful',
#  431: 'lire',
#  432: 'seoul',
#  433: 'profound',
#  434: '2.83',
#  435: 'flight',
#  436: 'widespread',
#  437: 'greenshields',
#  438: '3.25',
#  439: '77.4',
#  440: 'printed',
#  441: 'bob',
#  442: 'locate',
#  443: 'stipulated',
#  444: 'convince',
#  445: 'wish',
#  446: 'chiefly',
#  447: 'prohibited',
#  448: 'wave',
#  449: 'balance-of-payments',
#  450: 'toned',
#  451: 'instance',
#  452: 'office',
#  453: 'mid-1986',
#  454: 'let',
#  455: 'reviews',
#  456: 'video',
#  457: 'participant',
#  458: 'manufactured',
#  459: '1983',
#  460: 'wonder',
#  461: 'route',
#  462: 'disappointing',
#  463: 'frame',
#  464: 'enhancement',
#  465: 'shipped',
#  466: '641',
#  467: '2.72',
#  468: 'dicuss',
#  469: '17.48',
#  470: 'force',
#  471: 'flowing',
#  472: 'agencies',
#  473: 'health',
#  474: 'limit',
#  475: 'spotted',
#  476: 'wolf',
#  477: 'pennock',
#  478: 'commit',
#  479: '16.42-16.45',
#  480: 'easy',
#  481: 'providing',
#  482: 'argument',
#  483: 'unified',
#  484: 'furniture',
#  485: 'exchequer',
#  486: 'non-discriminatory',
#  487: '2.49',
#  488: 'dynamism',
#  489: '890',
#  490: 'suspension',
#  491: 'acquire',
#  492: '10.6',
#  493: 'indefinitely',
#  494: 'licences',
#  495: 'objection',
#  496: 'objected',
#  497: '31',
#  498: 'downward',
#  499: 'democracies',
#  500: 'southerners',
#  501: 'draconian',
#  502: 'preference',
#  503: 'decision-making',
#  504: 'contribution',
#  505: 'leeway',
#  506: 'regional',
#  507: 'owed',
#  508: 'koss',
#  509: '543',
#  510: 'convertible',
#  511: 'yaccobi',
#  512: 'sarney',
#  513: 'yeutter',
#  514: '6.67',
#  515: 'asian',
#  516: '13.',
#  517: 'jose',
#  518: '6.05',
#  519: 'categories',
#  520: 'noted',
#  521: '14.1',
#  522: '56.6',
#  523: 'frankfurt',
#  524: 'rah',
#  525: '1.05',
#  526: 'director',
#  527: 'bundesbank',
#  528: 'foodgrains',
#  529: 'yes',
#  530: 'sometime',
#  531: 'ryavec',
#  532: 'discriminated',
#  533: 'bumbled',
#  534: 'misfortune',
#  535: 'stephens',
#  536: 'policymaker',
#  537: 'goverment',
#  538: 'long',
#  539: 'numbers',
#  540: '3.51',
#  541: 'risk',
#  542: 'disruptions',
#  543: 'culprits',
#  544: 'create',
#  545: 'conflict',
#  546: 'stiff',
#  547: '4.4',
#  548: 'root',
#  549: 'yesterday',
#  550: 'slower',
#  551: 'commodities',
#  552: 'may',
#  553: 'orange',
#  554: 'establishment',
#  555: 'certificates',
#  556: '8.7',
#  557: 'red',
#  558: 'dispute',
#  559: '5.4',
#  560: '971',
#  561: 'facto',
#  562: 'indexation',
#  563: 'hesitate',
#  564: 'getty',
#  565: 'rules',
#  566: 'arguing',
#  567: 'offshoot',
#  568: 'failure',
#  569: 'bodies',
#  570: '340',
#  571: 'stabilize',
#  572: 'deficiency',
#  573: 'healthy',
#  574: 'concerned',
#  575: 'realize',
#  576: 'equipment',
#  577: 'item',
#  578: '1,700',
#  579: 'overwhelmed',
#  580: '1.113',
#  581: '417',
#  582: 'm-1',
#  583: '16.6',
#  584: 'accommodation',
#  585: 'butcher',
#  586: 'economy-wide',
#  587: 'entities',
#  588: 'oil',
#  589: '8,285',
#  590: 'average',
#  591: 'hardening',
#  592: '2.694',
#  593: 'subdued',
#  594: 'swing',
#  595: '4.12',
#  596: 'stages',
#  597: 'firms',
#  598: 'apartheid',
#  599: 'invite',
#  600: 'hissene',
#  601: 'preferences',
#  602: 'underscoring',
#  603: 'two-day',
#  604: 'norway',
#  605: 'yields',
#  606: 'negative',
#  607: 'patent',
#  608: 'pye',
#  609: '1.50',
#  610: '7.2',
#  611: 'african',
#  612: 'levels',
#  613: 'delayed',
#  614: '3,066.6',
#  615: '1989.',
#  616: 'raiders',
#  617: 'unleashed',
#  618: 'forthcoming',
#  619: 'directors',
#  620: 'nelson',
#  621: 'friday',
#  622: 'keys',
#  623: 'bethlehem',
#  624: 'sir',
#  625: 'factory',
#  626: 'shipping',
#  627: 'integration',
#  628: 'balanced',
#  629: '344',
#  630: 'overall',
#  631: 'dole',
#  632: 'aggravation',
#  633: 'program',
#  634: 'taste',
#  635: 'refiners',
#  636: 'benderley',
#  637: 'comprised',
#  638: 'huge',
#  639: 'plant',
#  640: 'sen.',
#  641: 'intervened',
#  642: '142.2',
#  643: 'der-hwa',
#  644: 'bentsen',
#  645: '``',
#  646: 'senators',
#  647: 'learning',
#  648: 'anti-japanese',
#  649: 'anyone',
#  650: 'finalised',
#  651: 'reform',
#  652: 'marlin',
#  653: 'issuance',
#  654: 'wide',
#  655: 'troubled',
#  656: 'specialist',
#  657: 'authorised',
#  658: 'gesture',
#  659: 'ongpin',
#  660: 'memorandum',
#  661: '10.69',
#  662: 'masaji',
#  663: 'opens',
#  664: 'wine',
#  665: 'maslen',
#  666: 'interested',
#  667: 'opinion',
#  668: 'editorial',
#  669: 'cerier',
#  670: 'evaluate',
#  671: 's.',
#  672: 'adverserial',
#  673: 'pesetas',
#  674: 'taka',
#  675: 'surviving',
#  676: '104',
#  677: '0.6800',
#  678: 'bank',
#  679: 'sustain',
#  680: 'drives',
#  681: '102.2',
#  682: 'seeks',
#  683: '59-billion-dlr',
#  684: 'junichiro',
#  685: 'push',
#  686: 'session',
#  687: '12-member',
#  688: 'lap-top',
#  689: 'struck',
#  690: 'ensure',
#  691: 'reluctance',
#  692: 'industries',
#  693: 'broaden',
#  694: 'dept',
#  695: 'repayment',
#  696: 'abiding',
#  697: 'overreacted',
#  698: '2.7',
#  699: '720',
#  700: 'mind',
#  701: 'osaka',
#  702: 'non-dollar',
#  703: 'ncso',
#  704: 'hopefully',
#  705: 'hunger',
#  706: 'armistice',
#  707: 'relieving',
#  708: '3.0',
#  709: 'slowing',
#  710: 'recognition',
#  711: '0.2.',
#  712: 'action',
#  713: 'economy',
#  714: 'lock',
#  715: 'wing',
#  716: 'banco',
#  717: 'weather',
#  718: '5.37',
#  719: '181',
#  720: 'liberalising',
#  721: 'shigeru',
#  722: 'thirdly',
#  723: '155',
#  724: 'german',
#  725: '246',
#  726: '233',
#  727: 'bit',
#  728: 'roy',
#  729: 'restricts',
#  730: '147.71',
#  731: 'idle',
#  732: 'power',
#  733: 'vengeance',
#  734: 'textile-state',
#  735: 'imec',
#  736: 'fall',
#  737: 'manila',
#  738: 'fisheries',
#  739: 'diminish',
#  740: 'apholte',
#  741: 'compete',
#  742: '6.5',
#  743: 'received',
#  744: 'tariffs',
#  745: 'minute',
#  746: '43.8',
#  747: 'younger',
#  748: 'defend',
#  749: 'oriented',
#  750: 'borrow',
#  751: 'carney',
#  752: 'dinars',
#  753: 'translated',
#  754: 'tea',
#  755: 'likewise',
#  756: 'none',
#  757: '751',
#  758: '11.11',
#  759: 'circle',
#  760: '72',
#  761: 'subsidization',
#  762: 'size',
#  763: 'u.s.-israeli',
#  764: 'autos',
#  765: 'function',
#  766: 'hence',
#  767: 'undersecretary',
#  768: 'shifts',
#  769: '3.5',
#  770: 'anti-u.s.',
#  771: 'privileged',
#  772: 'pointing',
#  773: 'barney',
#  774: 'least',
#  775: 'guidelines',
#  776: 'choices',
#  777: 'dutch',
#  778: 'momentum',
#  779: 'budgetary',
#  780: 'afford',
#  781: 'gilts',
#  782: 'habre',
#  783: 'minsiter',
#  784: 'pressed',
#  785: 'staged',
#  786: 'emerge',
#  787: 'measurement',
#  788: 'geneva',
#  789: 'stick',
#  790: 'ingenuity',
#  791: 'late',
#  792: '24-nation',
#  793: '723.2',
#  794: 'spectre',
#  795: 'real',
#  796: 'plunging',
#  797: '46.8',
#  798: 'april-june',
#  799: 'rid',
#  800: 'masaharu',
#  801: 'injected',
#  802: 'ruled',
#  803: '145',
#  804: 'middle',
#  805: 'toughen',
#  806: 'conciliation',
#  807: '210',
#  808: 'exist',
#  809: '5.23',
#  810: 'admitted',
#  811: '101.2',
#  812: 'upcoming',
#  813: 'tight-fisted',
#  814: '0.6864/69',
#  815: 'appear',
#  816: 'exempt',
#  817: 'trademarks',
#  818: 'applied',
#  819: 'punte',
#  820: 'teams',
#  821: 'developments',
#  822: 'certificate',
#  823: 'offshore',
#  824: 'clear',
#  825: 'rectified',
#  826: 'indian',
#  827: 'ammunition',
#  828: 'members',
#  829: 'old',
#  830: 'draw',
#  831: 'significant',
#  832: 'instead',
#  833: 'including',
#  834: 'henry',
#  835: 'jack',
#  836: 'manufactures',
#  837: 'artificial',
#  838: 'driving',
#  839: 'emerged',
#  840: 'withdrawal',
#  841: 'georgia',
#  842: 'insist',
#  843: 'merely',
#  844: 'fukukawa',
#  845: 'univerity',
#  846: 'worthwhile',
#  847: '6.8',
#  848: 'korea',
#  849: 'anti-dumping',
#  850: 'uruguay',
#  851: 'drive',
#  852: 'included',
#  853: 'deflationary',
#  854: 'diminishing',
#  855: 'conservations',
#  856: 'solutions',
#  857: 'ic',
#  858: 'drugs',
#  859: 'brokerage',
#  860: 'udagawa',
#  861: 'wide-ranging',
#  862: 'briskly',
#  863: 'prepaying',
#  864: '1991.',
#  865: 'tankers',
#  866: 'lee',
#  867: 'fruits',
#  868: 'cuevas',
#  869: 'like',
#  870: 'equip',
#  871: '235',
#  872: 'embark',
#  873: 'replace',
#  874: 'jestin',
#  875: 'judge',
#  876: 'anytime',
#  877: 'chief',
#  878: 'schedules',
#  879: 'assessment',
#  880: 'covers',
#  881: 'dlrs',
#  882: 'sector',
#  883: 'everyone',
#  884: 'barber',
#  885: 'machinery',
#  886: 'heritage',
#  887: 'consider',
#  888: '1986-1991',
#  889: '1.32',
#  890: 'barclays',
#  891: 'finding',
#  892: 'represents',
#  893: 'banking',
#  894: 'today',
#  895: '9.63',
#  896: 'ideal',
#  897: 'informally',
#  898: 'after-effect',
#  899: 'rupees',
#  900: 'winds',
#  901: 'bonn',
#  902: '218-page',
#  903: '2.65',
#  904: 'pattern',
#  905: 'companies',
#  906: 'origins',
#  907: '1.434',
#  908: 'processing',
#  909: 'ordered',
#  910: 'sympathise',
#  911: 'donations',
#  912: 'genuinely',
#  913: 'revising',
#  914: 'fibre',
#  915: 'discriminatory',
#  916: 'toshiba',
#  917: 'thus',
#  918: 'quantitative',
#  919: 'shape',
#  920: 'kept',
#  921: 'room',
#  922: 'presence',
#  923: 'team',
#  924: 'treatment',
#  925: 'students',
#  926: 'honda',
#  927: 'stock',
#  928: 'needs',
#  929: 'britain',
#  930: 'suffering',
#  931: 'wasted',
#  932: 'zhao',
#  933: '2.52',
#  934: '146.40/50',
#  935: 'erosion',
#  936: 'assigns',
#  937: 'loaned',
#  938: 'yugoslavia',
#  939: '13.82',
#  940: 'emphasis',
#  941: 'sumitomo',
#  942: 'lunch',
#  943: 'metals',
#  944: 'supercomputer',
#  945: 'commented',
#  946: 'archer',
#  947: 'dealt',
#  948: 'ceremony',
#  949: '7.28',
#  950: 'august',
#  951: 'linked',
#  952: 'strong',
#  953: 'heart',
#  954: 'producers',
#  955: 'europeans',
#  956: 'formalized',
#  957: 'yasuhiro',
#  958: 'floating',
#  959: 'extra',
#  960: 'tolerate',
#  961: 'entering',
#  962: 'exclude',
#  963: 'minoru',
#  964: '7.04',
#  965: '200',
#  966: 'observers',
#  967: 'puts',
#  968: 'echoes',
#  969: 'definitely',
#  970: '1.46',
#  971: 'inaccurate',
#  972: 'priority',
#  973: 'mission',
#  974: 'comparable',
#  975: 'crushing',
#  976: 'inseperable',
#  977: 'destination',
#  978: '146.50',
#  979: 'applications',
#  980: '15-member',
#  981: 'ceilings',
#  982: 'touch',
#  983: 'writing',
#  984: 'vested',
#  985: 'passenger',
#  986: '629.7',
#  987: 'slifer',
#  988: 'explanation',
#  989: '43',
#  990: 'concentrate',
#  991: 'endo',
#  992: 'fertilizer',
#  993: 'economies',
#  994: 'miet.t',
#  995: 'means',
#  996: 'discounts',
#  997: 'appeal',
#  998: 'cautious',
#  999: 'incompatible',
#  ...}

# %% [markdown]
# ## Prepare train data

# %%
total_count = 0
for count, value in enumerate(preprocessed_docs):
    total_count += count
    print(value)

print(total_count)
# Out:
# ['asian', 'exporters', 'fear', 'damage', 'u.s.-japan', 'rift', 'mounting', 'trade', 'friction', 'u.s.', 'japan', 'raised', 'fears', 'among', 'many', 'asia', "'s", 'exporting', 'nations', 'row', 'could', 'inflict', 'far-reaching', 'economic', 'damage', 'businessmen', 'officials', 'said', 'told', 'reuter', 'correspondents', 'asian', 'capitals', 'u.s.', 'move', 'japan', 'might', 'boost', 'protectionist', 'sentiment', 'u.s.', 'lead', 'curbs', 'american', 'imports', 'products', 'exporters', 'said', 'conflict', 'would', 'hurt', 'long-run', 'short-term', 'tokyo', "'s", 'loss', 'might', 'gain', 'u.s.', 'said', 'impose', '300', 'mln', 'dlrs', 'tariffs', 'imports', 'japanese', 'electronics', 'goods', 'april', '17', 'retaliation', 'japan', "'s", 'alleged', 'failure', 'stick', 'pact', 'sell', 'semiconductors', 'world', 'markets', 'cost', 'unofficial', 'japanese', 'estimates', 'put', 'impact', 'tariffs', '10', 'billion', 'dlrs', 'spokesmen', 'major', 'electronics', 'firms', 'said', 'would', 'virtually', 'halt', 'exports', 'products', 'hit', 'new', 'taxes', '``', 'would', "n't", 'able', 'business', "''", 'said', 'spokesman', 'leading', 'japanese', 'electronics', 'firm', 'matsushita', 'electric', 'industrial', 'co', 'ltd', 'lt', 'mc.t', '``', 'tariffs', 'remain', 'place', 'length', 'time', 'beyond', 'months', 'mean', 'complete', 'erosion', 'exports', 'goods', 'subject', 'tariffs', 'u.s.', "''", 'said', 'tom', 'murtha', 'stock', 'analyst', 'tokyo', 'office', 'broker', 'lt', 'james', 'capel', 'co', 'taiwan', 'businessmen', 'officials', 'also', 'worried', '``', 'aware', 'seriousness', 'u.s.', 'threat', 'japan', 'serves', 'warning', 'us', "''", 'said', 'senior', 'taiwanese', 'trade', 'official', 'asked', 'named', 'taiwan', 'trade', 'trade', 'surplus', '15.6', 'billion', 'dlrs', 'last', 'year', '95', 'pct', 'u.s.', 'surplus', 'helped', 'swell', 'taiwan', "'s", 'foreign', 'exchange', 'reserves', '53', 'billion', 'dlrs', 'among', 'world', "'s", 'largest', '``', 'must', 'quickly', 'open', 'markets', 'remove', 'trade', 'barriers', 'cut', 'import', 'tariffs', 'allow', 'imports', 'u.s.', 'products', 'want', 'defuse', 'problems', 'possible', 'u.s.', 'retaliation', "''", 'said', 'paul', 'sheen', 'chairman', 'textile', 'exporters', 'lt', 'taiwan', 'safe', 'group', 'senior', 'official', 'south', 'korea', "'s", 'trade', 'promotion', 'association', 'said', 'trade', 'dispute', 'u.s.', 'japan', 'might', 'also', 'lead', 'pressure', 'south', 'korea', 'whose', 'chief', 'exports', 'similar', 'japan', 'last', 'year', 'south', 'korea', 'trade', 'surplus', '7.1', 'billion', 'dlrs', 'u.s.', '4.9', 'billion', 'dlrs', '1985.', 'malaysia', 'trade', 'officers', 'businessmen', 'said', 'tough', 'curbs', 'japan', 'might', 'allow', 'hard-hit', 'producers', 'semiconductors', 'third', 'countries', 'expand', 'sales', 'u.s.', 'hong', 'kong', 'newspapers', 'alleged', 'japan', 'selling', 'below-cost', 'semiconductors', 'electronics', 'manufacturers', 'share', 'view', 'businessmen', 'said', 'short-term', 'commercial', 'advantage', 'would', 'outweighed', 'u.s.', 'pressure', 'block', 'imports', '``', 'short-term', 'view', "''", 'said', 'lawrence', 'mills', 'director-general', 'federation', 'hong', 'kong', 'industry', '``', 'whole', 'purpose', 'prevent', 'imports', 'one', 'day', 'extended', 'sources', 'much', 'serious', 'hong', 'kong', 'disadvantage', 'action', 'restraining', 'trade', "''", 'said', 'u.s.', 'last', 'year', 'hong', 'kong', "'s", 'biggest', 'export', 'market', 'accounting', '30', 'pct', 'domestically', 'produced', 'exports', 'australian', 'government', 'awaiting', 'outcome', 'trade', 'talks', 'u.s.', 'japan', 'interest', 'concern', 'industry', 'minister', 'john', 'button', 'said', 'canberra', 'last', 'friday', '``', 'kind', 'deterioration', 'trade', 'relations', 'two', 'countries', 'major', 'trading', 'partners', 'serious', 'matter', "''", 'button', 'said', 'said', 'australia', "'s", 'concerns', 'centred', 'coal', 'beef', 'australia', "'s", 'two', 'largest', 'exports', 'j ...
# ['thai', 'trade', 'deficit', 'widens', 'first', 'quarter', 'thailand', "'s", 'trade', 'deficit', 'widened', '4.5', 'billion', 'baht', 'first', 'quarter', '1987', '2.1', 'billion', 'year', 'ago', 'business', 'economics', 'department', 'said', 'said', 'janunary/march', 'imports', 'rose', '65.1', 'billion', 'baht', '58.7', 'billion', 'thailand', "'s", 'improved', 'business', 'climate', 'year', 'resulted', '27', 'pct', 'increase', 'imports', 'raw', 'materials', 'semi-finished', 'products', 'country', "'s", 'oil', 'import', 'bill', 'however', 'fell', '23', 'pct', 'first', 'quarter', 'due', 'lower', 'oil', 'prices', 'department', 'said', 'first', 'quarter', 'exports', 'expanded', '60.6', 'billion', 'baht', '56.6', 'billion', 'export', 'growth', 'smaller', 'expected', 'due', 'lower', 'earnings', 'many', 'key', 'commodities', 'including', 'rice', 'whose', 'earnings', 'declined', '18', 'pct', 'maize', '66', 'pct', 'sugar', '45', 'pct', 'tin', '26', 'pct', 'canned', 'pineapples', 'seven', 'pct', 'products', 'registering', 'high', 'export', 'growth', 'jewellery', '64', 'pct', 'clothing', '57', 'pct', 'rubber', '35', 'pct']
# ['japan', 'ministry', 'says', 'open', 'farm', 'trade', 'would', 'hit', 'u.s.', 'japan', "'s", 'agriculture', 'ministry', 'angered', 'u.s.', 'demands', 'japan', 'open', 'farm', 'products', 'market', 'tell', 'u.s.', 'officials', 'talks', 'later', 'month', 'liberalisation', 'would', 'harm', 'existing', 'u.s.', 'farm', 'exports', 'japan', 'senior', 'ministry', 'official', 'said', '``', 'imports', 'u.s.', 'would', 'drop', 'due', 'active', 'sales', 'drives', 'suppliers', "''", 'official', 'declined', 'named', 'said', '``', 'japan', 'largest', 'customer', 'u.s.', 'farm', 'products', 'reasonable', 'u.s.', 'demand', 'japan', 'liberalise', 'farm', 'import', 'market', "''", 'said', 'agriculture', 'minister', 'mutsuki', 'kato', 'said', 'u.s.', 'insists', 'japan', 'open', 'protected', 'rice', 'market', 'also', 'open', 'wheat', 'market', 'volume', 'origin', 'regulated', 'protect', 'local', 'farmers', 'australia', 'canada', 'could', 'increase', 'wheat', 'exports', 'competitive', 'u.s.', 'said', 'end-users', 'would', 'also', 'buy', 'origins', 'grain', 'traders', 'said', 'u.s.', 'agriculture', 'secretary', 'richard', 'lyng', 'due', 'visit', 'japan', 'talks', 'april', '16-27', 'said', 'ask', 'japan', 'offer', 'share', 'rice', 'market', 'u.s.', 'suppliers', 'remove', 'quotas', 'u.s.', 'beef', 'citrus', 'imports', 'countries', 'already', 'cutting', 'u.s.', 'market', 'share', 'australia', 'largest', 'beef', 'supplier', 'japan', 'trying', 'boost', 'exports', 'prior', 'expiry', 'four-year', 'beef', 'accord', 'next', 'march', '31.', 'imports', 'u.s.', 'corn', 'fallen', 'due', 'increased', 'sales', 'china', 'south', 'america', 'japanese', 'soybean', 'imports', 'brazil', 'expected', 'rise', 'sharply', 'year', 'although', 'u.s.', 'remain', 'largest', 'supplier', 'u.s.', 'feedgrain', 'sales', 'also', 'drop', 'japan', 'opens', 'beef', 'imports', 'since', 'japan', 'depends', 'almost', 'entirely', 'feedgrain', 'imports', 'mainly', 'u.s.', 'japanese', 'officials', 'said', 'indication', 'u.s.', 'position', 'came', 'last', 'december', 'secretary', 'agriculture', 'daniel', 'amstutz', 'said', 'japan', 'potential', 'provide', 'one', 'largest', 'boosts', 'u.s.', 'agricultural', 'exports', 'beef', 'market', 'alone', 'representing', 'one', 'billion', 'dlrs', 'new', 'business', 'u.s.', 'also', 'asked', 'general', 'agreement', 'tariffs', 'trade', 'investigate', 'legality', 'japanese', 'import', 'controls', '12', 'farm', 'products', 'including', 'fruit', 'juices', 'purees', 'pulp', 'tomato', 'juice', 'ketchup', 'sauce', 'peanuts', 'prepared', 'beef', 'products', 'miscellaneous', 'beans', 'help', 'calm', 'heated', 'trade', 'relations', 'u.s.', 'japan', "'s", 'top', 'business', 'group', 'keidanren', 'urged', 'government', 'remove', 'residual', 'import', 'restrictions', 'agricultural', 'products', 'agriculture', 'minister', 'kato', 'ruled', 'emotional', 'reaction', 'senior', 'ministry', 'official', 'said', 'farm', 'issue', 'become', 'scapegoat', 'trade', 'pressure', 'industrial', 'sector', '``', 'japan', 'largest', 'buyer', 'u.s.', 'farm', 'products', 'issues', 'discussed', 'table', "''", 'official', 'said']
# ['south', 'korea', 'moves', 'slow', 'growth', 'trade', 'surplus', 'south', 'korea', "'s", 'trade', 'surplus', 'growing', 'fast', 'government', 'started', 'taking', 'steps', 'slow', 'deputy', 'prime', 'minister', 'kim', 'mahn-je', 'said', 'told', 'press', 'conference', 'government', 'planned', 'increase', 'investment', 'speed', 'opening', 'local', 'market', 'foreign', 'imports', 'gradually', 'adjust', 'currency', 'hold', 'surplus', '``', 'proper', 'level', "''", 'said', 'government', 'would', 'allow', 'appreciate', 'much', 'short', 'period', 'time', 'south', 'korea', 'pressure', 'washington', 'revalue', 'u.s.', 'wants', 'south', 'korea', 'cut', 'trade', 'surplus', 'u.s.', 'rose', '7.4', 'billion', 'dlrs', '1986', '4.3', 'billion', 'dlrs', '1985.', 'kim', 'also', 'economic', 'planning', 'minister', 'said', 'prospects', 'bright', 'south', 'korean', 'economy', 'government', 'would', 'try', 'hold', 'current', 'account', 'surplus', 'around', 'five', 'billion', 'dlrs', 'year', 'next', 'five', 'years', '``', 'government', 'projections', 'eight', 'pct', 'gnp', 'growth', 'five', 'billion', 'dlrs', 'current', 'account', 'surplus', '12', 'pct', 'growth', 'exports', 'seemed', 'reasonable', 'early', 'year', 'surplus', 'growing', 'faster', 'expected', "''", 'said', 'trade', 'ministry', 'officials', 'said', 'south', 'korea', "'s", 'exports', 'rose', '35', 'pct', '9.34', 'billion', 'dlrs', 'first', 'three', 'months', 'year', 'imports', 'rose', '8.5', 'pct', '8.2', 'billion', 'dlrs', 'kim', 'said', 'swing', 'south', 'korea', "'s", 'current', 'account', 'surplus', '4.65', 'billion', 'dlrs', '1986', '890', 'mln', 'dlr', 'deficit', '1985', 'significant', 'surplus', 'enabled', 'country', 'reduce', 'foreign', 'debt', 'last', 'year', 'first', 'time', 'south', 'korea', "'s", 'foreign', 'debt', 'fell', '44.5', 'billion', 'dlrs', '1986', '46.8', 'billion', '1985', 'still', 'among', 'largest', 'asia', '``', 'huge', 'amount', 'foreign', 'debt', 'one', 'major', 'constraints', 'development', '...', 'last', 'year', 'major', 'turning', 'point', 'korean', 'economy', "''", 'kim', 'said', 'kim', 'said', 'government', 'plannned', 'reduce', 'ratio', 'foreign', 'debt', 'country', "'s", 'gnp', '20', 'pct', '1991', '50', 'pct', '1986', '``', 'government', 'however', 'want', 'accelerate', 'reducing', 'debt', 'making', 'excessive', 'trade', 'surplus', "''", 'said', 'kim', 'said', 'sudden', 'rise', 'surplus', 'would', 'cause', 'inflation', 'lead', 'trade', 'friction', 'seoul', "'s", 'major', 'trading', 'partners', 'particularly', 'united', 'states', '``', 'need', 'surplus', 'reduce', 'debt', 'taking', 'measures', 'hold', 'size', 'surplus', 'proper', 'level', "''", 'kim', 'said']
# ['japan', 'given', 'little', 'hope', 'avoiding', 'u.s.', 'sanctions', 'top', 'u.s.', 'official', 'said', 'japan', 'little', 'chance', 'convincing', 'u.s.', 'drop', 'threatened', 'trade', 'sanctions', 'despite', 'efforts', 'japanese', 'team', 'left', 'washington', 'today', 'michael', 'armacost', 'secretary', 'state', 'political', 'affairs', 'asked', 'press', 'conference', 'whether', 'japan', "'s", 'moves', 'boost', 'domestic', 'economy', 'open', 'markets', 'could', 'persuade', 'u.s.', 'impose', 'tariffs', 'japanese', 'imports', 'said', 'replied', '``', '...', 'probably', 'early', 'figures', 'demonstrate', 'situation', 'turned', 'around', 'permit', 'result', 'described', "''", 'armacost', 'said', 'u.s.', 'hopes', 'japan', 'take', 'steps', 'lift', 'domestic', 'economy', 'reduce', 'dependence', 'exports', 'remove', 'barriers', 'imports', 'settle', 'outstanding', 'trade', 'issues', '``', 'obvious', 'problems', 'moment', 'trade', 'area', 'wish', 'problems', 'divert', 'attention', 'important', 'areas', 'cooperation', 'continue', 'exist', 'security', 'political', 'issues', "''", 'said', '``', 'question', 'whether', 'cooperative', 'actions', 'governments', 'reduce', 'trade', 'imbalance', 'whether', 'congress', 'takes', 'action', 'reduce', 'protectionist', 'legislation', "''", 'said']
# ['japanese', 'official', 'takes', 'data', 'microchip', 'talks', 'ministry', 'international', 'trade', 'industry', 'miti', 'vice', 'minister', 'makoto', 'kuroda', 'leaves', 'washington', 'today', 'data', 'hopes', 'refute', 'u.s.', 'charges', 'japan', 'violated', 'pact', 'microchip', 'trade', 'three-man', 'japanese', 'trade', 'team', 'already', 'washington', 'laying', 'groundwork', 'talks', 'kuroda', 'deputy', 'u.s.', 'trade', 'representative', 'michael', 'smith', 'aimed', 'persuading', 'u.s.', 'impose', 'tariffs', 'certain', 'japanese', 'products', 'kuroda', 'said', 'taking', 'new', 'proposals', '``', 'nothing', 'briefcase', 'except', 'explanation', 'current', 'situation', "''", 'kuroda', 'told', 'daily', 'newspaper', 'asahi', 'shimbun', 'kuroda', 'said', 'u.s.', 'decision', 'based', 'incorrect', 'data', 'exaggerated', 'sense', 'miti', "'s", 'power', 'control', 'market', 'forces', '``', 'u.s.', 'excessive', 'expectations', 'stabilise', 'supply-demand', 'relations', 'disrupted', 'excess', 'inventories', 'since', '1985', 'take', 'time', "''", 'said', 'kuroda', 'also', 'laid', 'part', 'blame', 'low', 'u.s.', 'chip', 'sales', 'japan', 'lack', 'effort', 'american', 'firms', 'said', 'fails', 'talks', 'tomorrow', 'friday', 'forestall', 'sanctions', 'seek', 'talks', 'u.s.', 'trade', 'representative', 'clayton', 'yeutter', 'u.s.', 'officials', 'said', 'week', "'s", 'talks', 'unlikely', 'delay', 'imposition', 'tariffs']
# ['japan', 'given', 'little', 'hope', 'avoiding', 'u.s.', 'sanctions', 'top', 'u.s.', 'official', 'said', 'japan', 'little', 'chance', 'persuading', 'u.s.', 'drop', 'threatened', 'trade', 'sanctions', 'despite', 'efforts', 'japanese', 'team', 'left', 'washington', 'today', 'michael', 'armacost', 'secretary', 'state', 'political', 'affairs', 'asked', 'press', 'conference', 'whether', 'japan', "'s", 'moves', 'boost', 'domestic', 'economy', 'open', 'markets', 'could', 'persuade', 'u.s.', 'impose', 'tariffs', 'japanese', 'imports', 'said', 'replied', '``', '...', 'probably', 'early', 'figures', 'demonstrate', 'situation', 'turned', 'around', 'permit', 'result', 'described', "''", 'armacost', 'said', 'u.s.', 'hopes', 'japan', 'take', 'steps', 'lift', 'domestic', 'economy', 'reduce', 'dependence', 'exports', 'remove', 'barriers', 'imports', 'settle', 'outstanding', 'trade', 'issues', '``', 'obvious', 'problems', 'moment', 'trade', 'area', 'wish', 'problems', 'divert', 'attention', 'important', 'areas', 'cooperation', 'continue', 'exist', 'security', 'political', 'issues', "''", 'said', '``', 'question', 'whether', 'cooperative', 'actions', 'governments', 'reduce', 'trade', 'imbalance', 'whether', 'congress', 'takes', 'action', 'reduce', 'protectionist', 'legislation', "''", 'said']
# ['japan', 'last-ditch', 'effort', 'avert', 'tariffs', 'senior', 'japanese', 'officials', 'tomorrow', 'open', 'talks', 'american', 'trade', 'negotiators', 'last-ditch', 'effort', 'avert', 'new', 'high', 'u.s.', 'tariffs', 'imposed', 'wide', 'variety', 'japanese', 'electronic', 'exports', 'makoto', 'kuroda', 'vice', 'minister', 'japan', "'s", 'ministry', 'international', 'trade', 'industry', 'miti', 'hold', 'two', 'days', 'meetings', 'deputy', 'u.s.', 'trade', 'representative', 'michael', 'smith', 'secretary', 'commerce', 'bruce', 'smart', 'new', 'tariffs', 'go', 'effect', 'april', '17', 'retaliation', 'japan', "'s", 'failure', 'adhere', 'agreement', 'end', 'dumping', 'semiconductors', 'world', 'markets', 'cost', 'open', 'home', 'market', 'u.s.', 'semiconductor', 'shipments', 'imposed', 'goods', 'use', 'semiconductors', 'including', 'television', 'audio', 'equipment', 'computers', 'u.s.', 'japanese', 'officials', 'said', 'little', 'likelihood', 'talks', 'would', 'anything', 'avert', '100', 'pct', 'duties', '300', 'mln', 'dlrs', 'worth', 'japanese', 'shipments', 'president', 'reagan', 'announced', 'planned', 'tariffs', 'march', '27', 'said', 'close', 'monitoring', 'july', '1986', 'u.s.-japanese', 'semiconductor', 'pact', 'convinced', 'u.s.', 'officials', 'japan', 'honoring', 'agreement', 'making', 'annoucement', 'reagan', 'said', '``', 'committed', 'full', 'enforcement', 'trade', 'agreements', 'designed', 'provide', 'american', 'industry', 'free', 'fair', 'trade', "''", 'trade', 'analysts', 'said', 'move', 'aimed', 'much', 'japan', "'s", 'semiconductor', 'trade', 'practices', 'said', 'injured', 'u.s.', 'semiconductor', 'industry', 'congress', 'complained', 'presidential', 'timidity', 'trade', 'issues', 'congressional', 'democrats', 'pledged', 'enact', 'aggressive', 'trade', 'laws', 'counter', 'contend', 'reagan', "'s", 'inaction', 'redress', 'growing', 'u.s.', 'trade', 'deficit', 'last', 'year', 'reached', '169.8', 'billion', 'dlrs', 'one-third', 'deficit', 'japan', 'reagan', 'said', 'recent', 'signs', 'japan', 'beginning', 'adhere', 'pact', 'terminating', 'kuroda', 'said', 'leaving', 'tokyo', 'today', 'new', 'proposals', 'explanation', 'semiconductor', 'situation', 'told', 'daily', 'newspaper', 'ashai', 'shimbun', 'reagan', "'s", 'decision', 'based', 'inaccurate', 'data', 'exaggerated', 'sense', 'miti', "'s", 'power', 'control', 'japanese', 'traders', '``', 'united', 'states', 'excessive', 'expectations.', "''", 'said', 'stabilize', 'supply-demand', 'relations', 'disrupted', 'excess', 'inventories', 'since', '1985', 'take', 'time', "''", 'also', 'said', 'u.s.', 'firms', 'aggressive', 'enough', 'trying', 'sell', 'japanese', 'market']
# ['white', 'house', 'standing', 'firm', 'japanese', 'sanctions', 'presidential', 'spokesman', 'marlin', 'fitzwater', 'said', 'u.s.', 'trade', 'sanctions', 'japan', 'likely', 'take', 'effect', 'april', '17', 'spite', '``', 'full', 'court', 'press', "''", 'japanese', 'officials', 'avoid', '``', 'indications', 'take', 'effect', "''", 'said', '``', 'would', 'say', 'japan', 'applying', 'full', 'court', 'press', '...', 'certainly', 'putting', 'feet', 'forward', 'terms', 'explaining', 'position', "''", 'fitzwater', 'told', 'reporters', 'noted', 'high', 'level', 'meetings', 'trade', 'dispute', 'underway', 'said', '``', "n't", 'think', "'s", 'anything', 'report', "n't", 'believe', "'s", 'official', 'movement', "''"]
# ['white', 'house', 'says', 'japanese', 'tarriffs', 'likely', 'white', 'house', 'said', 'high', 'u.s.', 'tariffs', 'japanese', 'electronic', 'goods', 'would', 'likely', 'imposed', 'scheduled', 'april', '17', 'despite', 'all-out', 'effort', 'japan', 'avoid', 'presidential', 'spokesman', 'marlin', 'fitzwater', 'made', 'remark', 'one', 'day', 'u.s.', 'japanese', 'officials', 'meet', 'emergency', 'provisions', 'july', '1986', 'semiconductor', 'pact', 'discuss', 'trade', 'punitive', 'tariffs', 'fitzwater', 'said', '``', 'would', 'say', 'japan', 'applying', 'full-court', 'press', '...', 'certainly', 'putting', 'feet', 'forward', 'terms', 'explaining', 'position', "''", 'added', '``', 'indications', 'tariffs', 'take', 'effect', "''"]
# ['canada', 'plans', 'monitor', 'steel', 'imports', 'exports', 'trade', 'minister', 'says', 'canada', 'plans', 'monitor', 'steel', 'imports', 'exports', 'trade', 'minister', 'says']
# ['canada', 'monitor', 'steel', 'imports', 'exports', 'canada', 'plans', 'monitor', 'steel', 'shipments', 'flowing', 'country', 'attempt', 'appease', 'concerns', 'u.s.', 'high', 'level', 'canadian', 'steel', 'exports', 'trade', 'minister', 'pat', 'carney', 'said', '``', 'help', 'maintain', 'open', 'access', 'u.s.', 'steel', 'market', 'government', 'taking', 'action', 'ensure', 'accurate', 'data', 'exports', 'imports', 'canada', 'used', 'backdoor', 'u.s.', 'market', 'offshore', 'suppliers', "''", 'carney', 'said', 'carney', 'also', 'said', 'canadian', 'companies', 'asked', 'exercise', 'prudence', 'u.s.', 'market', 'countries', 'considering', 'establishing', 'joint', 'commission', 'study', 'growing', 'steel', 'problem', 'carney', 'told', 'house', 'commons', 'soon', 'announce', 'amendment', 'exports', 'imports', 'permits', 'act', 'set', 'monitoring', 'program', 'canadian', 'steel', 'shipments', 'u.s.', 'risen', '5.7', 'pct', 'cent', 'u.s.', 'market', 'recent', 'months', 'almost', 'double', 'level', 'two', 'years', 'ago', 'canadian', 'trade', 'officials', 'said', 'increase', 'canadian', 'shipments', 'comes', 'time', 'growing', 'anger', 'u.s.', 'rising', 'steel', 'imports', 'several', 'countries', 'face', 'decline', 'domestic', 'steel', 'industry', 'u.s.', 'lawmakers', 'proposed', 'canada', "'s", 'share', 'american', 'market', 'limited', '2.4', 'pct']
# ['deficit', 'cuts', 'seen', 'unable', 'cure', 'trade', 'deficit', 'financial', 'analysts', 'say', 'pleased', 'congressional', 'moves', 'trim', 'next', 'year', "'s", 'federal', 'budget', 'deficit', 'believe', 'actions', 'little', 'help', 'improve', 'u.s.', 'trade', 'deficit', 'buoy', 'economy', 'house', 'representatives', 'expected', 'vote', 'tomorrow', 'approve', 'trillion-dollar', 'budget', 'blueprint', 'coming', 'fiscal', 'year', 'reduces', 'deficit', '38', 'billion', 'dlrs', 'similarly', 'senate', 'budget', 'committee', 'approved', 'plan', 'would', 'cut', 'federal', 'red', 'ink', '37', 'billion', 'dlrs', 'next', 'year', '``', 'terms', 'economy', '37-38', 'billion', 'dlrs', 'infinitesimal', 'cuts', 'magnitude', 'little', 'impact', 'economy', 'trade', 'deficit', "''", 'said', 'stanley', 'collander', 'touche', 'ross', 'federal', 'budget', 'policy', 'analyst', '``', 'best', 'small', 'positive', 'effect', "''", 'collander', 'said', 'interview', 'federal', 'reserve', 'board', 'chairman', 'paul', 'volcker', 'repeatedly', 'told', 'congress', 'cutting', 'federal', 'red', 'ink', 'would', 'go', 'long', 'way', 'help', 'reduce', 'massive', 'trade', 'deficit', 'also', 'help', 'ease', 'downward', 'pressure', 'value', 'dollar', 'u.s.', 'government', 'attempted', 'remedy', 'trade', 'imbalance', 'driving', 'value', 'dollar', 'volcker', 'warned', 'fall', 'dollar', "'s", 'value', 'fraught', 'danger', 'decline', 'said', 'could', 'refuel', 'inflation', 'imported', 'goods', 'become', 'expensive', 'chase', 'away', 'foreign', 'capital', 'needed', 'finance', 'federal', 'budget', 'deficit', 'addition', 'february', 'u.s.', 'officials', 'meeting', 'major', 'industrialized', 'nations', 'paris', 'agreed', 'value', 'dollar', 'dropped', 'enough', 'world', 'exchange', 'rates', 'stabilized', 'around', 'current', 'levels', 'part', 'agreement', 'japan', 'west', 'germany', 'agreed', 'take', 'steps', 'stimulate', 'economies', 'united', 'states', 'agreed', 'cut', 'budget', 'deficit', 'alternative', 'driving', 'dollar', 'way', 'deal', 'trade', 'deficit', 'volcker', 'said', 'recently', 'reduce', 'u.s.', 'consumption', 'particularly', 'federal', 'spending', '``', "n't", 'deal', 'budget', 'deficit', 'everything', 'else', 'going', 'counterproductive', "''", 'volcker', 'said', 'recent', 'testimony', 'senate', 'banking', 'committee', 'volcker', 'also', 'said', 'would', 'prefer', 'tighten', 'government', "'s", 'purse', 'strings', 'fed', 'tighten', 'credit', 'supply', 'action', 'needed', 'fight', 'inflationary', 'pressures', 'assure', 'continued', 'flow', 'foreign', 'capital', 'united', 'states', 'analysts', 'say', 'fed', 'tightening', 'could', 'choke', 'current', 'modest', 'economic', 'expansion', 'threaten', 'recession', 'kemper', 'financial', 'services', 'economist', 'john', 'silvia', 'stressed', 'deficit', 'reduction', 'better', 'none', 'said', 'size', 'cuts', 'consideration', 'enough', 'give', 'federal', 'reserve', 'board', 'flexibility', 'needs', 'steer', 'economy', 'keep', 'value', 'dollar', 'plunging', 'world', 'exchange', 'markets', '``', "'s", 'doubt', 'deficit', 'reduction', 'helps', 'objective', 'stabilize', 'dollar', 'perserve', 'fed', "'s", 'flexibility', 'conduct', 'monetary', 'policy', 'answer', "'s", 'enough', "''", 'silvia', 'told', 'reuters', 'u.s.', 'trade', 'deficit', 'become', 'one', 'government', "'s", 'vexing', 'persistent', 'problems', '1986', 'deficit', '169.8', 'billion', 'dlrs', 'yet', 'little', 'indication', 'year', "'s", 'figure', 'lower', 'though', 'administration', 'officials', 'predicted', 'drop', '20', '30', 'billion', 'dlrs', 'year', "'s", 'end', 'past', 'volcker', 'joked', 'never', 'lost', 'sleep', 'worrying', 'whether', 'congress', 'would', 'cut', 'much', 'fat', 'federal', 'budget', 'hand', 'also', 'made', 'clear', 'attached', 'gradually', 'declining', 'deficit', 'ceilings', 'set', '1986-1991', 'period', 'last', 'year', "'s", 'gramm-rudman', 'balanced', 'budget', 'law', 'new', 'law', 'set', 'ceiling', '108', 'billion', 'dlrs', 'next',  ...
# ['economic', 'spotlight', 'telecom', 'key', 'japan', 'ministry', 'japan', "'s", 'little-known', 'ministry', 'posts', 'telecommunications', 'mpt', 'emerged', 'international', 'force', 'reckoned', 'political', 'analysts', 'said', 'mpt', 'thrust', 'spotlight', 'trade', 'rows', 'u.s.', 'britain', 'position', 'strength', 'due', 'control', 'lucrative', 'industry', 'ties', 'important', 'politicians', 'said', '``', 'ministry', 'standing', 'athwart', 'regulatory', 'control', 'key', 'industrial', 'sector', 'telecommunications', 'information', "''", 'said', 'one', 'diplomatic', 'source', '``', 'potent', 'political', 'force', "''", 'diplomatic', 'source', 'said', 'mpt', 'finding', 'domestic', 'political', 'prowess', 'always', 'help', 'comes', 'trade', 'friction', 'diplomacy', 'analysts', 'said', '``', 'ministry', 'minor', 'ministry', 'people', 'internationalized', "''", 'said', 'waseda', 'university', 'professor', 'mitsuru', 'uchida', '``', 'suddenly', "'re", 'standing', 'centre', 'world', 'community', 'sense', "'re", 'loss', 'face', 'situation', "''", 'recently', 'ministry', 'embroiled', 'row', 'london', 'efforts', 'britain', "'s", 'cable', 'wireless', 'plc', 'keep', 'major', 'stake', 'one', 'two', 'consortia', 'trying', 'compete', 'japan', "'s", 'lucrative', 'overseas', 'telephone', 'business', 'ministry', 'favoured', 'merger', 'two', 'rival', 'groups', 'arguing', 'market', 'support', 'one', 'competitor', 'kokusai', 'denshin', 'denwa', 'co', 'ltd', 'monopolizes', 'business', 'also', 'opposed', 'major', 'management', 'role', 'planned', 'merger', 'non-japanese', 'overseas', 'telecommunications', 'firm', 'grounds', 'international', 'precedent', 'exists', 'ministry', "'s", 'stance', 'outraged', 'london', 'threatened', 'retaliate', 'washington', 'says', 'merger', 'plan', 'evidence', 'japan', "'s", 'failure', 'honour', 'pledges', 'open', 'telecommunications', 'market', 'washington', 'also', 'angry', 'ministry', 'moves', 'says', 'limited', 'access', 'u.s.', 'firms', 'japan', "'s", 'car', 'telephone', 'satellite', 'communications', 'market', 'much', 'mpt', "'s", 'new', 'prominence', 'stems', 'growth', 'sector', 'regulates', '``', 'happening', 'important', 'shift', 'economy', 'makes', 'ministry', 'important', 'place', "''", 'said', 'james', 'abegglen', 'head', 'consulting', 'firm', 'asia', 'advisory', 'service', 'inc.', 'decision', 'open', 'telecommunications', 'industry', 'competition', 'new', 'set', 'laws', 'passed', '1985', 'boosted', 'rather', 'lessened', 'mpt', "'s", 'authority', 'analysts', 'said', '``', 'legal', 'framework', 'eased', 'became', 'de', 'facto', 'legal', 'framework', "''", 'said', 'bache', 'securities', 'japan', 'analyst', 'darrell', 'whitten', 'close', 'links', 'powerful', 'political', 'faction', 'ruling', 'liberal', 'democratic', 'party', 'ldp', 'nurtured', 'former', 'prime', 'minister', 'kakuei', 'tanaka', 'another', 'key', 'mpt', "'s", 'influence', 'analysts', 'said', '``', 'factions', 'ignored', 'mpt', '1970s', 'tanaka', 'faction', 'forward', 'looking', '...', 'recognized', 'importance', 'mpt', "''", 'uchida', 'said', 'many', 'former', 'bureaucrats', 'became', 'members', 'influential', 'political', 'group', 'added', 'ministry', 'also', 'power', 'financial', 'sector', 'due', '100,000', 'billion', 'yen', 'worth', 'deposits', 'postal', 'savings', 'system', 'analysts', 'said', 'mpt', 'helped', 'block', 'finance', 'ministry', 'plans', 'deregulate', 'interest', 'rates', 'small', 'deposits', 'key', 'element', 'financial', 'liberalisation', 'since', 'change', 'would', 'remove', 'postal', 'savings', 'system', "'s", 'ability', 'offer', 'slightly', 'higher', 'rates', 'banks', 'said', 'diplomatic', 'sources', 'frustrated', 'see', 'mpt', "'s", 'obstructionist', 'protectionist', 'posture', 'characterized', 'ministry', 'feudal', 'critics', 'charge', 'mpt', 'protecting', 'turf', 'limiting', 'competition', 'sheltering', 'former', 'monopolies', 'wing', 'providing', 'consumers', 'best', 'service', 'lowest', 'price', 'takes', 'back', 'seat' ...
# ['g-7', 'issues', 'statement', 'meeting', 'following', 'text', 'statement', 'group', 'seven', '--', 'u.s.', 'japan', 'west', 'germany', 'france', 'britain', 'italy', 'canada', '--', 'issued', 'washington', 'meeting', 'yesterday', '1.', 'finance', 'ministers', 'central', 'bank', 'governors', 'seven', 'major', 'industrial', 'countries', 'met', 'today', 'continued', 'process', 'multilateral', 'surveillance', 'economies', 'pursuant', 'arrangements', 'strengthened', 'economic', 'policy', 'coordination', 'agreed', '1986', 'tokyo', 'summit', 'heads', 'state', 'government', 'managing', 'director', 'international', 'monetary', 'fund', 'also', 'participated', 'meeting', '2.', 'ministers', 'governors', 'reaffirmed', 'commitment', 'cooperative', 'approach', 'agreed', 'recent', 'paris', 'meeting', 'noted', 'progress', 'achieved', 'implementing', 'undertakings', 'embodied', 'louvre', 'agreement', 'agreed', 'however', 'actions', 'essential', 'resist', 'rising', 'protectionist', 'pressures', 'sustain', 'global', 'economic', 'expansion', 'reduce', 'trade', 'imbalances', 'connection', 'welcomed', 'proposals', 'announced', 'governing', 'liberal', 'democratic', 'party', 'japan', 'extraordinary', 'urgent', 'measures', 'stimulate', 'japan', "'s", 'economy', 'early', 'implementation', 'large', 'supplementary', 'budget', 'exceeding', 'previous', 'years', 'well', 'unprecedented', 'front-end', 'loading', 'public', 'works', 'expenditures', 'government', 'japan', 'reaffirmed', 'intention', 'open', 'domestic', 'markets', 'foreign', 'goods', 'services', '3.', 'ministers', 'governors', 'reaffirmed', 'view', 'around', 'current', 'levels', 'currencies', 'within', 'ranges', 'broadly', 'consistent', 'economic', 'fundamentals', 'basic', 'policy', 'intentions', 'outlined', 'louvre', 'meeting', 'connection', 'welcomed', 'strong', 'implementation', 'louvre', 'agreement', 'concluded', 'present', 'prospective', 'progress', 'implementing', 'policy', 'undertakings', 'louvre', 'statement', 'provided', 'basis', 'continuing', 'close', 'cooperation', 'foster', 'stability', 'exchange', 'rates']
# ['soviet', 'trade', 'deficit', 'west', 'soars', '1986', 'soviet', 'trade', 'deficit', 'west', 'almost', 'quadrupled', 'last', 'year', 'reaching', '2.72', 'billion', 'roubles', 'compared', '713', 'mln', '1985', 'official', 'figures', 'showed', 'statistics', 'published', 'monthly', 'journal', 'foreign', 'trade', 'showed', 'soviet', 'trade', 'turnover', '1986', 'fell', '130.9', 'billion', 'roubles', '142.1', 'billion', 'previous', 'year', 'drop', '7.8', 'pct', 'moscow', "'s", 'trade', 'surplus', 'east', 'bloc', 'countries', 'continued', 'grow', '1986.', 'western', 'analysts', 'attributed', 'deficit', 'rise', 'west', 'world', 'oil', 'price', 'slump', 'hit', 'moscow', "'s", 'main', 'export', 'cut', 'hard', 'currency', 'earnings', 'needed', 'purchases', 'west']
# ['canada', 'february', 'trade', 'surplus', '1.25', 'billion', 'dlrs', 'january', '623', 'mln', 'dlrs', 'surplus', 'canada', 'february', 'trade', 'surplus', '1.25', 'billion', 'dlrs', 'january', '623', 'mln', 'dlrs', 'surplus']
# ['canada', 'february', 'trade', 'surplus', '1.2', 'billion', 'dlrs', 'canada', 'trade', 'surplus', '1.25', 'billion', 'dlrs', 'february', 'compared', 'upward', 'revised', '623', 'mln', 'dlrs', 'surplus', 'january', 'statistics', 'canada', 'said', 'january', 'surplus', 'originally', 'reported', '533', 'mln', 'dlrs', 'february', 'surplus', 'last', 'year', '189', 'mln', 'dlrs', 'february', 'exports', 'seasonally', 'adjusted', '10.44', 'billion', 'dlrs', '9.85', 'billion', 'january', '10.05', 'billion', 'february', '1986.', 'february', 'imports', '9.19', 'billion', 'dlrs', '9.23', 'billion', 'january', '9.86', 'billion', 'february', '1986']
# ['ec', 'launches', 'anti-dumping', 'probe', 'japanese', 'chips', 'european', 'community', 'launched', 'investigation', 'allegations', 'dumping', 'japanese', 'semiconductor', 'makers', 'move', 'diplomats', 'said', 'could', 'mark', 'intensification', 'world', 'trade', 'strains', 'tokyo', 'already', 'faces', 'deadline', 'april', '17', 'washington', 'imposition', '300', 'mln', 'dlrs', 'worth', 'tariffs', 'chips', 'imports', 'u.s.', 'ec', 'executive', 'commission', 'said', 'today', 'european', 'electrical', 'component', 'manufacturers', 'association', 'complained', 'japanese', 'firms', 'selling', 'high', 'capacity', 'eprom', 'type', 'erasable', 'programmable', 'read', 'memory', 'chips', 'unfairly', 'low', 'prices', 'japan', 'last', 'year', 'took', '78', 'pct', '170', 'mln', 'dlr', 'ec', 'eprom', 'market', '60', 'pct', '1984.', 'ec', 'firms', 'said', 'forced', 'offer', 'products', 'discount', '30', 'pct', 'order', 'compete', 'japanese', 'commission', 'said', 'believed', 'association', 'given', 'sufficient', 'elements', 'proof', 'dumping', 'warrant', 'investigation', 'could', 'lead', 'impose', 'duties', 'found', 'complaints', 'justified', 'commission', 'claims', 'last', 'year', "'s", 'accord', 'u.s.', 'japan', 'microchip', 'pricing', 'gives', 'u.s.', 'firms', 'privileged', 'access', 'japanese', 'market']
# ['g-7', 'issues', 'statement', 'meeting', 'following', 'text', 'statement', 'group', 'seven', '--', 'u.s.', 'japan', 'west', 'germany', 'france', 'britain', 'italy', 'canada', '--', 'issued', 'washington', 'meeting', 'yesterday', '1.', 'finance', 'ministers', 'central', 'bank', 'governors', 'seven', 'major', 'industrial', 'countries', 'met', 'today', 'continued', 'process', 'multilateral', 'surveillance', 'economies', 'pursuant', 'arrangements', 'strengthened', 'economic', 'policy', 'coordination', 'agreed', '1986', 'tokyo', 'summit', 'heads', 'state', 'government', 'managing', 'director', 'international', 'monetary', 'fund', 'also', 'participated', 'meeting', '2.', 'ministers', 'governors', 'reaffirmed', 'commitment', 'cooperative', 'approach', 'agreed', 'recent', 'paris', 'meeting', 'noted', 'progress', 'achieved', 'implementing', 'undertakings', 'embodied', 'louvre', 'agreement', 'agreed', 'however', 'actions', 'essential', 'resist', 'rising', 'protectionist', 'pressures', 'sustain', 'global', 'economic', 'expansion', 'reduce', 'trade', 'imbalances', 'connection', 'welcomed', 'proposals', 'announced', 'governing', 'liberal', 'democratic', 'party', 'japan', 'extraordinary', 'urgent', 'measures', 'stimulate', 'japan', "'s", 'economy', 'early', 'implementation', 'large', 'supplementary', 'budget', 'exceeding', 'previous', 'years', 'well', 'unprecedented', 'front-end', 'loading', 'public', 'works', 'expenditures', 'government', 'japan', 'reaffirmed', 'intention', 'open', 'domestic', 'markets', 'foreign', 'goods', 'services', '3.', 'ministers', 'governors', 'reaffirmed', 'view', 'around', 'current', 'levels', 'currencies', 'within', 'ranges', 'broadly', 'consistent', 'economic', 'fundamentals', 'basic', 'policy', 'intentions', 'outlined', 'louvre', 'meeting', 'connection', 'welcomed', 'strong', 'implementation', 'louvre', 'agreement', 'concluded', 'present', 'prospective', 'progress', 'implementing', 'policy', 'undertakings', 'louvre', 'statement', 'provided', 'basis', 'continuing', 'close', 'cooperation', 'foster', 'stability', 'exchange', 'rates']
# ['spanish', 'employers', 'worried', 'high', 'interest', 'rates', 'head', 'spain', "'s", 'employers', 'federation', 'jose', 'maria', 'cuevas', 'said', 'employers', 'worried', 'government', "'s", 'monetary', 'policies', 'high', 'real', 'interest', 'rates', 'hampering', 'investment', 'told', 'news', 'conference', 'wage', 'pacts', 'signed', 'far', 'year', 'endangering', 'government', "'s", 'five', 'pct', 'inflation', 'target', 'government', "'s", 'perceived', 'need', 'control', 'inflation', 'keeping', 'tight', 'rein', 'credit', 'unnecessary', 'said', 'high', 'real', 'interest', 'rates', 'attracting', 'influx', 'speculative', 'foreign', 'capital', 'undercutting', 'government', "'s", 'target', 'monetary', 'growth', 'cuevas', 'said', 'spain', "'s", 'closely-watched', 'measure', 'money', 'supply', 'liquid', 'assets', 'public', 'hands', 'grew', 'annualised', 'rate', '17', 'pct', 'march', '11.4', 'pct', 'december', 'last', 'year', 'target', 'range', '6.5', '9.5', 'pct', '1987.', 'combat', 'bank', 'spain', 'raised', 'call', 'money', 'rate', '14', 'times', 'far', 'year', '14.5', 'pct', 'present', '11.8', 'end-1986', 'cuevas', 'said', 'employers', 'heeding', 'government', "'s", 'call', 'hold', 'wage', 'increases', 'five', 'pct', 'inflation', 'target', 'year', 'increases', 'salary', 'reviews', 'awarded', 'last', 'year', 'new', 'wage', 'pacts', 'averaging', '5.6', 'pct', 'first', 'quarter', '1987.', 'agreements', 'covered', 'less', '40', 'pct', 'spanish', 'workers', 'cuevas', 'said', 'rest', 'still', 'wage', 'negotiations', 'said', 'spain', "'s", 'current', 'wave', 'strikes', 'mainly', 'affected', 'state', 'sector', 'government', 'trying', 'impose', 'five', 'pct', 'wage', 'ceiling', 'cuevas', 'said', 'employers', 'also', 'worried', 'trend', 'spain', "'s", 'foreign', 'trade', 'balance', 'trade', 'deficit', 'first', 'two', 'months', '1987', 'totalled', '233', 'billion', 'pesetas', '68', 'pct', 'increase', 'corresponding', 'period', 'last', 'year', 'however', 'employers', 'favour', 'devaluation', 'peseta', 'correct', 'imbalance']
# ['treasury', "'s", 'baker', 'says', 'trade', 'current', 'account', 'imbalances', '``', 'simply', 'sustainable', "''", 'treasury', "'s", 'baker', 'says', 'trade', 'current', 'account', 'imbalances', '``', 'simply', 'sustainable', "''"]
# ['sprinkel', 'says', 'tax', 'hike', 'would', 'reduce', 'deficit', 'council', 'economic', 'advisers', 'chairman', 'beryl', 'sprinkel', 'said', 'reagan', 'administration', 'remains', 'strongly', 'opposed', 'tax', 'increase', 'including', '18', 'billion', 'dlrs', 'new', 'revenues', 'budget', 'plan', 'congressional', 'democrats', '``', 'believe', 'significant', 'increases', 'taxes', 'would', 'reduce', 'deficits', 'could', 'adverse', 'effects', 'growth', "''", 'sprinkel', 'told', 'house', 'rules', 'committee', 'said', 'administration', 'wanted', 'continue', 'policy', 'gradually', 'reducing', 'deficits', 'restraining', 'government', 'spending', 'promoting', 'economic', 'growth', 'sprinkel', 'said', 'cutting', 'budget', 'deficit', 'best', 'way', 'lower', 'trade', 'deficit']
# ['colombia', 'jan', 'exports', 'coffee', 'values', 'fall', 'value', 'colombian', 'exports', 'coffee', 'rose', '55', 'pct', 'january', 'compared', 'period', 'last', 'year', 'apparently', 'setting', 'trend', 'trade', 'balance', '1987', 'government', 'statistics', 'institute', 'figures', 'show', 'amounted', '180.8', 'mln', 'dlrs', 'fob', 'compared', '147.5', 'mln', 'dlrs', 'coffee', 'drop', '42', 'pct', 'last', 'year', 'trade', 'balance', 'registered', '35', 'mln', 'dlr', 'surplus', 'compared', '56', 'mln', 'dlr', 'surplus', 'january', '1986.', 'national', 'planning', 'department', 'forecast', '1987', 'coffee', 'colombia', "'s", 'traditional', 'major', 'export', 'account', 'one-third', 'total', 'exports', '1.5', 'billion', 'dlrs']
# ['exports', 'coffee', 'rise', 'sharply', 'colombia', 'colombian', 'exports', 'coffee', 'rose', '55', 'pct', 'january', 'compared', 'period', 'last', 'year', 'figures', 'government', 'statistics', 'institute', 'show', 'non-coffee', 'exports', 'amounted', '180.8', 'mln', 'dlrs', 'fob', 'compared', '147.5', 'mln', 'dlrs', 'coffee', 'drop', '42', 'pct', 'last', 'year', 'trade', 'balance', 'registered', '35', 'mln', 'dlr', 'surplus', 'compared', '56', 'mln', 'dlr', 'surplus', 'january', '1986.', 'national', 'planning', 'department', 'forecast', '1987', 'coffee', 'colombia', "'s", 'traditional', 'major', 'export', 'account', 'one', 'third', 'total', 'exports', '1.5', 'billion', 'dlrs']
# ['canada', 'trade', 'rise', 'seen', 'start', 'recovery', 'canada', "'s", 'trade', 'picture', 'brightened', 'considerably', 'underscoring', 'economists', 'predictions', 'sector', 'would', 'post', 'long', 'awaited', 'recovery', 'year', 'federal', 'government', 'reported', 'today', 'monthly', 'surplus', 'soared', '1.25', 'billion', 'canadian', 'dlrs', 'february', 'double', 'january', "'s", '623', 'mln', 'dlrs', 'surplus', 'sharply', 'higher', 'february', '1986', "'s", '189', 'mln', 'dlr', 'tally', '``', 'hopefully', "'s", 'beginning', 'trend', "''", 'said', 'richardson', 'greenshields', 'canada', 'ltd', 'economist', 'susan', 'clark', 'toronto', 'economists', 'generally', "n't", 'expect', 'large', 'gains', 'next', 'months', 'looking', 'upward', 'trend', 'throughout', 'year', '``', 'thought', 'trade', 'balance', 'would', 'improve', '...', 'year', 'certainly', 'looks', 'morning', "'s", 'figure', 'indicative', "''", 'commented', 'economist', 'james', 'donegan', 'toronto', 'securities', 'firm', 'midland', 'doherty', 'ltd.', 'statistics', 'canada', 'reported', 'surplus', 'driven', '23', 'pct', 'gain', 'automobile', 'product', 'exports', 'record', '3.2', 'billion', 'dls', 'month', '``', 'recovery', 'automotive', 'sector', 'helped', 'push', 'value', 'exports', '5.9', 'pct', 'february', "''", 'agency', 'said', 'monthly', 'report', 'total', 'exports', 'expanded', '10.44', 'billion', 'dlrs', '9.85', 'billion', 'dlrs', 'february', 'imports', 'slipped', '9.19', 'billion', 'dlrs', '9.23', 'billion', 'dlrs', 'economists', 'predicted', '1987', 'trade', 'surplus', 'would', 'end', 'three', 'five', 'billion', 'dlrs', 'higher', 'last', 'year', "'s", 'dismal', '10.1', 'billion', 'dlr', 'total', '1985', 'surplus', '17.48', 'billion', 'dlrs', 'money', 'market', 'analysts', 'said', 'positive', 'trade', 'news', 'touched', 'modest', 'rally', 'canadian', 'dollar', 'rose', '76.85', 'u.s.', 'cts', 'north', 'american', 'markets', 'early', 'morning', 'closing', '76.58', 'cts', 'wednesday', 'currency', 'hovering', 'around', '76.78', 'cts', 'early', 'afternoon', 'trading', 'economists', 'banking', 'improved', 'trade', 'performance', 'year', 'stimulate', 'otherwise', 'sluggish', 'canadian', 'economy', 'money', 'market', 'analysts', 'said', 'positive', 'trade', 'news', 'touched', 'modest', 'rally', 'canadian', 'dollar', 'rose', '76.85', 'u.s.', 'cts', 'north', 'american', 'markets', 'early', 'morning', 'closing', '76.58', 'cts', 'wednesday', 'currency', 'hovering', 'around', '76.78', 'cts', 'early', 'afternoon', 'trading', 'economists', 'banking', 'improved', 'trade', 'performance', 'year', 'stimulate', 'otherwise', 'sluggish', 'canadian', 'economy', 'say', 'country', "'s", 'consumers', 'spending', 'torrid', 'pace', 'recent', 'years', 'sharply', 'curtail', 'outlays', 'year', 'help', 'curtail', 'flow', 'imports', 'country', 'meanwhile', 'demand', 'canadian', 'exports', 'united', 'states', 'far', 'country', "'s", 'largest', 'market', 'expected', 'strong', 'result', 'projected', 'rise', 'american', 'consumer', 'spending', 'relatively', 'low', 'value', 'canadian', 'currency', '``', 'maintain', "'s", 'going', 'drive', 'canada', "'s", 'export', 'performance', 'income', 'growth', 'u.s.', "''", 'said', 'midland', "'s", 'donegan', 'bank', 'nova', 'scotia', 'deputy', 'chief', 'economist', 'warren', 'jestin', 'less', 'optimistic', 'u.s.', 'outlook', 'said', 'could', 'mistake', 'read', 'much', 'february', "'s", 'trade', 'upturn', 'jestin', 'said', '``', 'given', 'fact', 'u.s.', 'economy', 'showing', 'signs', 'weakening', '--', 'particularly', 'car', 'sales', '--', 'would', 'indicate', 'part', 'strength', 'canada', "'s", 'trade', 'figures', 'probably', 'transitory', "''"]
# ['chilean', 'trade', 'surplus', 'narrows', 'slightly', 'february', 'chile', "'s", 'trade', 'surplus', 'narrowed', '102.2', 'mln', 'dlrs', 'february', '105.4', 'mln', 'dlrs', 'month', 'last', 'year', '18.2-mln-dlr', 'surplus', 'recorded', 'january', '1987', 'central', 'bank', 'said', 'exports', 'february', 'totalled', '379.4', 'mln', 'dlrs', '17.2', 'pct', 'january', 'figure', 'imports', 'fell', '9.2', 'pct', 'previous', 'month', '277.2', 'mln', 'dlrs', 'figures', 'month', 'last', 'year', '314', 'mln', '208.6', 'mln', 'dlrs', 'respectively', 'accumulated', 'trade', 'surplus', 'first', 'two', 'months', '1987', 'stands', '120.4', 'mln', 'dlrs', '132.8', 'mln', 'dlrs', 'previous', 'year']
# ['japan', 'warns', 'u.s.', 'may', 'retaliate', 'trade', 'dispute', 'japan', 'warned', 'united', 'states', 'may', 'take', 'retaliatory', 'measures', 'united', 'states', 'imposes', 'planned', 'trade', 'sanctions', 'april', '17', 'senior', 'government', 'official', 'said', 'shinji', 'fukukawa', 'vice', 'minister', 'international', 'trade', 'industry', 'ministry', 'said', 'statement', 'japan', 'would', 'consider', 'measures', 'general', 'agreement', 'tariffs', 'trade', 'actions', 'united', 'states', 'imposes', '100', 'pct', 'tariffs', 'japanese', 'exports', 'planned', 'next', 'week', 'however', 'fukukawa', 'said', 'japan', 'ready', 'continue', 'trade', 'talks', 'united', 'states', 'despite', 'failure', 'convince', 'america', 'call', 'threatened', 'tariffs', 'two', 'days', 'emergency', 'talks', 'ended', 'washington', 'yesterday', 'last', 'month', 'president', 'reagan', 'announced', 'sanctions', 'retaliation', 'called', 'japan', "'s", 'failure', 'honour', 'july', '1986', 'agreement', 'stop', 'dumping', 'computer', 'microchips', 'markets', 'outside', 'united', 'states', 'open', 'home', 'market', 'american', 'goods', 'fukukawa', 'said', 'united', 'states', 'regrettably', 'listened', 'japan', "'s", 'explanation', 'efforts', 'live', 'pact', 'said', 'washington', 'given', 'detailed', 'explanation', 'planned', 'impose', 'tariffs']
# ...
# ['baker', 'sees', '15', '20', 'billion', 'dlr', 'drop', 'trade', 'gap', 'treasury', 'secretary', 'james', 'baker', 'said', 'expected', 'u.s.', 'trade', 'deficit', 'fall', '15', 'billion', '20', 'billion', 'dlrs', '1987.', 'commenting', 'deficit', 'interview', 'cable', 'news', 'network', 'baker', 'said', '``', 'think', "'re", 'going', 'see', '15', '20', 'billion', 'dlr', 'reduction', 'year', "''", 'deficit', '170', 'billion', 'dlrs', '1986.', 'baker', 'noted', 'benefits', 'weaker', 'currency', 'take', '12', '18', 'months', 'affect', 'trade', 'balance', 'said', '18', 'months', 'since', 'plaza', 'agreement', 'lower', 'dollar', "'s", 'value']
# ['u.k.', 'visible', 'trade', 'deficit', 'narrows', 'february', 'britain', "'s", 'visible', 'trade', 'deficit', 'narrowed', 'seasonally', 'adjusted', 'provisional', '224', 'mln', 'stg', 'february', '527', 'mln', 'january', 'trade', 'industry', 'department', 'said', 'current', 'account', 'balance', 'payments', 'february', 'showed', 'seasonally', 'adjusted', 'provisional', 'surplus', '376', 'mln', 'stg', 'compared', 'surplus', '73', 'mln', 'january', 'invisibles', 'february', 'put', 'provisionally', '600', 'mln', 'surplus', 'january', 'seasonally', 'adjusted', 'imports', 'rose', 'february', '7.16', 'billion', 'stg', '6.73', 'billion', 'january', 'exports', 'rose', 'record', '6.93', 'billion', 'last', 'month', '6.20', 'billion', 'january', 'trade', 'department', 'officials', 'said', 'improvement', 'britain', "'s", 'current', 'account', 'contrasted', 'private', 'forecasts', 'attributed', 'much', 'strength', 'imports', 'rising', 'less', 'quickly', 'february', 'might', 'otherwise', 'expected', 'department', 'said', 'exceptionally', 'cold', 'weather', 'january', 'reduced', 'exports', 'month', 'element', 'catching', 'february', 'figures', 'seasonally', 'adjusted', 'volume', 'index', 'base', '1980', 'guide', 'underlying', 'non-oil', 'trade', 'showed', 'exports', 'rising', '131.0', '114.6', 'january', 'imports', 'rising', '142.2', '136.5.', 'value', 'british', 'oil', 'exports', 'february', 'rose', '751', 'mln', 'stg', '723', 'mln', 'jnauary', 'oil', 'imports', 'rose', '425', 'mln', '352', 'mln']
# ['hong', 'kong', 'february', 'trade', 'swings', 'deficit', 'hong', 'kong', 'recorded', '3.51', 'billion', 'h.k', 'dlr', 'deficit', 'february', '2.54', 'billion', 'dlr', 'surplus', 'january', 'imports', 'climbed', 'exports', 'slid', 'census', 'statistics', 'department', 'said', 'deficit', 'compared', 'deficit', '1.76', 'billion', 'dlrs', 'february', '1986.', 'imports', 'rose', '24.12', 'billion', 'dlrs', '2.6', 'pct', 'january', "'s", '23.52', 'billion', 'dlrs', '42', 'pct', '16.98', 'billion', 'dlrs', 'recorded', 'february', '1986.', 'total', 'exports', 'month', 'fell', '20.9', 'pct', '20.61', 'billion', 'dlrs', '26.06', 'billion', 'january', 'february', 'exports', 'still', '35.4', 'pct', '15.22', 'billion', 'dlrs', 'recorded', 'month', 'last', 'year', 're-exports', 'territory', "'s", 'traditional', 'entrepot', 'trade', 'outpaced', 'domestically', 'produced', 'exports', 'first', 'time', 'since', 'march', '1985.', 're-exports', 'fell', '11.6', 'pct', '10.62', 'billion', 'dlrs', '12.0', 'billion', 'dlrs', 'january', '54', 'pct', 'february', '1986', "'s", '6.88', 'billion', 'dlrs', 'domestic', 'exports', 'slid', '28.9', 'pct', '9.99', 'billion', 'dlrs', 'january', "'s", '14.05', 'billion', 'dlrs', '19.7', 'pct', '8.35', 'billion', 'dlrs', 'recorded', 'february', '1986']
# ['british', 'politicians', 'urge', 'japan', 'trade', 'sanctions', 'one', 'hundred', 'members', 'britain', "'s", 'ruling', 'conservative', 'party', 'signed', 'motion', 'calling', 'trade', 'sanctions', 'japan', 'force', 'tokyo', 'open', 'domestic', 'market', 'british', 'goods', 'government', 'announced', 'last', 'week', 'japan', '5.9', 'billion', 'dlr', 'trade', 'surplus', 'britain', '1986.', 'department', 'trade', 'industry', 'said', 'government', 'drawing', 'contingency', 'plans', 'force', 'japan', 'opening', 'domestic', 'markets', 'spokesman', 'said', 'moves', 'much', 'last', 'resort', 'ideas', 'considered', 'included', 'blocking', 'japanese', 'companies', 'trading', 'britain', 'revoking', 'licenses', 'japanese', 'operations', 'london', 'financial', 'district']
# ['u.k.', 'trade', 'figures', 'buoy', 'hopes', 'interest', 'rate', 'cut', 'release', 'u.k.', 'february', 'trade', 'data', 'showing', 'current', 'account', 'surplus', 'provisional', '376', 'mln', 'stg', '73', 'mln', 'surplus', 'january', 'boosted', 'hopes', 'early', 'cut', 'interest', 'rates', 'analysts', 'said', 'market', 'forecasts', 'worse', 'outcome', 'expectations', 'deficit', 'visible', 'trade', 'averaging', '750', 'mln', 'stg', 'official', 'figure', '224', 'mln', 'stg', 'sharply', 'narrower', 'january', "'s", '527', 'mln', 'deficit', '``', 'figures', 'unreservedly', 'good', "''", 'chase', 'manhattan', 'securities', 'economist', 'andrew', 'wroblewski', 'said', 'sterling', 'rebounded', 'trade', 'figures', 'reversing', 'weaker', 'morning', 'trend', 'stand', '72.1', 'pct', 'trade', 'weighted', 'index', 'basket', 'currencies', 'midday', 'unchanged', 'yesterday', "'s", 'close', '0.3', 'points', '1100', 'gmt', 'level', 'market', 'feared', 'deteriorating', 'non-oil', 'trade', 'pattern', 'would', 'undermine', 'international', 'support', 'sterling', 'motor', 'behind', 'recent', 'fall', 'u.k.', 'interest', 'rates', 'money', 'market', 'sources', 'said', 'market', 'begun', 'doubt', 'widely', 'expected', 'drop', 'bank', 'base', 'lending', 'rates', '9.5', 'pct', 'present', '10.0', 'pct', 'really', 'cards', 'sentiment', 'looks', 'turned', 'looks', 'danger', 'chancellor', 'exchequer', 'nigel', 'lawson', "'s", 'forecast', '1987', 'current', 'account', 'deficit', '2.5', 'billion', 'stg', 'exceeded', 'said', 'wroblewski', 'seasonally', 'adjusted', 'figures', 'showed', 'imports', 'rose', 'february', '7.16', 'billion', 'stg', '6.73', 'billion', 'january', 'exports', 'rose', 'record', '6.93', 'billion', '6.20', 'billion', 'however', 'chris', 'tinker', 'u.k.', 'analyst', 'brokers', 'phillips', 'drew', 'said', 'faster', 'rise', 'exports', 'imports', 'would', 'prove', 'partly', 'aberrational', 'coming', 'months', 'forecast', 'chancellor', "'s", 'budget', 'tax', 'cuts', 'would', 'increase', 'consumer', 'expediture', 'imported', 'goods', 'however', 'ian', 'harwood', 'economist', 'warburg', 'securities', 'said', 'firm', 'sharply', 'revising', '1987', 'current', 'account', 'deficit', 'forecast', 'light', 'latest', 'data', 'cutting', 'one', 'billion', 'stg', 'expected', 'full', 'year', 'total', '1.75', 'billion', 'stg', 'said', 'news', 'strong', 'growth', 'exports', 'non-oil', 'goods', 'confirmed', 'recent', 'bullish', 'surveys', 'among', 'members', 'confederation', 'british', 'industry', 'growth', 'imports', 'appears', 'flattening', 'even', 'january', "'s", 'bad', 'weather', 'curbed', 'consumer', 'spending', 'overseas', 'goods', 'import-intensive', 'stock', 'building', 'among', 'manufactureres', 'harwood', 'said', 'u.k.', 'government', 'bonds', 'gilts', 'surged', '1/2', 'point', 'better-than-expected', 'news', 'earlier', 'worries', 'figures', 'evaporated', 'sterling', 'peaked', 'high', '1.6075', 'dlrs', 'settling', 'steady', '1.6050', 'dlrs', '1300', 'gmt', 'nearly', 'cent', 'higher', 'european', 'low', '1.5960.', 'however', 'analysts', 'noted', 'turnabout', 'market', 'sentiment', 'still', 'looks', 'highly', 'vulnerable', 'political', 'news', 'morning', 'weakness', 'sterling', 'gilt', 'market', 'largely', 'attributed', 'newspaper', 'opinion', 'poll', 'showing', 'conservative', 'government', "'s", 'support', 'slipping', 'marplan', 'poll', 'published', '``', 'today', "''", 'showed', 'conservative', 'support', 'fallen', '36', 'pct', '38', 'pct', 'last', 'month', 'alliance', 'liberals', 'social', 'democrats', 'rallied', '31', 'pct', '21', 'pct', 'run', 'neck', 'neck', 'labour', 'party', 'whose', 'support', 'fell', '38', 'pct', 'poll', 'taken', 'budget', 'greeted', 'enthusiastically', 'financial', 'markets', 'seems', 'left', 'voters', 'indifferent', 'political', 'observers', 'said', 'another', 'regular', 'poll', 'due', 'tomorrow', 'eonomists', 'warn', 'today', "'s", 'improved', 'sentiment', 'could', 'dented', 'support', 'prime', 'minister', 'margaret', 'th ...
# ['s.', 'korea', 'may', 'buy', 'u.s.', 'oil', 'aid', 'trade', 'balance', 'south', 'korea', 'studying', 'plan', 'buy', 'coal', 'united', 'states', 'start', 'importing', 'alaskan', 'crude', 'oil', 'help', 'reduce', 'huge', 'trade', 'surplus', 'united', 'states', 'energy', 'ministry', 'officials', 'said', 'today', 'said', 'plan', 'would', 'dominate', 'discussions', 'two-day', 'energy', 'talks', 'officials', 'two', 'countries', 'washington', 'april', '1.', 'huh', 'sun-yong', 'attend', 'talks', 'three', 'seoul', 'government', 'officials', 'told', 'reuters', 'seoul', '``', 'positively', 'considering', 'buying', 'certain', 'amount', 'alaskan', 'oil', 'beginning', 'year', 'part', 'government', "'s", 'overall', 'plan', 'reduce', 'widening', 'trade', 'gap', 'two', 'countries', "''", 'huh', 'said', 'however', 'south', 'korean', 'refineries', 'considered', 'alaskan', 'oil', 'economically', 'uncompetitive']
# ['u.s', 'treasury', "'s", 'mulford', 'reaffirms', 'g-6', 'agreement', 'treasury', 'assistant', 'secretary', 'david', 'mulford', 'reaffirmed', 'u.s.', 'backing', 'paris', 'agreement', 'among', 'six', 'industrial', 'nations', 'cooperate', 'closely', 'foster', 'exchange', 'rate', 'stability', 'around', 'current', 'levels', 'testimony', 'prepared', 'delivery', 'senate', 'banking', 'subcommittee', 'mulford', 'said', 'broad', 'recognition', 'paris', '``', 'substantial', 'exchange', 'rate', 'shifts', 'could', 'damage', 'growth', 'adjustment', 'prospects', "''", 'also', 'said', 'clear', 'understandings', 'among', 'countries', 'regarding', 'cooperation', '``', 'refrained', 'establishing', 'system', 'target', 'zones', 'ranges', "''", 'mulford', 'also', 'said', 'six', 'nations', 'spelled', 'way', 'intend', 'deal', 'possible', 'market', 'developments', 'said', 'governments', 'must', 'retain', 'flexibility', 'dealing', 'exchange', 'market', 'pressures', 'efforts', 'establish', 'rigid', 'exchange', 'rate', 'objectives', '``', 'specify', 'precisely', 'goals', 'intervention', "''", 'would', 'hurt', 'official', 'attempts', 'react', 'market', 'pressures', 'said', 'accordingly', 'mulford', 'said', 'setting', 'specific', 'currency', 'objectives', 'intervention', 'achieve', 'objectives', 'would', 'counterproductive', 'commenting', 'trade', 'deficit', 'mulford', 'reiterated', 'treasury', 'position', 'current', 'account', 'deficit', 'decline', '148', 'billion', 'dlrs', 'last', 'year', 'around', '130', 'billion', 'dlrs', 'year', 'due', 'exchange', 'rate', 'adjustments', 'past', '18', 'months', 'added', 'trade', 'imbalances', 'would', 'also', 'corrected', 'commitments', 'west', 'germany', 'japan', 'stimulate', 'economies', 'u.s.', 'efforts', 'cut', 'budget', 'deficit', 'enhance', 'u.s.', 'competitiveness', 'also', 'said', 'newly', 'industrialized', 'countries', 'let', 'currencies', 'appreciate']
# ['keating', 'revises', 'australian', 'growth', 'forecast', 'treasurer', 'paul', 'keating', 'forecast', 'economic', 'growth', 'slightly', 'two', 'pct', 'financial', 'year', 'ending', 'june', 'year', '2.25', 'pct', 'forecast', 'contained', '1986/87', 'budget', 'delivered', 'last', 'august', 'australia', "'s", 'terms', 'trade', 'also', 'fell', '18', 'pct', 'past', 'two', 'years', 'told', 'parliament', 'terms', 'trade', 'difference', 'import', 'export', 'price', 'indexes', 'despite', 'figures', 'budget', 'forecast', '1.75', 'pct', 'annual', 'growth', 'employment', 'would', 'met', 'keating', 'said', 'unemployment', 'currently', '8.2', 'pct', 'workforce', '``', 'government', 'dragging', 'australia', 'trading', 'holocaust', 'kind', 'seen', 'since', 'second', 'world', 'war', "''", 'keating', 'said', '``', 'pushing', 'place', 'recession', 'holding', 'gains', 'unemployment', 'bringing', 'unemployment', "''", 'said', 'adding', 'government', 'help', 'country', 'avoid', 'recession']
# ['u.s.', 'asks', 'japan', 'end', 'agriculture', 'import', 'controls', 'u.s.', 'wants', 'japan', 'eliminate', 'import', 'controls', 'agricultural', 'products', 'within', 'three', 'years', 'visiting', 'u.s.', 'under-secretary', 'state', 'economic', 'affairs', 'allen', 'wallis', 'told', 'eishiro', 'saito', 'chairman', 'federation', 'economic', 'organisations', 'keidanren', 'spokesman', 'keidanren', 'said', 'spokesman', 'quoted', 'wallis', 'saying', 'drastic', 'measures', 'would', 'needed', 'stave', 'protectionist', 'legislation', 'congress', 'wallis', 'attending', 'sub-cabinet-level', 'bilateral', 'trade', 'meeting', 'made', 'remark', 'yesterday', 'talks', 'saito', 'wallis', 'quoted', 'saying', 'reagan', 'administration', 'wants', 'japanese', 'cooperation', 'white', 'house', 'ensure', 'u.s.', 'trade', 'bill', 'moderate', 'one', 'rather', 'containing', 'retaliatory', 'measures', 'antagonising', 'particular', 'country', 'also', 'quoted', 'saying', 'u.s.', 'would', 'pleased', 'japan', 'halve', 'restrictions', 'agricultural', 'imports', 'within', 'five', 'years', 'country', 'cope', 'abolition', 'within', 'three', 'spokesman', 'said', 'japan', 'currently', 'restricts', 'imports', '22', 'agricultural', 'products', 'ban', 'rice', 'imports', 'triggered', 'recent', 'u.s.', 'complaints', 'japan', "'s", 'agricultural', 'policy']
# ['mulford', 'says', 'germany', 'japan', 'treasury', 'assistant', 'secretary', 'david', 'mulford', 'said', 'believe', 'west', 'germany', 'japan', 'yet', 'carried', 'international', 'responsibilities', '``', 'believe', 'time', "''", 'mulford', 'told', 'senate', 'banking', 'subcommittee', 'said', 'u.s.', 'trade', 'deficit', 'continue', 'improving', 'next', 'two', 'years', '``', 'need', 'policy', 'actions', "''", 'across', 'entire', 'front', 'u.s.', 'trade', 'relations', 'including', 'canada', 'newly-industrialized', 'countries', 'nics', 'particular', 'said', 'efforts', 'south', 'korea', 'taiwan', 'strengthen', 'currencies', 'still', 'disappointing', 'mulford', 'also', 'said', 'oecd', 'nations', 'need', 'grow', 'average', 'three', 'pct', 'help', 'resolve', 'international', 'debt', 'crisis', 'noted', 'japanese', 'european', 'imports', 'latin', 'nations', 'significantly', 'smaller', 'imports', 'u.s.', 'stressed', 'germany', 'japan', 'must', 'continue', 'take', 'economic', 'structural', 'measures', 'ensure', 'stronger', 'sustained', 'economic', 'growth']
# 117370

# %%
import numpy as np

def random_batch(batch_size, word_sequence, window_size=2):
    skip_grams = []
    # get skip-grams with the specified window size
    for sent in word_sequence:
        for i in range(len(sent)):
            target = word2index[sent[i]]
            
            # get the context words within the window size
            start = max(0, i - window_size)
            end = min(len(sent), i + window_size + 1)
            context = [word2index[sent[j]] for j in range(start, end) if j != i]
            for w in context:
                skip_grams.append([target, w])
    
    # print("Skipgrams:")
    # for skip in skip_grams:
    #     print(skip)
    
    # select random skip-grams for the batch
    random_inputs = []
    random_labels = []
    random_index = np.random.choice(range(len(skip_grams)), batch_size, replace=False)
        
    for i in random_index:
        random_inputs.append([skip_grams[i][0]])  # target word
        random_labels.append([skip_grams[i][1]])  # context word
            
    return np.array(random_inputs), np.array(random_labels)

# %% [markdown]
# ### Testing the method

# %%
batch_size = 2
input_batch, target_batch = random_batch(batch_size=batch_size, word_sequence=preprocessed_docs, window_size=2)

# %%
target_batch
# Out:
# array([[7498],
#        [5075]])

# %%
input_batch
# Out:
# array([[2512],
#        [4861]])

# %% [markdown]
# ## Negative Sampling

# %%
from collections import Counter

word_count = Counter(flatten(preprocessed_docs))
num_total_words = sum([c for w, c in word_count.items()])

# %%
word_count[','], word_count["."]
# Out:
# (0, 0)

# %%
num_total_words
# Out:
# 78611

# %%
Z = 0.001
unigram_table = []

for vo in vocab:
    unigram_table.extend([vo] * int(((word_count[vo] / num_total_words) ** 0.75) / Z))

# %%
Counter(unigram_table)
# Out:
# Counter({'said': 67,
#          'trade': 64,
#          'u.s.': 46,
#          'billion': 40,
#          "'s": 38,
#          '``': 37,
#          "''": 36,
#          'japan': 31,
#          'dlrs': 28,
#          'would': 26,
#          'year': 25,
#          'pct': 23,
#          'mln': 22,
#          'deficit': 22,
#          'surplus': 20,
#          'exports': 19,
#          'last': 19,
#          'japanese': 19,
#          'imports': 17,
#          'foreign': 16,
#          'countries': 16,
#          'ec': 15,
#          'states': 14,
#          'government': 14,
#          'february': 14,
#          'united': 13,
#          'officials': 13,
#          'economic': 13,
#          'january': 13,
#          'market': 13,
#          'also': 13,
#          'told': 13,
#          'world': 12,
#          'tariffs': 12,
#          'gatt': 12,
#          'new': 12,
#          'agreement': 12,
#          'two': 11,
#          '1986': 11,
#          'goods': 11,
#          'dollar': 11,
#          'reagan': 11,
#          'current': 10,
#          'washington': 10,
#          'could': 10,
#          'minister': 10,
#          'official': 10,
#          'markets': 10,
#          'products': 9,
#          'export': 9,
#          'bank': 9,
#          'bill': 9,
#          'domestic': 9,
#          'house': 9,
#          'one': 9,
#          'industry': 9,
#          'talks': 9,
#          'account': 9,
#          'growth': 9,
#          'added': 9,
#          'yeutter': 8,
#          'economy': 8,
#          'rose': 8,
#          'quarter': 8,
#          'first': 8,
#          'ministry': 8,
#          'take': 8,
#          'major': 8,
#          'cut': 8,
#          'figures': 8,
#          'meeting': 8,
#          'taiwan': 8,
#          'international': 8,
#          'import': 8,
#          'south': 8,
#          'action': 7,
#          'korea': 7,
#          'congress': 7,
#          'week': 7,
#          'trading': 7,
#          'april': 7,
#          'dlr': 7,
#          'debt': 7,
#          'policy': 7,
#          'prices': 7,
#          '1987': 7,
#          'years': 7,
#          'european': 7,
#          'open': 7,
#          'president': 7,
#          'next': 7,
#          'canada': 7,
#          'nations': 7,
#          'expected': 7,
#          'exchange': 7,
#          'months': 6,
#          'department': 6,
#          'production': 6,
#          'may': 6,
#          'today': 6,
#          'tokyo': 6,
#          'fell': 6,
#          'ministers': 6,
#          'rise': 6,
#          'retaliation': 6,
#          'legislation': 6,
#          'help': 6,
#          'made': 6,
#          'reduce': 6,
#          'budget': 6,
#          'farm': 6,
#          'plan': 6,
#          'general': 6,
#          'community': 6,
#          'increase': 6,
#          'pact': 6,
#          'demand': 6,
#          'committee': 6,
#          'compared': 6,
#          'sanctions': 6,
#          'earlier': 6,
#          'west': 6,
#          'balance': 6,
#          'semiconductor': 6,
#          'american': 6,
#          'month': 6,
#          'rate': 6,
#          'country': 6,
#          'commerce': 5,
#          'administration': 5,
#          'much': 5,
#          'dispute': 5,
#          'oil': 5,
#          'firms': 5,
#          'semiconductors': 5,
#          'analysts': 5,
#          '--': 5,
#          'period': 5,
#          'yen': 5,
#          'three': 5,
#          'agreed': 5,
#          '1986.': 5,
#          'report': 5,
#          'lower': 5,
#          'china': 5,
#          'march': 5,
#          'however': 5,
#          'make': 5,
#          'secretary': 5,
#          'way': 5,
#          'currency': 5,
#          'measures': 5,
#          'must': 5,
#          'payments': 5,
#          '1985': 5,
#          'value': 5,
#          'five': 5,
#          'round': 5,
#          'negotiations': 5,
#          'nakasone': 5,
#          'says': 5,
#          'sources': 5,
#          'record': 5,
#          'end': 5,
#          'agriculture': 5,
#          'industrial': 5,
#          'time': 5,
#          'agricultural': 5,
#          'need': 5,
#          'canadian': 5,
#          'rates': 5,
#          'senate': 5,
#          'practices': 4,
#          'fall': 4,
#          'including': 4,
#          'companies': 4,
#          'britain': 4,
#          'full': 4,
#          'issue': 4,
#          'reporters': 4,
#          'europe': 4,
#          'system': 4,
#          'national': 4,
#          'decline': 4,
#          'interest': 4,
#          'pressure': 4,
#          'december': 4,
#          'commission': 4,
#          'relations': 4,
#          'baker': 4,
#          'subsidies': 4,
#          'september': 4,
#          'cuts': 4,
#          'high': 4,
#          'impose': 4,
#          'prime': 4,
#          'set': 4,
#          'war': 4,
#          'tax': 4,
#          'spokesman': 4,
#          'representative': 4,
#          'reuters': 4,
#          'brazil': 4,
#          'called': 4,
#          'whether': 4,
#          'continue': 4,
#          'around': 4,
#          '10': 4,
#          "n't": 4,
#          'policies': 4,
#          'growing': 4,
#          'services': 4,
#          'treasury': 4,
#          'baldrige': 4,
#          'say': 4,
#          'issues': 4,
#          'unfair': 4,
#          'likely': 4,
#          'large': 4,
#          'bilateral': 4,
#          'drop': 4,
#          'part': 4,
#          'political': 4,
#          'finance': 4,
#          'key': 4,
#          'visit': 4,
#          'protectionist': 4,
#          'total': 4,
#          'forecast': 4,
#          'senior': 4,
#          'federal': 4,
#          'asked': 4,
#          'council': 4,
#          'third': 4,
#          'see': 4,
#          'volcker': 4,
#          'statistics': 4,
#          'barriers': 4,
#          'soviet': 4,
#          'investment': 4,
#          'chairman': 4,
#          'problem': 4,
#          'chip': 4,
#          'chips': 4,
#          'terms': 4,
#          'plans': 4,
#          'recent': 4,
#          'financial': 4,
#          'well': 4,
#          'think': 4,
#          'developing': 4,
#          'free': 4,
#          'germany': 4,
#          'partners': 4,
#          'efforts': 4,
#          'still': 4,
#          'problems': 4,
#          'group': 4,
#          'show': 4,
#          'development': 4,
#          'announced': 4,
#          'statement': 4,
#          'state': 4,
#          'since': 4,
#          'miti': 4,
#          'due': 4,
#          'paris': 3,
#          'marks': 3,
#          'quotas': 3,
#          'noted': 3,
#          'long': 3,
#          'yesterday': 3,
#          'rules': 3,
#          'failure': 3,
#          'reform': 3,
#          'industries': 3,
#          'german': 3,
#          'uruguay': 3,
#          'like': 3,
#          'strong': 3,
#          'means': 3,
#          'price': 3,
#          'increased': 3,
#          'currencies': 3,
#          'boost': 3,
#          'union': 3,
#          'adjusted': 3,
#          'july': 3,
#          'effort': 3,
#          'makers': 3,
#          'news': 3,
#          'beef': 3,
#          'largest': 3,
#          'effect': 3,
#          'central': 3,
#          'showed': 3,
#          'economists': 3,
#          'little': 3,
#          'less': 3,
#          'british': 3,
#          'decision': 3,
#          'computer': 3,
#          'capital': 3,
#          '1985.': 3,
#          'six': 3,
#          'rising': 3,
#          'french': 3,
#          'work': 3,
#          'tariff': 3,
#          'conference': 3,
#          'move': 3,
#          'progress': 3,
#          'moves': 3,
#          'might': 3,
#          'spending': 3,
#          'subcommittee': 3,
#          '...': 3,
#          'india': 3,
#          'want': 3,
#          'white': 3,
#          '300': 3,
#          'higher': 3,
#          'surpluses': 3,
#          'output': 3,
#          'fourth': 3,
#          'wants': 3,
#          'clayton': 3,
#          'within': 3,
#          'needed': 3,
#          'go': 3,
#          'consumer': 3,
#          'buy': 3,
#          'james': 3,
#          'support': 3,
#          'among': 3,
#          'stg': 3,
#          'inflation': 3,
#          'figure': 3,
#          'product': 3,
#          'revised': 3,
#          'laws': 3,
#          'another': 3,
#          'sees': 3,
#          'important': 3,
#          'come': 3,
#          'deal': 3,
#          'stop': 3,
#          'protectionism': 3,
#          'lyng': 3,
#          'give': 3,
#          'later': 3,
#          'certain': 3,
#          'worth': 3,
#          'data': 3,
#          'retaliate': 3,
#          'many': 3,
#          'de': 3,
#          'u.k.': 3,
#          'electronic': 3,
#          'access': 3,
#          'ago': 3,
#          'going': 3,
#          'good': 3,
#          'possible': 3,
#          'private': 3,
#          'even': 3,
#          'textile': 3,
#          'africa': 3,
#          'reduction': 3,
#          '1988': 3,
#          'cost': 3,
#          'proposal': 3,
#          'sales': 3,
#          'business': 3,
#          '20': 3,
#          'already': 3,
#          'early': 3,
#          'level': 3,
#          'four': 3,
#          'hit': 3,
#          'fiscal': 3,
#          'get': 3,
#          'october': 3,
#          'dumping': 3,
#          'imposed': 3,
#          'monetary': 3,
#          'oecd': 3,
#          'restrictions': 3,
#          'remain': 3,
#          'western': 3,
#          'ways': 3,
#          'include': 3,
#          'accord': 3,
#          'mainly': 2,
#          'according': 2,
#          'member': 2,
#          'exporters': 2,
#          'areas': 2,
#          'telecommunications': 2,
#          'avoid': 2,
#          'warned': 2,
#          'enough': 2,
#          '50': 2,
#          'ended': 2,
#          "'re": 2,
#          'adding': 2,
#          'target': 2,
#          'office': 2,
#          'force': 2,
#          'director': 2,
#          'concerned': 2,
#          'equipment': 2,
#          'average': 2,
#          'african': 2,
#          'levels': 2,
#          'friday': 2,
#          'overall': 2,
#          'program': 2,
#          'huge': 2,
#          'power': 2,
#          'carney': 2,
#          'least': 2,
#          'late': 2,
#          'real': 2,
#          'clear': 2,
#          'members': 2,
#          'included': 2,
#          'chief': 2,
#          'sector': 2,
#          'consider': 2,
#          'banking': 2,
#          'stock': 2,
#          'producers': 2,
#          'yasuhiro': 2,
#          'economies': 2,
#          'improvement': 2,
#          'credits': 2,
#          'loans': 2,
#          'close': 2,
#          'recently': 2,
#          '18': 2,
#          'taking': 2,
#          'rha': 2,
#          'service': 2,
#          'threatened': 2,
#          'calls': 2,
#          'duties': 2,
#          'money': 2,
#          'controls': 2,
#          'businessmen': 2,
#          'source': 2,
#          'unless': 2,
#          'reported': 2,
#          'shultz': 2,
#          'volume': 2,
#          'potential': 2,
#          'used': 2,
#          'signs': 2,
#          'imbalances': 2,
#          'us': 2,
#          'difficult': 2,
#          'reserve': 2,
#          'global': 2,
#          'greater': 2,
#          'past': 2,
#          'annual': 2,
#          'half': 2,
#          'food': 2,
#          'levy': 2,
#          'australia': 2,
#          'study': 2,
#          'reserves': 2,
#          'start': 2,
#          'solve': 2,
#          'special': 2,
#          'measure': 2,
#          'latest': 2,
#          'present': 2,
#          'purchases': 2,
#          'question': 2,
#          'relief': 2,
#          'trend': 2,
#          'overseas': 2,
#          'opening': 2,
#          'urged': 2,
#          'ldp': 2,
#          'better': 2,
#          'imbalance': 2,
#          'situation': 2,
#          'microchip': 2,
#          'eight': 2,
#          'declined': 2,
#          'company': 2,
#          'hopes': 2,
#          'leaders': 2,
#          'securities': 2,
#          'short-term': 2,
#          'tomorrow': 2,
#          'row': 2,
#          'abroad': 2,
#          'expand': 2,
#          'signed': 2,
#          'joint': 2,
#          'manufacturing': 2,
#          'trying': 2,
#          'gap': 2,
#          'deficits': 2,
#          'lead': 2,
#          'proposed': 2,
#          'long-term': 2,
#          'corp': 2,
#          '1.5': 2,
#          'provisional': 2,
#          '15': 2,
#          'selling': 2,
#          'america': 2,
#          'democratic': 2,
#          'net': 2,
#          'stimulate': 2,
#          'competitiveness': 2,
#          'seasonally': 2,
#          'press': 2,
#          'improve': 2,
#          'main': 2,
#          'informal': 2,
#          'basic': 2,
#          'taken': 2,
#          '30': 2,
#          'ltd': 2,
#          'result': 2,
#          'paul': 2,
#          'case': 2,
#          'considered': 2,
#          'try': 2,
#          'costs': 2,
#          'australian': 2,
#          'computers': 2,
#          'gross': 2,
#          'reducing': 2,
#          'making': 2,
#          'items': 2,
#          'hope': 2,
#          'sides': 2,
#          'oils': 2,
#          'tonnes': 2,
#          'indonesia': 2,
#          'believe': 2,
#          'yet': 2,
#          'call': 2,
#          'response': 2,
#          'textiles': 2,
#          'coffee': 2,
#          'future': 2,
#          'seek': 2,
#          'keep': 2,
#          'cable': 2,
#          'top': 2,
#          'diplomats': 2,
#          'u.s.-japan': 2,
#          'list': 2,
#          'sure': 2,
#          'days': 2,
#          'countertrade': 2,
#          'reached': 2,
#          'richard': 2,
#          'chance': 2,
#          'hard': 2,
#          'zealand': 2,
#          'raise': 2,
#          'friction': 2,
#          'steel': 2,
#          'change': 2,
#          'totalled': 2,
#          'ruling': 2,
#          'june': 2,
#          'process': 2,
#          'congressional': 2,
#          'law': 2,
#          'proposals': 2,
#          'despite': 2,
#          'nearly': 2,
#          'position': 2,
#          'competition': 2,
#          'beginning': 2,
#          'institute': 2,
#          'share': 2,
#          'hold': 2,
#          'similar': 2,
#          'given': 2,
#          'kong': 2,
#          'specific': 2,
#          '12': 2,
#          'point': 2,
#          '1': 2,
#          'per': 2,
#          'board': 2,
#          'able': 2,
#          'tough': 2,
#          'provide': 2,
#          'meet': 2,
#          'adjustment': 2,
#          'impact': 2,
#          'allow': 2,
#          'microchips': 2,
#          'rather': 2,
#          'retaliatory': 2,
#          'meetings': 2,
#          'place': 2,
#          'technology': 2,
#          'firm': 2,
#          'back': 2,
#          'agreements': 2,
#          'imported': 2,
#          'lt': 2,
#          'seen': 2,
#          'live': 2,
#          'become': 2,
#          'approved': 2,
#          'shipments': 2,
#          'order': 2,
#          'alleged': 2,
#          'resolve': 2,
#          'manufacturers': 2,
#          'changes': 2,
#          'actions': 2,
#          'seven': 2,
#          'organisation': 2,
#          'package': 2,
#          'mark': 2,
#          'estimated': 2,
#          'deputy': 2,
#          'gave': 2,
#          'korean': 2,
#          'act': 2,
#          'sharply': 2,
#          'prepared': 2,
#          'several': 2,
#          'analyst': 2,
#          'ahead': 2,
#          'affairs': 2,
#          'fair': 2,
#          'continued': 2,
#          'francs': 2,
#          'external': 2,
#          'steps': 2,
#          'without': 2,
#          'narrowed': 2,
#          'put': 2,
#          'offer': 2,
#          'clercq': 2,
#          'maintain': 2,
#          'monthly': 2,
#          'leading': 2,
#          'grow': 2,
#          'rice': 2,
#          'crisis': 2,
#          'conable': 2,
#          'use': 2,
#          'disputes': 2,
#          'aid': 2,
#          'forecasts': 2,
#          'panel': 2,
#          'serious': 2,
#          'reach': 2,
#          'low': 2,
#          'electronics': 2,
#          'planning': 2,
#          'particularly': 2,
#          'although': 2,
#          'aimed': 2,
#          'far': 2,
#          'discuss': 2,
#          'term': 2,
#          'public': 2,
#          'spain': 2,
#          'france': 2,
#          'basis': 2,
#          'previous': 2,
#          'credit': 2,
#          'second': 2,
#          'saying': 2,
#          'television': 2,
#          'widened': 2,
#          'interview': 2,
#          'lost': 2,
#          'curbs': 2,
#          'commodity': 2,
#          'banks': 2,
#          'designed': 2,
#          'economist': 2,
#          'final': 2,
#          'hong': 2,
#          'face': 2,
#          'prevent': 2,
#          'probably': 2,
#          'association': 2,
#          'increasing': 2,
#          '2.5': 2,
#          'cooperation': 2,
#          'soon': 2,
#          'bid': 1,
#          'moore': 1,
#          'comes': 1,
#          'worried': 1,
#          'imf': 1,
#          'named': 1,
#          'expectations': 1,
#          'arms': 1,
#          'consumption': 1,
#          'followed': 1,
#          'positive': 1,
#          'dollars': 1,
#          'getting': 1,
#          'chamber': 1,
#          'reports': 1,
#          'damage': 1,
#          'interests': 1,
#          'denied': 1,
#          'remove': 1,
#          'left': 1,
#          'jumped': 1,
#          'potash': 1,
#          'offered': 1,
#          'cause': 1,
#          'dropped': 1,
#          'strength': 1,
#          'faster': 1,
#          'commitments': 1,
#          'replied': 1,
#          'home': 1,
#          'sprinkel': 1,
#          'stopped': 1,
#          '1.8': 1,
#          'exported': 1,
#          'gains': 1,
#          'eiu': 1,
#          'common': 1,
#          'peru': 1,
#          'remained': 1,
#          'moscow': 1,
#          'urgent': 1,
#          'holding': 1,
#          'predicted': 1,
#          '1987/88': 1,
#          'poland': 1,
#          'halt': 1,
#          'dan': 1,
#          'seoul': 1,
#          'convince': 1,
#          'let': 1,
#          'manufactured': 1,
#          'limit': 1,
#          'licences': 1,
#          '31': 1,
#          'asian': 1,
#          'risk': 1,
#          'conflict': 1,
#          'commodities': 1,
#          'stabilize': 1,
#          'healthy': 1,
#          'two-day': 1,
#          'norway': 1,
#          '7.2': 1,
#          'balanced': 1,
#          'sen.': 1,
#          'bentsen': 1,
#          'senators': 1,
#          'marlin': 1,
#          'opens': 1,
#          'wine': 1,
#          'interested': 1,
#          's.': 1,
#          'push': 1,
#          'session': 1,
#          'ensure': 1,
#          '2.7': 1,
#          'slowing': 1,
#          'compete': 1,
#          'dinars': 1,
#          'size': 1,
#          '3.5': 1,
#          'toughen': 1,
#          'indian': 1,
#          'significant': 1,
#          'instead': 1,
#          'machinery': 1,
#          'rupees': 1,
#          'pattern': 1,
#          'toshiba': 1,
#          'thus': 1,
#          'team': 1,
#          'needs': 1,
#          'yugoslavia': 1,
#          'august': 1,
#          'europeans': 1,
#          '200': 1,
#          'priority': 1,
#          'mission': 1,
#          'writing': 1,
#          'massive': 1,
#          'unchanged': 1,
#          'pakistan': 1,
#          'establish': 1,
#          'slash': 1,
#          'sale': 1,
#          'east': 1,
#          'challenge': 1,
#          'settle': 1,
#          'discussed': 1,
#          'small': 1,
#          'samuels': 1,
#          'nation': 1,
#          'violations': 1,
#          'burden': 1,
#          'moving': 1,
#          'resources': 1,
#          'parliament': 1,
#          'diplomat': 1,
#          'difference': 1,
#          'governments': 1,
#          'previously': 1,
#          '60': 1,
#          'short': 1,
#          'speaking': 1,
#          'wang': 1,
#          'paper': 1,
#          'fund': 1,
#          'amendment': 1,
#          'competitive': 1,
#          'crude': 1,
#          'bond': 1,
#          'variety': 1,
#          'simply': 1,
#          'parts': 1,
#          'rest': 1,
#          'reasonable': 1,
#          'complained': 1,
#          'israeli': 1,
#          '169.8': 1,
#          'goal': 1,
#          'benefits': 1,
#          'deals': 1,
#          'stability': 1,
#          'approval': 1,
#          'pass': 1,
#          'ending': 1,
#          'u.s': 1,
#          'fats': 1,
#          'tools': 1,
#          'nine': 1,
#          'summit': 1,
#          'rejected': 1,
#          'people': 1,
#          'run': 1,
#          'initiative': 1,
#          '1987.': 1,
#          'kansai': 1,
#          'negotiate': 1,
#          'thing': 1,
#          'starting': 1,
#          'conservative': 1,
#          '4.5': 1,
#          'delegates': 1,
#          'cent': 1,
#          'ease': 1,
#          'malaysia': 1,
#          'procurement': 1,
#          'significantly': 1,
#          'funds': 1,
#          'defense': 1,
#          'exchanges': 1,
#          'generally': 1,
#          'rep.': 1,
#          'compares': 1,
#          'explain': 1,
#          'advantage': 1,
#          'renewed': 1,
#          'vs': 1,
#          'electric': 1,
#          'requires': 1,
#          'announcement': 1,
#          'solution': 1,
#          'representatives': 1,
#          'understanding': 1,
#          'direct': 1,
#          'reflecting': 1,
#          'quality': 1,
#          'airport': 1,
#          'hearing': 1,
#          'fight': 1,
#          'tamura': 1,
#          'feb': 1,
#          'accounts': 1,
#          '1.2': 1,
#          'liberal': 1,
#          'supported': 1,
#          '1984': 1,
#          'expect': 1,
#          'application': 1,
#          'rises': 1,
#          'kim': 1,
#          'grey': 1,
#          'launched': 1,
#          'memory': 1,
#          'hours': 1,
#          'bureau': 1,
#          'intervention': 1,
#          'channon': 1,
#          'missions': 1,
#          'island': 1,
#          'george': 1,
#          'took': 1,
#          'standards': 1,
#          'showing': 1,
#          'available': 1,
#          'officially': 1,
#          'fendt': 1,
#          'implementing': 1,
#          'request': 1,
#          'becoming': 1,
#          'takes': 1,
#          'substantial': 1,
#          'consideration': 1,
#          'seem': 1,
#          'successful': 1,
#          'pending': 1,
#          'indication': 1,
#          'reasons': 1,
#          'issued': 1,
#          'certainly': 1,
#          '1985/86': 1,
#          'quoted': 1,
#          'leader': 1,
#          'comecon': 1,
#          'raising': 1,
#          'diplomatic': 1,
#          'unilateral': 1,
#          'sugar': 1,
#          'closed': 1,
#          'north': 1,
#          'weakness': 1,
#          'poehl': 1,
#          'expects': 1,
#          'based': 1,
#          'grain': 1,
#          'hurt': 1,
#          'achieve': 1,
#          'nec': 1,
#          'maki': 1,
#          'discussions': 1,
#          'rapidly': 1,
#          'principles': 1,
#          'remarks': 1,
#          'restructuring': 1,
#          'provisions': 1,
#          'demands': 1,
#          'spokeswoman': 1,
#          'series': 1,
#          '527': 1,
#          'decided': 1,
#          'double': 1,
#          'things': 1,
#          'expanding': 1,
#          'effects': 1,
#          'vital': 1,
#          'reason': 1,
#          'considering': 1,
#          'london': 1,
#          'scheduled': 1,
#          'commercial': 1,
#          'quick': 1,
#          'hungary': 1,
#          'release': 1,
#          'posted': 1,
#          'jim': 1,
#          'bankers': 1,
#          'therefore': 1,
#          'partly': 1,
#          'underlying': 1,
#          'weak': 1,
#          'citrus': 1,
#          'cut-price': 1,
#          'purchase': 1,
#          'falls': 1,
#          'merchandise': 1,
#          'seems': 1,
#          'voted': 1,
#          'marketing': 1,
#          'boycott': 1,
#          '0.5': 1,
#          'allowed': 1,
#          'line': 1,
#          'institution': 1,
#          'dealers': 1,
#          'affect': 1,
#          'appreciate': 1,
#          'side': 1,
#          'minimum': 1,
#          'influence': 1,
#          'gdp': 1,
#          ...})

# %%
import random
import torch

def prepare_sequence(seq, word2index):
    idxs = list(map(lambda w: word2index[w] if word2index.get(w) is not None else word2index["<UNK>"], seq))
    return torch.LongTensor(idxs)

def negative_sampling(targets, unigram_table, k):
    batch_size = targets.size(0)
    neg_samples = []
    for i in range(batch_size):
        nsample = []
        target_index = targets[i].item()
        while len(nsample) < k: # num of sampling
            neg = random.choice(unigram_table)
            if word2index[neg] == target_index:
                continue
            nsample.append(neg)
        neg_samples.append(prepare_sequence(nsample, word2index).view(1, -1))
    return torch.cat(neg_samples)

# %% [markdown]
# ### Testing negative sampling

# %%
input_batch  = torch.Tensor(input_batch)
target_batch = torch.LongTensor(target_batch)

# %%
input_batch.shape, target_batch.shape
# Out:
# (torch.Size([2, 1]), torch.Size([2, 1]))

# %%
target_batch
# Out:
# tensor([[7498],
#         [5075]])

# %% [markdown]
# ## Model

# %% [markdown]
# ### Skipgram

# %%
from torch import nn

class SkipgramNegSampling(nn.Module):
    
    def __init__(self, vocab_size, emb_size):
        super(SkipgramNegSampling, self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, emb_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, emb_size) # out embedding
        self.logsigmoid = nn.LogSigmoid()
                    
    def forward(self, center_words, target_words, negative_words):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, window_size, emb_size]
        neg_embeds    = -self.embedding_u(negative_words) # [batch_size, window_size * num_neg, emb_size]
        
        positive_score = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #[batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, window_size]
        
        negative_score = neg_embeds.bmm(center_embeds.transpose(1, 2))
        #[batch_size, k, emb_size] @ [batch_size, emb_size, 1] = [batch_size, k, 1]
        
        loss = self.logsigmoid(positive_score) + torch.sum(self.logsigmoid(negative_score), 1)
                
        return -torch.mean(loss)
    
    def prediction(self, inputs):
        embeds = self.embedding_v(inputs)
        
        return embeds

# %% [markdown]
# # Training

# %%
from torch import optim

batch_size     = 512 # mini-batch size
embedding_size = 2 #so we can later plot
model          = SkipgramNegSampling(voc_size, embedding_size)
num_neg        = 10 # num of negative sampling

optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# def epoch_time(start_time, end_time):
#     elapsed_time = end_time - start_time
#     elapsed_mins = int(elapsed_time / 60)
#     elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
#     return elapsed_mins, elapsed_secs

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time % 60)
    elapsed_millis = int((elapsed_time - int(elapsed_time)) * 1000)  # Extract milliseconds
    return elapsed_mins, elapsed_secs, elapsed_millis

# %%
model = model.to(device=device)

# %%
import time

total_training_time = 0
# Training
num_epochs = 2000
for epoch in range(num_epochs):
    
    start = time.time()
    
    input_batch, target_batch = random_batch(batch_size, preprocessed_docs, window_size=2)
    
    #input_batch: [batch_size, 1]
    input_batch = torch.LongTensor(input_batch).to(device=device)
    
    #target_batch: [batch_size, 1]
    target_batch = torch.LongTensor(target_batch).to(device=device)

    #negs_batch:   [batch_size, num_neg]
    negs_batch = negative_sampling(target_batch, unigram_table, num_neg).to(device=device)
    
    optimizer.zero_grad()
        
    loss = model(input_batch, target_batch, negs_batch)
    
    
    
    loss.backward()
    optimizer.step()

    end = time.time()
    epoch_mins, epoch_secs, epoch_millis = epoch_time(start, end)
    total_training_time += (end - start)


    if (epoch + 1) % 100 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f} | time: {epoch_mins}m {epoch_secs}s {epoch_millis}ms")

total_mins, total_secs, total_millis = epoch_time(0, total_training_time)
print(f"Total training time: {total_mins}m {total_secs}s {total_millis}ms")
# Out:
# Epoch: 100 | cost: 9.357941 | time: 0m 0s 414ms
# Epoch: 200 | cost: 8.970984 | time: 0m 0s 482ms
# Epoch: 300 | cost: 8.958160 | time: 0m 0s 484ms
# Epoch: 400 | cost: 8.682599 | time: 0m 0s 396ms
# Epoch: 500 | cost: 8.578339 | time: 0m 0s 504ms
# Epoch: 600 | cost: 8.517206 | time: 0m 0s 391ms
# Epoch: 700 | cost: 8.297796 | time: 0m 0s 492ms
# Epoch: 800 | cost: 8.322064 | time: 0m 0s 488ms
# Epoch: 900 | cost: 8.315296 | time: 0m 0s 402ms
# Epoch: 1000 | cost: 8.147488 | time: 0m 0s 526ms
# Epoch: 1100 | cost: 8.124233 | time: 0m 0s 412ms
# Epoch: 1200 | cost: 8.048967 | time: 0m 0s 412ms
# Epoch: 1300 | cost: 7.948369 | time: 0m 0s 421ms
# Epoch: 1400 | cost: 7.851759 | time: 0m 0s 406ms
# Epoch: 1500 | cost: 7.737219 | time: 0m 0s 405ms
# Epoch: 1600 | cost: 7.656116 | time: 0m 0s 498ms
# Epoch: 1700 | cost: 7.549522 | time: 0m 0s 390ms
# Epoch: 1800 | cost: 7.591581 | time: 0m 0s 513ms
# Epoch: 1900 | cost: 7.386629 | time: 0m 0s 422ms
# Epoch: 2000 | cost: 7.270208 | time: 0m 0s 398ms
# Total training time: 15m 3s 810ms

# %% [markdown]
# ## Plotting the embeddings

# %%
vocab[:10]
# Out:
# ['managers',
#  '93.76',
#  'deliberate',
#  'stretching',
#  'topple',
#  'products',
#  'mainly',
#  'woong',
#  'refuse',
#  'jobless']

# %%
word = vocab[0]

# %%
id = word2index[word]
id
# Out:
# 0

# %%
id_tensor = torch.LongTensor([id]).to(device=device)
id_tensor
# Out:
# tensor([0], device='cuda:0')

# %%
#get the embedding by averaging
v_embed = model.embedding_v(id_tensor)
u_embed = model.embedding_u(id_tensor)

v_embed, u_embed
# Out:
# (tensor([[-0.7236, -1.8384]], device='cuda:0', grad_fn=<EmbeddingBackward0>),
#  tensor([[-0.5137,  0.3212]], device='cuda:0', grad_fn=<EmbeddingBackward0>))

# %%
word_embed = (v_embed + u_embed) / 2
word_embed[0][1]
# Out:
# tensor(-0.7586, device='cuda:0', grad_fn=<SelectBackward0>)

# %%
def get_embed(word):
    id_tensor = torch.LongTensor([word2index[word]]).to(device=device)
    v_embed = model.embedding_v(id_tensor)
    u_embed = model.embedding_u(id_tensor) 
    word_embed = (v_embed + u_embed) / 2 
    x, y = word_embed[0][0].item(), word_embed[0][1].item()

    return x, y

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(6,3))
for i, word in enumerate(vocab[:20]): #loop each unique vocab
    x, y = get_embed(word)
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2), textcoords='offset points')
plt.show()

# %%
torch.save(model.state_dict(), "models/word2vec_negativesampling.pth")

# %% [markdown]
# ## Cosine similarity

# %%
tax = get_embed('tax')
money = get_embed('money')
billion = get_embed('billion')
million = get_embed('million')

canada = get_embed('canada')
thai = get_embed('thai')
japan = get_embed('japan')

# %%
from numpy import dot
from numpy.linalg import norm


def cos_sim(a, b):
    cos_sim = dot(a, b) / (norm(a) * norm(b))
    return cos_sim


print(f'tax vs money: {cos_sim(tax, money)}')
print(f'tax vs billion: {cos_sim(tax, billion)}')
print(f'tax vs million: {cos_sim(tax, million)}')
print(f'money vs billion: {cos_sim(money, billion)}')
print(f'money vs million: {cos_sim(money, million)}')
print(f'billion vs million: {cos_sim(billion, million)}')

print(f'canada vs thai: {cos_sim(canada, thai)}')
print(f'canada vs japan: {cos_sim(canada, japan)}')
print(f'thai vs japan: {cos_sim(thai, japan)}')
# Out:
# tax vs money: -0.015888137936660076
# tax vs billion: 0.966166878262742
# tax vs million: 0.9731281979465963
# money vs billion: 0.24253459716230896
# money vs million: 0.2147737414631249
# billion vs million: 0.9995934052391191
# canada vs thai: -0.3604500814423447
# canada vs japan: 0.868343985333394
# thai vs japan: 0.1496284252888744

# %%
#scipy version
from scipy import spatial

def cos_sim(a, b):
    cos_sim = 1 - spatial.distance.cosine(a, b)  #distance = 1 - similarlity, because scipy only gives distance
    return cos_sim


print(f'tax vs money: {cos_sim(tax, money)}')
print(f'tax vs billion: {cos_sim(tax, billion)}')
print(f'tax vs million: {cos_sim(tax, million)}')
print(f'money vs billion: {cos_sim(money, billion)}')
print(f'money vs million: {cos_sim(money, million)}')
print(f'billion vs million: {cos_sim(billion, million)}')

print(f'canada vs thai: {cos_sim(canada, thai)}')
print(f'canada vs japan: {cos_sim(canada, japan)}')
print(f'thai vs japan: {cos_sim(thai, japan)}')
# Out:
# tax vs money: -0.015888137936659996
# tax vs billion: 0.9661668782627422
# tax vs million: 0.9731281979465962
# money vs billion: 0.24253459716230896
# money vs million: 0.2147737414631249
# billion vs million: 0.9995934052391191
# canada vs thai: -0.3604500814423446
# canada vs japan: 0.868343985333394
# thai vs japan: 0.14962842528887443
